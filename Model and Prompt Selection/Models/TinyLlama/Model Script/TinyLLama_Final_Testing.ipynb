# %%
# !pip install transformers accelerate sentencepiece
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.55.4)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.10.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (0.2.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.34.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (2.8.0+cu126)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.4.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.8.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
import json
import torch
from typing import List, Dict, Any

# %%
MODEL_ID = "TinyLlama/TinyLlama-1.1B-Chat-v1.0"
device = 0 if torch.cuda.is_available() else -1
print(f"Using device: {'GPU' if device==0 else 'CPU'}")

# Do not force model_max_length; load as-is from config
tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)
model = AutoModelForCausalLM.from_pretrained(
    MODEL_ID,
    device_map="auto" if device == 0 else None,
    torch_dtype=torch.bfloat16 if device == 0 else torch.float32,
    low_cpu_mem_usage=True,
)

# Llama-style padding: set pad to eos
if tokenizer.pad_token_id is None:
    tokenizer.pad_token_id = tokenizer.eos_token_id

chat_pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    max_new_tokens=1024,
    do_sample=True,
    temperature=0.7,
    top_p=0.95,
    top_k=50,
)
# Out:
# Using device: GPU
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/551 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/608 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.20G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# Device set to use cuda:0

# %%
# Helper to render a chat with the official template
def render_chat(system, user):
    messages = [
        {"role": "system", "content": system},
        {"role": "user", "content": user},
    ]
    return tokenizer.apply_chat_template(
        messages, tokenize=False, add_generation_prompt=True
    )

# %%
SYSTEM_PROMPT = "You are a careful academic assistant. Be precise and give clear structured output (not JSON, not CSV, no files)."

# %%
def build_detection_prompt(submission: str, few_shots: list) -> str:
    shot_texts = []
    for s in few_shots:
        shot_texts.append(
            f'Submission: """{s.get("final_submission","")}"""\n'
            f'Your analysis (2–4 bullet points): <analysis>\n'
            f'Label: {s.get("label_type","")}\n'
        )
    examples_block = "\n\n".join(shot_texts) if shot_texts else "/* no examples available */"
    user_block = f"""You are an AI text-source classifier for academic integrity.
Decide whether the student submission is Human, AI, or Hybrid (AI-assisted).
Guidelines:
- Consider discourse features (specificity, subjectivity, personal context), style consistency, local/global coherence, repetitiveness, and cliché patterns.
- Hybrid = meaningful human writing with some AI assistance, or explicit admission of mixed use.
Examples:
{examples_block}
Now analyze the NEW submission and respond in plain text with the following structure:
Label: ...
Rationale:
- point 1
- point 2
Flags: ...
NEW submission:
\"\"\"{submission}\"\"\""""
    return render_chat(SYSTEM_PROMPT, user_block)

# %%
def build_feedback_prompt(domain: str, assignment_prompt: str, rubric_text: str, submission: str) -> str:
    user_block = f"""You are a supportive assessor. Provide actionable feedback aligned to the rubric.
Return plain structured text only (no JSON, no files).
Sections to include:
1) Overall Summary: 2–4 sentences on strengths and priorities.
2) Criteria Feedback: for each rubric criterion include:
   - Criterion
   - Rating (excellent, good, average, needs_improvement, poor)
   - Evidence (1–3 bullet points citing excerpts or behaviors)
   - Improvement Tip: one concrete step
3) Suggested Grade: short string (optional)
Context:
- Domain: {domain}
- Assignment prompt: {assignment_prompt}
Rubric (verbatim):
{rubric_text}
Student submission:
\"\"\"{submission}\"\"\""""
    return render_chat(SYSTEM_PROMPT, user_block)

# %%
# Rubric formatting helper
# -----------------------------
def format_rubric(rubric):
    formatted_rubric = f"Rubric ID: {rubric['rubric_id']}\n\nCriteria:\n"
    for item in rubric['criteria']:
        formatted_rubric += f"Criterion: {item['criterion_id']}\nName: {item['name']}\nDescription: {item['description']}\nPerformance Descriptors:\n"
        for key, val in item['performance_descriptors'].items():
            formatted_rubric += f"  - {key}: {val}\n"
    return formatted_rubric

# %%
# Load JSON data
# -----------------------------
with open("psychology.json") as f:
    data = json.load(f)

rubric_text = format_rubric(data['rubric'])
few_shots = data.get("few_shots", [])

# -----------------------------
# Loop through all submissions
# -----------------------------
for i, submission in enumerate(data['submissions'], 1):
    submission_text = submission['final_submission']
    label_type = submission.get("label_type", "Unknown")

    # Generate feedback
    feedback_prompt = build_feedback_prompt(
        domain=data['domain'],
        assignment_prompt=data.get("prompt", "Analyze student submission and provide detailed feedback"),
        rubric_text=rubric_text,
        submission=submission_text
    )
    feedback_outputs = chat_pipe(
        feedback_prompt,
        return_full_text=False,
        eos_token_id=tokenizer.eos_token_id
    )
    feedback_response = feedback_outputs[0]['generated_text'].strip()

    # Run AI Detection
    detection_prompt = build_detection_prompt(submission_text, few_shots)
    detection_outputs = chat_pipe(
        detection_prompt,
        return_full_text=False,
        eos_token_id=tokenizer.eos_token_id
    )
    detection_response = detection_outputs[0]['generated_text'].strip()

    # Print results
    print(f"\n--- SUBMISSION {i} (Label: {label_type}) ---")
    print("\n--- RUBRIC-ALIGNED FEEDBACK ---\n")
    print(feedback_response)
    print("\n--- ACADEMIC INTEGRITY DETECTION ---\n")
    print(detection_response)
# Out:
# This is a friendly reminder - the current text generation call will exceed the model's predefined maximum length (2048). Depending on the model, you may observe exceptions, performance degradation, or nothing at all.
# --- SUBMISSION 1 (Label: AI) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# Here is a revised version of the rubric for the psychology assignment:
#
# Criteria:
# Criterion: c1
# Name: Conceptual Understanding of Biases
# Description: Demonstrates comprehension of selected biases, including theoretical foundations.
# Performance Descriptors:
#   - excellent: Shows precise and in-depth understanding of cognitive biases, with clear links to relevant psychological theories.
#   - good: Understands biases well, though one may be less developed. Sound theoretical support.
#   - average: Adequate explanation of at least two biases; minor inaccuracies present.
#   - needs_improvement: Limited explanation with surface-level or confused understanding of biases.
#   - poor: Major misunderstanding or misrepresentation of the biases or their definitions.
# Criterion: c2
# Name: Application to Real-World Scenarios
# Description: Applies biases meaningfully to examples from everyday or professional contexts.
# Performance Descriptors:
#   - excellent: Applies biases to a variety of insightful and relevant real-world cases, with clear articulation of cause-effect.
#   - good: Examples are appropriate and mostly well explained; some links may be weaker.
#   - average: Includes examples, but explanation lacks depth or connection is unclear.
#   - needs_improvement: Examples are vague, generic, or disconnected from biases.
#   - poor: No real-world application present.
# Criterion: c3
# Name: Critical Evaluation and Mitigation Strategies
# Description: Explores ways to recognize or reduce the impact of cognitive biases.
# Performance Descriptors:
#   - excellent: Provides thoughtful, research-backed strategies to mitigate biases and reflects on psychological implications.
#   - good: Discusses plausible strategies, though some may be underdeveloped or lacking in depth.
#   - average: Mentions bias mitigation with limited detail or superficial treatment.
#   - needs_improvement: Strategies are unclear or unrelated to specific biases.
#   - poor: No discussion of mitigation or critical reflection.
# Criterion: c4
# Name: Structure and Academic Writing
# Description: Quality of writing, paragraph flow, citations, and tone.
# Performance Descriptors:
#   - excellent: Highly coherent and academic in tone, with flawless grammar and proper referencing.
#   - good: Mostly clear and professional; occasional grammar or structural issues.
#   - average: Organization is present but with inconsistencies or awkward phrasing.
#   - needs_improvement: Structure and tone hinder clarity; referencing or grammar needs work.
#   - poor: Disorganized, informal, or unacademic; serious issues with readability.
#
# Student submission:
# """Cognitive biases significantly influence human decision-making, often leading to systematic errors in judgment. For instance, confirmation bias leads individuals to seek out information that aligns with their preexisting beliefs, which can skew decision-making in fields like healthcare, where a doctor might ignore conflicting evidence (Nickerson, 1998). Anchoring biases affect consumer behavior, as initial price points can shape perceptions of value, influencing purchasing decisions (Tversky & Kahneman, 1974). The availability heuristic biases individuals in legal settings, where recent or vivid events may unduly influence verdicts. Awareness of these biases and strategies like critical reflection, seeking diverse perspectives, and using data-driven decision tools can mitigate their impact, improving overall judgment.
# References
# Nickerson, R. S. (1998). Confirmation bias. Review of psychology.com.com.
# Tversky, A. (1974) (psychology. Psychology, psychology). Available.)
# I am theorbi, consumer, aviation,ro,rovers,consumer, theater.
# Cognitive theorizingheuristic,buzzes are, as recent,village, consumer,ro or,consumer, consumer,ro,ro, consumer,assistant, consumer,ro <|
#
# and,roving, consumer, av.
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# The NEW submission has been analyzed as Human. The guidelines for human writing include clear structured output, meaningful human writing, and some AI assistance. The NEW submission does not fall into the category of hybrid, as explicit admission of mixed use is not present. The NEW submission meets all guidelines for human writing, and the analysis suggests that the student has not used any AI assistance.
#
# --- SUBMISSION 2 (Label: AI) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# I don't have access to the specific rubric and the specific assignment for which you are providing feedback. However, I can provide you with a general outline for providing feedback on a psychology assignment.
#
# 1. Overall summary:
#   - draft a brief summary of the main takeaways from the assignment
#   - include a clear and concise description of the rubric and the criteria outlined
#
# 2. criteria feedback:
#   - for each rubric criterion, provide a short statement that outlines the criteria and how it was addressed in the assignment
#   - provide specific examples of how the rubric criterion was addressed in the assignment
#   - include a brief analysis of the strengths and weaknesses of the assignment
#   - provide a brief explanation of why the rubric criterion was necessary and why it was addressed in the assignment
#
# 3. suggested grade:
#   - provide a brief explanation of how the grade would be calculated based on the rubric
#   - provide a clear indication of the expected level of effort required for each grade level
#   - include a brief explanation of how the rubric was developed and what factors were considered when rating the assignment
#
# 4. context:
#   - provide a brief explanation of the psychological theories that are discussed in the assignment
#   - include a brief analysis of how the psychological theories were applied in the assignment
#   - provide a brief explanation of how awareness or mitigation strategies can improve judgment
#
# 5. application to real-world scenarios:
#   - provide examples of how the biases discussed in the assignment are relevant to everyday or professional contexts
#   - include a brief analysis of how the biases can impact decision-making in real-world scenarios
#   - provide a brief explanation of how critical evaluation and mitigation strategies can be applied to mitigate the impact of cognitive biases
#
# 6. structure and academic writing:
#   - provide a brief explanation of how the assignment followed the guidelines outlined in the rubric
#   - provide specific examples of how the assignment followed the guidelines
#   - provide a brief analysis of how the assignment demonstrated academic writing skills, including grammar, punctuation, and citation style
#
# 7. student submission:
#   - provide a brief summary of the assignment and how it was completed
#   - provide a brief summary of the student's understanding of the assignment and how they applied the concepts discussed
#   - provide a brief analysis of how the student demonstrated understanding of the assignment and the rubric
#   - include a brief explanation of how the student's submission demonstrates their academic growth and improvement over time
#
# i hope this helps! let me know if you have any further questions.
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# The NEW submission is categorized as Human due to the student's clear and specific use of discourse features such as specificity, subjectivity, and personal context. The use of AI-assisted assistance is evident through the incorporation of cliché patterns and the presence of certain style consistencies.
#
# The student's hybrid submission falls under the category of meaningful human writing with some AI assistance, as the submission contains a mix of explicit admission of mixed use and meaningful human writing. While the submission contains some AI-assisted assistance, the student has clearly acknowledged its use and used it appropriately.
#
# The labeling of the NEW submission as a hybrid indicates that the student has recognized the need to balance human and AI assistance in their writing, and has taken steps to ensure that their hybrid submission contains clear discourse features and adheres to appropriate style consistencies.
#
# --- SUBMISSION 3 (Label: Human) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# Here is a revised version of the rubric with actionable feedback aligned to the text:
#
# Criteria:
# Criterion: c1
# Name: Conceptual Understanding of Biases
# Description: Demonstrates comprehension of selected biases, including theoretical foundations.
# Performance Descriptors:
# - excellent: Shows precise and in-depth understanding of cognitive biases, with clear links to relevant psychological theories.
# - good: Understands biases well, though one may be less developed. Sound theoretical support.
# - average: Adequate explanation of at least two biases; minor inaccuracies present.
# - needs_improvement: Limited explanation with surface-level or confused understanding of biases.
# - poor: Major misunderstanding or misrepresentation of the biases or their definitions.
# Criterion: c2
# Name: Application to Real-World Scenarios
# Description: Applies biases meaningfully to examples from everyday or professional contexts.
# Performance Descriptors:
# - excellent: Applies biases to a variety of insightful and relevant real-world cases, with clear articulation of cause-effect.
# - good: Examples are appropriate and mostly well explained; some links may be weaker.
# - average: Includes examples, but explanation lacks depth or connection is unclear.
# - needs_improvement: Examples are vague, generic, or disconnected from biases.
# - poor: No real-world application present.
# Criterion: c3
# Name: Critical Evaluation and Mitigation Strategies
# Description: Explores ways to recognize or reduce the impact of cognitive biases.
# Performance Descriptors:
# - excellent: Provides thoughtful, research-backed strategies to mitigate biases and reflects on psychological implications.
# - good: Discusses plausible strategies, though some may be underdeveloped or lacking in depth.
# - average: Mentions bias mitigation with limited detail or superficial treatment.
# - needs_improvement: Strategies are unclear or unrelated to specific biases.
# - poor: No discussion of mitigation or critical reflection.
# Criterion: c4
# Name: Structure and Academic Writing
# Description: Quality of writing, paragraph flow, citations, and tone.
# Performance Descriptors:
# - excellent: Highly coherent and academic in tone, with flawless grammar and proper referencing.
# - good: Mostly clear and professional; occasional grammar or structural issues.
# - average: Organization is present but with inconsistencies or awkward phrasing.
# - needs_improvement: Structure and tone hinder clarity; referencing or grammar needs work.
# - poor: Disorganized, informal, or unacademic; serious issues with readability.
# I hope this revision is helpful! Let me know if you have any further questions.
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Rationale:
# - point 1
# - point 2
#
# Flags:
# - NEW submission:
# - point 1
# - point 2
#
# NEW submission:
# """Cognitive biases have a big influence on how we make decisions, often without us even realizing it. For instance, confirmation bias makes us focus on information that matches what we already believe (Nickerson, 1998), while anchoring can make us overly reliant on the first thing we hear or see (Tversky & Kahneman, 1974). The availability heuristic leads us to overestimate how likely something is based on how easily we can recall examples of it. By recognizing these biases and using strategies like challenging our own thinking or seeking out different viewpoints, we can make more balanced and thoughtful decisions, especially in areas like healthcare or when making purchases.
# References:
# Nickerson, R. S. (1998). Confirmation bias: A ubiquitous phenomenon in many guises. Review of General Psychology, 2(2), 175–220. https://doi.org/10.1037/1089-2680.2.2.175
# Tversky, A., & Kahneman, D. (1974). Judgment under uncertainty: Heuristics and biases. Science, 185(4157), 1124–1131. https://doi.org/10.1126/science.185.4157.1124""
#
# --- SUBMISSION 4 (Label: Human) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# To provide actionable feedback aligned to the rubric, we recommend the following sections:
#
# 1) Overall Summary:
# - Provide a brief overview of the overall theme and objective of the paper, highlighting the importance of cognitive biases in decision-making.
# - Introduce the selected biases and their impact on decision-making.
#
# 2) Criteria Feedback:
# - For each criterion, provide a brief explanation of the criteria and their importance, and an example of how the criterion is used in real-world scenarios.
# - Discuss any potential mitigation strategies or academic writing issues in the paper.
#
# 3) Suggested Grade:
# - Provide a clear and concise suggestion for the student's grade based on the rubric's performance descriptors.
#
# Criteria:
# - Criterion: c1
# - Name: Conceptual Understanding of Biases
# - Description: Demonstrates comprehension of selected biases, including theoretical foundations. - Performance Descriptors:
#   - excellent: Shows precise and in-depth understanding of cognitive biases, with clear links to relevant psychological theories. - good: Understands biases well, though one may be less developed. - average: Adequate explanation of at least two biases; minor inaccuracies present. - needs_improvement: Limited explanation with surface-level or confused understanding of biases. - poor: Major misunderstanding or misrepresentation of the biases or their definitions. Criterion: c2
# - Name: Application to Real-World Scenarios
# - Description: Applies biases meaningfully to examples from everyday or professional contexts. - Performance Descriptors:
#   - excellent: Applies biases to a variety of insightful and relevant real-world cases, with clear articulation of cause-effect. - good: Examples are appropriate and mostly well explained; some links may be weaker. - average: Includes examples, but explanation lacks depth or connection is unclear. - needs_improvement: Examples are vague, generic, or disconnected from biases. - poor: No real-world application present. Criterion: c3
# - Name: Critical Evaluation and Mitigation Strategies
# - Description: Explores ways to recognize or reduce the impact of cognitive biases. - Performance Descriptors:
#   - excellent: Provides thoughtful, research-backed strategies to mitigate biases and reflects on psychological implications. - good: Discusses plausible strategies, though some may be underdeveloped or lacking in depth. - average: Mentions bias mitigation with limited detail or superficial treatment. - needs_improvement: Strategies are unclear or unrelated to specific biases. - poor: No discussion of mitigation or critical reflection. Criterion: c4
# - Name: Structure and Academic Writing
# - Description: Quality of writing, paragraph flow, citations, and tone. - Performance Descriptors:
#   - excellent: Highly coherent and academic in tone, with flawless grammar and proper referencing. - good: Mostly clear and professional; occasional grammar or structural issues. - average: Organization is present but with inconsistencies or awkward phrasing. - needs_improvement: Structure and tone hinder clarity; referencing or grammar needs work. - poor: Disorganized, informal, or unacademic; serious issues with readability. We recommend using a mix of textual and visual elements, such as images, charts, and graphs, to enhance understanding and to demonstrate your understanding of the biases and their impact on decision-making. Additionally, consider using active voice and avoiding passive voice whenever possible to emphasize the importance of cognitive biases and the impact they can have on decision-making.
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Rationale:
#
# The NEW submission demonstrates a clear understanding of cognitive biases and their impact on decision-making. The author uses examples of confirmation bias and anchoring to illustrate how these biases can lead to errors in judgement. They also provide a real-life example of a judge using anchoring to influence their decision-making, highlighting the importance of being aware of these biases and taking time to reflect or practice mindfulness to make better, more balanced decisions. The NEW submission contains clear and concise language, with proper use of subheadings and bullet points to organize the information. The author uses a simple and straightforward style, avoiding jargon and technical language where possible. The submission meets the guidelines for a Hybrid submission, as it contains both human and AI-assisted elements, demonstrating a clear understanding of the context in which the student submission was made.
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# --- SUBMISSION 5 (Label: Hybrid) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# I am unable to provide actionable feedback based on the rubric provided. However, based on the rubric, the following is a suggestion for the evaluation of the student's work:
#
# 1) Overall Summary:
# - A clear and concise summary of the student's work, highlighting the overall focus and purpose of the essay.
# - A brief summary of the student's understanding of the cognitive biases discussed in the assignment, such as confirmation bias, anchoring, and the availability heuristic.
#
# 2) Criteria Feedback:
# - A short string (optional) that provides specific feedback on the student's understanding and application of cognitive biases in their work.
# - A list of criteria (c1-c4) and a grading scale that includes "excellent," "good," "average," "needs improvement," and "poor."
# - For "criteria," the grading scale should include "excellent" for excellent performance, "good" for good performance, and "needs improvement" for areas that require improvement.
# - For "performance descriptors," the grading scale should include "excellent" for excellent performance, "good" for good performance, and "needs improvement" for areas that require improvement.
#
# 3) Suggested Grade:
# - A suggested grade of "excellent" for excellent performance, "good" for good performance, and "needs improvement" for areas that require improvement.
#
# 4) Context:
# - A brief context section that provides information about the assignment, the rubric, and the assessment process.
# - A brief explanation of the cognitive biases discussed in the assignment and how they can influence decision-making.
#
# 5) Criteria:
# - A list of the criteria for evaluating the student's work, including "c1-c4" and "c3-c4."
# - "c1" and "c2" should refer to the criteria for critical evaluation and mitigation strategies, respectively.
# - "c3" and "c4" should refer to the criteria for structure and academic writing, respectively.
#
# 6) Student Submission:
# - A well-structured and academic essay that demonstrates a thorough understanding of cognitive biases and their impact on decision-making.
# - The submission should include a clear and concise summary of the student's work, as well as specific feedback on their understanding and application of cognitive biases.
# - The submission should include a brief context section and a grading scale that includes "excellent," "good," "average," "needs improvement," and "poor."
# - The submission should also include a detailed explanation of the cognitive biases discussed in the assignment and how they can influence decision-making.
# - The submission should follow the rubric provided and provide clear evidence of the student's critical evaluation and mitigation strategies, structure, and academic writing.
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Response:
#
# Label: Hybrid
#
# Rationale:
# The NEW submission contains a mix of human and AI-assisted writing, and it is determined that the submission is a hybrid.
#
# Flags:
# - Point 1: The submission contains several instances of human-written language and AI-assisted writing, including repetitiveness and cliché patterns. This indicates that the submission is hybrid.
# - Point 2: While the submission is clearly human-written, there is evidence of AI assistance in some areas, such as the use of style and tone. This indicates that the submission is hybrid.
#
# NEW submission:
# ```
# Cognitive biases, such as confirmation bias, anchoring, and the availability heuristic, will be able to shape human decision-making by distorting perceptions and judgments based on a lot of reasons. This includes prior beliefs, initial information, or recent experiences. These biases manifest in areas like healthcare, law, and consumer behavior, where they can lead to bad decisions and reinforce flawed thinking. Awareness of these biases, combined with strategies like critical thinking, counterfactual reasoning, and diverse perspectives, can help mitigate their influence and improve judgment.
# References:
# Nickerson, R. S. (1998). Confirmation bias: A ubiquitous phenomenon in many guises. Review of General Psychology, 2(2), 175–220. https://doi.org/10.1037/1089-2680.2.2.175
# Tversky, A., & Kahneman, D. (1974). Judgment under uncertainty: Heuristics and biases. Science, 185(4157), 1124–1131. https://doi.org/10.1126/science.185.4157.1124
#
# --- SUBMISSION 6 (Label: Hybrid) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# I am unable to generate a valid pdf file for the provided text material. However, here is the revised version of the rubric with actionable feedback aligned to the given rubric:
#
# Rubric (verbatim):
# Rubric ID: rub_psychology_0001
#
# Criteria:
# Criterion: c1
# Name: Conceptual Understanding of Biases
# Description: Demonstrates comprehension of selected biases, including theoretical foundations.
# Performance Descriptors:
#   - excellent: Shows precise and in-depth understanding of cognitive biases, with clear links to relevant psychological theories.
#   - good: Understands biases well, though one may be less developed. Sound theoretical support.
#   - average: Adequate explanation of at least two biases; minor inaccuracies present.
#   - needs_improvement: Limited explanation with surface-level or confused understanding of biases.
#   - poor: Major misunderstanding or misrepresentation of the biases or their definitions.
# Criterion: c2
# Name: Application to Real-World Scenarios
# Description: Applies biases meaningfully to examples from everyday or professional contexts.
# Performance Descriptors:
#   - excellent: Applies biases to a variety of insightful and relevant real-world cases, with clear articulation of cause-effect.
#   - good: Examples are appropriate and mostly well explained; some links may be weaker.
#   - average: Includes examples, but explanation lacks depth or connection is unclear.
#   - needs_improvement: Examples are vague, generic, or disconnected from biases.
#   - poor: No real-world application present.
# Criterion: c3
# Name: Critical Evaluation and Mitigation Strategies
# Description: Explores ways to recognize or reduce the impact of cognitive biases.
# Performance Descriptors:
#   - excellent: Provides thoughtful, research-backed strategies to mitigate biases and reflects on psychological implications.
#   - good: Discusses plausible strategies, though some may be underdeveloped or lacking in detail or superficial treatment.
#   - average: Mentions bias mitigation with limited detail or superficial treatment.
#   - needs_improvement: Strategies are unclear or unrelated to specific biases.
#   - poor: No discussion of mitigation or critical reflection.
# Criterion: c4
# Name: Structure and Academic Writing
# Description: Quality of writing, paragraph flow, citations, and tone.
# Performance Descriptors:
#   - excellent: Highly coherent and academic in tone, with flawless grammar and proper referencing.
#   - good: Mostly clear and professional; occasional grammar or structural issues.
#   - average: Organization is present but with inconsistencies or awkward phrasing.
#   - needs_improvement: Structure and tone hinder clarity; referencing or grammar needs work.
#   - poor: Disorganized, informal, or unacademic; serious issues with readability.
#
# Student submission:
# """Cognitive biases, such as confirmation bias (Nickerson, 1998), anchoring (Tversky & Kahneman, 1974), and the availability heuristic, affect decision-making by leading individuals to rely on bias information or patterns. These biases can have significant implications in areas like healthcare, law, and consumer behavior, often resulting in bad choices or judgments. Mitigating their impact requires strategies like reflective thinking, seeking diverse viewpoints, and promoting awareness of cognitive distortions. References
# Nickerson, R. S. (1998). Confirmation bias: A ubiquitous phenomenon in many guises. Review of General Psychology, 2(2), 175–220. https://doi.org/10.1037/1089-articulation.2.175
# Tversky, A., & Kahneman, D. (1974). Judgment:astudent’syhub oralheuristic.org."""
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Explanation:
#
# The NEW submission is a hybrid of human and AI-assisted content. It contains a mix of evidence-based and personal opinions, with some AI assistance to ensure consistency in style and clarity.
#
# The rationale section highlights the importance of cognitive biases in decision-making, and the NEW submission includes strategies to mitigate their impact. For example, the section discusses how reflective thinking, diverse viewpoints, and awareness of cognitive distortions can help individuals make better decisions.
#
# The flags section flags the use of confirmation bias and its potential impact on decision-making. The NEW submission includes a clear statement that the author has acknowledged using AI assistance to ensure consistency in style and clarity.
#
# Overall, the NEW submission provides evidence-based insights on cognitive biases and strategies to mitigate their impact. The AI-assisted elements are clearly marked and integrated into the content, ensuring consistency and clarity.

# %%
# Load JSON data
# -----------------------------
with open("engineering.json") as f:
    data = json.load(f)

rubric_text = format_rubric(data['rubric'])
few_shots = data.get("few_shots", [])

# -----------------------------
# Loop through all submissions
# -----------------------------
for i, submission in enumerate(data['submissions'], 1):
    submission_text = submission['final_submission']
    label_type = submission.get("label_type", "Unknown")

    # Generate feedback
    feedback_prompt = build_feedback_prompt(
        domain=data['domain'],
        assignment_prompt=data.get("prompt", "Analyze student submission and provide detailed feedback"),
        rubric_text=rubric_text,
        submission=submission_text
    )
    feedback_outputs = chat_pipe(
        feedback_prompt,
        return_full_text=False,
        eos_token_id=tokenizer.eos_token_id
    )
    feedback_response = feedback_outputs[0]['generated_text'].strip()

    # Run AI Detection
    detection_prompt = build_detection_prompt(submission_text, few_shots)
    detection_outputs = chat_pipe(
        detection_prompt,
        return_full_text=False,
        eos_token_id=tokenizer.eos_token_id
    )
    detection_response = detection_outputs[0]['generated_text'].strip()

    # Print results
    print(f"\n--- SUBMISSION {i} (Label: {label_type}) ---")
    print("\n--- RUBRIC-ALIGNED FEEDBACK ---\n")
    print(feedback_response)
    print("\n--- ACADEMIC INTEGRITY DETECTION ---\n")
    print(detection_response)
# Out:
# --- SUBMISSION 1 (Label: AI) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# Here is a revised version of the rubric for the supportive assessor, with additional feedback and actionable guidance:
#
# Criteria:
# Criterion: c1
# Name: Scope & Comprehensiveness
# Description: Explains the entire process from initial design to final assembly, including all key phases.
# Performance Descriptors:
#   - excellent: Provides an exceptionally thorough and detailed account of all phases from design to assembly, expertly integrating equipment layout, efficiency metrics, and safety protocols.
#   - good: Covers most essential phases of production line setup, addressing equipment, efficiency, and safety well, with minor areas for further detail.
#   - average: Addresses most phases but with limited detail; some key aspects of design-to-assembly flow, efficiency, or safety may be omitted.
#   - needs_improvement: Addresses some aspects of production line setup, but with significant omissions in key areas like design-to-assembly flow, equipment, efficiency, or safety.
#   - poor: Offers a vague or very limited description, lacking fundamental components of production line setup.
# Criterion: c2
# Name: Technical Acumen
# Description: Demonstrates accurate understanding and application of manufacturing engineering principles and terminology.
# Performance Descriptors:
#   - excellent: Demonstrates a masterful understanding of manufacturing engineering principles, applying precise terminology and advanced concepts with consistent accuracy.
#   - good: Applies manufacturing engineering principles with sound understanding; minimal inaccuracies do not detract from the overall explanation.
#   - average: Applies some manufacturing principles with a basic understanding; some inaccuracies are present.
#   - needs_improvement: Exhibits a limited grasp of manufacturing engineering principles; several inaccuracies are present.
#   - poor: Shows little to no understanding of core manufacturing engineering concepts; numerous errors.
# Criterion: c3
# Name: Clarity & Structure
# Description: Presents a logical, well-structured, and easy-to-follow explanation.
# Performance Descriptors:
#   - excellent: Presents an impeccably organized, logical, and lucid explanation. The flow of ideas is seamless, making the response exceptionally easy to comprehend.
#   - good: Delivers a generally clear and structured explanation. Ideas are mostly coherent, though some transitions could be refined.
#   - average: The explanation has some structure but is not consistently clear; the flow of ideas is sometimes difficult to follow.
#   - needs_improvement: The explanation lacks clear organization and coherence, making it challenging to follow in parts.
#   - poor: The response is disjointed, confusing, and largely incomprehensible.
# Criterion: c4
# Name: Depth of Analysis
# Description: Offers detailed reasoning and specific examples for design and process choices.
# Performance Descriptors:
#   - excellent: Offers profound insights and specific, illustrative examples, along with robust justifications for decisions related to layout, efficiency enhancements, and safety measures.
#   - good: Provides good explanations with sufficient detail, though, to-day, laptheoretical, exceptionallyorganized, and easy tofollow, and lucid, andeasy, lucid.
#   - average: Provides somekeyboard, lucid, lucid, lucid, lucid, lucid, lucidity, and easy, lucid, lucid, lucid, lucid, and lucid, lucid, lucid, lucid, lucid, lucid, lucid, lucid, lucid, lucid, lucid, lucid, lucid, lucid, unclear, which:assible, lucid, toast, easy, so thatacles toast, and detailed, IAST, zerout, AL> |raced, AL andassen, meaning, ASU, AL, LaTeX,z, AS, AL, AS, AZ, as, AL, with, and, andasts, AZ, andz, AL,s, orid, andasted, SS,s,z, asfust, and, AL,z,s,zfs, please,s,zfeed, and, or, andfsts, andfusts, ands,safts
# andz <no example orfasts,zf ands, FAST,s ands, withs, ASFUSTFSTM <stud,futorification,s,acles, yourwolferencesuitsferscriptsfatts,s,ss examples.dsumsums,zference,zes, withfuls
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Response:
#
# Label: AI
#
# Rationale:
# The NEW submission is an AI-assisted academic essay that follows a structured multi-phase process for a new consumer product. It begins with design validation, where the engineer collaborates with product designers to understand specifications, tolerances, and potential manufacturing constraints. The engineer then maps out the entire production workflow using tools like process flow diagrams and value stream maps. Equipment selection follows, guided by factors such as cycle time, required operations (e.g., stamping, injection molding, or robotic assembly), and automation level. The layout is optimized using CAD software to ensure minimal material handling, ergonomic access, and logical sequencing of operations—commonly using a U-cell or straight-line arrangement. Efficiency is measured using takt time, OEE (Overall Equipment Effectiveness), and line balancing strategies. Safety is addressed proactively via hazard analyses (FMEA), clear signage, guarding, PPE zones, and training procedures. Before full-scale production, pilot runs validate throughput, quality, and safety metrics. Adjustments are made based on feedback, and the line enters continuous improvement through lean practices like Kaizen and 5S audits.
#
# --- SUBMISSION 2 (Label: AI) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# To provide actionable feedback aligned to the rubric, we will use plain structured text only (no JSON, no files) and include sections to include:
#
# 1) Overall Summary: A clear, concise, and professional summary of the overall output (not JSON, not CSV, no files) that provides a clear understanding of the rubric's criteria.
#
# 2) Criteria Feedback: For each criterion, provide a clear, concise, and specific explanation of the criteria's performance. For example, for criterion "c1", provide a clear, detailed, and thorough account of the process of designing, setting up, and executing a production line, including equipment layout, efficiency considerations, and safety protocols.
#
# 3) Suggested Grade: Short string (optional)
#
# Criteria:
#
# Criterion: c1
# Name: Scope & Comprehensiveness
# Description: Explains the entire process from initial design to final assembly, including all key phases.
#
# Performance Descriptors:
#   - excellent: Provides an exceptionally thorough and detailed account of all phases of production line setup, addressing equipment, efficiency, and safety well, with minor areas for further detail.
#   - good: Covers most essential phases of production line setup, but with limited detail; some key aspects of design-to-assembly flow, efficiency, or safety may be omitted.
#   - average: Addresses most phases but with limited detail; some key aspects of design-to-assembly flow, efficiency, or safety may be omitted.
#   - needs_improvement: Addresses some aspects of production line setup, but with significant omissions in key areas like design-to-assembly flow, equipment, efficiency, or safety.
#   - poor: Offers a vague or very limited description, lacking fundamental components of production line setup.
#
# Criterion: c2
# Name: Technical Acumen
# Description: Demonstrates accurate understanding and application of manufacturing engineering principles and terminology.
#
# Performance Descriptors:
#   - excellent: Demonstrates a masterful understanding of manufacturing engineering principles, applying precise terminology and advanced concepts with consistent accuracy.
#   - good: Applies manufacturing engineering principles with sound understanding; minimal inaccuracies do not detract from the overall explanation.
#   - average: Applies some manufacturing principles with a basic understanding; some inaccuracies are present.
#   - needs_improvement: Exhibits a limited grasp of manufacturing engineering principles; numerous errors.
#   - poor: Shows little to no understanding of core manufacturing engineering concepts; numerous errors.
#
# Criterion: c3
# Name: Clarity & Structure
# Description: Presents a logical, well-structured, and easy-to-follow explanation.
#
# Performance Descriptors:
#   - excellent: Presents an impeccably organized, logical, and lucid explanation. The flow of ideas is seamless, making the response exceptionally easy to comprehend.
#   - good: Delivers a generally clear and structured explanation. Ideas are mostly coherent, though some transitions could be refined.
#   - average: The explanation has some structure but is not consistently clear; the flow of ideas is sometimes difficult to follow.
#   - needs_improvement: The explanation lacks clear organization and coherence, making it challenging; some incoherent flow of ideas.
#   - poor: The explanation lacks clear and coherent and coherent and/or needs to beeasy.
#
# Criteria:
#
# Criteria:
#
# Criteria: c4
# Name:criteria:c3
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Label: Human
# Rationale: The NEW submission is written by a human writer who understands the significance of manufacturing engineering in producing high-quality products. They have carefully crafted the text to address the main points of the assignment, highlighting the importance of understanding the final product's design, selecting appropriate machinery, and optimizing production processes. The writer also highlights the importance of safety measures in ensuring the production line is operated efficiently.
#
# Flags:
# - point 1: The NEW submission is not marked as a Human or Hybrid submission. The assignment specifically asks for a Human-written submission.
# - point 2: The NEW submission includes clear descriptions of the process of designing a production workflow that outlines each step, from material handling to packaging. This is a specific human writing style that aligns with the given guidelines.
# - point 3: The NEW submission includes safety measures, such as emergency shutoff systems and ergonomic assessments, that are integral to the production line. These features are not present in a Hybrid submission.
#
# NEW submission:
# "A manufacturing engineer sets up a production line through a step-by-step approach that begins with understanding the final product's design. This includes identifying critical dimensions, required materials, and the functional assembly process. Using digital modeling tools, the engineer then designs a production workflow that outlines each step, from material handling to packaging. Machinery is chosen based on process needs, such as CNC machining, welding, or automated pick-and-place arms. Layout decisions aim to reduce travel time and motion waste, and simulations are used to test throughput scenarios. The engineer defines efficiency metrics, including takt time and line balancing indices, to match production capacity with demand. Safety is integrated through emergency shutoff systems, ergonomic assessments, and regulatory compliance such as OSHA standards. Prior to launch, engineers run pilot batches to test the system and collect data on defect rates, downtime, and operator feedback. Improvements are made iteratively until the production line reaches stable, high-performance output."
#
# --- SUBMISSION 3 (Label: Human) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# Here is a sample assessment report for a manufacturing engineering course in which the rubric is aligned to the course outline, and the performance descriptors are based on the assessment rubric.
#
# Criteria:
# Criterion: c1
# Name: Scope & Comprehensiveness
# Description: Explains the entire process from initial design to final assembly, including all key phases.
# Performance Descriptors:
#   - excellent: Provides an exceptionally thorough and detailed account of all phases from design to assembly, expertly integrating equipment layout, efficiency metrics, and safety protocols.
#   - good: Covers most essential phases of production line setup, addressing equipment, efficiency, and safety well, with minor areas for further detail.
#   - average: Addresses most phases but with limited detail; some key aspects of design-to-assembly flow, efficiency, or safety may be omitted.
#   - needs_improvement: Addresses some aspects of production line setup, but with significant omissions in key areas like design-to-assembly flow, equipment, efficiency, or safety.
#   - poor: Offers a vague or very limited description, lacking fundamental components of production line setup.
#
# Criterion: c2
# Name: Technical Acumen
# Description: Demonstrates accurate understanding and application of manufacturing engineering principles and terminology.
# Performance Descriptors:
#   - excellent: Demonstrates a masterful understanding of manufacturing engineering principles, applying precise terminology and advanced concepts with consistent accuracy.
#   - good: Applies manufacturing engineering principles with sound understanding; minimal inaccuracies do not detract from the overall explanation.
#   - average: Applies some manufacturing principles with a basic understanding; some inaccuracies are present.
#   - needs_improvement: Exhibits a limited grasp of manufacturing engineering principles; several inaccuracies are present.
#   - poor: Shows little to no understanding of core manufacturing engineering concepts; numerous errors.
#
# Criterion: c3
# Name: Clarity & Structure
# Description: Presents a logical, well-structured, and easy-to-follow explanation.
# Performance Descriptors:
#   - excellent: Presents an impeccably organized, logical, and lucid explanation. The flow of ideas is seamless, making the response exceptionally easy to comprehend.
#   - good: Delivers a generally clear and structured explanation. Ideas are mostly coherent, though some transitions could be refined.
#   - average: The explanation has some structure but is not consistently clear; the flow of ideas is sometimes difficult to follow.
#   - needs_improvement: The explanation lacks clear organization and coherence, making it challenging to follow in parts.
#   - poor: The response is disjointed, confusing, and largely incomprehensible.
#
# Criterion: c4
# Name: Depth of Analysis
# Description: Offers detailed reasoning and specific examples for design and process choices.
# Performance Descriptors:
#   - excellent: Offers profound insights and specific, illustrative examples, along with robust justifications for decisions related to layout, efficiency, and safety, but could benefit from deeper analytical insights.
#   - good: Provides good explanations with sufficient detail regarding layout, efficiency, and safety, but could benefit from deeper analytical insights.
#   - average: Provides basic explanations with some detail, but lacks specific examples or robust reasoning.
#   - needs_improvement: Supplies basic explanations with minimal detail; lacks specific examples or robust reasoning.
#   - poor: Presents superficially, lacks robust insights and specifics.
# Criterion: c5
# Name:
# -age, lacks robust insights, -as, lakes
# Criterion: -grades:,age:restricted-Criterion -e.
# Performing.com.
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Analysis:
#
# - Point 1: The submission is a well-planned and detailed description of the manufacturing process, including the design, layout, and testing of a production line. The writer has carefully considered each aspect, including materials and tools, workplace safety, and machine placement.
#
# - Point 2: The submission uses precise and descriptive language, including details about the guardrails, signage, and training. The writer also mentions the importance of making the system work well before ramping up production.
#
# - Flags:
#
# - New submission: The submission is Human, as it is written by a person with experience in manufacturing engineering.
#
# - Rationale: The writer has made a conscious decision to share their experience and knowledge with others, as they believe that their expertise could be helpful to others in the field.
#
# - Point 3: The submission covers a variety of topics, including the importance of safety, the design of the production line, and the training of workers.
#
# - Flags:
#
# - Hybrid: The writer has used both AI and human input in the submission, demonstrating their commitment to academic integrity.
#
# - Point 4: The submission uses a clear and concise structure, with each paragraph supporting the main point.
#
# - Flags:
#
# - No clear indication of AI or Hybrid use, as the submission is written by a human.
#
# Overall, the submission is clear, precise, and well-organized, demonstrating careful consideration of the manufacturing process and the importance of safety in the workplace.
#
# --- SUBMISSION 4 (Label: Human) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# You are a supportive assessor. Please provide actionable feedback aligned to the rubric for each criterion.
#
# Criterion: c1
# Name: Scope & Comprehensiveness
#
# Criteria: c1
# Name: Scope & Comprehensiveness
#
# Description: Explains the entire process from initial design to final assembly, including all key phases.
#
# Performance Descriptors:
# - excellent: Provides an exceptionally thorough and detailed account of all phases from design to assembly, expertly integrating equipment layout, efficiency metrics, and safety protocols.
# - good: Covers most essential phases of production line setup, addressing equipment, efficiency, and safety well, with minor areas for further detail.
# - average: Addresses most phases but with limited detail; some key aspects of design-to-assembly flow, efficiency, or safety may be omitted.
# - needs_improvement: Addresses some aspects of production line setup, but with significant omissions in key areas like design-to-assembly flow, equipment, efficiency, or safety.
# - poor: Offers a vague or very limited description, lacking fundamental components of production line setup.
#
# Criterion: c2
# Name: Technical Acumen
#
# Criteria: c2
# Name: Technical Acumen
#
# Description: Demonstrates accurate understanding and application of manufacturing engineering principles and terminology.
#
# Performance Descriptors:
# - excellent: Demonstrates a masterful understanding of manufacturing engineering principles, applying precise terminology and advanced concepts with consistent accuracy.
# - good: Applies manufacturing engineering principles with sound understanding; minimal inaccuracies do not detract from the overall explanation.
# - average: Applies some manufacturing principles with a basic understanding; some inaccuracies are present.
# - needs_improvement: Exhibits a limited grasp of manufacturing engineering principles; several inaccuracies are present.
# - poor: Shows little to no understanding of core manufacturing engineering concepts; numerous errors.
#
# Criterion: c3
# Name: Clarity & Structure
#
# Criteria: c3
# Name: Clarity & Structure
#
# Description: Presents a logical, well-structured, and easy-to-follow explanation.
#
# Performance Descriptors:
# - excellent: Presents an impeccably organized, logical, and lucid explanation. The flow of ideas is seamless, making the response exceptionally easy to comprehend.
# - good: Delivers a generally clear and structured explanation. Ideas are mostly coherent, though some transitions could be refined.
# - average: The explanation has some structure but is not consistently clear; the flow of ideas is sometimes difficult to follow.
# - needs_improvement: The explanation lacks clear organization and coherence, making it challenging to follow in parts.
# - poor: The response is disjointed, confusing, and largely incomprehensible.
#
# Criterion: c4
# Name: Depth of Analysis
#
# Criteria: c4
# Name: Depth of Analysis
#
# Description: Offers detailed reasoning and specific examples for design and process choices.
#
# Performance Descriptors:
# - excellent: Offers profound insights and specific, illustrative examples, along with robust justifications for decisions related to layout, efficiency, and safety measures.
# - good: Provides good explanations with sufficient detail regarding layout, efficiency, and safety, but could benefit from deeper analytical insights.
# - average: Provides basic explanations with some detail, but lacks specific examples or robust reasoning.
# - needs_improvement: Supplies basic explanations with minimal detail; lacks specifics and robust reasoning.
# - poor: Shows minimal or weak evidence, lacks robust explanation, wither specific examples and robust.
# Criterion: c4.
# Name:suggestions
#
# Criterion: c3.
# Name: sutro
# Name:criterion, and_assistant.
# Name:solution for aforc3.4c5:
# Criteria:money.4s,c1:miter.criter, answer for Explan and3,cause,3,ename:mistimized, c3.
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Based on the provided text material, the submission is considered Human. The author clearly describes the process of setting up a new production line, including the need to look at drawings, talk with designers, match steps with tools or machines, and avoid confusion. The author also notes safety concerns and provides steps to ensure productivity and minimize errors. The use of specific and personal context is evident, as the author describes the need to find solutions for issues that arise during the setup process. Overall, the submission is considered Human and is consistent with AI-assisted writing.
#
# --- SUBMISSION 5 (Label: Hybrid) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# Here is a sample feedback for a manufacturing engineering course in which the rubric is verbatim:
#
# Criteria:
# Criterion: c1
# Name: Scope & Comprehensiveness
# Description: Explains the entire process from initial design to final assembly, including all key phases.
# Performance Descriptors:
#   - excellent: Provides an exceptionally thorough and detailed account of all phases from design to assembly, expertly integrating equipment layout, efficiency metrics, and safety protocols.
#   - good: Covers most essential phases of production line setup, addressing equipment, efficiency, and safety well, with minor areas for further detail.
#   - average: Addresses most phases but with limited detail; some key aspects of design-to-assembly flow, but with significant omissions in key areas like design-to-assembly flow, equipment, efficiency, or safety.
#   - needs_improvement: Addresses some aspects of production line setup, but with significant omissions in key areas like design-to-assembly flow, equipment, efficiency, or safety.
#   - poor: Offers a vague or very limited description, lacking fundamental components of production line setup.
# Criterion: c2
# Name: Technical Acumen
# Description: Demonstrates accurate understanding and application of manufacturing engineering principles and terminology.
# Performance Descriptors:
#   - excellent: Demonstrates a masterful understanding of manufacturing engineering principles, applying precise terminology and advanced concepts with consistent accuracy.
#   - good: Applies manufacturing engineering principles with sound understanding; minimal inaccuracies do not detract from the overall explanation.
#   - average: Applies some manufacturing engineering principles with a basic understanding; some inaccuracies are present.
#   - needs_improvement: Exhibits a limited grasp of core manufacturing engineering concepts; numerous errors.
#   - poor: Shows little to no understanding of core manufacturing engineering concepts; numerous errors.
# Criterion: c3
# Name: Clarity & Structure
# Description: Presents a logical, well-structured, and easy-to-follow explanation.
# Performance Descriptors:
#   - excellent: Presents an impeccably organized, logical, and lucid explanation. The flow of ideas is seamless, making the response exceptionally easy to comprehend.
#   - good: Delivers a generally clear and structured explanation. Ideas are mostly coherent, though some transitions could be refined.
#   - average: The explanation has some structure but is not consistently clear; the flow of ideas is sometimes difficult to follow.
#   - needs_improvement: The explanation lacks clear organization and coherence, making it challenging to follow in parts.
#   - poor: The response is disjointed, confusing, and largely incomprehensible.
# Criterion: c4
# Name: Depth of Analysis
# Description: Offers detailed reasoning and specific examples for design and process choices.
# Performance Descriptors:
#   - excellent: Offers profound insights and specific, illustrative examples, along with robust justifications for decisions related to layout, efficiency enhancements, and safety measures.
#   - good: Provides good explanations with sufficient detail regarding layout, efficiency, and safety, but could benefit from deeper analytical insights.
#   - average: Provides basic explanations with some detail, which? which is not sufficient,rocks in your work.texter, which meanspronotes, because theyespecially, the flow ofexplanations, but with cohere andro, and, because,explanations, because, and you, but,efficiency, androbots. Neutral, you,efficiency, e,explanations, eases,explanations,e,explan:front with avenge. Explan, and,explan,e,e,explan, robust,explan,effices:vocestable.
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Label: Human
#
# Rationale:
# The NEW submission is human-written and includes specificity, subjectivity, and personal context. The author uses language that is natural and flows well, and the writing style is clear and concise. The student submission also demonstrates a good understanding of the topic, including technical details and practical applications. The rationale behind the NEW submission is that it provides a clear and detailed explanation of a complex process, with a focus on the technical aspects. The NEW submission meets the guidelines for meaningful human writing, including meaningful human writing with some AI assistance, or explicit admission of mixed use.
#
# Flags:
# - Point 1: The NEW submission meets the requirements for a hybrid submission, as the author mentions that some AI assistance was used. The rationale for using AI assistance in this context is to improve the writing quality, which is an important aspect of the submission.
# - Point 2: The NEW submission is not explicit about the admission of mixed use, but it appears that the student has acknowledged the use of AI assistance in this context. The rationale for using AI assistance in this context is that it is necessary to meet the guidelines for a hybrid submission.
#
# Overall, the NEW submission meets the guidelines for meaningful human writing, including meaningful human writing with some AI assistance, or explicit admission of mixed use.
#
# --- SUBMISSION 6 (Label: Hybrid) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# To provide actionable feedback aligned to the rubric, the following sections should be included:
#
# 1) Overall Summary:
# - Title: "Setting up a basic production line for a new consumer product"
# - Abstract: A detailed overview of the production setup for a product.
# - Introduction: A brief description of the product and the manufacturing process.
# - Background: A brief explanation of the engineering domain, the assignment, and the rubric.
# - Methodology: A detailed explanation of the engineering process, including the design phase, layout, and efficiency considerations.
# - Results: The results of the setup analysis, including the takt time, bottlenecks, and safety measures.
# - Conclusion: A summary of the findings and the recommendations for improvement.
#
# Criteria:
# Criterion: c1
# Name: Scope & Comprehensiveness
# Description: Explains the entire process from initial design to final assembly, including all key phases.
# - Perfect: The production setup includes all key phases, from design to assembly, and covers all essential aspects.
# - Good: The setup covers most essential phases but omits significant areas.
# - Average: The setup covers some essential phases, but omits other important areas.
# - Needs Improvement: The setup does not cover all essential phases, omits significant areas, or lacks critical information.
#
# Criterion: c2
# Name: Technical Acumen
# Description: Demonstrates accurate understanding and application of manufacturing engineering principles and terminology.
# - Perfect: The engineer is proficient in the engineering domain and applies manufacturing engineering principles with consistency.
# - Good: The engineer demonstrates a basic understanding of manufacturing engineering principles, but lacks in-depth knowledge.
# - Average: The engineer has some knowledge of manufacturing engineering principles, but not enough to apply them correctly.
# - Needs Improvement: The engineer lacks sufficient knowledge of manufacturing engineering principles or lacks application of these principles correctly.
#
# Criterion: c3
# Name: Clarity & Structure
# Description: Presents a logical, well-structured, and easy-to-follow explanation.
# - Perfect: The explanation flows smoothly, with logical organization, and is easily understood.
# - Good: The explanation is well-structured, with clear organization and logical flow.
# - Average: The explanation has some structure, but could benefit from better organization and flow.
# - Needs Improvement: The explanation lacks clear organization and flow, making it challenging to follow.
#
# Criterion: c4
# Name: Depth of Analysis
# Description: Offers detailed reasoning and specific examples for design and process choices.
# - Perfect: The engineer provides deep analysis and reasoning for all design and process choices, including layout, efficiency enhancements, and safety measures.
# - Good: The engineer provides some analysis and reasoning, but lacks depth and specificity.
# - Average: The engineer provides limited analysis and reasoning, but focuses on key decisions that are central to the setup.
# - Needs Improvement: The engineer provides limited analysis and reasoning, only providing general overviews or generic statements.
#
# Criterion: c5
# Name: Language & Presentation
# Description: Writing is clear, professional, and free of grammatical errors.
# - Perfect: The engineer provides clear and concise, polished writing, free of grammatical errors.
# - Good: The engineer provides well-written, clear, polished writing with no grammatical errors.
# - Average: The engineer provides clear, polished. The engineer provides clear, grammatical errors.eduction.
# - Average, clear and poles that.
# - Assistant: Good.
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Rationale:
#
# - Point 1: The NEW submission follows a clear and structured organization with detailed technical design. The engineer has carefully considered the product design, identifying key operations, and selecting machines that are efficient and compatible with the materials. The layout groups processes logically and minimizes material handling, with optimization for efficiency and safety measures in place.
#
# - Point 2: The NEW submission uses simulation software to predict performance under various conditions, which is an integral part of the setup process. This ensures that the setup meets performance and safety targets.
#
# - Point 3: The NEW submission includes a limited production run to identify defects, cycle inefficiencies, and unanticipated safety issues. This process helps the engineer to refine the setup until it meets performance, quality, and safety targets.
#
# Flags:
#
# - Point 1: The NEW submission meets the criteria of being a hybrid submission. The engineer has used a combination of human and AI assistance in the production line setup.
#
# - Point 2: The NEW submission includes a limited production run, which demonstrates the engineer's commitment to quality control.
#
# Conclusion:
#
# The NEW submission meets the criteria of being a hybrid submission, demonstrating a combination of human and AI assistance in the production line setup. The limited production run is a critical component of the process, ensuring that performance and safety targets are met.

# %%
# Load JSON data
# -----------------------------
with open("it.json") as f:
    data = json.load(f)

rubric_text = format_rubric(data['rubric'])
few_shots = data.get("few_shots", [])

# -----------------------------
# Loop through all submissions
# -----------------------------
for i, submission in enumerate(data['submissions'], 1):
    submission_text = submission['final_submission']
    label_type = submission.get("label_type", "Unknown")

    # Generate feedback
    feedback_prompt = build_feedback_prompt(
        domain=data['domain'],
        assignment_prompt=data.get("prompt", "Analyze student submission and provide detailed feedback"),
        rubric_text=rubric_text,
        submission=submission_text
    )
    feedback_outputs = chat_pipe(
        feedback_prompt,
        return_full_text=False,
        eos_token_id=tokenizer.eos_token_id
    )
    feedback_response = feedback_outputs[0]['generated_text'].strip()

    # Run AI Detection
    detection_prompt = build_detection_prompt(submission_text, few_shots)
    detection_outputs = chat_pipe(
        detection_prompt,
        return_full_text=False,
        eos_token_id=tokenizer.eos_token_id
    )
    detection_response = detection_outputs[0]['generated_text'].strip()

    # Print results
    print(f"\n--- SUBMISSION {i} (Label: {label_type}) ---")
    print("\n--- RUBRIC-ALIGNED FEEDBACK ---\n")
    print(feedback_response)
    print("\n--- ACADEMIC INTEGRITY DETECTION ---\n")
    print(detection_response)
# Out:
# --- SUBMISSION 1 (Label: AI) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# Title: Artificial Intelligence in Modern Cybersecurity: Application of Machine Learning to Threat Detection and Response
#
# Section 1: Overall Summary
#
# 1) Overall Summary:
#    - AI plays a pivotal role in modern cybersecurity, automating threat detection and enhancing incident response.
#    - Machine learning algorithms can analyze massive datasets in real-time and identify anomalies or malicious patterns that traditional rule-based systems may overlook.
#
# Section 2: Criteria Feedback
#
# Criterion: c1
#
# Name: Understanding of Topic
#
# Description: Demonstrates clear and accurate understanding of AI and its impact on cybersecurity.
# Performance Descriptors:
#   - excellent: Displays comprehensive knowledge and insightful connections to the topic.
#   - good: Shows clear understanding with minor errors or omissions.
#   - average: Basic knowledge with some misunderstandings or generalizations.
#   - needs_improvement: Limited grasp of the topic; key ideas missing.
#   - poor: Fails to convey understanding of AI in cybersecurity.
#
# Criterion: c2
#
# Name: Application to Real-World Context
#
# Description: Effectively relates AI technologies to real-world cybersecurity scenarios.
# Performance Descriptors:
#   - excellent: Provides rich, relevant, and realistic examples or experiences.
#   - good: Examples are appropriate and mostly relevant.
#   - average: Some real-world application, but lacks detail or depth.
#   - needs_improvement: Vague or poorly connected real-world references.
#   - poor: No meaningful application to real-world cybersecurity contexts.
#
# Section 3: Criteria Feedback
#
# Criterion: c3
#
# Name: Critical Thinking and Insight
#
# Description: Shows depth of thought and insight in discussing implications, challenges, or future directions.
# Performance Descriptors:
#   - excellent: Demonstrates critical insight, questioning assumptions or exploring complexities.
#   - good: Shows some thoughtful analysis beyond basic explanation.
#   - average: Some insight, but largely descriptive or surface-level.
#   - needs_improvement: Little analysis or original thought.
#   - poor: No critical thinking evident.
#
# Section 4: Criteria Feedback
#
# Criterion: c4
#
# Name: Originality and Perspective
#
# Description: Brings a unique point of view or reflection that adds value beyond general knowledge.
# Performance Descriptors:
#   - excellent: Offers a distinct and engaging perspective with original reflections or experiences.
#   - good: Demonstrates some personal insight or unique angle.
#   - average: Some originality present, but mostly general or derivative.
#   - needs_improvement: Minimal personal voice or perspective.
#   - poor: No originality; generic or copied response.
#
# Section 5: Criteria Feedback
#
# Criterion: c5
#
# Name: Clarity and Communication
#
# Description: Presents ideas clearly, logically, and in a well-structured manner suitable for an IT audience.
# Performance Descriptors:
#   - excellent: Clear, concise, and well-organized; highly appropriate for audience.
#   - good: Generally clear and logical; some lapses in flow or word choice.
#   - average: Understood with effort; lacks polish or has minor confusion.
#   - needs_improvement: Ideas poorly expressed or disorganized.
#   - poor: Very difficult to understand or follow.
#
# Conclusion:
#
# - Overall Summary: 2–4 sentences on strengths and priorities.
# - Criteria Feedback: for each rubric criterion include:
#    - Criterion
#    - Rating (excellent, good, average, needs improvement, poor)
#    - Evidence (1–3 bullet points citing excerpts or behaviors)
#    - Improvement Tip: one concrete step
# - Suggested Grade: short string (optional)
#
# Context:
# - Domain: Information Technology
# - Assignment prompt: In a few sentences, examine the role of Artificial Intelligence in modern cybersecurity, providing examples of its applications and potential risks.
# - Rubric ID: rub_it_0002
#
# Criteria:
# - c1
# - c2
# - c3
# - c4
# - c5
#
# Criteria Feedback:
# - excellent: Displays
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Here is the analysis of the NEW submission:
#
# Label: Human
#
# Rationale:
# The NEW submission contains human-written language and does not rely heavily on AI assistance. The author appears to have taken the time to carefully craft their writing, with specificity, subjectivity, and personal context present. However, it is not clear if the submission is truly human or AI-assisted.
#
# Flags:
# - Point 1: The author has included a clear and concise explanation of the benefits of AI in cybersecurity. This is a clear flag that the submission is likely human.
# - Point 2: The author has used a variety of discourse features, including specificity, subjectivity, and personal context, indicating that they are aware of the limitations of AI in cybersecurity. This is a clear flag that the submission is likely human.
# - Flags 3-5: The submission does not appear to be heavily influenced by AI. The admission of mixed use is a clear flag that the submission is likely human.
#
# Overall, the NEW submission appears to be a clear example of human writing with some AI assistance. However, it is still unclear if the author truly believes that AI can replace human writing entirely.
#
# --- SUBMISSION 2 (Label: AI) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# Title: Artificial Intelligence in Modern Cybersecurity
#
# Rubric (verbatim):
# Rubric ID: rub_it_0002
#
# Criteria:
# Criterion: c1
# Name: Understanding of Topic
# Description: Demonstrates clear and accurate understanding of AI and its impact on cybersecurity.
# Performance Descriptors:
#   - excellent: Displays comprehensive knowledge and insightful connections to the topic.
#   - good: Shows clear understanding with minor errors or omissions.
#   - average: Basic knowledge with some misunderstandings or generalizations.
#   - needs_improvement: Limited grasp of the topic; key ideas missing.
#   - poor: Fails to convey understanding of AI in cybersecurity.
#
# Criterion: c2
# Name: Application to Real-World Context
# Description: Effectively relates AI technologies to real-world cybersecurity scenarios.
# Performance Descriptors:
#   - excellent: Provides rich, relevant, and realistic examples or experiences.
#   - good: Examples are appropriate and mostly relevant.
#   - average: Some real-world application, but lacks detail or depth.
#   - needs_improvement: Vague or poorly connected real-world references.
#   - poor: No meaningful application to real-world cybersecurity contexts.
#
# Criterion: c3
# Name: Critical Thinking and Insight
# Description: Shows depth of thought and insight in discussing implications, challenges, or future directions.
# Performance Descriptors:
#   - excellent: Demonstrates critical insight, questioning assumptions or exploring complexities.
#   - good: Shows some thoughtful analysis beyond basic explanation.
#   - average: Some insight, but largely descriptive or surface-level.
#   - needs_improvement: Little analysis or original thought.
#   - poor: No critical thinking evident.
#
# Criterion: c4
# Name: Originality and Perspective
# Description: Brings a unique point of view or reflection that adds value beyond general knowledge.
# Performance Descriptors:
#   - excellent: Offers a distinct and engaging perspective with original reflections or experiences.
#   - good: Demonstrates some personal insight or unique angle.
#   - average: Some originality present, but mostly general or derivative.
#   - needs_improvement: Minimal personal voice or perspective.
#   - poor: No originality; generic or copied response.
#
# Criterion: c5
# Name: Clarity and Communication
# Description: Presents ideas clearly, logically, and in a well-structured manner suitable for an IT audience.
# Performance Descriptors:
#   - excellent: Clear, concise, and well-organized; highly appropriate for audience.
#   - good: Generally clear and logical; some lapses in flow or word choice.
#   - average: Understood with effort; lacks polish or has minor confusion.
#   - needs_improvement: Ideas poorly expressed or disorganized.
#   - poor: Very difficult to understand or follow.
#
# Student submission:
# """AI-based cybersecurity solutions such as behavioral analytics and automated intrusion detection systems have allowed organizations to proactively detect zero-day attacks. Deep learning models are now being used to identify phishing emails and ransomware signatures faster than manual methods, providing a critical layer of defense against evolving cyber threats."""
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# I do not have access to specific academic submissions, but based on the guidelines provided, the student submission can be considered as human writing with some AI assistance. The student's use of discourse features, such as specificity, subjectivity, and personal context, aligns with the guidelines. The student's use of language and tone also aligns with human writing. The student's use of style consistency and local/global coherence is also consistent with human writing. The student's inclusion of explicit admission of mixed use, such as mentioning the use of AI in some parts of the text, does not go against the guidelines. The student's use of meaningful human writing with some AI assistance, or explicit admission of mixed use, does not violate the guidelines. The student's submission can be considered as hybrid, meaning that some parts of the text are human-written and some parts are AI-assisted. The student's use of the phrase "now analyze" and the flags do not violate the guidelines. Overall, the student's submission can be considered as human writing with some AI assistance, although it may not meet the strictest guidelines.
#
# --- SUBMISSION 3 (Label: Human) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# Criteria:
# Criterion: c1
# Name: Understanding of Topic
# Description: Demonstrates clear and accurate understanding of AI and its impact on cybersecurity.
# Performance Descriptors:
#   - excellent: Displays comprehensive knowledge and insightful connections to the topic.
#   - good: Shows clear understanding with minor errors or omissions.
#   - average: Basic knowledge with some misunderstandings or generalizations.
#   - needs_improvement: Limited grasp of the topic; key ideas missing.
#   - poor: Fails to convey understanding of AI in cybersecurity.
#
# Criterion: c2
# Name: Application to Real-World Context
# Description: Effectively relates AI technologies to real-world cybersecurity scenarios.
# Performance Descriptors:
#   - excellent: Provides rich, relevant, and realistic examples or experiences.
#   - good: Examples are appropriate and mostly relevant.
#   - average: Some real-world application, but lacks detail or depth.
#   - needs_improvement: Vague or poorly connected real-world references.
#   - poor: No meaningful application to real-world cybersecurity contexts.
#
# Criterion: c3
# Name: Critical Thinking and Insight
# Description: Shows depth of thought and insight in discussing implications, challenges, or future directions.
# Performance Descriptors:
#   - excellent: Demonstrates critical insight, questioning assumptions or exploring complexities.
#   - good: Shows some thoughtful analysis beyond basic explanation.
#   - average: Some insight, but largely descriptive or surface-level.
#   - needs_improvement: Little analysis or original thought.
#   - poor: No critical thinking evident.
#
# Criterion: c4
# Name: Originality and Perspective
# Description: Brings a unique point of view or reflection that adds value beyond general knowledge.
# Performance Descriptors:
#   - excellent: Offers a distinct and engaging perspective with original reflections or experiences.
#   - good: Demonstrates some personal insight or unique angle.
#   - average: Some originality present, but mostly general or derivative.
#   - needs_improvement: Minimal personal voice or perspective.
#   - poor: No originality; generic or copied response.
#
# Criterion: c5
# Name: Clarity and Communication
# Description: Presents ideas clearly, logically, and in a well-structured manner suitable for an IT audience.
# Performance Descriptors:
#   - excellent: Clear, concise, and well-organized; highly appropriate for audience.
#   - good: Generally clear and logical; some lapses in flow or word choice.
#   - average: Understood with effort; lacks polish or has minor confusion.
#   - needs_improvement: Ideas poorly expressed or disorganized.
#   - poor: Very difficult to understand or follow.
#
# Student submission:
# "Last year, my company faced a targeted phishing campaign. At the time, we were testing a new AI-based email filter. It actually flagged several emails that our old system missed. I was skeptical at first, but the AI picked up on odd phrasing patterns and sender behavior that looked normal on the surface. That incident really changed how I view AI in cybersecurity — it’s not about replacing human analysts, but enhancing what we can do."
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Based on the provided text material, the student submission is considered Human. The use of discourse features such as specificity, subjectivity, and personal context is apparent, highlighting human writing. Additionally, the use of AI assistance in flagging emails that would have gone unnoticed by the old system is also evident. However, the use of AI-assisted language and patterns is not explicitly mentioned, leading to mixed use. The submission does not fall under the Hybrid category, as the student clearly acknowledges the use of AI assistance.
#
# --- SUBMISSION 4 (Label: Human) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# Here is a revised version of the feedback for the student's submission:
#
# Assessment:
#
# Criteria:
# Criterion: c1
# Name: Understanding of Topic
# Description: Demonstrates clear and accurate understanding of AI and its impact on cybersecurity.
# Performance Descriptors:
#   - excellent: Displays comprehensive knowledge and insightful connections to the topic.
#   - good: Shows clear understanding with minor errors or omissions.
#   - average: Basic knowledge with some misunderstandings or generalizations.
#   - needs_improvement: Limited grasp of the topic; key ideas missing.
#   - poor: Fails to convey understanding of AI in cybersecurity.
#
# Student submission:
# """As a junior security analyst, I used to spend hours going through alerts manually. Once we integrated an AI-powered tool into our workflow, it cut our alert triage time by more than half. What really stood out was that the system kept learning — it got better at distinguishing real threats from noise. That kind of adaptability has been a game-changer in how we manage our SOC."""
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Given the submission "NEW submission: As a junior security analyst, I used to spend hours going through alerts manually. Once we integrated an AI-powered tool into our workflow, it cut our alert triage time by more than half. What really stood out was that the system kept learning — it got better at distinguishing real threats from noise. That kind of adaptability has been a game-changer in how we manage our SOC.",
#
# I have analyzed the NEW submission and have come to the conclusion that it is a Human submission.
#
# 1. Point 1: The use of the word "As" immediately indicates that this is a Human submission.
#
# 2. Point 2: The use of the word "junior" indicates that this is a Human submission.
#
# 3. Flags: The use of the phrase "once we integrated" indicates that this is a Human submission.
#
# 4. Point 1: The sentence "We used to spend hours going through alerts manually" strongly implies that this is a Human submission.
#
# 5. Point 2: The sentence "Once we integrated an AI-powered tool into our workflow" highlights the integration of an AI-powered tool into the workflow, which is a Human submission.
#
# 6. Point 3: The sentence "It cut our alert triage time by more than half" indicates that this is a Human submission.
#
# 7. Flags: The use of the phrase "adaptability" implies that this is a Human submission.
#
# 8. Point 4: The sentence "What really stood out was that the system kept learning — it got better at distinguishing real threats from noise. That kind of adaptability has been a game-changer in how we manage our SOC." highlights the adaptability of the AI-powered tool, which is a Human submission.
#
# 9. Flags: The use of the phrase "kind of" indicates that this is a Human submission.
#
# 10. Point 5: The sentence "That kind of adaptability has been a game-changer in how we manage our SOC." strongly implies that this is a Human submission.
#
# Overall, this submission is a Human submission, as it meets all the guidelines for Human submissions.
#
# --- SUBMISSION 5 (Label: Hybrid) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# [Rubric ID: rub_it_0002]
#
# Criteria:
# Criterion: c1
# Name: Understanding of Topic
# Description: Demonstrates clear and accurate understanding of AI and its impact on cybersecurity.
# Performance Descriptors:
#   - excellent: Displays comprehensive knowledge and insightful connections to the topic.
#   - good: Shows clear understanding with minor errors or omissions.
#   - average: Basic knowledge with some misunderstandings or generalizations.
#   - needs_improvement: Limited grasp of the topic; key ideas missing.
#   - poor: Fails to convey understanding of AI in cybersecurity.
#
# Criterion: c2
# Name: Application to Real-World Context
# Description: Effectively relates AI technologies to real-world cybersecurity scenarios.
# Performance Descriptors:
#   - excellent: Provides rich, relevant, and realistic examples or experiences.
#   - good: Examples are appropriate and mostly relevant.
#   - average: Some real-world application, but lacks detail or depth.
#   - needs_improvement: Vague or poorly connected real-world references.
#   - poor: No meaningful application to real-world cybersecurity contexts.
#
# Criterion: c3
# Name: Critical Thinking and Insight
# Description: Shows depth of thought and insight in discussing implications, challenges, or future directions.
# Performance Descriptors:
#   - excellent: Demonstrates critical insight, questioning assumptions or exploring complexities.
#   - good: Shows some thoughtful analysis beyond basic explanation.
#   - average: Some insight, but largely descriptive or surface-level.
#   - needs_improvement: Little analysis or original thought.
#   - poor: No critical thinking evident.
#
# Criterion: c4
# Name: Originality and Perspective
# Description: Brings a unique point of view or reflection that adds value beyond general knowledge.
# Performance Descriptors:
#   - excellent: Offers a distinct and engaging perspective with original reflections or experiences.
#   - good: Demonstrates some personal insight or unique angle.
#   - average: Some originality present, but mostly general or derivative.
#   - needs_improvement: Minimal personal voice or perspective.
#   - poor: No originality; generic or copied response.
#
# Criterion: c5
# Name: Clarity and Communication
# Description: Presents ideas clearly, logically, and in a well-structured manner suitable for an IT audience.
# Performance Descriptors:
#   - excellent: Clear, concise, and well-organized; highly appropriate for audience.
#   - good: Generally clear and logical; some lapses in flow or word choice.
#   - average: Understood with effort; lacks polish or has minor confusion.
#   - needs_improvement: Ideas poorly expressed or disorganized.
#   - poor: Very difficult to understand or follow.
#
# Student submission:
# """We used AI to monitor user activity across our cloud environment. While the algorithm caught some abnormal logins, it also raised false alarms that confused our junior staff. It taught us that AI needs to be trained and guided — we had to tweak the model and update the feedback loop. AI brought the speed, but human expertise brought the accuracy. It's that collaboration that made our response both fast and smart."""
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Sure, here's a structure for the analysis of a NEW submission:
#
# Label: Human
#
# Rationale:
# - point 1
# - point 2
#
# Flags:
# - flag 1 (False alarm)
#
# NEW submission:
# ```
# We used AI to monitor user activity across our cloud environment. While the algorithm caught some abnormal logins, it also raised false alarms that confused our junior staff. It taught us that AI needs to be trained and guided — we had to tweak the model and update the feedback loop. AI brought the speed, but human expertise brought the accuracy. It's that collaboration that made our response both fast and smart.
#
# In this NEW submission, we have taken the time to carefully consider the human-AI mix. We've recognized the potential for the AI to generate false alarms, and we've responded by incorporating human expertise into the model. This collaboration has resulted in a more accurate and efficient response to the issue.
#
# Overall, while the NEW submission may seem like a simple AI-assisted solution, it's actually a complex collaboration between human and AI expertise. We're proud of our team's ability to navigate this dynamic, and we're confident that our final response is a result of our careful analysis and collaboration.
#
# --- SUBMISSION 6 (Label: Hybrid) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# Criteria:
# Criterion: c1
# Name: Understanding of Topic
# Description: Demonstrates clear and accurate understanding of AI and its impact on cybersecurity.
# Performance Descriptors:
#   - excellent: Displays comprehensive knowledge and insightful connections to the topic.
#   - good: Shows clear understanding with minor errors or omissions.
#   - average: Basic knowledge with some misunderstandings or generalizations.
#   - needs_improvement: Limited grasp of the topic; key ideas missing.
#   - poor: Fails to convey understanding of AI in cybersecurity.
#
# Student submission:
# "We recently ran a red team-blue team exercise. Our AI tools were excellent at identifying command-and-control traffic, but when it came to lateral movement, it was our experienced analysts who noticed the subtle signs. The AI was a force multiplier, not a silver bullet. That balance between automation and intuition is what makes modern cybersecurity truly effective."
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# According to the provided guidelines, the submitted paper meets the criteria for Human authorship. The analysis of the NEW submission reveals that while the AI text-source classifier accurately identified the command-and-control traffic, it struggled with lateral movement detection. This indicates that while the AI assisted the human author, the balance between automation and intuition was not entirely optimal. The paper is therefore considered a Hybrid, with some human writing and AI assistance.

# %%
# Load JSON data
# -----------------------------
with open("teaching.json") as f:
    data = json.load(f)

rubric_text = format_rubric(data['rubric'])
few_shots = data.get("few_shots", [])

# -----------------------------
# Loop through all submissions
# -----------------------------
for i, submission in enumerate(data['submissions'], 1):
    submission_text = submission['final_submission']
    label_type = submission.get("label_type", "Unknown")

    # Generate feedback
    feedback_prompt = build_feedback_prompt(
        domain=data['domain'],
        assignment_prompt=data.get("prompt", "Analyze student submission and provide detailed feedback"),
        rubric_text=rubric_text,
        submission=submission_text
    )
    feedback_outputs = chat_pipe(
        feedback_prompt,
        return_full_text=False,
        eos_token_id=tokenizer.eos_token_id
    )
    feedback_response = feedback_outputs[0]['generated_text'].strip()

    # Run AI Detection
    detection_prompt = build_detection_prompt(submission_text, few_shots)
    detection_outputs = chat_pipe(
        detection_prompt,
        return_full_text=False,
        eos_token_id=tokenizer.eos_token_id
    )
    detection_response = detection_outputs[0]['generated_text'].strip()

    # Print results
    print(f"\n--- SUBMISSION {i} (Label: {label_type}) ---")
    print("\n--- RUBRIC-ALIGNED FEEDBACK ---\n")
    print(feedback_response)
    print("\n--- ACADEMIC INTEGRITY DETECTION ---\n")
    print(detection_response)
# Out:
# --- SUBMISSION 1 (Label: AI) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# You are a supportive assessor. Provide actionable feedback aligned to the rubric.
#
# Sure, here's an actionable feedback based on the rubric:
#
# Criteria:
# Criterion: c1
# Name: Understanding of Early Literacy Development
# Description: Demonstrates knowledge of foundational early literacy skills (e.g., phonological awareness, vocabulary, print knowledge) and developmental milestones for ages 3 to 6 years.
# Performance Descriptors:
#   - excellent: Demonstrates deep understanding of multiple early literacy components and clearly explains developmental progression with relevant examples.
#   - good: Demonstrates clear understanding of key early literacy components and typical development.
#   - average: Demonstrates basic understanding; coverage of developmental aspects is general.
#   - needs_improvement: Superficial or unclear explanation of literacy components or development.
#   - poor: Fails to demonstrate understanding of early literacy development.
#
# Criterion: c2
# Name: Evaluation of Evidence-Based Approaches
# Description: Critically evaluates instructional methods and interventions shown to support pre-reading skills (e.g., dialogic reading, phonemic games, shared book reading).
# Performance Descriptors:
#   - excellent: Provides insightful evaluation of multiple evidence-based strategies with critical commentary and research support.
#   - good: Explains and supports at least one or two approaches with credible evidence.
#   - average: Describes common strategies with limited analysis or research links.
#   - needs_improvement: Mentions strategies with minimal connection to evidence.
#   - poor: Fails to evaluate or explain instructional approaches.
#
# Criterion: c3
# Name: Consideration of Diversity and Inclusion
# Description: Addresses how approaches can be adapted for learners with diverse linguistic, cultural, and developmental needs.
# Performance Descriptors:
#   - excellent: Thoughtfully discusses diverse learner needs with examples and inclusive practices drawn from research.
#   - good: Identifies key considerations for diverse learners with some application.
#   - average: Mentions diversity but without detailed application.
#   - needs_improvement: Minimal attention to learners with diverse needs.
#   - poor: Fails to consider diversity or inclusion.
#
# Criterion: c4
# Name: Research Integration and Referencing
# Description: Uses and integrates relevant, credible academic sources effectively and references them appropriately.
# Performance Descriptors:
#   - excellent: Integrates extensive peer-reviewed sources with accurate citation and strong alignment with arguments.
#   - good: Uses several appropriate sources with correct citation.
#   - average: Uses some academic sources but with limited integration or citation errors.
#   - needs_improvement: Relies on few or weak sources; citation is inconsistent.
#   - poor: Sources are absent or unreliable; no referencing.
#
# Criterion: c5
# Name: Structure and Academic Writing
# Description: Essay is logically structured with clear introduction, body, and conclusion; academic style is maintained with correct grammar and syntax.
# Performance Descriptors:
#   - excellent: Highly structured and coherent essay with academic tone, precise language, and no grammatical errors.
#   - good: Well-structured and mostly formal; few minor grammatical or expression issues.
#   - average: Basic structure is present; academic tone inconsistent.
#   - needs_improvement: Poor flow or insufficiently written.
#   - poor: Sources are absent.
#
# Student submission.
# - Difficulty, including and referencing-credible.
#
# Sources,
# Seven
# Suggested sources, Examples are you, you citations are
# Sources,ive,citations, which are)
#
# [red).
# existing, citese,i,abstract,ification:,Examples
#
#
# Sent.com,ifiable, citing.
# ide, examples, citreffect,citified research.
#
# Canstufe, citing, citing. Ex,igents, citing,effic,ser,cita,er,ic, suggestions,istant,res,cing,ress,erc,sr,stfic,ser,ifications, especially,ser,e, research, formatting,er,ser,ss,serific,st,rés,erst,ss,sts,st, andc,sent,ss,cers,e,e,s,sent,
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# The NEW submission by student A, assessed as Human, meets the guidelines for academic integrity. The submission contains a well-structured paragraph that presents a clear and coherent argument based on current research and evidence-based strategies for early literacy development. The rationale for the argument is supported by a range of peer-reviewed sources, including the work of authors such as Neuman and Wright (2014) and Snow (2006). The argument is presented in a clear and structured manner, with specific examples and supporting evidence provided to illustrate the effectiveness of the proposed strategies. The submission is well-organized and follows standard academic writing conventions, including a formal writing style. Overall, the submission meets the guidelines for academic integrity and is therefore a human submission.
#
# --- SUBMISSION 2 (Label: AI) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# You are a supportive and rigorous assessor. Provide clear and detailed feedback aligned to the rubric, including actionable guidance aligned with the rubric criteria.
#
# Criteria:
# Criterion: c1
# Name: Understanding of Early Literacy Development
# Description: Demonstrates knowledge of foundational early literacy skills (e.g., phonological awareness, vocabulary, print knowledge) and developmental milestones for ages 3 to 6 years.
# Performance Descriptors:
#   - excellent: Demonstrates deep understanding of multiple early literacy components and clearly explains developmental progression with relevant examples.
#   - good: Demonstrates clear understanding of key early literacy components and typical development.
#   - average: Demonstrates basic understanding; coverage of developmental aspects is general.
#   - needs_improvement: Superficial or unclear explanation of literacy components or development.
#   - poor: Fails to demonstrate understanding of early literacy development.
#
# Student submission:
# """Early literacy development involves acquiring key skills such as phonological awareness, vocabulary, and an understanding of print, which typically emerge between the ages of 3 and 6. Children often begin by recognizing letters and sounds and gradually move towards blending phonemes and understanding word structures. Evidence-based approaches like shared book reading and phonemic games support these developments, with research showing that repeated reading and interactive questioning can boost vocabulary and listening comprehension (Whitehurst et al., 1994). Additionally, strategies can be adjusted to support children from diverse cultural and linguistic backgrounds—for example, using bilingual books or incorporating culturally familiar content can enhance relevance and motivation. While this response touches on important considerations for inclusion, more detail on implementation could strengthen the analysis. Nonetheless, academic sources are used appropriately, and the writing follows a mostly formal tone and minimal grammatical issues."""
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Explanation:
#
# The NEW submission is human-written academic content, which includes a clear introduction and conclusion, supporting evidence-based practices for early literacy development, and an emphasis on diverse cultural and linguistic backgrounds. The writer adheres to standard academic writing conventions, such as using proper grammar and punctuation, avoiding vague or overused language, and demonstrating understanding of complex ideas. The NEW submission also includes flags indicating potential issues with accuracy, style, and content.
#
# Rationale:
#
# The NEW submission's focus on academic writing conventions and the use of evidence-based practices for early literacy development make it a hybrid submission. The writer's use of shared book reading and phonemic games supports the development of key skills such as phonological awareness, vocabulary, and understanding of print. The writer's adherence to standard academic writing conventions ensures the integrity of the content and demonstrates a strong understanding of complex ideas.
#
# Label:
#
# The NEW submission is considered a human-written academic content, as it is written by a human, and adheres to standard academic writing conventions.
#
# Rationale:
#
# The NEW submission's content is based on academic sources, and the writer's use of these sources demonstrates their ability to integrate relevant information into a coherent and informative essay. The writer's use of evidence-based practices for early literacy development supports the development of key skills such as phonological awareness, vocabulary, and understanding of print. The writer's emphasis on diverse cultural and linguistic backgrounds adds to the authenticity of the submission and demonstrates their understanding of complex ideas.
#
# Label:
#
# The NEW submission is considered a human-written academic content, as it is written by a human and integrates relevant academic sources.
#
# Flags:
#
# The NEW submission's flags include potential issues with accuracy, style, and content.
#
# Explanation:
#
# The NEW submission's use of shared book reading and phonemic games supports the development of key skills such as phonological awareness and vocabulary. The writer's use of bilingual books and incorporating culturally familiar content enhances relevance and motivation. However, the writer's language and tone could be improved by incorporating more descriptive and engaging language, as well as addressing grammatical issues. Additionally, the writer's use of an unsupported argument regarding the benefits of shared book reading could be refined, as it does not support the overall argument of the submission.
#
# Rationale:
#
# The NEW submission's use of bilingual books and culturally familiar content supports the development of key skills such as phonological awareness and vocabulary. The writer's use of shared book reading and phonemic games enhances relevance and motivation by providing a fun and engaging learning experience. The writer's use of an unsupported argument regarding the benefits of shared book reading may detract from the overall argument of the submission and may need to be revised to support the overall argument.
#
# Label:
#
# The NEW submission is considered a human-written academic content, as it is written by a human and uses bilingual books and culturally familiar content to support the development of key skills such as phonological awareness and vocabulary. The writer's use of shared book reading and phonemic games enhances relevance and motivation and supports the overall argument of the submission.
#
# Flags:
#
# The NEW submission's flags include potential issues with accuracy, style, and content.
#
# Explanation:
#
# The NEW submission's use of shared book reading and phonemic games does not enhance relevance and motivation as it does not support the overall argument of the submission. The writer's language and tone could be improved by incorporating more descriptive and engaging language. Additionally, the writer's use of an unsupported argument regarding the benefits of shared book reading could be refined, as it does not support the overall argument of the submission.
#
# Rationale:
#
# The NEW submission's use of shared book reading and phonemic games does not enhance relevance and motivation as it does not support the overall argument of the submission. The writer's use of an unsupported argument regarding the benefits of shared book reading may detract from the overall argument of the submission.
#
# Label:
#
# The NEW submission is considered a human-written academic content, as it is written by a human and does not enhance the overall argument of the submission.
#
# Rationale:
#
# The NEW submission's use of shared book reading and phonemic games does not
#
# --- SUBMISSION 3 (Label: Human) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# Criteria:
# Criterion: c1
# Name: Understanding of Early Literacy Development
# Description: Demonstrates knowledge of foundational early literacy skills (e.g., phonological awareness, vocabulary, print knowledge) and developmental milestones for ages 3 to 6 years.
# Performance Descriptors:
#   - excellent: Demonstrates deep understanding of multiple early literacy components and clearly explains developmental progression with relevant examples.
#   - good: Demonstrates clear understanding of key early literacy components and typical development.
#   - average: Demonstrates basic understanding; coverage of developmental aspects is general.
#   - needs_improvement: Superficial or unclear explanation of literacy components or development.
#   - poor: Fails to demonstrate understanding of early literacy development.
# Criterion: c2
# Name: Evaluation of Evidence-Based Approaches
# Description: Critically evaluates instructional methods and interventions shown to support pre-reading skills (e.g., dialogic reading, phonemic games, shared book reading).
# Performance Descriptors:
#   - excellent: Provides insightful evaluation of multiple evidence-based strategies with critical commentary and research support.
#   - good: Explains and supports at least one or two approaches with credible evidence.
#   - average: Describes common strategies with limited analysis or research links.
#   - needs_improvement: Mentions strategies with minimal connection to evidence.
#   - poor: Fails to evaluate or explain instructional approaches.
# Criterion: c3
# Name: Consideration of Diversity and Inclusion
# Description: Addresses how approaches can be adapted for learners with diverse linguistic, cultural, and developmental needs.
# Performance Descriptors:
#   - excellent: Thoughtfully discusses diverse learner needs with examples and inclusive practices drawn from research.
#   - good: Identifies key considerations for diverse learners with some application.
#   - average: Mentions diverse learners but without detailed application.
#   - needs_improvement: Minimal attention to learner diversity.
#   - poor: Fails to consider diverse learners or inclusion.
# Criterion: c4
# Name: Research Integration and Referencing
# Description: Uses and integrates relevant, credible academic sources effectively and references them appropriately.
# Performance Descriptors:
#   - excellent: Integrates extensive peer-reviewed sources with accurate citation and strong alignment with arguments.
#   - good: Uses several appropriate sources with correct citation.
#   - average: Uses some academic sources but with limited integration or citation errors.
#   - needs_improvement: Relies on few or weak sources; citation is inconsistent.
#   - poor: Sources are absent or unreliable; no referencing.
# Criterion: c5
# Name: Structure and Academic Writing
# Description: Essay is logically structured with clear introduction, body, and conclusion; academic style is maintained with correct grammar and syntax.
# Performance Descriptors:
#   - excellent: Highly structured and coherent essay with academic tone, precise language, and no grammatical errors.
#   - good: Well-structured and mostly formal; few minor grammatical or expression issues.
#   - average: Basic structure is present; academic tone inconsistently used.
#   - needs_improvement: Poor flow or informal writing; many language issues.
#   - poor: Disorganised, informal, and difficult to follow.
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Response:
# Yes, the NEW submission is a human-written document, and the student's analysis is a clear and precise one. The submission contains a clear explanation of the significance of early literacy development and the importance of phonological awareness in this phase. The discussion of the role of phonological awareness in the development of later reading skills is well-supported by the provided evidence. The student has adhered to guidelines for discourse features and has clearly stated the student's own insights and perspectives. The submission is not a mix of human and AI assistance, but rather a clear and coherent account of the student's own reasoning. The student has responded with a clear and logical argument, which is supported by evidence and reasoned reasoning. The submission is considered human, with some AI assistance, as it is supported by clear and well-supported discourse features, and meets the other guidelines for classification.
#
# --- SUBMISSION 4 (Label: Human) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# [Your Academic Assessor's Name]
#
# [Your Academic Assessor's Position]
#
# Subject: Assessment of the Teaching Techniques for Supporting Pre-Reading Skills in Diverse Learners
#
# Dear [Assistant's Name],
#
# I am writing to provide feedback on your Teaching Techniques for Supporting Pre-Reading Skills in Diverse Learners assessment. As an academic assessor, I have been tasked to assess the performance of [Assistant's Name] in this assessment. The purpose of this feedback is to provide you with an evaluation of your performance, including areas that need improvement, and to ensure that your assessment is accurate and objective.
#
# Criteria:
#
# Criterion: c1
# Name: Understanding of Early Literacy Development
# Description: Demonstrates knowledge of foundational early literacy skills (e.g., phonological awareness, vocabulary, print knowledge) and developmental milestones for ages 3 to 6 years.
# Performance Descriptors:
#   - excellent: Demonstrates deep understanding of multiple early literacy components and clearly explains developmental progression with relevant examples.
#   - good: Demonstrates clear understanding of key early literacy components and typical development.
#   - average: Demonstrates basic understanding; coverage of developmental aspects is general.
#   - needs_improvement: Superficial or unclear explanation of literacy components or development.
#   - poor: Fails to demonstrate understanding of early literacy development.
#
# Criterion: c2
# Name: Evaluation of Evidence-Based Approaches
# Description: Critically evaluates instructional methods and interventions shown to support pre-reading skills (e.g., dialogic reading, phonemic games, shared book reading).
# Performance Descriptors:
#   - excellent: Provides insightful evaluation of multiple evidence-based strategies with critical commentary and research support.
#   - good: Explains and supports at least one or two approaches with credible evidence.
#   - average: Describes common strategies with limited analysis or research links.
#   - needs_improvement: Mentions strategies with minimal connection to evidence.
#   - poor: Fails to evaluate or explain instructional approaches.
#
# Criterion: c3
# Name: Consideration of Diversity and Inclusion
# Description: Addresses how approaches can be adapted for learners with diverse linguistic, cultural, and developmental needs.
# Performance Descriptors:
#   - excellent: Thoughtfully discusses diverse learner needs with examples and inclusive practices drawn from research.
#   - good: Identifies key considerations for diverse learners with some application.
#   - average: Mentions diverse learners but without detailed application.
#   - needs_improvement: Minimal attention to learner diversity.
#   - poor: Fails to consider diverse learners or inclusion.
#
# Criterion: c4
# Name: Research Integration and Referencing
# Description: Uses and integrates relevant, credible academic sources effectively and references them appropriately.
# Performance Descriptors:
#   - excellent: Integrates extensive peer-reviewed sources with accurate citation and strong alignment with arguments.
#   - good: Uses several appropriate sources with correct citation.
#   - average: Uses some academic sources but with limited integration or citation errors.
#   - needs_improvement: Relies on few or weak sources; citation is inconsistent.
#   - poor: Sources are absent or unreliable; no referencing.
#
# Student submission:
#
# Learning to read doesn't just start when a child enters school—early literacy development begins much earlier, especially between the ages of 3 and 6. During this time, children start to develop key pre-reading skills like phonological awareness, vocabulary, and knowledge about print. For example, they begin to understand that words are made up of sounds, and they start to recognise letters and how to handle a book. These skills are the building blocks that help children learn to read later on. Most children show certain patterns in their development, like being able to rhyme simple words around age 4 or recognising a few letters of the alphabet before starting school.
#
# For this assessment, I will be looking for the following criteria:
#
# Criterion: c1
# Criteria:
#   - excellent: Demonstrates deep understanding of multiple early childhood."Learning to readings'phil, andes, and developmental milestoneevidence, and research-based crediblecitationis.
# Or
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Label: Human
#
# Rationale:
# The NEW submission appears to be a human-written essay that demonstrates clear and precise thought and language. The student clearly understands the importance of early literacy development and how it can lead to improved reading skills. However, there are some inconsistencies and redundancies in the text, which could be due to the use of a text-mining algorithm. Overall, the submission seems to be a well-written and thoughtful piece.
#
# Flags:
# 1. Point 1: The use of "early literacy development" is not specific enough and could be misleading. It suggests that the student has not fully understood the concept of literacy development.
# 2. Point 2: The use of "rather than" in "Learning to read doesn't just start when a child enters school" is an example of a cliché pattern.
# 3. Flags: The student's use of repetitive phrases ("early literacy development" and "rather than") and language that is too general ("begins") may indicate that they are using a text-mining algorithm or a pre-determined template.
#
# Given the text, the submission seems to be a clear and well-thought-out piece, but there are some inconsistencies and redundancies that could be addressed through further editing.
#
# --- SUBMISSION 5 (Label: Hybrid) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# [Rubric ID: rub_teaching_0025]
#
# Criteria:
# Criterion: c1
# Name: Understanding of Early Literacy Development
# Description: Demonstrates knowledge of foundational early literacy skills (e.g., phonological awareness, vocabulary, print knowledge) and developmental milestones for ages 3 to 6 years. Performance Descriptors:
#
# - excellent: Demonstrates deep understanding of multiple early literacy components and clearly explains developmental progression with relevant examples.
# - good: Demonstrates clear understanding of key early literacy components and typical development.
# - average: Demonstrates basic understanding; coverage of developmental aspects is general.
# - needs_improvement: Superficial or unclear explanation of literacy components or development.
# - poor: Fails to demonstrate understanding of early literacy development.
#
# Criterion: c2
# Name: Evaluation of Evidence-Based Approaches
# Description: Critically evaluates instructional methods and interventions shown to support pre-reading skills (e.g., dialogic reading, phonemic games, shared book reading). Performance Descriptors:
#
# - excellent: Provides insightful evaluation of multiple evidence-based strategies with critical commentary and research support.
# - good: Explains and supports at least one or two approaches with credible evidence.
# - average: Describes common strategies with limited analysis or research links.
# - needs_improvement: Mentions strategies with minimal connection to evidence.
# - poor: Fails to evaluate or explain instructional approaches.
#
# Criterion: c3
# Name: Consideration of Diversity and Inclusion
# Description: Addresses how approaches can be adapted for learners with diverse linguistic, cultural, and developmental needs. Performance Descriptors:
#
# - excellent: Thoughtfully discusses diverse learner needs with examples and inclusive practices drawn from research.
# - good: Identifies key considerations for diverse learners with some application.
# - average: Mentions diverse learners but without detailed application.
# - needs_improvement: Minimal attention to learner diversity.
# - poor: Fails to consider diversity or inclusion.
#
# Criterion: c4
# Name: Research Integration and Referencing
# Description: Uses and integrates relevant, credible academic sources effectively and references them appropriately. Performance Descriptors:
#
# - excellent: Integrates extensive peer-reviewed sources with accurate citation and strong alignment with arguments.
# - good: Uses several appropriate sources with correct citation.
# - average: Uses some academic sources but with limited integration or citation errors.
# - needs_improvement: Relies on few or weak sources; citation is inconsistent.
# - poor: Sources are absent or unreliable; no referencing.
#
# Criterion: c5
# Name: Structure and Academic Writing
# Description: Essay is logically structured with clear introduction, body, and conclusion; academic style is maintained with correct grammar and syntax. Performance Descriptors:
#
# - excellent: Highly structured and coherent essay with academic tone, precise language, and no grammatical errors.
# - good: Well-structured and mostly formal; few minor grammatical or expression issues.
# - average: Basic structure is present; academic tone inconsistently used.
# - needs_improvement: Poor flow or informal writing; many language issues.
# - poor: Disorganised, informal, and difficult to follow.
#
# Student submission:
#
# Early literacy development is a critical phase for children aged between 3 and 6. During this foundational period, children typically begin developing core pre-reading skills like phonological awareness, vocabulary knowledge, and an understanding of print concepts. Phonological awareness, in particular, is a strong predictor of later reading success. It includes the ability to recognize and manipulate sounds in spoken words, like rhyming or identifying beginning sounds. According to Lonigan et al. (2000), this skill emerged gradually, often starting with larger sound chunks.comprising phonological awareness, in particular, is a strong predictor of later reading success. It includes the ability to recognize and manipulate.
#
# Student, according to. According to Lonigan. In Lonary, Research Integration and Referral, Assessment, and Assistant.
# Student. Evaluator, as. Answers.pdf as well, assigning,alus.
# Ess, Assistant, Lon, Assistant, Research, Integrator, sender, Lecture
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Analysis:
#
# - Point 1: The NEW submission follows the standard structure for a formal academic paper. The introduction outlines the research question and the purpose of the paper.
#
# - Point 2: The NEW submission is a combination of human and AI-assisted content. The author clearly acknowledges that the submission is a combination of AI-assisted and human writing. The use of AI in generating the text is evident through the use of templates and pre-written sections, such as the abstract and introduction. However, the author also acknowledges that the AI assistance did not result in a complete or uniform output.
#
# - Flags: The NEW submission is marked as "Early literacy development is a critical phase for children aged between 3 and 6. During this foundational period, children typically begin developing core pre-reading skills like phonological awareness, vocabulary knowledge, and an understanding of print concepts. Phonological awareness, in particular, is a strong predictor of later reading success. It includes the ability to recognize and manipulate sounds in spoken words, like rhyming or identifying beginning sounds. According to Lonigan et al. (2000), this skill emerges gradually, often starting with larger sound chunks (e.g. syllables) and becoming more refined over time (e.g. phonemes). The child rapidly acquires new vocabulary through exposure to rich language environments. He or she also starts to grasp print conventions by knowing that print carries meaning and how to handle a book. This sets the stage for decoding and comprehension later on." This flag indicates that the submission contains both human and AI-assisted content, highlighting the importance of identifying and managing sources of data and information.
#
# - Label: Human
# - Rationale: The NEW submission is a combination of human and AI-assisted content, making it a hybrid. The author acknowledges that AI-assisted writing may not result in a complete or uniform output, and the submission contains a mix of human and AI-assisted content.
#
# --- SUBMISSION 6 (Label: Hybrid) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# To provide actionable feedback aligned to the rubric, we can create a plain structured text only (no JSON, no CSV, no files) with sections that include:
#
# 1) Overall Summary:
#
# - Name: Understanding of Early Literacy Development
# - Description: Demonstrates knowledge of foundational early literacy skills (e.g., phonological awareness, vocabulary, print knowledge) and developmental milestones for ages 3 to 6 years.
# - Rating (excellent, good, average, needs_improvement, poor):
#
# - Criterion: c1
# - Name: Understanding of Early Literacy Development
# - Description: Demonstrates knowledge of foundational early literacy skills (e.g., phonological awareness, vocabulary, print knowledge) and developmental milestones for ages 3 to 6 years.
# - Performance Descriptors:
#   - excellent: Demonstrates deep understanding of multiple early literacy components and clearly explains developmental progression with relevant examples.
#   - good: Demonstrates clear understanding of key early literacy components and typical development.
#   - average: Demonstrates basic understanding; coverage of developmental aspects is general.
#   - needs_improvement: Superficial or unclear explanation of literacy components or development.
#   - poor: Fails to demonstrate understanding of early literacy development.
#
# Criterion: c2
# - Name: Evaluation of Evidence-Based Approaches
# - Description: Critically evaluates instructional methods and interventions shown to support pre-reading skills (e.g., dialogic reading, phonemic games, shared book reading).
# - Performance Descriptors:
#   - excellent: Provides insightful evaluation of multiple evidence-based strategies with critical commentary and research support.
#   - good: Explains and supports at least one or two approaches with credible evidence.
#   - average: Describes common strategies with limited analysis or research links.
#   - needs_improvement: Mentions strategies with minimal connection to evidence.
#   - poor: Fails to evaluate or explain instructional approaches.
#
# Criterion: c3
# - Name: Consideration of Diversity and Inclusion
# - Description: Addresses how approaches can be adapted for learners with diverse linguistic, cultural, and developmental needs.
# - Performance Descriptors:
#   - excellent: Thoughtfully discusses diverse learner needs with examples and inclusive practices drawn from research.
#   - good: Identifies key considerations for diverse learners with some application.
#   - average: Mentions diversity but without detailed application.
#   - needs_improvement: Minimal attention to learner diversity.
#   - poor: Fails to consider diversity or inclusion.
#
# Criterion: c4
# - Name: Research Integration and Referencing
# - Description: Uses and integrates relevant, credible academic sources effectively and references them appropriately.
# - Performance Descriptors:
#   - excellent: Integrates extensive peer-reviewed sources with accurate citation and strong alignment with arguments.
#   - good: Uses several appropriate sources with correct citation.
#   - average: Uses some academic sources but with limited integration or citation errors.
#   - needs_improvement: Relies on few or weak sources; citation is inconsistent.
#   - poor: Sources are absent or unreliable; no referencing.
#
# Criterion: c5
# - Name: Structure and Academic Writing
# - Description: Essay is logically structured with clear introduction, body, and conclusion; academic style is maintained with correct grammar and syntax.
# - Performance Descriptors:
#   - excellent: Highly structured and coherent essay with academic tone, precise language, and no grammatical errors.
#   - good: Well-structured and mostly formal; few minor grammatical or expression issues.
#   - average: Basic structure is present; academic tone inconsistently used.
#   - needs_improvement: Poor flow or informal writing; many language issues.
#   - poor: Disorganised, informal, and difficult to follow.
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Rationale:
# The NEW submission does not meet the requirements for human-assisted academic writing. While the passage does demonstrate a basic understanding of phonological awareness, vocabulary, and print, it is not clear how this knowledge was acquired or applied in the context of the current submission. The passage lacks any evidence of critical thinking or analysis, making it difficult to determine whether the student's writing is genuine or the result of human assistance.
#
# Label: AI
# Flags:
# - Flag: No human-assisted writing
# - Flag: No evidence of critical thinking or analysis

# %%
# Load JSON data
# -----------------------------
with open("accounting.json") as f:
    data = json.load(f)

rubric_text = format_rubric(data['rubric'])
few_shots = data.get("few_shots", [])

# -----------------------------
# Loop through all submissions
# -----------------------------
for i, submission in enumerate(data['submissions'], 1):
    submission_text = submission['final_submission']
    label_type = submission.get("label_type", "Unknown")

    # Generate feedback
    feedback_prompt = build_feedback_prompt(
        domain=data['domain'],
        assignment_prompt=data.get("prompt", "Analyze student submission and provide detailed feedback"),
        rubric_text=rubric_text,
        submission=submission_text
    )
    feedback_outputs = chat_pipe(
        feedback_prompt,
        return_full_text=False,
        eos_token_id=tokenizer.eos_token_id
    )
    feedback_response = feedback_outputs[0]['generated_text'].strip()

    # Run AI Detection
    detection_prompt = build_detection_prompt(submission_text, few_shots)
    detection_outputs = chat_pipe(
        detection_prompt,
        return_full_text=False,
        eos_token_id=tokenizer.eos_token_id
    )
    detection_response = detection_outputs[0]['generated_text'].strip()

    # Print results
    print(f"\n--- SUBMISSION {i} (Label: {label_type}) ---")
    print("\n--- RUBRIC-ALIGNED FEEDBACK ---\n")
    print(feedback_response)
    print("\n--- ACADEMIC INTEGRITY DETECTION ---\n")
    print(detection_response)
# Out:
# --- SUBMISSION 1 (Label: AI) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# Criteria:
# Criterion: c1
# Name: Understanding of Blockchain Concepts
# Description: Demonstrates knowledge of blockchain principles (decentralization, immutability, smart contracts) and their relevance to accounting.
# Performance Descriptors:
#   - excellent: Clearly explains multiple blockchain concepts and maps each to relevant accounting applications.
#   - good: Accurately describes 1–2 blockchain concepts and gives examples.
#   - average: Mentions blockchain concepts but with limited detail.
#   - needs_improvement: Basic or unclear understanding of concepts.
#   - poor: Fails to explain blockchain accurately.
# Criterion: c2
# Name: Analysis of Accounting Impact
# Description: Evaluates how blockchain technology affects auditing, financial reporting, and data integrity.
# Performance Descriptors:
#   - excellent: Insightfully discusses enhanced transparency, automation, audit trails, and associated challenges.
#   - good: Explains basic benefits like improved data accuracy or reduced reconciliation.
#   - average: Makes general claims without detailed analysis.
#   - needs_improvement: Mentions impact with minimal support.
#   - poor: No clear link to accounting outcomes.
# Criterion: c3
# Name: Use of Real-World Examples/Case Studies
# Description: Incorporates actual or realistic examples of blockchain application in accounting or finance.
# Performance Descriptors:
#   - excellent: Provides multiple well-explained examples with relevance.
#   - good: Provides at least one relevant example.
#   - average: Mentions example(s) with little context.
#   - needs_improvement: Example(s) are vague or unrelated.
#   - poor: No examples given.
# Criterion: c4
# Name: Structure and Academic Style
# Description: Presents arguments in a well-structured, formal academic tone.
# Performance Descriptors:
#   - excellent: Highly coherent essay with formal tone and logical flow.
#   - good: Mostly well-structured with clear transitions.
#   - average: Some structure; style inconsistently academic.
#   - needs_improvement: Unclear flow or casual language.
#   - poor: Disorganised or informal.
#
# Student submission:
# """Blockchain technology, defined by its decentralization, immutability, and transparency, is transforming traditional accounting practices, particularly in auditing and financial reporting. Its core principles—decentralized ledgers, immutable records, and smart contracts—enable significant improvements in efficiency and trust. Smart contracts automate tasks like invoicing and reconciliation, reducing errors and intermediaries. For auditing, blockchain’s immutable records create tamper-proof audit trails, simplifying verification and enhancing fraud detection. Real-time financial reporting becomes feasible as transactions are instantly recorded on a shared ledger, improving transparency and decision-making. For example, Ernst & Young uses its Blockchain Analyzer to audit cryptocurrency transactions, streamlining assurance processes, while JPMorgan’s Quorum platform facilitates efficient interbank reconciliations. However, challenges persist. Regulatory uncertainty, such as the lack of clear accounting standards for blockchain assets, complicates compliance. Scalability issues in public blockchains and the high cost of integrating with legacy systems pose barriers, particularly for smaller firms. Additionally, adopting blockchain requires significant technical expertise. Despite these hurdles, blockchain’s potential to enhance data integrity and automation signals a transformative shift in accounting, as demonstrated by firms like PwC exploring blockchain-based auditing tools. As technology and regulations evolve, blockchain will likely redefine trust and efficiency in accounting practices."""
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Label: Human
#
# Rationale:
# The NEW submission clearly demonstrates the use of human writing with some AI assistance, specifically in the form of the use of blockchain technology to enhance data integrity and automation in accounting practices. The author has clearly considered the discourse features, style consistency, local/global coherence, repetitiveness, and cliché patterns, and has presented a well-structured and compelling analysis. The submission meets the criteria for Human label.
#
# Flags:
# - The submission contains no direct references to AI, suggesting that the author has not used AI assistance in the creation of the submission.
# - The use of blockchain technology is a clear example of the use of AI in accounting, and the author has presented a compelling argument for how this technology can improve data integrity and automation in accounting practices.
#
# NEW submission:
# ```
# Blockchain technology, defined by its decentralization, immutability, and transparency, is transforming traditional accounting practices, particularly in auditing and financial reporting. Its core principles—decentralized ledgers, immutable records, and smart contracts—enable significant improvements in efficiency and trust. Smart contracts automate tasks like invoicing and reconciliation, reducing errors and intermediaries. For auditing, blockchain’s immutable records create tamper-proof audit trails, simplifying verification and enhancing fraud detection. Real-time financial reporting becomes feasible as transactions are instantly recorded on a shared ledger, improving transparency and decision-making. For example, Ernst & Young uses its Blockchain Analyzer to audit cryptocurrency transactions, streamlining assurance processes, while JPMorgan’s Quorum platform facilitates efficient interbank reconciliations. However, challenges persist. Regulatory uncertainty, such as the lack of clear accounting standards for blockchain assets, complicates compliance. Scalability issues in public blockchains and the high cost of integrating with legacy systems pose barriers, particularly for smaller firms. Additionally, adopting blockchain requires significant technical expertise. Despite these hurdles, blockchain’s potential to enhance data integrity and automation signals a transformative shift in accounting, as demonstrated by firms like PwC exploring blockchain-based auditing tools. As technology and regulations evolve, blockchain will likely redefine trust and efficiency in accounting practices.
#
# --- SUBMISSION 2 (Label: AI) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# Here is a revised version of the feedback:
#
# Rubric (verbatim):
# Rubric ID: rub_accounting_0001
#
# Criteria:
# Criterion: c1
# Name: Understanding of Blockchain Concepts
# Description: Demonstrates knowledge of blockchain principles (decentralization, immutability, smart contracts) and their relevance to accounting.
# Performance Descriptors:
#   - excellent: Clearly explains multiple blockchain concepts and maps each to relevant accounting applications.
#   - good: Accurately describes 1–2 blockchain concepts and gives examples.
#   - average: Mentions blockchain concepts but with limited detail.
#   - needs_improvement: Basic or unclear understanding of concepts.
#   - poor: Fails to explain blockchain accurately.
# Criterion: c2
# Name: Analysis of Accounting Impact
# Description: Evaluates how blockchain technology affects auditing, financial reporting, and data integrity.
# Performance Descriptors:
#   - excellent: Insightfully discusses enhanced transparency, automation, audit trails, and associated challenges.
#   - good: Explains basic benefits like improved data accuracy or reduced reconciliation.
#   - average: Makes general claims without detailed analysis.
#   - needs_improvement: Mentions impact with minimal support.
#   - poor: No clear link to accounting outcomes.
# Criterion: c3
# Name: Use of Real-World Examples/Case Studies
# Description: Incorporates actual or realistic examples of blockchain application in accounting or finance.
# Performance Descriptors:
#   - excellent: Provides multiple well-explained examples with relevance.
#   - good: Provides at least one relevant example.
#   - average: Mentions example(s) with little context.
#   - needs_improvement: Example(s) are vague or unrelated.
#   - poor: No examples given.
# Criterion: c4
# Name: Structure and Academic Style
# Description: Presents arguments in a well-structured, formal academic tone.
# Performance Descriptors:
#   - excellent: Highly coherent essay with formal tone and logical flow.
#   - good: Mostly well-structured with clear transitions.
#   - average: Some structure; style inconsistently academic.
#   - needs_improvement: Unclear flow or casual language.
#   - poor: Disorganised or informal.
# Student submission:
# """Blockchain technology, defined by its decentralized ledgers, immutability, and transparency, is revolutionizing traditional accounting practices, particularly in auditing and financial reporting. Its core principles—decentralized ledgers, immutable records, and smart contracts—enable significant improvements in efficiency, trust, and accuracy. This essay explores blockchain’s transformative effects, supported by real-world applications and challenges.
# Blockchain’s immutability ensures financial records are tamper-proof, creating reliable audit trails that simplify verification and enhance fraud detection. For instance, Ernst & Young (EY) employs its Blockchain Analyzer to audit cryptocurrency transactions, streamlining assurance processes. Smart contracts automate tasks like invoicing or reconciliation, reducing manual errors and intermediaries. This automation supports real-time financial reporting, allowing companies to produce accurate, transparent financial statements instantly, as demonstrated by IBM’s blockchain-based supply chain financing, which minimizes reporting delays."""
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Label: Human
#
# Rationale:
# The NEW submission by the student is clearly Human, as it follows the expected structure and adheres to the guidelines set out. The essay discusses the significant impact of blockchain technology on traditional accounting practices, particularly in auditing and financial reporting. The author uses real-world applications and challenges to support their claims, and the essay is well-structured, with clear paragraphs and subheadings.
#
# Flags:
# The essay includes flags indicating that the submission is Human, AI, and Hybrid. The flags are used to highlight areas where the submission may be considered a hybrid, such as its mix of AI and human elements. Additionally, the submission includes some cliché patterns, such as repetitive statements about immutability and automation, which may indicate a hybrid submission.
#
# NEW submission:
# """Blockchain technology, defined by its decentralization, immutability, and transparency, is revolutionizing traditional accounting practices, particularly in auditing and financial reporting. Its core principles—decentralized ledgers, immutable records, and smart contracts—enable significant improvements in efficiency, trust, and accuracy. This essay explores blockchain’s transformative effects, supported by real-world applications and challenges.
#
# Blockchain’s immutability ensures financial records are tamper-proof, creating reliable audit trails that simplify verification and enhance fraud detection. For instance, Ernst & Young (EY) employs its Blockchain Analyzer to audit cryptocurrency transactions, streamlining assurance processes. Smart contracts automate tasks like invoicing or reconciliation, reducing manual errors and intermediaries. This automation supports real-time financial reporting, allowing companies to produce accurate, transparent financial statements instantly, as demonstrated by IBM’s blockchain-based supply chain financing, which minimizes reporting delays."""
#
# --- SUBMISSION 3 (Label: Human) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# Here is a revised version of the rubric for the accounting assignment, with actionable feedback aligned to the rubric:
#
# Criteria:
# Criterion: c1
# Name: Understanding of Blockchain Concepts
# Description: Demonstrates knowledge of blockchain principles (decentralization, immutability, smart contracts) and their relevance to accounting.
# Performance Descriptors:
# - Excellent: Clearly explains multiple blockchain concepts and maps each to relevant accounting applications. - Good: Accurately describes 1–2 blockchain concepts and gives examples. - Average: Mentions blockchain concepts but with limited detail. - Needs improvement: Basic or unclear understanding of concepts. - Poor: Fails to explain blockchain accurately. Criterion: c2
# Name: Analysis of Accounting Impact
# Description: Evaluates how blockchain technology affects auditing, financial reporting, and data integrity.
# Performance Descriptors:
# - Excellent: Insightfully discusses enhanced transparency, automation, audit trails, and associated challenges. - Good: Explains basic benefits like improved data accuracy or reduced reconciliation. - Average: Makes general claims without detailed analysis. - Needs improvement: Mentions impact with minimal support. - Poor: No clear link to accounting outcomes. Criterion: c3
# Name: Use of Real-World Examples/Case Studies
# Description: Incorporates actual or realistic examples of blockchain application in accounting or finance.
# Performance Descriptors:
# - Excellent: Provides multiple well-explained examples with relevance. - Good: Provides at least one relevant example. - Average: Mentions example(s) with little context. - Needs improvement: Example(s) are vague or unrelated. - Poor: No examples given. Criterion: c4
# Name: Structure and Academic Style
# Description: Presents arguments in a well-structured, formal academic tone.
# Performance Descriptors:
# - Excellent: Highly coherent essay with formal tone and logical flow. - Good: Mostly well-structured with clear transitions. - Average: Some structure; style inconsistently academic. - Needs improvement: Unclear flow or casual language. - Poor: Disorganised or informal. Criterion: c5
# Name: Academic Writing
# Description: Presents arguments in a clear, concise, and well-organized manner.
# Performance Descriptors:
# - Excellent: Clear and concise argument with logical flow. - Good: Clear and concise argument with logical flow, but some inconsistencies. - Average: Logical argument with inconsistencies. - Needs improvement: Inconsistent logical flow, some contradictions. - Poor: Inconsistent logical flow, contradictions, and lack of coherence.
# Student submission:
# """As a business student fascinated by tech, I see blockchain revolutionizing traditional accounting. Its decentralized, tamper-proof ledger could transform bookkeeping, auditing, and financial reporting, though it’s not without challenges. In bookkeeping, blockchain’s real-time, cryptographically secure transaction recording reduces errors and fraud. Unlike centralized databases prone to mistakes, blockchain’s distributed ledger ensures accuracy, automating tasks like reconciliations. Companies like IBM are already using it for supply chain finance, cutting paperwork. Auditing could benefit hugely. Blockchain’s “triple-entry” system creates a verifiable transaction record, slashing audit times. Firms like Deloitte are testing this, showing faster, cheaper audits. But, if bad data enters, it’s still a problem—garbage in, garbage out. For financial reporting, blockchain enables real-time updates, giving stakeholders instant insights. A 2023 study suggested this could boost market efficiency, but companies might resist such transparency.  Challenges include high setup costs, lack of accounting standards for blockchain, and privacy concerns. It’s a trust-building tool, great for fraud prevention, but not a full replacement for traditional systems yet. In short, blockchain promises efficiency and trust in accounting but needs time to mature. Accountants must adapt gradually, blending old and new methods. But the benefits of blockchain, like transparency and immutability, are clear. Accounting professionals must be ready to integrate this technology into their practices to ensure the best possible outcome."""
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Label: Human
#
# Rationale:
# The NEW submission is Human in the sense that it contains original, meaningful language that accurately reflects the author's perspective and understanding of the topic. The author's use of specificity, subjectivity, and personal context highlights their genuine and nuanced understanding of the material. While there are some instances of AI assistance, it is not overwhelmingly apparent and does not detract from the author's contribution.
#
# Flags:
# The NEW submission does not contain any significant flaws that would indicate the use of AI assistance. The author's use of clear and precise structured output demonstrates their mastery of the assignment's guidelines.
#
# NEW submission:
# "As a business student fascinated by tech, I see blockchain revolutionizing traditional accounting. Its decentralized, tamper-proof ledger could transform bookkeeping, auditing, and financial reporting. While there are some challenges to be addressed, such as high setup costs, lack of accounting standards for blockchain, and privacy concerns, these can be overcome through careful planning and implementation. As a result, blockchain promises efficiency and trust in accounting, but needs time to mature. Accountants must adapt gradually, blending old and new methods. In short, blockchain has the potential to transform accounting but requires careful consideration and planning to ensure its successful implementation."
#
# --- SUBMISSION 4 (Label: Human) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# Criteria:
# Criterion: c1
# Name: Understanding of Blockchain Concepts
# Description: Demonstrates knowledge of blockchain principles (decentralization, immutability, smart contracts) and their relevance to accounting.
# Performance Descriptors:
#   - excellent: Clearly explains multiple blockchain concepts and maps each to relevant accounting applications.
#   - good: Accurately describes 1–2 blockchain concepts and gives examples.
#   - average: Mentions blockchain concepts but with limited detail.
#   - needs_improvement: Basic or unclear understanding of concepts.
#   - poor: Fails to explain blockchain accurately.
#
# Criterion: c2
# Name: Analysis of Accounting Impact
# Description: Evaluates how blockchain technology affects auditing, financial reporting, and data integrity.
# Performance Descriptors:
#   - excellent: Insightfully discusses enhanced transparency, automation, audit trails, and associated challenges.
#   - good: Explains basic benefits like improved data accuracy or reduced reconciliation.
#   - average: Makes general claims without detailed analysis.
#   - needs_improvement: Mentions impact with minimal support.
#   - poor: No clear link to accounting outcomes.
#
# Criterion: c3
# Name: Use of Real-World Examples/Case Studies
# Description: Incorporates actual or realistic examples of blockchain application in accounting or finance.
# Performance Descriptors:
#   - excellent: Provides multiple well-explained examples with relevance.
#   - good: Provides at least one relevant example.
#   - average: Mentions example(s) with little context.
#   - needs_improvement: Example(s) are vague or unrelated.
#   - poor: No examples given.
#
# Criterion: c4
# Name: Structure and Academic Style
# Description: Presents arguments in a well-structured, formal academic tone.
# Performance Descriptors:
#   - excellent: Highly coherent essay with formal tone and logical flow.
#   - good: Mostly well-structured with clear transitions.
#   - average: Some structure; style inconsistently academic.
#   - needs_improvement: Unclear flow or casual language.
#   - poor: Disorganised or informal.
#
# Student submission:
# """As a business student fascinated by tech, I see blockchain reshaping accounting, auditing, and financial reporting, though it’s not without challenges. Blockchain’s decentralized, tamper-proof ledger records transactions transparently, reducing errors in bookkeeping. Unlike traditional double-entry systems, blockchain’s “triple-entry” approach creates a verifiable, shared record, cutting down on manual reconciliations. For example, companies like IBM use blockchain for supply chain finance, automating transaction entries. Auditing could be revolutionized too. Real-time access to immutable records means auditors can verify transactions faster, slashing time and costs. Firms like Deloitte are testing this, showing promising results. However, blockchain’s only as good as the data entered—mistakes or fraud at input still cause issues. Financial reporting might shift to real-time with blockchain, giving stakeholders instant insights into a company’s finances, potentially boosting market transparency. But here’s the catch: implementing blockchain is pricey, and small firms might struggle. Plus, accounting standards like GAAP aren’t blockchain-ready, and privacy concerns loom large with transparent ledgers. Critically, blockchain enhances trust but will not replace traditional accounting soon. It’s more of a complementary tool, best for specific cases. Accountants must adapt gradually, balancing innovation with practical hurdles like cost and regulation."""
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Here is a response to the given text:
#
# Label: Hybrid
# Rationale:
# - Point 1: The submission appears to be a hybrid of human and AI writing, with some human-like elements such as subjectivity and personal context. The AI assistance is evident in the use of automated translation tools to improve the clarity and conciseness of the writing.
# - Point 2: The submission is a combination of human and AI writing, with some AI assistance in the form of automated translation tools. However, the use of AI assistance is limited to improving clarity and conciseness, and the human-like elements remain evident.
# - Point 3: The submission is explicitly a hybrid of human and AI writing, with some human-like elements such as subjectivity and personal context, and some AI assistance in the form of automated translation tools. The use of AI assistance is limited to improving clarity and conciseness, and the human-like elements remain evident.
# - Flags:
#   - The submission is a hybrid of human and AI writing, with some human-like elements such as subjectivity and personal context, and some AI assistance in the form of automated translation tools.
#
# NEW submission:
# """As a business student fascinated by tech, I see blockchain reshaping accounting, auditing, and financial reporting, though it’s not without challenges. Blockchain’s decentralized, tamper-proof ledger records transactions transparently, reducing errors in bookkeeping. Unlike traditional double-entry systems, blockchain’s “triple-entry” approach creates a verifiable, shared record, cutting down on manual reconciliations. For example, companies like IBM use blockchain for supply chain finance, automating transaction entries. Auditing could be revolutionized too. Real-time access to immutable records means auditors can verify transactions faster, slashing time and costs. Firms like Deloitte are testing this, showing promising results. However, blockchain’s only as good as the data entered—mistakes or fraud at input still cause issues. Financial reporting might shift to real-time with blockchain, giving stakeholders instant insights into a company’s finances, potentially boosting market transparency. But here’s the catch: implementing blockchain is pricey, and small firms might struggle. Plus, accounting standards like GAAP aren’t blockchain-ready, and privacy concerns loom large with transparent ledgers. Critically, blockchain enhances trust but will not replace traditional accounting soon. It’s more of a complementary tool, best for specific cases. Accountants must adapt gradually, balancing innovation with practical hurdles like cost and regulation."""
#
# --- SUBMISSION 5 (Label: Hybrid) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# Here is a revised version of the feedback, aligned to the rubric:
#
# Criteria:
# Criterion: c1
# Name: Understanding of Blockchain Concepts
# Description: Demonstrates knowledge of blockchain principles (decentralization, immutability, smart contracts) and their relevance to accounting.
# Performance Descriptors:
#   - excellent: Clearly explains multiple blockchain concepts and maps each to relevant accounting applications.
#   - good: Accurately describes 1–2 blockchain concepts and gives examples.
#   - average: Mentions blockchain concepts but with limited detail.
#   - needs_improvement: Basic or unclear understanding of concepts.
#   - poor: Fails to explain blockchain accurately.
#
# Criterion: c2
# Name: Analysis of Accounting Impact
# Description: Evaluates how blockchain technology affects auditing, financial reporting, and data integrity.
# Performance Descriptors:
#   - excellent: Insightfully discusses enhanced transparency, automation, audit trails, and associated challenges.
#   - good: Explains basic benefits like improved data accuracy or reduced reconciliation.
#   - average: Makes general claims without detailed analysis.
#   - needs_improvement: Mentions impact with minimal support.
#   - poor: No clear link to accounting outcomes.
#
# Criterion: c3
# Name: Use of Real-World Examples/Case Studies
# Description: Incorporates actual or realistic examples of blockchain application in accounting or finance.
# Performance Descriptors:
#   - excellent: Provides multiple well-explained examples with relevance.
#   - good: Provides at least one relevant example.
#   - average: Mentions example(s) with little context.
#   - needs_improvement: Example(s) are vague or unrelated.
#   - poor: No examples given.
#
# Criterion: c4
# Name: Structure and Academic Style
# Description: Presents arguments in a well-structured, formal academic tone.
# Performance Descriptors:
#   - excellent: Highly coherent essay with formal tone and logical flow.
#   - good: Mostly well-structured with clear transitions.
#   - average: Some structure; style inconsistently academic.
#   - needs_improvement: Unclear flow or casual language.
#   - poor: Disorganised or informal.
#
# Student submission:
# """Blockchain technology significantly reshapes traditional accounting practices, including auditing and financial reporting, by enhancing transparency, efficiency, and accuracy. Its decentralized, immutable ledger ensures real-time, tamper-proof transaction records, reducing errors and fraud. In accounting, blockchain automates bookkeeping through smart contracts, minimizing manual entries and enabling instant reconciliation. This streamlines processes like accounts payable and receivable, cutting costs and time. For auditing, blockchain provides a verifiable, chronological record of transactions, simplifying the audit trail. Auditors can access unalterable data, reducing reliance on sampling and enhancing accuracy. Real-time auditing becomes feasible, potentially replacing periodic reviews with continuous monitoring. However, challenges arise, such as the need for auditors to develop blockchain expertise and address privacy concerns with transparent ledgers. In financial reporting, blockchain ensures data integrity, fostering trust in financial statements. It enables faster reporting cycles and reduces discrepancies between entities. Yet, adoption requires significant investment in infrastructure and regulatory alignment. While blockchain promises efficiency and reliability, its integration demands a shift in skills, standards, and processes, reshaping the accounting profession. Based on the rubric provided, the feedback aligns with the student submission. The student's essay is well-structured and flows logically. The academic tone is formal, but not too formal. There are few errors in grammar and punctuation, and the essay is coherent and well-explained. The student has adequate knowledge of the blockchain concepts and smart contracts, and their relevance to accounting. However, the student has not explained the practical applications of blockchain in accounting and finance, which could be improved upon. The student's description of real-world examples and case studies is limited to a few examples, which are not relevant to the rubric's focus on auditing and financial reporting.
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Label: Hybrid
#
# Rationale:
# The NEW submission presents an AI-assisted analysis of the NEW blockchain technology. The text is well-organized, and the rationale section clearly explains the benefits of blockchain for accounting and auditing, including real-time transaction records, verifiable audit trail, and enhanced accuracy. The flags section identifies some potential challenges, such as the need for blockchain expertise and privacy concerns, which could be addressed through education and collaboration. Overall, the NEW submission demonstrates a clear understanding of the potential benefits and limitations of blockchain for accounting and auditing.
#
# --- SUBMISSION 6 (Label: Hybrid) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# Criteria:
# Criterion: c1
# Name: Understanding of Blockchain Concepts
# Description: Demonstrates knowledge of blockchain principles (decentralization, immutability, smart contracts) and their relevance to accounting. Performance Descriptors:
#   - excellent: Clearly explains multiple blockchain concepts and maps each to relevant accounting applications. - good: Accurately describes 1–2 blockchain concepts and gives examples. - average: Mentions blockchain concepts but with limited detail. - needs_improvement: Basic or unclear understanding of concepts. - poor: Fails to explain blockchain accurately.
# Criterion: c2
# Name: Analysis of Accounting Impact
# Description: Evaluates how blockchain technology affects auditing, financial reporting, and data integrity. Performance Descriptors:
#   - excellent: Insightfully discusses enhanced transparency, automation, audit trails, and associated challenges. - good: Explains basic benefits like improved data accuracy or reduced reconciliation. - average: Makes general claims without detailed analysis. - needs_improvement: Mentions impact with minimal support. - poor: No clear link to accounting outcomes.
# Criterion: c3
# Name: Use of Real-World Examples/Case Studies
# Description: Incorporates actual or realistic examples of blockchain application in accounting or finance. Performance Descriptors:
#   - excellent: Provides multiple well-explained examples with relevance. - good: Provides at least one relevant example. - average: Mentions example(s) with little context. - needs_improvement: Example(s) are vague or unrelated. - poor: No examples given.
# Criterion: c4
# Name: Structure and Academic Style
# Description: Presents arguments in a well-structured, formal academic tone. Performance Descriptors:
#   - excellent: Highly coherent essay with formal tone and logical flow. - good: Mostly well-structured with clear transitions. - average: Some structure; style inconsistently academic. - needs_improvement: Unclear flow or casual language. - poor: Disorganised or informal.
# Student submission:
# ""Blockchain technology significantly transforms traditional accounting practices, enhancing efficiency, transparency, and security. Its decentralized, immutable ledger ensures real-time, tamper-proof recording of transactions, reducing errors and fraud risks. In financial reporting, blockchain enables automated, accurate data aggregation, streamlining processes like reconciliation and ensuring compliance with standards. Smart contracts automate routine tasks, such as invoice settlements, minimizing manual intervention and costs. In auditing, blockchain shifts the focus from sample-based verification to comprehensive, real-time data analysis. Auditors can access a transparent audit trail, improving accuracy and reducing audit time. However, challenges arise, including the need for new auditing standards to address blockchain-specific risks like smart contract vulnerabilities. Accountants must adapt to technical skills, such as understanding distributed ledger technology. While blockchain enhances trust and efficiency, it disrupts traditional roles, requiring firms to invest in training and infrastructure. Regulatory uncertainty and scalability issues also pose hurdles. Overall, blockchain fosters a more reliable, automated accounting ecosystem but demands significant adaptation from professionals to fully realize its potential."""
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Label: Human
#
# Rationale:
# The NEW submission is a human-written academic essay that demonstrates clear attention to detail and understanding of the subject matter. The use of specificity, subjectivity, and personal context reinforces the author's perspective and adds authenticity to their writing. The use of discourse features such as clear, concise language and appropriate use of academic vocabulary reinforce the author's education and academic expertise.
#
# Flags:
# - Point 1: The author's use of specificity is evident in the use of concrete examples to support their argument. This demonstrates a clear understanding of the topic and provides readers with a more nuanced understanding of the issue.
# - Point 2: The author's use of subjectivity is evident in their personal perspective, which is evident in their use of first-person pronouns and their focus on the positive impact of blockchain on accounting.
# - Point 3: The author's use of personal context is evident in their acknowledgement of the challenges that arise due to blockchain's disruptive nature. This demonstrates a clear understanding of the issue and helps to contextualize the discussion.
#
# Overall, while the NEW submission is not entirely free of errors, the author's attention to detail, subjectivity, and personal context demonstrate a clear understanding of the topic and the potential impact of blockchain on accounting.
