# %%
# ==== 0) Setup (Colab-friendly) ====
# !pip -q install google-generativeai>=0.7.2

import os, json, re, textwrap
from typing import List, Dict, Any
from getpass import getpass
from datetime import datetime
import google.generativeai as genai

# Secure API key (Colab / local)
if "GEMINI_API_KEY" not in os.environ or not os.environ["GEMINI_API_KEY"]:
    os.environ["GEMINI_API_KEY"] = getpass("Enter your GEMINI_API_KEY: ")
genai.configure(api_key=os.environ["GEMINI_API_KEY"])

# -------------------------
# 1) File paths (uploaded)
# -------------------------
PATHS = [
    "teaching.json",
    "psychology.json",
    "it.json",
    "engineering.json",
    "accounting.json",
]

def load_json(path: str):
    with open(path, "r", encoding="utf-8") as f:
        return json.load(f)

# -------------------------
# 2) Rubric -> readable text
# -------------------------
def rubric_to_text(rubric: Dict[str, Any]) -> str:
    """Flatten rubric JSON to a readable block of text for the model."""
    lines = []
    rid = rubric.get("rubric_id", "rubric_id_unknown")
    lines.append(f"Rubric ID: {rid}")
    lines.append("Criteria:")
    for c in rubric.get("criteria", []):
        cid = c.get("criterion_id","")
        name = c.get("name","")
        desc = c.get("description","")
        lines.append(f"- {cid}: {name}")
        if desc:
            lines.append(f"  Description: {desc}")
        pd = c.get("performance_descriptors", {})
        if pd:
            lines.append("  Performance descriptors:")
            for k, v in pd.items():
                lines.append(f"    - {k}: {v}")
    return "\n".join(lines)

# -------------------------
# 3) Base prompts (YOUR VERSION: plain text only)
# -------------------------
SYSTEM_PROMPT = "You are a careful academic assistant. Be precise and give clear structured output (not JSON, not CSV, no files)."

def build_detection_prompt(submission: str, few_shots: List[Dict[str, Any]]) -> List[Dict[str, str]]:
    """
    Academic Integrity Detector Prompt (Plain Text)
    Expected Output:
        Label: Human | AI | Hybrid
        Rationale:
        - short bullet point 1
        - short bullet point 2
        Flags: style_inconsistency / high_verbatim / generic_phrasing / none
    """
    shot_texts = []
    for s in few_shots:
        shot_texts.append(
            f'Submission: """{s.get("final_submission","")}"""\n'
            f'Your analysis (2–4 bullet points): <analysis>\n'
            f'Label: {s.get("label_type","")}\n'
        )
    examples_block = "\n\n".join(shot_texts) if shot_texts else "/* no examples available */"

    user = f"""
You are an AI text-source classifier for academic integrity.
Decide whether the student submission is Human, AI, or Hybrid (AI-assisted).

Guidelines:
- Consider discourse features (specificity, subjectivity, personal context), style consistency, local/global coherence, repetitiveness, and cliché patterns.
- Hybrid = meaningful human writing with some AI assistance, or explicit admission of mixed use.

Examples:
{examples_block}

Now analyze the NEW submission and respond in plain text with the following structure:
Label: ...
Rationale:
- point 1
- point 2
Flags: ...
NEW submission:
\"\"\"{submission}\"\"\"\n
"""
    return [
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user", "content": user},
    ]

def build_feedback_prompt(domain: str, assignment_prompt: str, rubric_text: str, submission: str) -> List[Dict[str, str]]:
    """
    Rubric-Aligned Feedback Prompt (Plain Text)
    Expected Output:
        Overall Summary:
        <2–4 sentence overview>

        Criteria Feedback:
        Criterion: <criterion_id>
        Rating: Excellent | Good | Average | Needs Improvement | Poor
        Evidence:
        - point 1
        - point 2
        Improvement Tip: one concrete suggestion

        Overall Rating: Excellent | Good | Average | Needs Improvement | Poor
    """
    user = f"""
You are a supportive assessor. Provide actionable feedback aligned to the rubric.
Return plain structured text only (no JSON, no files).

Sections to include:
1) Overall Summary: 2–4 sentences on strengths and priorities.
2) Criteria Feedback: for each rubric criterion include:
   - Criterion
   - Rating (excellent, good, average, needs_improvement, poor)
   - Evidence (1–3 bullet points citing excerpts or behaviors)
   - Improvement Tip (one concrete step)
3) Overall Rating: Excellent | Good | Average | Needs Improvement | Poor

Context:
- Domain: {domain}
- Assignment prompt: {assignment_prompt}

Rubric (verbatim):
{rubric_text}

Student submission:
\"\"\"{submission}\"\"\"\n
"""
    return [
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user", "content": user},
    ]

# ------------------------------------------------
# 4) Gemini call helper (no 'system' role allowed)
# ------------------------------------------------
def call_gemini(messages, model_name="gemini-1.5-pro", temperature=0.2, max_output_tokens=1536):
    """
    google-generativeai >= 0.7.x
    - Merges any 'system' content into the first 'user' message
    - Converts to 'parts' format
    - Requests plain text (no JSON)
    """
    # 0) Separate & merge system messages
    system_buf = []
    user_msgs = []
    for m in messages:
        role = m.get("role", "user")
        content = m.get("content", "")
        if role == "system":
            if isinstance(content, list):
                content = "\n".join(str(x) for x in content)
            system_buf.append(str(content))
        else:
            user_msgs.append({"role": role, "content": content})

    if not user_msgs:
        user_msgs = [{"role": "user", "content": ""}]

    if system_buf:
        preface = "\n".join(system_buf).strip()
        user_msgs[0]["content"] = (preface + "\n\n" + user_msgs[0].get("content","")).strip()

    # 1) Convert to parts
    norm_msgs = []
    for m in user_msgs:
        norm_msgs.append({"role": m.get("role", "user"), "parts": [m.get("content", "")]})

    # 2) Create model & generate
    model = genai.GenerativeModel(model_name)
    resp = model.generate_content(
        norm_msgs,
        generation_config={
            "temperature": temperature,
            "max_output_tokens": max_output_tokens,
            # no response_mime_type -> plain text
        }
    )

    # 3) Return text robustly
    if hasattr(resp, "text") and isinstance(resp.text, str) and resp.text.strip():
        return resp.text.strip()

    try:
        cand0 = resp.candidates[0]
        parts = getattr(cand0, "content", cand0).parts
        out = "".join(getattr(p, "text", "") for p in parts)
        return out.strip()
    except Exception:
        return ""

# -------------------------
# 5) Runner
# -------------------------
def run_all():
    all_outputs: List[Dict[str, Any]] = []

    for path in PATHS:
        data = load_json(path)
        domain = data.get("domain", "Unknown")
        assign_prompt = data.get("prompt", "")
        rubric = data.get("rubric", {})
        submissions = data.get("submissions", [])

        rubric_text = rubric_to_text(rubric)
        few_shots = submissions[:2] if len(submissions) >= 2 else submissions[:1]

        dataset_block = {
            "path": path,
            "domain": domain,
            "assignment_prompt": assign_prompt,
            "n_submissions": len(submissions),
            "items": []
        }

        for idx, sub in enumerate(submissions, start=1):
            submission_text = sub.get("final_submission", "")

            # A) Detection
            det_msgs = build_detection_prompt(submission_text, few_shots=few_shots)
            det_text = call_gemini(det_msgs, max_output_tokens=1024)

            # B) Feedback
            fb_msgs = build_feedback_prompt(domain, assign_prompt, rubric_text, submission_text)
            fb_text = call_gemini(fb_msgs, max_output_tokens=2048)

            dataset_block["items"].append({
                "index": idx,
                "detection": det_text,
                "feedback": fb_text
            })

        all_outputs.append(dataset_block)

    return all_outputs

# -------------------------
# 6) Execute & print
# -------------------------
if __name__ == "__main__":
    results = run_all()

    print("\n===== EVALUATION RUN =====")
    print(f"Timestamp: {datetime.now().isoformat(timespec='seconds')}")
    for ds in results:
        print("\n--------------------------------------------")
        print(f"Source : {ds['path']}")
        print(f"Domain : {ds['domain']}")
        print(f"Prompt : {ds['assignment_prompt']}")
        print(f"#Subs  : {ds['n_submissions']}")
        for item in ds["items"]:
            print(f"\n  Submission #{item['index']}:")
            print("  --- Detection ---")
            print(textwrap.indent(item["detection"] or "[No output]", "    "))
            print("  --- Feedback ---")
            print(textwrap.indent(item["feedback"] or "[No output]", "    "))
# Out:
# ===== EVALUATION RUN =====
# Timestamp: 2025-09-01T13:19:27
#
# --------------------------------------------
# Source : teaching.json
# Domain : Teaching
# Prompt : Examine current research on early literacy development and evaluate evidence-based approaches for supporting pre-reading skills in diverse learners aged 3 to 6 years.
# #Subs  : 6
#
#   Submission #1:
#   --- Detection ---
#     Label: AI
#
#     Rationale:
#     - The text exhibits a high level of academic precision and fluency, characteristic of AI-generated text trained on academic corpora.  The vocabulary and sentence structures are sophisticated, but lack a distinct authorial voice.
#     - The paragraph reads as a general overview of the topic, lacking specific examples or deeper critical analysis that would typically be present in human-written academic work.  While it cites sources, it doesn't engage with them deeply.
#     - The concluding sentence, "The argument presented is grounded in current evidence, framed within a structured and academically rigorous paragraph that reflects clarity, coherence, and a formal writing style," is highly meta and self-referential, a common characteristic of AI writing.  A human writer would be less likely to explicitly praise their own work in this way.
#
#     Flags: Overly formal and generalized language, lack of specific examples or critical analysis, meta-commentary on the writing itself.
#   --- Feedback ---
#     1) Overall Summary:
#     This submission demonstrates a good understanding of early literacy development and evidence-based approaches. The student effectively integrates research to support their points and maintains a clear, academic writing style.  A priority for improvement is expanding the discussion of diversity and inclusion with more specific examples and research-based strategies.
#
#     2) Criteria Feedback:
#
#     - Criterion: c1: Understanding of Early Literacy Development
#       Rating: good
#       Evidence:
#         - "Current research on early literacy development highlights the foundational role of phonological awareness, vocabulary acquisition, and print knowledge in preparing children aged 3 to 6 for reading."
#         - "Children typically progress from recognizing environmental print and basic letter-sound associations at age 3 to developing phonemic segmentation and decoding skills by age 6."
#       Improvement Tip: While the developmental progression is mentioned, providing specific examples of each skill at different age levels would strengthen this section.
#
#     - Criterion: c2: Evaluation of Evidence-Based Approaches
#       Rating: good
#       Evidence:
#         - "Evidence-based strategies such as dialogic reading and phonemic awareness games have proven highly effective in this stage, particularly when implemented consistently and in developmentally appropriate ways."
#         -  Cites Justice & Ezell (2002) and Lonigan et al. (2008).
#         - Explains the benefits of dialogic reading: "not only enhances vocabulary but also fosters narrative skills and inferencing abilities."
#       Improvement Tip:  Discuss and evaluate one additional evidence-based approach to broaden the scope.
#
#     - Criterion: c3: Consideration of Diversity and Inclusion
#       Rating: average
#       Evidence:
#         - "Importantly, these approaches must be adapted for diverse learners."
#         - Mentions adapting for multilingual learners and children with developmental delays.
#       Improvement Tip: Provide more specific examples of inclusive practices and connect them to relevant research. For example, discuss specific strategies for incorporating home languages or types of visual supports.
#
#     - Criterion: c4: Research Integration and Referencing
#       Rating: good
#       Evidence:
#         - Cites relevant sources like Justice & Ezell (2002), Lonigan et al. (2008), Neuman and Wright (2014), and Snow (2006).
#         - Integrates research to support claims about the effectiveness of strategies and the importance of literacy equity.
#       Improvement Tip: While the citations are present, providing a complete reference list at the end would enhance academic rigor.
#
#     - Criterion: c5: Structure and Academic Writing
#       Rating: good
#       Evidence:
#         - The submission is a well-structured paragraph with a clear flow of ideas.
#         - Maintains a formal and academic tone throughout.
#       Improvement Tip: While presented as a single paragraph, expanding into a more traditional essay format with distinct introduction, body paragraphs, and conclusion would strengthen the structure, especially for longer assignments.
#
#
#     3) Overall Rating: Good
#
#   Submission #2:
#   --- Detection ---
#     Label: AI
#
#     Rationale:
#     - The text exhibits a highly structured and formulaic presentation of information typical of AI-generated academic content.  It efficiently covers key concepts but lacks the nuanced depth or unique perspective expected from human writing.
#     - While the inclusion of a citation (Whitehurst et al., 1994) suggests academic engagement, the overall text reads as a generalized summary of common knowledge in early literacy development rather than a synthesis of specific research findings.  The citation itself is a common one in the field and easily accessible to an AI.
#     - The language used, while grammatically correct and academically appropriate, lacks distinctive stylistic features.  It adheres to a neutral, objective tone, avoiding any personal voice or subjective interpretation.  This absence of individual expression further points towards AI authorship.
#     - The concluding sentence ("While this response...minimal grammatical issues") displays a self-referential quality and an awareness of potential critique, a characteristic sometimes observed in AI-generated text attempting to mimic reflective human writing.
#
#     Flags: Generic phrasing, lack of specific examples or detailed analysis, overly structured presentation, neutral tone, self-referential concluding remark.
#   --- Feedback ---
#     1) Overall Summary: This submission demonstrates a good understanding of early literacy development and identifies relevant evidence-based approaches.  While it touches upon diversity and inclusion, further exploration of adaptations for diverse learners would strengthen the analysis. The writing is well-structured and uses academic sources appropriately.  Prioritizing deeper discussion of diversity and inclusion, along with providing more specific examples of adaptations, will elevate the quality of the work.
#
#     2) Criteria Feedback:
#
#     - Criterion: c1: Understanding of Early Literacy Development
#       Rating: Good
#       Evidence:
#         - "Early literacy development involves acquiring key skills such as phonological awareness, vocabulary, and an understanding of print, which typically emerge between the ages of 3 and 6."
#         - "Children often begin by recognizing letters and sounds and gradually move towards blending phonemes and understanding word structures."
#       Improvement Tip: Provide more specific examples of developmental milestones within each literacy component (e.g., rhyming for phonological awareness, understanding story sequence for narrative skills).
#
#     - Criterion: c2: Evaluation of Evidence-Based Approaches
#       Rating: Good
#       Evidence:
#         - "Evidence-based approaches like shared book reading and phonemic games support these developments..."
#         - "...research showing that repeated reading and interactive questioning can boost vocabulary and listening comprehension (Whitehurst et al., 1994)."
#       Improvement Tip:  Expand on the explanation of *how* these approaches support development.  For example, explain the mechanisms by which shared book reading promotes vocabulary growth.
#
#     - Criterion: c3: Consideration of Diversity and Inclusion
#       Rating: Average
#       Evidence:
#         - "strategies can be adjusted to support children from diverse cultural and linguistic backgrounds—for example, using bilingual books or incorporating culturally familiar content can enhance relevance and motivation."
#       Improvement Tip: Provide more concrete examples of adaptations for diverse learners. Consider discussing specific challenges faced by learners with different needs (e.g., dyslexia, English language learners) and how evidence-based approaches can be tailored to address those needs.
#
#     - Criterion: c4: Research Integration and Referencing
#       Rating: Good
#       Evidence:
#         - Includes a relevant citation (Whitehurst et al., 1994) to support a claim.
#       Improvement Tip: Integrate more research to support the points made about early literacy development and the effectiveness of different approaches.
#
#     - Criterion: c5: Structure and Academic Writing
#       Rating: Good
#       Evidence:
#         - "The writing follows a logical structure with a mostly formal tone and minimal grammatical issues."
#       Improvement Tip: While the tone is mostly formal, ensure consistent academic style throughout.  Avoid informal phrases like "While this response touches on..."  Instead, use more formal phrasing such as "While this analysis addresses..."
#
#     3) Overall Rating: Good
#
#   Submission #3:
#   --- Detection ---
#     Label: Human
#     Rationale:
#     - The writing demonstrates a genuine, personal engagement with the topic, using phrases like "such a critical phase" and "so much foundational learning takes place." This suggests human expression rather than AI-generated text.
#     - The explanation of phonological awareness goes beyond a general definition and provides specific examples like "rhyming or identifying beginning sounds."  This level of detail and illustrative approach points towards human input.
#     - The text exhibits a natural flow of ideas and incorporates personal reflections, such as emphasizing the gradual nature of phonological awareness development. This nuanced approach is more characteristic of human writing.
#     - While the text includes a citation, it's integrated naturally within the explanation, further supporting the impression of human-authored content.
#
#     Flags: None
#   --- Feedback ---
#     1) Overall Summary: The submission demonstrates a good understanding of early literacy development and touches upon key pre-reading skills. However, it primarily focuses on describing these skills and lacks the critical evaluation of evidence-based approaches and considerations for diverse learners expected at this level.  Prioritizing a deeper exploration of instructional strategies and their application to diverse contexts will significantly strengthen the work.  Additionally, expanding the use of academic sources beyond the single citation will enhance the academic rigor.
#
#     2) Criteria Feedback:
#
#     - c1: Understanding of Early Literacy Development
#         - Rating: Good
#         - Evidence:
#             - "children typically begin developing core pre-reading skills like phonological awareness, vocabulary knowledge, and an understanding of print concepts."
#             -  "Phonological awareness... includes the ability to recognize and manipulate sounds in spoken words, like rhyming or identifying beginning sounds."
#             - "According to Lonigan et al. (2000), this skill emerges gradually, often starting with larger sound chunks (like syllables) and becoming more refined over time (e.g., phonemes)."
#         - Improvement Tip: While the foundational skills are well-described, consider elaborating on the interconnectedness of these skills and how they contribute to overall literacy development.
#
#     - c2: Evaluation of Evidence-Based Approaches
#         - Rating: Poor
#         - Evidence: The submission does not evaluate specific instructional methods or interventions.
#         - Improvement Tip: Introduce and critically evaluate evidence-based approaches for supporting pre-reading skills, such as dialogic reading, shared book reading, and phonemic awareness games.  Provide research-based evidence to support the effectiveness of these approaches.
#
#     - c3: Consideration of Diversity and Inclusion
#         - Rating: Poor
#         - Evidence: The submission does not address diverse learner needs or inclusive practices.
#         - Improvement Tip: Discuss how individual learner differences (linguistic, cultural, developmental) can influence literacy development and how instructional approaches can be adapted to meet these diverse needs.
#
#     - c4: Research Integration and Referencing
#         - Rating: Needs_improvement
#         - Evidence: Only one source (Lonigan et al., 2000) is cited.  The integration of research is limited.
#         - Improvement Tip: Integrate more peer-reviewed research throughout the essay to support claims and provide a more comprehensive overview of the topic. Ensure accurate and consistent referencing.
#
#     - c5: Structure and Academic Writing
#         - Rating: Good
#         - Evidence: The writing is clear and generally well-organized. The tone is appropriate for an academic context.
#         - Improvement Tip: While the current structure is adequate, consider adding a more formal introduction and conclusion to frame the discussion and summarize key takeaways.
#
#     3) Overall Rating: Needs Improvement
#
#   Submission #4:
#   --- Detection ---
#     Label: Human
#     Rationale:
#     - The text exhibits a conversational, explanatory tone, avoiding overly formal or academic phrasing. This suggests a human's natural writing style.
#     - The examples provided are simple and relatable, typical of a human explaining a concept to a general audience.  They lack the complexity or specificity often found in AI-generated text.
#     - The submission focuses on a general overview of early literacy development, without delving into specific research studies or theoretical frameworks. This is more indicative of a human summarizing common knowledge.
#     - The progression of ideas flows naturally, reflecting a human train of thought rather than a structured, information-dense output typical of AI.
#     Flags: None
#   --- Feedback ---
#     1) Overall Summary:
#     The submission demonstrates a basic understanding of early literacy development and touches upon key pre-reading skills. However, it lacks the depth and breadth expected for a comprehensive analysis of the topic.  It primarily focuses on defining early literacy and briefly mentioning developmental milestones, omitting discussion of evidence-based approaches, diversity, and research integration.  Prioritizing these missing components will significantly strengthen the work.
#
#     2) Criteria Feedback:
#
#     - Criterion: c1: Understanding of Early Literacy Development
#       Rating: Average
#       Evidence:
#         - "Learning to read doesn't just start when a child enters school—early literacy development begins much earlier, especially between the ages of 3 and 6." (Identifies the relevant age range)
#         - "During this time, children start to develop key pre-reading skills like phonological awareness, vocabulary, and knowledge about print." (Lists key pre-reading skills)
#         - "For example, they begin to understand that words are made up of sounds, and they start to recognise letters and how to handle a book." (Provides basic examples)
#       Improvement Tip: Expand on the explanation of each pre-reading skill and provide more specific examples of developmental milestones for each age within the 3-6 range.  Consider incorporating stages of development (e.g., emergent, developing, proficient).
#
#     - Criterion: c2: Evaluation of Evidence-Based Approaches
#       Rating: Poor
#       Evidence:
#         - No evidence of evaluating instructional methods or interventions.
#       Improvement Tip: Introduce and critically evaluate evidence-based approaches for supporting pre-reading skills, such as dialogic reading, shared book reading, and phonemic awareness activities.  Discuss the research supporting these approaches.
#
#     - Criterion: c3: Consideration of Diversity and Inclusion
#       Rating: Poor
#       Evidence:
#         - No mention of diversity or inclusion.
#       Improvement Tip: Discuss how individual learner differences (linguistic, cultural, developmental) can influence early literacy development and how instructional approaches can be adapted to meet diverse needs.
#
#     - Criterion: c4: Research Integration and Referencing
#       Rating: Poor
#       Evidence:
#         - No evidence of research integration or referencing.
#       Improvement Tip: Integrate relevant academic sources (e.g., peer-reviewed journals, books) to support claims and provide evidence for the effectiveness of different approaches.  Use a consistent referencing style (e.g., APA, MLA).
#
#     - Criterion: c5: Structure and Academic Writing
#       Rating: Average
#       Evidence:
#         - The submission has a basic introductory paragraph.
#         - The writing is relatively clear and easy to understand.
#         - Lacks a formal essay structure with distinct introduction, body, and conclusion.
#       Improvement Tip: Develop a more formal essay structure with a clear introduction outlining the scope of the essay, body paragraphs dedicated to specific aspects of the prompt (evidence-based approaches, diversity, etc.), and a concluding paragraph summarizing key findings.
#
#     3) Overall Rating: Needs Improvement
#
#   Submission #5:
#   --- Detection ---
#     Label: Human
#     Rationale:
#     - The text exhibits a natural flow of ideas with specific examples like "rhyming or identifying beginning sounds" and "(e.g. syllables) and becoming more refined over time (e.g. phonemes)," indicating human-like thought processes.
#     - The writing includes a personal touch with the use of "He or she," which, while slightly informal, adds a human element not typically seen in AI-generated text.
#     - The explanation of phonological awareness demonstrates a nuanced understanding of the topic, moving beyond general descriptions to more specific details about its developmental progression.  This suggests human comprehension and synthesis of information.
#     - The text maintains a consistent style and tone throughout, focusing on providing informative explanations rather than simply listing facts or research findings.
#     Flags: None
#   --- Feedback ---
#     1) Overall Summary:
#     The submission demonstrates a good foundational understanding of early literacy development, particularly phonological awareness. However, it primarily focuses on describing literacy components and lacks the critical evaluation of evidence-based approaches, consideration of diverse learners, and robust research integration expected for a comprehensive analysis.  Expanding on instructional strategies, incorporating diverse learner needs, and integrating more research will significantly strengthen the essay.
#
#     2) Criteria Feedback:
#
#     - Criterion: c1: Understanding of Early Literacy Development
#       Rating: Good
#       Evidence:
#         - "During this foundational period, children typically begin developing core pre-reading skills like phonological awareness, vocabulary knowledge, and an understanding of print concepts."
#         - "Phonological awareness, in particular, is a strong predictor of later reading success."
#         -  "According to Lonigan et al. (2000), this skill emerges gradually, often starting with larger sound chunks...and becoming more refined over time."
#       Improvement Tip: While the description of phonological awareness is strong, briefly explain other components like print awareness and vocabulary development with similar depth and examples.
#
#     - Criterion: c2: Evaluation of Evidence-Based Approaches
#       Rating: Poor
#       Evidence:
#         - The submission does not discuss any specific instructional methods or interventions.
#       Improvement Tip: Introduce and critically evaluate at least two evidence-based approaches for supporting pre-reading skills, such as dialogic reading, shared book reading, or phonemic awareness games.  Explain how these approaches work and why they are effective, citing research to support your claims.
#
#     - Criterion: c3: Consideration of Diversity and Inclusion
#       Rating: Poor
#       Evidence:
#         - The submission does not address diverse learner needs or inclusive practices.
#       Improvement Tip:  Discuss how individual learner differences (e.g., language background, cultural experiences, developmental variations) might influence early literacy development and how instructional approaches can be adapted to support these diverse needs.
#
#     - Criterion: c4: Research Integration and Referencing
#       Rating: Needs Improvement
#       Evidence:
#         - Only one source (Lonigan et al., 2000) is cited.
#         - The context surrounding the citation suggests it is used appropriately, but more sources are needed.
#       Improvement Tip: Integrate more peer-reviewed research articles to support claims about literacy development and the effectiveness of instructional approaches. Ensure all sources are cited correctly throughout the text and included in a complete reference list.
#
#     - Criterion: c5: Structure and Academic Writing
#       Rating: Average
#       Evidence:
#         - The introduction is clear, but the submission lacks a distinct body and conclusion.
#         - The writing is generally clear but uses informal language ("He or she").
#       Improvement Tip:  Organize the essay into distinct sections with a clear introduction, body paragraphs focusing on specific aspects of the prompt (e.g., different instructional approaches), and a concluding paragraph summarizing key points. Maintain a formal academic tone throughout.
#
#     3) Overall Rating: Needs Improvement
#
#   Submission #6:
#   --- Detection ---
#     Label: Human
#     Rationale:
#     - The submission demonstrates a good understanding of early literacy development, but expresses it in simpler terms than typically seen in academic writing.  This suggests a student grappling with the concepts, rather than an AI flawlessly retrieving and presenting information.
#     - The writing exhibits a natural, conversational flow, with observations like "it has been observed" and "most children are able to." This less formal, slightly subjective tone points towards human authorship.
#     - The progression of ideas, while logical, lacks the tight structure and precise vocabulary often found in AI-generated text.  The focus is on conveying general understanding rather than showcasing academic prowess.
#     - The absence of specific citations or detailed examples further suggests a student summarizing their understanding, rather than an AI compiling information from multiple sources.
#     Flags: None
#   --- Feedback ---
#     1) Overall Summary:
#     The submission demonstrates a basic understanding of early literacy development but lacks depth in evaluating evidence-based approaches, considering diversity, and integrating research. While the introduction identifies key pre-reading skills, the essay needs further development to meet the assignment's requirements.  Prioritize expanding on instructional strategies, incorporating diverse learner needs, and including credible research with proper citations.
#
#     2) Criteria Feedback:
#     - c1: Understanding of Early Literacy Development
#         - Rating: Average
#         - Evidence:
#             - "key skills such as phonological awareness, vocabulary, and an understanding of print could be developed much earlier, especially between the ages of 3 and 6."
#             - "children begin to understand that words are made up of sounds."
#             - "They also learn to recognise letters and handle books."
#         - Improvement Tip:  Elaborate on the developmental progression of each pre-reading skill, providing specific examples of how these skills manifest at different ages between 3 and 6.
#
#     - c2: Evaluation of Evidence-Based Approaches
#         - Rating: Poor
#         - Evidence: No evidence-based approaches are discussed.
#         - Improvement Tip: Introduce and critically evaluate at least two evidence-based instructional methods (e.g., dialogic reading, shared book reading) that support pre-reading skills, citing research to support their effectiveness.
#
#     - c3: Consideration of Diversity and Inclusion
#         - Rating: Poor
#         - Evidence: No mention of diversity or inclusion.
#         - Improvement Tip:  Discuss how individual learner differences (linguistic, cultural, developmental) can influence pre-reading development and how instructional approaches can be adapted to meet diverse needs.
#
#     - c4: Research Integration and Referencing
#         - Rating: Poor
#         - Evidence: No research sources are used or cited.
#         - Improvement Tip: Integrate at least three credible academic sources (e.g., peer-reviewed journals, books) to support your claims about early literacy development and evidence-based practices. Ensure accurate and consistent referencing using a standard citation style (e.g., APA).
#
#     - c5: Structure and Academic Writing
#         - Rating: Average
#         - Evidence:
#             - The essay has a basic introductory paragraph.
#             - The writing is relatively clear but lacks a formal academic tone.
#             - No conclusion is present.
#         - Improvement Tip: Develop a more structured essay with distinct introduction, body paragraphs (each focusing on a specific aspect of the prompt), and a concluding paragraph. Maintain a formal academic tone throughout.
#
#     3) Overall Rating: Needs Improvement
#
# --------------------------------------------
# Source : psychology.json
# Domain : Psychology
# Prompt : Critically evaluate the role of cognitive biases in human decision-making. Select at least three cognitive biases (e.g., confirmation bias, anchoring, availability heuristic) and explain how they influence decision-making in real-world scenarios (e.g., healthcare, law, relationships, consumer behavior). Discuss the psychological theories behind them and explore how awareness or mitigation strategies can improve judgment.
# #Subs  : 6
#
#   Submission #1:
#   --- Detection ---
#     Label: AI
#     Rationale:
#     - The text exhibits a highly structured and formulaic presentation of information, typical of AI-generated content.  Each paragraph introduces a bias, provides a brief explanation, and offers a domain-specific example. This consistent pattern lacks the nuances and digressions expected in human writing.
#     - The language used, while academically appropriate, lacks a distinct authorial voice.  It reads as a generalized synthesis of information rather than conveying a unique perspective or argument.
#     Flags: Generic phrasing, predictable structure, lack of authorial voice.
#   --- Feedback ---
#     1) Overall Summary:
#     The submission provides a concise overview of how cognitive biases influence decision-making. It effectively links confirmation bias, anchoring bias, and the availability heuristic to real-world scenarios. However, it needs further development regarding the psychological theories underlying these biases and a more in-depth exploration of mitigation strategies.
#
#     2) Criteria Feedback:
#
#     - Criterion: c1: Conceptual Understanding of Biases
#       Rating: Good
#       Evidence:
#         - Clearly defines confirmation bias, anchoring bias, and availability heuristic.
#         - Provides relevant citations to seminal research (Nickerson, 1998; Tversky & Kahneman, 1974).
#       Improvement Tip: Expand on the psychological theories underpinning each bias. For example, discuss the role of cognitive dissonance in confirmation bias or the dual-process theory in relation to heuristics.
#
#     - Criterion: c2: Application to Real-World Scenarios
#       Rating: Good
#       Evidence:
#         - Links confirmation bias to healthcare, anchoring bias to consumer behavior, and availability heuristic to legal settings.
#       Improvement Tip: Provide more specific examples within each scenario. Instead of stating that anchoring affects consumer behavior, describe a specific instance, like how a high initial price can make a subsequent lower price seem more appealing.
#
#     - Criterion: c3: Critical Evaluation and Mitigation Strategies
#       Rating: Average
#       Evidence:
#         - Mentions mitigation strategies like critical reflection, seeking diverse perspectives, and data-driven tools.
#       Improvement Tip: Develop the discussion of mitigation strategies by explaining how each strategy specifically counteracts the biases discussed. For instance, explain how "seeking diverse perspectives" helps overcome confirmation bias.
#
#     - Criterion: c4: Structure and Academic Writing
#       Rating: Good
#       Evidence:
#         - Well-organized paragraph with clear topic sentences.
#         - Uses appropriate academic tone and correct referencing format.
#       Improvement Tip: While the references are correctly formatted, consider integrating them more smoothly into the text. Instead of just citing the authors, briefly mention the study or its key findings within the sentence.
#
#     3) Overall Rating: Good
#
#   Submission #2:
#   --- Detection ---
#     Label: AI
#     Rationale:
#     - The text exhibits a highly structured and predictable pattern typical of AI-generated content, presenting information about cognitive biases in a formulaic manner.  Each paragraph introduces a bias, provides a brief explanation, and offers a simple example.
#     - The language used is generally academic and lacks specific details or personal insights that would suggest human authorship.  For example, the application of confirmation bias to relationships is quite generic ("overlooking potential red flags").
#     Flags: Generic examples, predictable structure, lack of specific details.
#   --- Feedback ---
#     1) Overall Summary: The submission demonstrates a good understanding of cognitive biases and their application to real-world scenarios.  The chosen examples are relevant, and the theoretical grounding is sound. However, the discussion of mitigation strategies and critical evaluation could be more developed, and the structure, while adequate, could benefit from more explicit transitions between ideas.
#
#     2) Criteria Feedback:
#     - Criterion: c1: Conceptual Understanding of Biases
#       Rating: good
#       Evidence:
#         - Clearly defines confirmation bias, anchoring bias, and availability heuristic.
#         - Correctly links confirmation bias to relationships, anchoring bias to consumer behavior, and availability heuristic to healthcare.
#         - Provides appropriate citations to seminal research (Nickerson, 1998; Tversky & Kahneman, 1974).
#       Improvement Tip: Briefly explain the core psychological theories underpinning each bias, beyond simply naming the researchers.
#
#     - Criterion: c2: Application to Real-World Scenarios
#       Rating: good
#       Evidence:
#         - Provides relevant examples for each bias in different domains (relationships, consumer behavior, healthcare).
#         - Explains the connection between the bias and the scenario in a comprehensible way.
#       Improvement Tip:  Explore the nuances of how these biases manifest in the chosen scenarios. For example, how might anchoring bias affect negotiations beyond initial price setting?
#
#     - Criterion: c3: Critical Evaluation and Mitigation Strategies
#       Rating: average
#       Evidence:
#         - Mentions strategies like "considering alternative perspectives and relying on objective data."
#       Improvement Tip: Expand on the suggested mitigation strategies.  How can individuals actively consider alternative perspectives? What constitutes "objective data" in different contexts, and how can access to it be improved?
#
#     - Criterion: c4: Structure and Academic Writing
#       Rating: good
#       Evidence:
#         - Writing is clear and concise.
#         - Citations are formatted correctly.
#         - Maintains an academic tone.
#       Improvement Tip: Use transition phrases to connect the different sections (e.g., between the explanation of each bias and its real-world application, and between the examples and the mitigation strategies). This will improve the flow and coherence.
#
#     3) Overall Rating: Good
#
#   Submission #3:
#   --- Detection ---
#     Label: AI
#
#     Rationale:
#     - The text exhibits a simplified, generalized explanation of cognitive biases.  It lacks specific, nuanced examples of how these biases manifest in real-world scenarios.  For example, it mentions healthcare and purchases but doesn't elaborate on the *how*.
#     - The language used ("big influence," "first thing we hear or see," "easily we can recall") leans towards informal, conversational style, which is less characteristic of formal academic writing.  This suggests potential AI generation optimized for casual readability.
#     - While coherent, the text follows a predictable structure: introduce bias, give a basic explanation, and suggest general mitigation strategies.  This formulaic approach is common in AI-generated content.
#
#     Flags: Overly simplistic explanations, informal language, predictable structure.
#   --- Feedback ---
#     Overall Summary: The submission provides a concise overview of three cognitive biases and their impact on decision-making.  While it correctly defines and references key biases, it lacks depth in real-world application and mitigation strategies.  Prioritizing the development of these areas will significantly strengthen the analysis.
#
#     Criteria Feedback:
#
#     - Criterion: c1: Conceptual Understanding of Biases
#       Rating: Good
#       Evidence:
#         - Clearly defines confirmation bias, anchoring bias, and availability heuristic.
#         - Provides accurate citations to seminal research.
#       Improvement Tip: Briefly explain the psychological theories underpinning each bias, going beyond just their definitions.
#
#     - Criterion: c2: Application to Real-World Scenarios
#       Description: Applies biases meaningfully to examples from everyday or professional contexts.
#       Rating: Needs_Improvement
#       Evidence:
#         - Mentions healthcare and purchasing decisions but lacks specific examples.
#       Improvement Tip: Develop concrete scenarios illustrating how each bias influences decisions in these contexts. For example, describe how anchoring might affect price negotiations or how the availability heuristic could lead to misdiagnosis in healthcare.
#
#     - Criterion: c3: Critical Evaluation and Mitigation Strategies
#       Rating: Average
#       Evidence:
#         - Mentions strategies like "challenging our own thinking" and "seeking out different viewpoints."
#       Improvement Tip: Elaborate on these strategies and connect them directly to the specific biases discussed.  Explain *how* these strategies mitigate the impact of each bias.
#
#     - Criterion: c4: Structure and Academic Writing
#       Rating: Good
#       Evidence:
#         - Clear and concise writing style.
#         - Correct referencing format.
#       Improvement Tip: While the writing is generally sound, ensure a more formal academic tone throughout. Avoid informal phrases like "has a big influence."
#
#     Overall Rating: Average
#
#   Submission #4:
#   --- Detection ---
#     Label: AI
#     Rationale:
#     - The text exhibits a simplified, generalized explanation of cognitive biases. It uses casual language ("backs up," "first piece of info," "get us to buy things") not typical of formal academic writing.
#     - While the examples provided are relevant, they lack the depth and nuance expected in a sophisticated academic discussion. The example of a judge giving "too much weight to the first testimony" is overly simplistic and lacks specific legal context.
#     - The suggested mitigation strategies ("taking time to reflect or practice mindfulness") are generic and lack the specificity of evidence-based debiasing techniques.
#     Flags: Overly simplistic explanations, casual tone, lack of specific examples, generic mitigation strategies.
#   --- Feedback ---
#     Overall Summary:
#     The submission demonstrates a basic understanding of confirmation bias and anchoring, applying them to relevant real-world scenarios. However, it needs further development in terms of exploring a third bias, elaborating on the psychological theories, and providing more specific mitigation strategies.  The discussion of psychological theories underlying the biases is absent.  Expanding on these areas will significantly strengthen the analysis.
#
#     Criteria Feedback:
#
#     - Criterion: c1: Conceptual Understanding of Biases
#       Rating: Average
#       Evidence:
#         - Defines confirmation bias and anchoring with citations.
#         - Briefly mentions how these biases affect judgment.
#         - Does not discuss the psychological theories behind the biases.
#       Improvement Tip: Incorporate a third cognitive bias and explain the psychological theories underpinning each of the three, referencing relevant research.
#
#     - Criterion: c2: Application to Real-World Scenarios
#       Rating: Good
#       Evidence:
#         - Provides relevant examples in law and consumer behavior.
#         - Clearly links anchoring to marketing strategies.
#         - Could benefit from more detailed explanation of how confirmation bias influences legal decisions.
#       Improvement Tip: Expand on the real-world examples by providing more context and detail, illustrating the step-by-step influence of the bias on decision-making.
#
#     - Criterion: c3: Critical Evaluation and Mitigation Strategies
#       Rating: Needs Improvement
#       Evidence:
#         - Mentions awareness and mindfulness as mitigation strategies.
#         - Lacks specific, actionable strategies related to each bias.
#         - Does not delve into the psychological implications of these strategies.
#       Improvement Tip:  Provide concrete, research-based mitigation strategies for each bias. For example, how can "mindfulness" be practically applied to counter anchoring in consumer decisions?
#
#     - Criterion: c4: Structure and Academic Writing
#       Rating: Good
#       Evidence:
#         - Clear and concise writing style.
#         - Proper referencing using APA style.
#         - Minor improvements could be made to the introductory sentence to make it more engaging.
#       Improvement Tip:  Start with a more compelling hook to draw the reader in and briefly preview the biases to be discussed.
#
#     Overall Rating: Average
#
#   Submission #5:
#   --- Detection ---
#     Label: AI
#
#     Rationale:
#     - The text exhibits generic phrasing ("a lot of reasons," "bad decisions," "flawed thinking") and lacks specific examples, which is characteristic of AI-generated content.
#     - The phrasing "will be able to shape" is unusual and suggests a lack of human nuance in expressing the influence of cognitive biases.
#     - While the submission includes citations, the overall text quality and lack of depth suggest limited human engagement with the material.
#
#     Flags: Generic phrasing, lack of specific examples, unnatural phrasing.
#   --- Feedback ---
#     Overall Summary: The submission demonstrates a basic understanding of cognitive biases and their impact on decision-making. However, it lacks depth in explaining the chosen biases, applying them to real-world scenarios, and exploring mitigation strategies.  The writing also needs improvement in terms of clarity and precision.  Prioritizing detailed explanations and concrete examples will significantly strengthen the analysis.
#
#     Criteria Feedback:
#
#     - Criterion: c1: Conceptual Understanding of Biases
#       Rating: Needs_improvement
#       Evidence:
#         - "Cognitive biases, such as confirmation bias, anchoring, and the availability heuristic, will be able to shape human decision-making by distorting perceptions and judgments based on a lot of reasons." (Vague and lacks specific explanations of each bias)
#         - Mentions prior beliefs, initial information, and recent experiences but doesn't clearly link them to the respective biases.
#       Improvement Tip:  Provide distinct definitions and explanations for confirmation bias, anchoring, and availability heuristic. Elaborate on the underlying psychological mechanisms for each.
#
#     - Criterion: c2: Application to Real-World Scenarios
#       Rating: Poor
#       Evidence:
#         - "These biases manifest in areas like healthcare, law, and consumer behavior, where they can lead to bad decisions and reinforce flawed thinking." (Generic mention of areas without specific examples)
#       Improvement Tip: Develop concrete examples of how each bias influences decision-making in the mentioned areas (healthcare, law, consumer behavior).  Illustrate with clear cause-and-effect scenarios.
#
#     - Criterion: c3: Critical Evaluation and Mitigation Strategies
#       Rating: Average
#       Evidence:
#         - "Awareness of these biases, combined with strategies like critical thinking, counterfactual reasoning, and diverse perspectives, can help mitigate their influence and improve judgment." (Mentions strategies but lacks depth)
#       Improvement Tip:  Explain how each suggested strategy (critical thinking, counterfactual reasoning, diverse perspectives) can specifically counteract the effects of the chosen biases. Provide more detailed and nuanced discussion.
#
#     - Criterion: c4: Structure and Academic Writing
#       Rating: Needs_improvement
#       Evidence:
#         - "will be able to shape" (imprecise phrasing)
#         - "a lot of reasons" (informal language)
#         - The overall flow and connection between ideas could be improved.
#       Improvement Tip: Revise the writing for clarity and precision. Replace vague phrases with more specific language. Ensure a smooth transition between ideas and maintain a formal academic tone.
#
#     Overall Rating: Needs Improvement
#
#   Submission #6:
#   --- Detection ---
#     Label: AI
#
#     Rationale:
#     - The text exhibits a highly structured and formulaic presentation of information characteristic of AI-generated content.  It efficiently summarizes key concepts but lacks depth or nuanced discussion.
#     - The language used is generally sterile and lacks the kind of specific examples or personal insights that would be expected in human-written academic work.  Phrases like "bad choices or judgments" are vague and simplistic.
#     - While grammatically correct, the writing lacks stylistic flair and reads as a compilation of generic statements about cognitive biases.
#
#     Flags: Overly concise and generalized language, lack of specific examples, formulaic structure.
#   --- Feedback ---
#     Overall Summary: The submission demonstrates a basic understanding of cognitive biases and their impact on decision-making. However, it lacks depth in explaining the chosen biases, applying them to real-world scenarios, and exploring mitigation strategies.  The essay needs significant expansion to meet the assignment's requirements.  Prioritize developing specific examples and exploring mitigation techniques in more detail.
#
#     Criteria Feedback:
#
#     - Criterion: c1: Conceptual Understanding of Biases
#       Rating: Average
#       Evidence:
#         - Defines three common cognitive biases: confirmation bias, anchoring, and availability heuristic.
#         - Provides citations for confirmation bias and anchoring.
#         - Briefly mentions how biases "lead individuals to rely on biased information or patterns."
#       Improvement Tip: Expand on the theoretical foundations of each bias.  Explain *how* they work, not just *what* they are. For example, describe the underlying cognitive processes involved in the availability heuristic.
#
#     - Criterion: c2: Application to Real-World Scenarios
#       Rating: Needs Improvement
#       Evidence:
#         - Mentions relevant areas like healthcare, law, and consumer behavior but doesn't provide specific examples.
#         - States biases "often result in bad choices or judgments" without illustrating how.
#       Improvement Tip: Develop concrete examples of how each bias plays out in real-world situations. For instance, describe how confirmation bias might influence a doctor's diagnosis or a consumer's purchasing decision.
#
#     - Criterion: c3: Critical Evaluation and Mitigation Strategies
#       Rating: Average
#       Evidence:
#         - Lists some mitigation strategies: "reflective thinking, seeking diverse viewpoints, and promoting awareness of cognitive distortions."
#       Improvement Tip: Elaborate on the suggested mitigation strategies. Explain how they work to counteract specific biases.  For example, how does "seeking diverse viewpoints" help mitigate confirmation bias?
#
#     - Criterion: c4: Structure and Academic Writing
#       Rating: Good
#       Evidence:
#         - The writing is generally clear and concise.
#         - Includes two relevant academic references with correct formatting.
#         - Tone is appropriate for an academic submission.
#       Improvement Tip: While the current structure is acceptable for a short summary, it will need to be expanded with distinct paragraphs for each bias, its theoretical background, real-world applications, and mitigation strategies.
#
#     Overall Rating: Needs Improvement
#
# --------------------------------------------
# Source : it.json
# Domain : Information Technology
# Prompt : In a few sentences, examine the role of Artificial Intelligence in modern cybersecurity, providing examples of its applications and potential risks.
# #Subs  : 6
#
#   Submission #1:
#   --- Detection ---
#     Label: AI
#
#     Rationale:
#     - The text exhibits a high level of technical precision and uses industry-specific terminology (e.g., "SIEM systems," "rule-based systems") characteristic of AI-generated content on technical topics.
#     - The writing is concise, focused, and lacks any personal anecdotes, opinions, or digressions that would suggest human authorship.  It reads like a well-structured overview or summary.
#     - The text uses common AI-generated phrasing patterns like "plays a pivotal role" and "identifying anomalies or malicious patterns."
#
#     Flags: Generic language, lack of specific examples, overly concise and polished style.
#   --- Feedback ---
#     1) Overall Summary:
#     The submission demonstrates a good foundational understanding of AI's role in cybersecurity and provides a relevant example. However, it lacks depth in exploring real-world applications, critical analysis of potential risks, and original insights.  The response would benefit from expanding on the mentioned applications and addressing potential downsides of using AI in cybersecurity.
#
#     2) Criteria Feedback:
#
#     - Criterion: c1: Understanding of Topic
#       Rating: Good
#       Evidence:
#         - "Artificial Intelligence plays a pivotal role in modern cybersecurity by automating threat detection, enhancing incident response, and reducing false positives in Security Information and Event Management (SIEM) systems."
#       Improvement Tip: Briefly define AI and machine learning in the context of cybersecurity to further solidify your understanding.
#
#     - Criterion: c2: Application to Real-World Context
#       Rating: Average
#       Evidence:
#         - "Machine learning algorithms can analyze massive datasets in real-time, identifying anomalies or malicious patterns that traditional rule-based systems may overlook."
#       Improvement Tip: Provide a specific example of a real-world cybersecurity scenario where AI is applied, such as malware detection or phishing email identification.  Detail how AI is used in that specific scenario.
#
#     - Criterion: c3: Critical Thinking and Insight
#       Rating: Needs Improvement
#       Evidence:
#         - The submission primarily focuses on the positive aspects of AI in cybersecurity.
#       Improvement Tip: Discuss potential risks or challenges associated with using AI in cybersecurity, such as adversarial attacks or the dependence on high-quality data.
#
#     - Criterion: c4: Originality and Perspective
#       Rating: Needs Improvement
#       Evidence:
#         - The response provides a general overview of AI's role.
# ...
#
#
#     3) Overall Rating: Good
#
#   Submission #2:
#   --- Detection ---
#     Label: AI
#
#     Rationale:
#     - The text exhibits a highly structured and formulaic presentation characteristic of AI-generated content.  It follows a predictable pattern of introducing a concept, explaining its benefits, providing examples, and then briefly mentioning challenges.
#     - The language, while sophisticated, lacks a distinct authorial voice or perspective. It reads as a generalized overview compiled from various sources rather than a nuanced argument developed by a human writer.
#     - The examples, while relevant, are presented superficially, lacking the depth of analysis or critical evaluation that would be expected in a student-written essay.  They serve more as illustrative points than as evidence integrated into a larger argument.
#
#     Flags: Generic phrasing ("transformative effects," "significant improvements"), lack of specific detail or original analysis, predictable structure.
#   --- Feedback ---
#     1) Overall Summary:
#     The submission demonstrates a good understanding of blockchain and its potential impact on accounting.  The student effectively links key blockchain concepts to accounting practices and provides a relevant example.  However, further analysis of the challenges and a more structured approach would strengthen the argument.
#
#     2) Criteria Feedback:
#
#     - Criterion: c1: Understanding of Blockchain Concepts
#       Rating: good
#       Evidence:
#         - "Blockchain technology, defined by its decentralization, immutability, and transparency, is revolutionizing traditional accounting practices..."
#         - "Its core principles—decentralized ledgers, immutable records, and smart contracts—enable significant improvements..."
#       Improvement Tip: Briefly explain *how* decentralization, immutability, and smart contracts specifically relate to accounting improvements (e.g., how immutability improves audit trails).
#
#     - Criterion: c2: Analysis of Accounting Impact
#       Rating: average
#       Evidence:
#         - "Blockchain’s immutability ensures financial records are tamper-proof, creating reliable audit trails..."
#         - "Smart contracts automate tasks like invoicing or reconciliation, reducing manual errors..."
#       Improvement Tip:  Go beyond stating the benefits and analyze the *implications* of these changes. For example, how does real-time reporting impact regulatory compliance or investor relations?  Also, discuss potential challenges of blockchain adoption in accounting.
#
#     - Criterion: c3: Use of Real-World Examples/Case Studies
#       Rating: good
#       Evidence:
#         - "For instance, Ernst & Young (EY) employs its Blockchain Analyzer to audit cryptocurrency transactions..."
#         - "IBM’s blockchain-based supply chain financing, which minimizes reporting delays."
#       Improvement Tip: Briefly elaborate on the cited examples, providing more context on how they function and the specific benefits achieved.
#
#     - Criterion: c4: Structure and Academic Style
#       Rating: average
#       Evidence:
#         - The introduction and conclusion are concise.
#         - The overall flow is logical.
#         - The tone is generally academic, but could be more formal.
#       Improvement Tip: Use headings and subheadings to organize the essay more clearly.  Expand the conclusion to summarize key arguments and offer a final thought.
#
#     3) Overall Rating: Good
#
#   Submission #3:
#   --- Detection ---
#     Label: Human
#     Rationale:
#     - The text exhibits a clear personal voice and perspective ("As a business student fascinated by tech, I see...").  It integrates personal experience and observation into the discussion.
#     - The writing demonstrates a nuanced understanding of blockchain's potential and limitations, acknowledging both the benefits and drawbacks. This balanced perspective is less common in purely AI-generated text.
#     - The essay incorporates specific examples and name-drops companies like IBM and Deloitte, but does so in a way that feels organic and supports the arguments, rather than simply listing examples for the sake of it.  The "garbage in, garbage out" analogy and reference to a 2023 study further contribute to the impression of human input.
#     Flags: None
#   --- Feedback ---
#     1) Overall Summary:
#     The submission demonstrates a good understanding of blockchain's potential impact on accounting, providing relevant examples and touching upon key benefits. However, it needs further development in terms of fully exploring the core concepts of blockchain and presenting a more structured, academic argument.  Prioritizing a deeper explanation of concepts like immutability and smart contracts, along with a more formal tone, would significantly enhance the analysis.
#
#     2) Criteria Feedback:
#
#     - Criterion: c1: Understanding of Blockchain Concepts
#       Rating: Good
#       Evidence:
#         - "decentralized, tamper-proof ledger"
#         - "distributed ledger ensures accuracy"
#         - Mentions "triple-entry" system.
#       Improvement Tip: Explicitly define and explain key terms like immutability and smart contracts, relating them to accounting processes.
#
#     - Criterion: c2: Analysis of Accounting Impact
#       Rating: Good
#       Evidence:
#         - Discusses benefits for bookkeeping, auditing, and financial reporting.
#         - Mentions "reduced errors and fraud," "faster, cheaper audits," and "real-time updates."
#         - Acknowledges challenges like "garbage in, garbage out."
#       Improvement Tip: Expand on the challenges of blockchain implementation in accounting, exploring issues like regulatory uncertainty and scalability.
#
#     - Criterion: c3: Use of Real-World Examples/Case Studies
#       Rating: Good
#       Evidence:
#         - Mentions IBM's use in supply chain finance.
#         - Cites Deloitte's testing of blockchain for auditing.
#         - Refers to a 2023 study (though unspecified).
#       Improvement Tip: Provide more details about the cited examples and the 2023 study, including specific outcomes or findings.
#
#     - Criterion: c4: Structure and Academic Style
#       Rating: Needs Improvement
#       Evidence:
#         - While the essay flows logically, the tone is conversational (e.g., "As a business student fascinated by tech," "It’s a trust-building tool").
#         - Lacks formal headings or sub-sections.
#       Improvement Tip: Adopt a more formal, objective tone throughout the essay and use headings to structure the analysis more clearly.
#
#     3) Overall Rating: Good
#
#   Submission #4:
#   --- Detection ---
#     Label: Human
#
#     Rationale:
#     - The text exhibits a strong personal voice and perspective ("As a business student fascinated by tech, I see...").  This suggests genuine human engagement with the topic.
#     - The writing includes nuanced arguments, acknowledging both the potential and limitations of blockchain in accounting ("blockchain’s only as good as the data entered," "It’s more of a complementary tool..."). This balanced perspective is less characteristic of typical AI-generated text.
#     - The text uses casual and idiomatic language ("here’s the catch," "slashing time and costs") which contributes to a natural, conversational tone.  This is more indicative of human writing.
#
#     Flags: None
#   --- Feedback ---
#     1) Overall Summary:
#     The submission demonstrates a good understanding of blockchain and its potential impact on accounting.  The student provides relevant examples and identifies key benefits like increased transparency and automation. However, further analysis of the challenges and a more structured approach would strengthen the argument.
#
#     2) Criteria Feedback:
#     - Criterion: c1: Understanding of Blockchain Concepts
#       Rating: good
#       Evidence:
#         - "Blockchain’s decentralized, tamper-proof ledger records transactions transparently, reducing errors in bookkeeping."
#         - "Unlike traditional double-entry systems, blockchain’s “triple-entry” approach creates a verifiable, shared record, cutting down on manual reconciliations."
#       Improvement Tip: Briefly explain the concept of immutability and its implications for audit trails.
#
#     - Criterion: c2: Analysis of Accounting Impact
#       Rating: good
#       Evidence:
#         - "Auditing could be revolutionized too. Real-time access to immutable records means auditors can verify transactions faster, slashing time and costs."
#         - "Financial reporting might shift to real-time with blockchain, giving stakeholders instant insights into a company’s finances, potentially boosting market transparency."
#       Improvement Tip:  Deepen the analysis by discussing the potential impact on internal controls and risk management.
#
#     - Criterion: c3: Use of Real-World Examples/Case Studies
#       Rating: good
#       Evidence:
#         - "For example, companies like IBM use blockchain for supply chain finance, automating transaction entries."
#         - "Firms like Deloitte are testing this, showing promising results."
#       Improvement Tip: Provide more context around the IBM and Deloitte examples, explaining how blockchain is specifically applied in those cases.
#
#     - Criterion: c4: Structure and Academic Style
#       Rating: average
#       Evidence:
#         - While the essay flows logically, the tone is slightly informal (e.g., "But here’s the catch").
#         - The introduction and conclusion could be more concise and impactful.
#       Improvement Tip:  Adopt a more formal tone throughout the essay and revise the introduction to clearly state the argument.  Strengthen the conclusion by summarizing the key findings and implications.
#
#
#     3) Overall Rating: Good
#
#   Submission #5:
#   --- Detection ---
#     Label: AI
#
#     Rationale:
#     - The text exhibits a highly structured and formulaic presentation of information characteristic of AI-generated content.  It systematically lays out the benefits and challenges of blockchain in accounting, following a predictable pattern.
#     - While the information is generally accurate, it lacks depth and specific, real-world examples.  The references to applications are generic (e.g., "streamlines processes like accounts payable and receivable") without concrete illustrations.
#     - The text maintains a consistently formal and objective tone, devoid of any personal insights or subjective perspectives, which is common in AI-generated text.
#
#     Flags: Lacks specific examples; overly structured; consistently formal tone.
#   --- Feedback ---
#     1) Overall Summary: The submission demonstrates a good understanding of blockchain's impact on accounting, highlighting key benefits like enhanced transparency and automation.  While it touches upon real-world implications, providing more concrete examples would strengthen the analysis.  The writing is well-structured and maintains an academic tone.  Focusing on developing more specific examples and addressing the associated challenges in greater depth would elevate the analysis.
#
#     2) Criteria Feedback:
#     - Criterion: c1: Understanding of Blockchain Concepts
#       Rating: good
#       Evidence:
#         - "decentralized, immutable ledger ensures real-time, tamper-proof transaction records"
#         - "automates bookkeeping through smart contracts"
#       Improvement Tip: Expand on the concept of smart contracts and their specific applications within accounting processes beyond automation.
#
#     - Criterion: c2: Analysis of Accounting Impact
#       Rating: good
#       Evidence:
#         - "reducing errors and fraud"
#         - "simplifying the audit trail"
#         - "faster reporting cycles and reduces discrepancies"
#       Improvement Tip:  Deepen the analysis by discussing the specific challenges of blockchain implementation in accounting, such as data privacy, standardization, and regulatory hurdles.
#
#     - Criterion: c3: Use of Real-World Examples/Case Studies
#       Rating: needs_improvement
#       Evidence:
#         - The submission lacks concrete real-world examples or case studies.
#       Improvement Tip: Incorporate at least one specific example of a company using blockchain for accounting or auditing, detailing the implementation and outcomes.  For instance, discuss a supply chain application using blockchain for inventory tracking and its impact on financial reporting.
#
#     - Criterion: c4: Structure and Academic Style
#       Rating: excellent
#       Evidence:
#         - The essay is well-organized with a clear introduction and logical flow of ideas.
#         - The language is consistently formal and academic.
#       Improvement Tip: While the structure is sound, consider adding headings or subheadings to further enhance readability, especially for longer analyses.
#
#     3) Overall Rating: Good
#
#   Submission #6:
#   --- Detection ---
#     Label: AI
#
#     Rationale:
#     - The text exhibits a highly structured and formulaic presentation of information characteristic of AI-generated content.  It efficiently covers key aspects of blockchain in accounting but lacks a nuanced or critical perspective.
#     - The language, while grammatically correct, leans towards generic phrasing ("significantly transforms," "enhancing efficiency, transparency, and security") and lacks specific, real-world examples to support its claims.  While it mentions challenges, it doesn't delve into the complexities of these challenges.
#     - The text maintains a consistent, objective tone throughout, devoid of any personal insights or subjective interpretations, which is common in AI-generated text.
#
#     Flags: Lacks depth, overly general, formulaic presentation.
#   --- Feedback ---
#     1) Overall Summary:
#     The submission demonstrates a good understanding of blockchain's impact on accounting, highlighting key benefits like enhanced transparency and automation in auditing and financial reporting.  While the core concepts are addressed, incorporating specific examples and refining the structure would strengthen the analysis.  Addressing the identified challenges with more depth would also improve the submission.
#
#     2) Criteria Feedback:
#
#     - Criterion: c1: Understanding of Blockchain Concepts
#       Rating: good
#       Evidence:
#         - "decentralized, immutable ledger ensures real-time, tamper-proof recording of transactions"
#         - "Smart contracts automate routine tasks, such as invoice settlements"
#       Improvement Tip: Explicitly define decentralization, immutability, and smart contracts before discussing their applications.
#
#     - Criterion: c2: Analysis of Accounting Impact
#       Rating: good
#       Evidence:
#         - "In financial reporting, blockchain enables automated, accurate data aggregation, streamlining processes like reconciliation"
#         - "In auditing, blockchain shifts the focus from sample-based verification to comprehensive, real-time data analysis."
#       Improvement Tip: Explore the challenges of blockchain implementation in accounting in more detail, such as data privacy concerns and the need for new regulatory frameworks.
#
#     - Criterion: c3: Use of Real-World Examples/Case Studies
#       Rating: poor
#       Evidence:
#         - No specific examples provided.
#       Improvement Tip: Incorporate at least one real-world example of blockchain application in accounting or finance, such as a company using blockchain for supply chain management or a pilot program for blockchain-based auditing.
#
#     - Criterion: c4: Structure and Academic Style
#       Rating: average
#       Evidence:
#         - The introduction and conclusion are present, but the overall structure could be improved with clearer headings and sub-sections.
#         - The tone is generally academic, but some phrasing could be more formal.
#       Improvement Tip: Use headings and subheadings to organize the essay more clearly and ensure a consistent formal tone throughout.  For example, create separate sections for the impact on auditing, financial reporting, and challenges.
#
#     3) Overall Rating: Good
