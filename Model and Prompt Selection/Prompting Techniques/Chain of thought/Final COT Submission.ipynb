# %% [markdown]
# # Gemini 1.5 -flash Academic Integrity & Feedback Script (Chain-of-Thought)

# %% [markdown]
# ## Overview
# This notebook processes five domain datasets, generates rubric-aligned feedback, and performs AI/Human/Hybrid detection with Chain-of-Thought prompting and voting. CoT allows the AI to reason step-by-step before giving final structured output.

# %% [markdown]
# ## Setup & Dependencies
#
# Install and import the required Python libraries and the Google GenAI SDK for API access, JSON handling, and data processing.

# %%
# --- Setup & dependencies ---
# pip install -U google-genai
# Environment: export GEMINI_API_KEY="YOUR_KEY"

import os, json, re
from typing import List, Dict, Any, Optional
from google import genai
from google.genai import types
from collections import Counter

# %% [markdown]
# ## Configuration
#
# Define dataset file paths and maximum few-shot examples.

# %%
# -----------------------------
# CONFIG
# -----------------------------
DATASETS = [
    "engineering.json",
    "accounting.json",
    "it.json",
    "psychology.json",
    "teaching.json"
]
MAX_EXAMPLES = 3

# %% [markdown]
# ## Initialize Gemini
#
# Set up the Gemini API client and select the model.

# %%
# -----------------------------
# Initialize Gemini
# -----------------------------
client = genai.Client(api_key="AIzaSyCRZq_vYZ2cxJEH__NFcdPChTR-4lIrAUw")
GEMINI_MODEL = "gemini-1.5-flash"

# %% [markdown]
# ## Output Sanitizers & Parsers
#
# Functions to clean AI outputs and enforce structured format

# %%
# Output sanitizers & parsers
# -----------------------------
_LEAK_PAT = re.compile(
    r"(?im)^(?:reasoning|hidden reasoning|internal reasoning|analysis|"
    r"chain[- ]?of[- ]?thought|scratchpad|thought process)\s*:.*?$"
)

def _strip_leaks(txt: str) -> str:
    return _LEAK_PAT.sub("", txt)

def enforce_detection_format(txt: str) -> str:
    txt = _strip_leaks(txt).strip()
    if "Label:" not in txt:
        txt = "Label: Unknown\n" + txt
    if "Confidence:" not in txt:
        txt += "\nConfidence: 0.50"
    if "Rationale:" not in txt:
        txt += "\nRationale:\n- concise point\n- concise point"
    if "Flags:" not in txt:
        txt += "\nFlags: none"
    if "Diagnostics:" not in txt:
        txt += (
            "\nDiagnostics:\n"
            "- style_repetitiveness: medium\n"
            "- predictability_cues: some\n"
            "- structure_artifacts: some\n"
            "- perturbation_note: not checked"
        )
    return txt.strip()

_det_label_re = re.compile(r"(?im)^Label:\s*(.*)$")
_det_conf_re  = re.compile(r"(?im)^Confidence:\s*([01](?:\.\d+)?)")
_det_flags_re = re.compile(r"(?im)^Flags:\s*(.*)$")

def parse_detection_blocks(txt: str) -> Dict[str, Any]:
    label, conf, flags = None, None, None
    m = _det_label_re.search(txt)
    if m: label = m.group(1).strip()
    m = _det_conf_re.search(txt)
    if m:
        try:
            conf = float(m.group(1))
        except:
            conf = None
    m = _det_flags_re.search(txt)
    if m: flags = m.group(1).strip()
    return {"label": label, "confidence": conf, "flags": flags, "raw": txt}

# %% [markdown]
# ## Chat Rendering
#
# Format system, user, and assistant messages for Gemini.

# %%
# Chat rendering
# -----------------------------
SYSTEM_PROMPT = (
    "You are a careful academic assistant. Use internal reasoning but never reveal it. "
    "Only output the requested final structured sections (not JSON, not CSV, no files)."
)

def render_chat(system: str, user: str) -> str:
    return f"[SYSTEM] {system}\n[USER] {user}\n[ASSISTANT]"

# %%
# Rubric formatting
# -----------------------------
def format_rubric(r: Dict[str,Any]):
    formatted, names = [], []
    formatted.append(f"Rubric ID: {r.get('rubric_id', 'N/A')}\n")
    formatted.append("Criteria:\n")
    for item in r.get('criteria', []):
        nm = item.get('name', 'Criterion')
        names.append(nm)
        formatted.append(f"Criterion: {item.get('criterion_id','')}\nName: {nm}\nDescription: {item.get('description','')}\nPerformance Descriptors:\n")
        for key, val in item.get('performance_descriptors', {}).items():
            formatted.append(f"  - {key}: {val}\n")
    return "".join(formatted), names

# %% [markdown]
# ## Few-Shots Helper
#
# Select representative examples from Human, AI, and Hybrid labels.

# %%
# Few-shots helper
# -----------------------------
def pick_few_shots(subs: List[Dict[str,Any]], max_examples:int=3) -> List[Dict[str,Any]]:
    """
    Prioritize one example from each label (Human, AI, Hybrid) if available, then fill up.
    """
    buckets = {"Human": [], "AI": [], "Hybrid": []}
    for s in subs:
        label = str(s.get("label_type", "")).strip()
        if label in buckets:
            buckets[label].append(s)
    shots: List[Dict[str,Any]] = []
    for lbl in ["Human","AI","Hybrid"]:
        if buckets[lbl]:
            shots.append(buckets[lbl][0])
    for s in subs:
        if len(shots) >= max_examples:
            break
        if s not in shots:
            shots.append(s)
    return shots[:max_examples]

# %% [markdown]
# ## Feedback Prompt (Chain-of-Thought)
#
# Prompt the model to reason step-by-step before giving structured feedback.

# %%
# Feedback prompt
# -----------------------------
def build_feedback_prompt(domain: str, assignment_prompt: str, rubric_text: str,
                          submission: str, criterion_names: Optional[List[str]] = None) -> str:
    crit_block = ""
    if criterion_names:
        crit_lines = [f"- {n}" for n in criterion_names]
        crit_block = "Criteria List:\n" + "\n".join(crit_lines) + "\n"
    user_block = f"""
You are a supportive assessor. 
Think step by step about the rubric, the domain, and the student’s submission before producing feedback.  
Internally, perform the following reasoning process (do not show this reasoning in your final output):  
1. Understand assignment context (domain, goals)  
2. Map submission to rubric descriptors  
3. Identify strengths (align with "excellent" or "good")  
4. Identify weaknesses (gaps, misalignments)  
5. Select concrete evidence from text  
6. Suggest actionable, domain-relevant improvements  
7. Ensure tone is constructive, professional, encouraging  
Final output ONLY in this structure (no extra text):
1) Overall Summary: 2–4 sentences  
2) Criteria Feedback:
{('   (cover each criterion listed below)\n' + crit_block) if crit_block else ''}
   - Criterion  
   - Rating (excellent, good, average, needs_improvement, poor)  
   - Evidence (1–3 bullet points tied to submission)  
   - Improvement Tip (1 concrete step)  
3) Suggested Grade (optional)  
DOMAIN:
{domain}
ASSIGNMENT:
{assignment_prompt}
Rubric (verbatim):
{rubric_text}
Student submission:
\"\"\"{submission}\"\"\""""
    return render_chat(SYSTEM_PROMPT, user_block)

# %% [markdown]
# ## Detection Prompt (Chain-of-Thought)
#
# Prompt the model to reason before deciding Human, AI, or Hybrid.

# %%
# Detection prompt
# -----------------------------
def build_detection_prompt(submission: str, few_shots: List[Dict[str, Any]] = None) -> str:
    examples_block = "/* no examples available */"
    if few_shots:
        shot_texts = []
        for s in few_shots:
            fs_txt = s.get("final_submission", "")
            fs_lbl = s.get("label_type", "Unknown")
            shot_texts.append(
                f'Submission: """{fs_txt}"""\n'
                f'Notes:\n- lexical diversity\n- predictability/artifacts\n- overall evidence\n'
                f'Label: {fs_lbl}\n'
            )
        examples_block = "\n\n".join(shot_texts)

    user_block = f"""
You are an AI text-source classifier for academic integrity.
Internally, think step by step, but only output the final structured result.
Final output ONLY in this structure (no extra commentary):
Label: Human | AI | Hybrid
Confidence: 0.00–1.00
Rationale:
- concise point 1
- concise point 2
Flags: style_inconsistency / high_verbatim / generic_phrasing / none
Diagnostics:
- style_repetitiveness: low|medium|high
- predictability_cues: none|some|strong
- structure_artifacts: none|some|strong
- perturbation_note: one sentence summary
Few-shot exemplars:
{examples_block}
NEW submission:
\"\"\"{submission}\"\"\""""
    return render_chat(SYSTEM_PROMPT, user_block)

# %% [markdown]
# ## Generation Utility
#
# Call Gemini API to generate text based on the prompt.

# %%
# Generation utility
# -----------------------------
def gen_text(prompt_str: str, max_new_tokens=512, temperature: Optional[float]=None):
    cfg = types.GenerateContentConfig(
        temperature=temperature if temperature is not None else 0.5,
        max_output_tokens=max_new_tokens,
    )
    resp = client.models.generate_content(
        model=GEMINI_MODEL,
        contents=prompt_str,
        config=cfg,
    )
    return (resp.text or "").strip()

# %% [markdown]
# ## Self-Consistency Voting
#
# Run multiple passes and aggregate results for reliability.

# %%
# Self-consistency voting
# -----------------------------
def detect_with_votes(submission: str, few_shots: List[Dict[str,Any]], k: int = 3):
    votes = []
    for j in range(k):
        prompt = build_detection_prompt(submission, few_shots=few_shots)
        raw = gen_text(prompt, max_new_tokens=384, temperature=0.3)
        norm = enforce_detection_format(raw)
        parsed = parse_detection_blocks(norm)
        votes.append(parsed)

    labels = [v.get("label","").lower() for v in votes if v.get("label")]
    confs = [v.get("confidence") for v in votes if isinstance(v.get("confidence"), (int,float))]

    majority = "unknown"
    if labels:
        c = Counter(labels)
        top_label, top_count = c.most_common(1)[0]
        if "ai" in c and "human" in c and abs(c["ai"] - c["human"]) <= 1:
            majority = "hybrid"
        else:
            majority = top_label
    mean_conf = round(sum(confs)/len(confs), 3) if confs else None
    return {"votes": votes, "majority_label": majority.capitalize(), "mean_confidence": mean_conf}

# %% [markdown]
# ## Main Loop – Process 5 Datasets
#
# Load datasets, generate CoT feedback, and detect AI/Human/Hybrid submissions.

# %%
# MAIN LOOP – process 5 datasets
# -----------------------------
if __name__ == "__main__":
    for dataset in DATASETS:
        with open(dataset, encoding="utf-8") as f:
            data = json.load(f)
        rubric_text, criterion_names = format_rubric(data['rubric'])
        few_shots = pick_few_shots(data['submissions'], MAX_EXAMPLES)

        print(f"\n================= Processing {dataset} =================")

        for i, submission in enumerate(data['submissions'], 1):
            submission_text = submission['final_submission']
            label_type = submission.get("label_type", "Unknown")

            # Generate rubric-aligned feedback
            feedback_prompt = build_feedback_prompt(
                domain=data['domain'],
                assignment_prompt=data.get("prompt", "Analyze student submission"),
                rubric_text=rubric_text,
                submission=submission_text,
                criterion_names=criterion_names
            )
            feedback_response = gen_text(feedback_prompt, max_new_tokens=768, temperature=0.5)

            # Run AI Detection with voting
            det_result = detect_with_votes(submission_text, few_shots, k=3)

            # Print results
            print(f"\n--- SUBMISSION {i} (True Label: {label_type}) ---")
            print("\n--- RUBRIC-ALIGNED FEEDBACK ---\n")
            print(feedback_response)
            print("\n--- ACADEMIC INTEGRITY DETECTION ---\n")
            print(f"Majority Label: {det_result['majority_label']}")
            print(f"Mean Confidence: {det_result['mean_confidence']}")
            for v in det_result['votes']:
                print(f"- Vote: {v['label']} (conf={v['confidence']})")
# Out:
# ================= Processing engineering.json =================
#
# --- SUBMISSION 1 (True Label: AI) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# 1) Overall Summary:
# This submission provides a good overview of setting up a basic production line.  The student demonstrates a solid understanding of key phases and considerations, including equipment selection, layout optimization, and safety protocols.  However, the response could benefit from more specific examples and a deeper exploration of certain analytical aspects.
#
# 2) Criteria Feedback:
#    - Criterion: Scope & Comprehensiveness
#    - Rating: good
#    - Evidence:
#      - Covers all major phases from design to final assembly.
#      - Addresses equipment, efficiency, and safety considerations.
#      - Mentions key tools and methodologies (process flow diagrams, value stream maps, FMEA).
#    - Improvement Tip: Include a brief example of a specific product and how these phases would be applied.
#
#    - Criterion: Technical Acumen
#    - Rating: good
#    - Evidence:
#      - Accurately uses manufacturing engineering terminology (takt time, OEE, Kaizen, 5S).
#      - Demonstrates understanding of key concepts (line balancing, U-cell layout).
#      - Shows awareness of relevant tools and techniques (CAD software, FMEA).
#    - Improvement Tip: Elaborate on the specific calculations or analyses involved in determining takt time or OEE for a realistic scenario.
#
#    - Criterion: Clarity & Structure
#    - Rating: good
#    - Evidence:
#      - Presents a logical sequence of steps in production line setup.
#      - Uses clear and concise language.
#      - The explanation is easy to follow.
#    - Improvement Tip:  Add transitional sentences to improve the flow between paragraphs, particularly between equipment selection and layout optimization.
#
#    - Criterion: Depth of Analysis
#    - Rating: average
#    - Evidence:
#      - Mentions efficiency and safety but lacks specific examples of how these were addressed in a real-world scenario.
#      - Justification for design choices is limited.
#      - Could benefit from deeper discussion of specific equipment choices.
#    - Improvement Tip: Provide a specific example of an efficiency improvement strategy implemented and its impact on the production line.
#
#    - Criterion: Language & Presentation
#    - Rating: excellent
#    - Evidence:
#      - Writing is clear, concise, and professional.
#      - No grammatical errors are present.
#      - Uses precise language appropriate for the domain.
#    - Improvement Tip: Maintain this high standard of writing.
#
#
# 3) Suggested Grade (optional): B
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Majority Label: Ai
# Mean Confidence: 0.95
# - Vote: AI (conf=0.95)
# - Vote: AI (conf=0.95)
# - Vote: AI (conf=0.95)
#
# --- SUBMISSION 2 (True Label: AI) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# 1) Overall Summary:
# The student submission provides a good overview of setting up a manufacturing production line.  It covers key phases from design to assembly, incorporating equipment selection, efficiency considerations, and safety protocols. While the explanation is clear and well-structured, expanding on specific examples and deeper analysis of efficiency metrics would enhance the response.
#
#
# 2) Criteria Feedback:
#    - Criterion: Scope & Comprehensiveness
#    - Rating: good
#    - Evidence:
#      - Covers all major phases from design to final assembly.
#      - Addresses equipment selection, efficiency, and safety.
#      - Could include more detail on specific equipment or processes.
#    - Improvement Tip:  Provide a specific example of a production line layout, including the type and placement of machinery for a particular product.
#
#    - Criterion: Technical Acumen
#    - Rating: good
#    - Evidence:
#      - Demonstrates understanding of key concepts like takt time and line balancing.
#      - Mentions relevant safety standards (OSHA).
#      - Could benefit from more precise terminology and deeper explanation of certain techniques.
#    - Improvement Tip: Define and explain in more detail one or two key manufacturing engineering terms used (e.g., takt time, line balancing).
#
#    - Criterion: Clarity & Structure
#    - Rating: good
#    - Evidence:
#      - Presents a logical step-by-step approach.
#      - Easy to follow and understand.
#      - Could benefit from more detailed transitions between steps.
#    - Improvement Tip: Use clear headings or subheadings to separate different phases of the production line setup.
#
#    - Criterion: Depth of Analysis
#    - Rating: average
#    - Evidence:
#      - Mentions efficiency metrics but lacks specific examples.
#      - Briefly addresses safety but doesn't delve into specific measures.
#      - Explanation of decision-making processes could be more detailed.
#    - Improvement Tip: Provide a specific example of how efficiency was improved or a safety hazard was mitigated during the setup process.
#
#    - Criterion: Language & Presentation
#    - Rating: excellent
#    - Evidence:
#      - Writing is clear, concise, and professional.
#      - Free of grammatical errors.
#      - Uses precise language appropriate for the domain.
#    - Improvement Tip:  No specific improvement needed.
#
#
# 3) Suggested Grade (optional):  B+
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Majority Label: Ai
# Mean Confidence: 0.95
# - Vote: AI (conf=0.95)
# - Vote: AI (conf=0.95)
# - Vote: AI (conf=0.95)
#
# --- SUBMISSION 3 (True Label: Human) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# 1) Overall Summary:
# The student's submission provides a reasonable overview of setting up a basic production line.  It touches upon key stages, from design analysis to testing, and incorporates elements of efficiency and safety. However, the explanation lacks depth and specific examples, limiting the overall impact.
#
#
# 2) Criteria Feedback:
#    - Criterion: Scope & Comprehensiveness
#    - Rating: good
#    - Evidence:
#      - Covers the main phases from design to testing.
#      - Mentions equipment layout, efficiency, and safety considerations.
#      - However, lacks detailed explanation of each phase.
#    - Improvement Tip: Expand on each step with specific examples of equipment, processes, and metrics used.
#
#    - Criterion: Technical Acumen
#    - Rating: average
#    - Evidence:
#      - Uses general manufacturing terms correctly.
#      - Lacks specific technical details or advanced concepts.
#      - Doesn't mention specific efficiency metrics or safety standards.
#    - Improvement Tip: Include specific examples of machinery, processes, and relevant manufacturing engineering terminology.
#
#    - Criterion: Clarity & Structure
#    - Rating: good
#    - Evidence:
#      - Presents a logical sequence of steps.
#      - Explanation is easy to follow.
#      - Could benefit from more transitional phrases for smoother flow.
#    - Improvement Tip: Use clearer transitions between steps to improve the flow and coherence of the explanation.
#
#    - Criterion: Depth of Analysis
#    - Rating: needs_improvement
#    - Evidence:
#      - Explanation is relatively superficial.
#      - Lacks specific examples to illustrate the points.
#      - Doesn't justify the choices made regarding layout, efficiency, or safety.
#    - Improvement Tip: Provide specific examples of equipment selection, layout decisions, and safety measures, explaining the reasoning behind each choice.
#
#    - Criterion: Language & Presentation
#    - Rating: good
#    - Evidence:
#      - Writing is clear and concise.
#      - Uses professional language.
#      - Minor grammatical improvements could be made.
#    - Improvement Tip: Review for minor grammatical errors and refine sentence structure for improved flow.
#
#
# 3) Suggested Grade (optional):
# B-
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Majority Label: Human
# Mean Confidence: 0.95
# - Vote: Human (conf=0.95)
# - Vote: Human (conf=0.95)
# - Vote: Human (conf=0.95)
#
# --- SUBMISSION 4 (True Label: Human) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# 1) Overall Summary:
# This submission provides a basic overview of setting up a production line.  It touches upon key aspects like work breakdown, equipment placement, and safety considerations. However, it lacks depth in analysis and specific examples to illustrate the engineering principles involved.  The explanation could benefit from more detail and technical precision.
#
# 2) Criteria Feedback:
#    - Criterion: Scope & Comprehensiveness
#    - Rating: average
#    - Evidence:
#      - The submission covers the main phases of setting up a production line.
#      - However, it lacks detail on specific equipment choices, efficiency metrics, and detailed safety protocols.
#      - The explanation of the design-to-assembly flow is superficial.
#    - Improvement Tip: Expand on the selection of specific equipment, provide examples of efficiency calculations (e.g., takt time), and elaborate on the implementation of specific safety measures.
#
#    - Criterion: Technical Acumen
#    - Rating: average
#    - Evidence:
#      - The submission uses some relevant manufacturing terminology (e.g., "emergency stops").
#      - However, it lacks the precise application of manufacturing engineering principles and advanced concepts.
#      -  There is limited discussion of specific techniques for optimizing efficiency or layout.
#    - Improvement Tip: Incorporate specific manufacturing engineering concepts and terminology (e.g., lean manufacturing principles, line balancing) to support the explanation.
#
#    - Criterion: Clarity & Structure
#    - Rating: good
#    - Evidence:
#      - The explanation is presented in a logical sequence, easy to follow.
#      - The language is simple and straightforward.
#      - The flow of ideas is generally coherent.
#    - Improvement Tip:  While the structure is good, using subheadings or visual aids could improve the overall clarity and organization.
#
#    - Criterion: Depth of Analysis
#    - Rating: needs_improvement
#    - Evidence:
#      - The submission lacks detailed reasoning and specific examples to justify design and process choices.
#      - There is minimal discussion of the rationale behind equipment placement or safety measures.
#      - The analysis of efficiency considerations is superficial.
#    - Improvement Tip: Provide specific examples of design decisions and explain the reasoning behind them.  Include calculations or data to support claims about efficiency improvements.
#
#    - Criterion: Language & Presentation
#    - Rating: good
#    - Evidence:
#      - The writing is clear and concise.
#      - The language is professional and appropriate for the domain.
#      - Minor grammatical issues are present but do not impede understanding.
#    - Improvement Tip: Proofread carefully to eliminate minor grammatical errors and ensure consistent professional tone.
#
#
# 3) Suggested Grade (optional):
# B-
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Majority Label: Human
# Mean Confidence: 0.95
# - Vote: Human (conf=0.95)
# - Vote: Human (conf=0.95)
# - Vote: Human (conf=0.95)
#
# --- SUBMISSION 5 (True Label: Hybrid) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# 1) Overall Summary:
#
# This submission provides a good overview of setting up a production line, covering key stages from design review to trial runs.  The student demonstrates understanding of relevant concepts like lean manufacturing and safety integration. However,  deeper analysis and specific examples would strengthen the response.
#
#
# 2) Criteria Feedback:
#
# - Criterion: Scope & Comprehensiveness
#    - Rating: good
#    - Evidence:
#      - Covers most phases of production line setup.
#      - Addresses equipment selection, layout, efficiency, and safety.
#      - Mentions lean approaches and trial runs.
#    - Improvement Tip: Include a more detailed breakdown of each phase, perhaps using a numbered list or flowchart.
#
# - Criterion: Technical Acumen
#    - Rating: good
#    - Evidence:
#      - Correctly uses terms like "takt time," "lean manufacturing," and "cellular manufacturing."
#      - Demonstrates understanding of efficiency and safety considerations.
#      - Shows awareness of the importance of data-driven adjustments.
#    - Improvement Tip:  Provide specific examples of equipment choices and their justifications based on product design and volume.
#
# - Criterion: Clarity & Structure
#    - Rating: good
#    - Evidence:
#      - Presents a logical flow of steps in production line setup.
#      - Uses clear and concise language.
#      - The explanation is easy to follow.
#    - Improvement Tip:  Consider using headings and subheadings to improve the organization and readability.
#
# - Criterion: Depth of Analysis
#    - Rating: average
#    - Evidence:
#      - Mentions concepts like minimizing non-value-adding steps but lacks specific examples.
#      - Explains efficiency improvements but doesn't provide detailed calculations or examples.
#      - The discussion of safety is brief and lacks concrete examples of safety measures.
#    - Improvement Tip:  Provide specific examples of how lean principles were applied in equipment layout and workflow.  Quantify efficiency improvements with data or calculations.
#
# - Criterion: Language & Presentation
#    - Rating: good
#    - Evidence:
#      - Uses professional and precise language.
#      - Writing is clear and easy to understand.
#      - Minor grammatical or spelling errors are absent.
#    - Improvement Tip:  No specific improvement needed.
#
#
# 3) Suggested Grade (optional):  B
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Majority Label: Hybrid
# Mean Confidence: 0.85
# - Vote: Hybrid (conf=0.85)
# - Vote: Hybrid (conf=0.85)
# - Vote: Hybrid (conf=0.85)
#
# --- SUBMISSION 6 (True Label: Hybrid) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# 1) Overall Summary:
# This submission provides a good overview of setting up a basic production line in manufacturing engineering.  It covers key phases from design to assembly, incorporating considerations for equipment, efficiency, and safety.  However,  some areas could benefit from more detailed explanation and specific examples to enhance the analysis.
#
# 2) Criteria Feedback:
#    - Criterion: Scope & Comprehensiveness
#    - Rating: good
#    - Evidence:
#      - Covers the main phases from design to assembly.
#      - Includes equipment selection, efficiency optimization, and safety measures.
#      - Mentions testing and iterative refinement.
#    - Improvement Tip:  Expand on the description of the production sequence, providing specific examples of operations for the chosen product.
#
#    - Criterion: Technical Acumen
#    - Rating: good
#    - Evidence:
#      - Correctly mentions takt time and simulation software.
#      - Demonstrates understanding of ergonomic considerations and iterative testing.
#      - Uses relevant manufacturing terminology (e.g., bottlenecks).
#    - Improvement Tip: Define and elaborate on specific metrics used for efficiency calculations (e.g., cycle time, OEE).
#
#    - Criterion: Clarity & Structure
#    - Rating: good
#    - Evidence:
#      - Presents a logical flow of steps in setting up the production line.
#      - Uses clear and concise language.
#      - The explanation is easy to follow.
#    - Improvement Tip: Use headings or subheadings to further improve the structure and readability.
#
#    - Criterion: Depth of Analysis
#    - Rating: average
#    - Evidence:
#      - Mentions efficiency optimization and safety measures.
#      - Briefly describes the use of simulation software.
#      - Lacks specific examples to illustrate the concepts.
#    - Improvement Tip: Provide concrete examples of how bottlenecks were identified and addressed, and illustrate the safety measures with specific examples.
#
#    - Criterion: Language & Presentation
#    - Rating: good
#    - Evidence:
#      - Uses clear and professional language.
#      - Free of grammatical errors.
#      - Writing style is concise and easy to understand.
#    - Improvement Tip:  No significant improvements needed.
#
#
# 3) Suggested Grade (optional): B
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Majority Label: Hybrid
# Mean Confidence: 0.85
# - Vote: Hybrid (conf=0.85)
# - Vote: Hybrid (conf=0.85)
# - Vote: Hybrid (conf=0.85)
#
# ================= Processing accounting.json =================
#
# --- SUBMISSION 1 (True Label: AI) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# 1) Overall Summary:
# This essay offers a good overview of blockchain's impact on accounting.  The student effectively explains core blockchain concepts and their application in auditing and financial reporting, supported by relevant real-world examples.  However, a more in-depth analysis of the challenges and a stronger conclusion would enhance the submission.
#
#
# 2) Criteria Feedback:
#    - Criterion: Understanding of Blockchain Concepts
#    - Rating: good
#    - Evidence:
#      - Clearly defines decentralization, immutability, and transparency.
#      - Explains the relevance of decentralized ledgers and smart contracts to accounting processes.
#      - Connects these concepts to improved efficiency and trust.
#    - Improvement Tip:  Expand on the concept of consensus mechanisms in blockchain and their role in ensuring data integrity.
#
#    - Criterion: Analysis of Accounting Impact
#    - Rating: good
#    - Evidence:
#      - Discusses the impact on auditing (tamper-proof audit trails).
#      - Explains the impact on financial reporting (real-time data, improved transparency).
#      - Mentions automation benefits (invoicing, reconciliation).
#    - Improvement Tip:  Develop a more nuanced discussion of the challenges related to data privacy and security within blockchain systems.
#
#    - Criterion: Use of Real-World Examples/Case Studies
#    - Rating: good
#    - Evidence:
#      - Mentions Ernst & Young's Blockchain Analyzer.
#      - Includes JPMorgan's Quorum platform as an example.
#      - Refers to PwC's exploration of blockchain-based auditing tools.
#    - Improvement Tip: Provide more detailed descriptions of these examples, explaining their specific functionalities and impact on accounting practices.
#
#    - Criterion: Structure and Academic Style
#    - Rating: good
#    - Evidence:
#      - Essay is logically structured with a clear introduction and conclusion.
#      - Uses academic tone and vocabulary.
#      - Transitions between paragraphs are mostly smooth.
#    - Improvement Tip: Enhance the conclusion by summarizing key findings and offering a more forward-looking perspective on the future of blockchain in accounting.
#
#
# 3) Suggested Grade (optional):
# B
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Majority Label: Ai
# Mean Confidence: 0.95
# - Vote: AI (conf=0.95)
# - Vote: AI (conf=0.95)
# - Vote: AI (conf=0.95)
#
# --- SUBMISSION 2 (True Label: AI) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# 1) Overall Summary:
# This essay offers a promising start to analyzing blockchain's impact on accounting.  The student demonstrates a good understanding of core blockchain concepts and their relevance to auditing and financial reporting.  However, the analysis could be deepened, and more diverse examples would strengthen the argument.
#
#
# 2) Criteria Feedback:
#    - Criterion: Understanding of Blockchain Concepts
#    - Rating: good
#    - Evidence:
#      - Clearly defines decentralization, immutability, and transparency.
#      - Connects these concepts to accounting applications (audit trails, fraud detection).
#      - Mentions smart contracts as a key feature.
#    - Improvement Tip:  Expand on the concept of distributed ledger technology and its implications for data management in accounting.
#
#    - Criterion: Analysis of Accounting Impact
#    - Rating: good
#    - Evidence:
#      - Explains how immutability improves audit trails and fraud detection.
#      - Discusses the automation potential of smart contracts for tasks like reconciliation.
#      - Mentions real-time financial reporting as a benefit.
#    - Improvement Tip: Analyze the impact on different stakeholders (e.g., auditors, regulators, investors) and discuss potential challenges alongside the benefits.
#
#    - Criterion: Use of Real-World Examples/Case Studies
#    - Rating: good
#    - Evidence:
#      - Uses EY's Blockchain Analyzer as an example of blockchain in auditing.
#      - Mentions IBM's supply chain financing as an example of real-time reporting.
#    - Improvement Tip: Include a wider range of examples, showcasing different applications of blockchain across various accounting functions (e.g., tax, regulatory compliance).
#
#    - Criterion: Structure and Academic Style
#    - Rating: good
#    - Evidence:
#      - Essay is well-structured with a clear introduction and logical flow.
#      - Uses formal academic language.
#    - Improvement Tip:  Consider adding a conclusion that summarizes key findings and offers a forward-looking perspective on the future of blockchain in accounting.
#
#
# 3) Suggested Grade (optional):
# B
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Majority Label: Ai
# Mean Confidence: 0.95
# - Vote: AI (conf=0.95)
# - Vote: AI (conf=0.95)
# - Vote: AI (conf=0.95)
#
# --- SUBMISSION 3 (True Label: Human) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# 1) Overall Summary:
# This submission demonstrates a good understanding of blockchain's potential in accounting.  The student effectively highlights key benefits in bookkeeping, auditing, and financial reporting, supported by relevant examples. However, a more in-depth analysis of the challenges and a stronger academic structure would enhance the work.
#
# 2) Criteria Feedback:
#    - Criterion: Understanding of Blockchain Concepts
#    - Rating: good
#    - Evidence:
#      - Accurately describes core concepts like decentralization and immutability.
#      - Connects these concepts to accounting applications (e.g., reduced errors in bookkeeping).
#      - Mentions "triple-entry" system, although explanation could be more detailed.
#    - Improvement Tip: Expand on the explanation of smart contracts and their role in automating accounting processes.
#
#    - Criterion: Analysis of Accounting Impact
#    - Rating: good
#    - Evidence:
#      - Explains benefits like improved data accuracy and reduced reconciliation.
#      - Discusses potential impact on auditing (faster, cheaper audits).
#      - Acknowledges challenges such as resistance to transparency and data integrity issues.
#    - Improvement Tip:  Develop a more nuanced discussion of the impact on financial reporting standards and regulatory compliance.
#
#    - Criterion: Use of Real-World Examples/Case Studies
#    - Rating: good
#    - Evidence:
#      - Mentions IBM's use of blockchain in supply chain finance.
#      - Refers to Deloitte's testing of blockchain for auditing.
#      - Cites a 2023 study on market efficiency (though the source isn't specified).
#    - Improvement Tip:  Provide more detailed descriptions of the examples and cite the 2023 study formally.
#
#    - Criterion: Structure and Academic Style
#    - Rating: average
#    - Evidence:
#      - The essay presents a logical flow of ideas.
#      - The tone is generally informal, using phrases like "I see" and "In short".
#      - Transitions between sections could be smoother and more explicitly stated.
#    - Improvement Tip:  Revise the essay to adopt a more formal academic tone and strengthen transitions between paragraphs.
#
#
# 3) Suggested Grade (optional):
# B
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Majority Label: Human
# Mean Confidence: 0.95
# - Vote: Human (conf=0.95)
# - Vote: Human (conf=0.95)
# - Vote: Human (conf=0.95)
#
# --- SUBMISSION 4 (True Label: Human) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# 1) Overall Summary:
# This submission demonstrates a good understanding of blockchain's potential impact on accounting.  The student effectively highlights key benefits like increased transparency and automation, supported by relevant examples. However, the analysis could be deepened by exploring the challenges more comprehensively and integrating a more rigorous academic structure.
#
# 2) Criteria Feedback:
#    - Criterion: Understanding of Blockchain Concepts
#    - Rating: good
#    - Evidence:
#      - Accurately describes decentralized and tamper-proof ledger aspects.
#      - Mentions the concept of a shared record, although not explicitly defining "triple-entry."
#      - Connects blockchain's features to accounting applications.
#    - Improvement Tip: Expand on core blockchain concepts like smart contracts and consensus mechanisms, explaining their relevance to accounting processes.
#
#    - Criterion: Analysis of Accounting Impact
#    - Rating: good
#    - Evidence:
#      - Explains how blockchain improves data accuracy and reduces reconciliation efforts.
#      - Discusses potential impacts on auditing and financial reporting.
#      - Acknowledges challenges like implementation costs and regulatory hurdles.
#    - Improvement Tip:  Develop a more nuanced analysis by comparing the advantages and disadvantages of blockchain adoption in accounting in greater detail, including a discussion of potential risks.
#
#    - Criterion: Use of Real-World Examples/Case Studies
#    - Rating: good
#    - Evidence:
#      - Mentions IBM's use of blockchain in supply chain finance.
#      - Refers to Deloitte's exploration of blockchain in auditing.
#    - Improvement Tip:  Provide more detailed case studies, analyzing the specific outcomes and challenges faced by the companies mentioned.
#
#    - Criterion: Structure and Academic Style
#    - Rating: average
#    - Evidence:
#      - The essay presents a logical flow of ideas.
#      - However, the tone is somewhat informal ("here's the catch").
#      - Transitions between sections could be smoother.
#    - Improvement Tip:  Revise the essay to adopt a more formal academic tone, using stronger transitions and a clearer structure with distinct paragraphs for each argument.
#
#
# 3) Suggested Grade (optional):
# B
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Majority Label: Human
# Mean Confidence: 0.95
# - Vote: Human (conf=0.95)
# - Vote: Human (conf=0.95)
# - Vote: Human (conf=0.95)
#
# --- SUBMISSION 5 (True Label: Hybrid) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# 1) Overall Summary:
# This submission demonstrates a good understanding of blockchain's potential impact on accounting.  The student effectively highlights key benefits in areas like auditing and financial reporting, while also acknowledging implementation challenges.  The analysis could be strengthened with more specific examples and a deeper exploration of the complexities involved.
#
# 2) Criteria Feedback:
#    - Criterion: Understanding of Blockchain Concepts
#    - Rating: good
#    - Evidence:
#      - Accurately describes core blockchain concepts like decentralization and immutability.
#      - Connects these concepts to accounting applications (e.g., automation, improved audit trails).
#      - Mentions smart contracts as a mechanism for automation.
#    - Improvement Tip:  Expand on the explanation of smart contracts, illustrating their functionality with a simple example relevant to accounting.
#
#    - Criterion: Analysis of Accounting Impact
#    - Rating: good
#    - Evidence:
#      - Clearly explains how blockchain enhances transparency, efficiency, and accuracy in accounting.
#      - Discusses benefits for auditing (e.g., simplified audit trails, real-time auditing).
#      - Identifies challenges related to expertise and privacy.
#    - Improvement Tip:  Analyze the impact on specific financial reporting standards (e.g., IFRS, GAAP) and delve deeper into the implications for regulatory compliance.
#
#    - Criterion: Use of Real-World Examples/Case Studies
#    - Rating: needs_improvement
#    - Evidence:
#      - Lacks concrete real-world examples of blockchain implementation in accounting.
#      - The discussion remains largely theoretical.
#    - Improvement Tip:  Incorporate at least one case study of a company or organization using blockchain for accounting purposes.
#
#    - Criterion: Structure and Academic Style
#    - Rating: good
#    - Evidence:
#      - The essay is well-structured with a logical flow of ideas.
#      - The writing style is mostly formal and academic.
#    - Improvement Tip:  Enhance the introduction and conclusion to provide a stronger framing of the analysis.
#
#
# 3) Suggested Grade (optional):
# B
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Majority Label: Ai
# Mean Confidence: 0.95
# - Vote: AI (conf=0.95)
# - Vote: AI (conf=0.95)
# - Vote: AI (conf=0.95)
#
# --- SUBMISSION 6 (True Label: Hybrid) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# 1) Overall Summary:
#
# This submission demonstrates a good understanding of blockchain's potential impact on accounting.  The student effectively highlights key benefits in areas like financial reporting and auditing, while also acknowledging associated challenges.  The analysis could be strengthened by incorporating specific real-world examples and expanding on the discussion of potential disruptions to existing accounting practices.
#
#
# 2) Criteria Feedback:
#
#    - Criterion: Understanding of Blockchain Concepts
#    - Rating: good
#    - Evidence:
#      - Accurately describes core concepts like decentralization and immutability.
#      - Connects these concepts to accounting applications (e.g., tamper-proof records).
#      - Mentions smart contracts and their relevance to automation.
#    - Improvement Tip:  Expand on the explanation of consensus mechanisms within blockchain technology and their impact on data integrity.
#
#    - Criterion: Analysis of Accounting Impact
#    - Rating: good
#    - Evidence:
#      - Explains benefits in areas such as reduced errors, improved data accuracy, and streamlined reconciliation.
#      - Discusses the shift in auditing focus from sampling to real-time data analysis.
#      - Identifies challenges like the need for new auditing standards.
#    - Improvement Tip:  Provide a more in-depth analysis of how blockchain might affect the roles of different accounting professionals (e.g., auditors, financial analysts).
#
#    - Criterion: Use of Real-World Examples/Case Studies
#    - Rating: needs_improvement
#    - Evidence:
#      - Lacks concrete real-world examples of blockchain implementation in accounting or finance.
#      - The analysis remains largely theoretical.
#    - Improvement Tip:  Incorporate at least one case study illustrating a company's use of blockchain for accounting purposes.
#
#    - Criterion: Structure and Academic Style
#    - Rating: good
#    - Evidence:
#      - Presents arguments in a logical and coherent manner.
#      - Uses academic tone and language.
#      - Transitions between ideas are mostly clear.
#    - Improvement Tip:  Consider using subheadings to improve the organization and readability of the analysis.
#
#
# 3) Suggested Grade (optional):  B
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Majority Label: Ai
# Mean Confidence: 0.95
# - Vote: AI (conf=0.95)
# - Vote: AI (conf=0.95)
# - Vote: AI (conf=0.95)
#
# ================= Processing it.json =================
#
# --- SUBMISSION 1 (True Label: AI) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# 1) Overall Summary:
#
# This submission demonstrates a good foundational understanding of AI in cybersecurity, effectively highlighting key applications.  However,  it would benefit from expanding on real-world examples and exploring potential risks and challenges to achieve a more comprehensive analysis.  The writing is clear and concise, suitable for an IT audience.
#
#
# 2) Criteria Feedback:
#
#    - Criterion: Understanding of Topic
#    - Rating: good
#    - Evidence:
#      - Accurately describes AI's role in threat detection and incident response.
#      - Correctly mentions the reduction of false positives in SIEM systems.
#      - Shows understanding of machine learning's role in anomaly detection.
#    - Improvement Tip:  Expand on the types of machine learning algorithms used in cybersecurity.
#
#    - Criterion: Application to Real-World Context
#    - Rating: average
#    - Evidence:
#      - Mentions real-world application in SIEM systems.
#      - Lacks specific examples of AI applications in cybersecurity beyond SIEM.
#      - Does not provide concrete examples of threats or incidents.
#    - Improvement Tip: Provide a specific real-world example of an AI-powered cybersecurity tool or incident.
#
#    - Criterion: Critical Thinking and Insight
#    - Rating: average
#    - Evidence:
#      - The submission identifies AI's advantages in cybersecurity.
#      - It lacks discussion of potential drawbacks or limitations.
#      - No exploration of ethical concerns or future challenges is present.
#    - Improvement Tip: Discuss potential risks associated with AI in cybersecurity, such as adversarial attacks or bias in algorithms.
#
#    - Criterion: Originality and Perspective
#    - Rating: average
#    - Evidence:
#      - The response presents generally accepted information.
#      - No unique perspective or original insight is offered.
#      - The analysis is largely descriptive rather than analytical.
#    - Improvement Tip: Offer a unique perspective on a specific challenge or opportunity within the field.
#
#    - Criterion: Clarity and Communication
#    - Rating: good
#    - Evidence:
#      - The writing is clear, concise, and well-structured.
#      - The language is appropriate for an IT audience.
#      - The ideas are presented logically and easily understood.
#    - Improvement Tip:  Consider adding a concluding sentence to summarize the main points.
#
#
# 3) Suggested Grade (optional): B
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Majority Label: Ai
# Mean Confidence: 0.95
# - Vote: AI (conf=0.95)
# - Vote: AI (conf=0.95)
# - Vote: AI (conf=0.95)
#
# --- SUBMISSION 2 (True Label: AI) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# 1) Overall Summary:
#
# The submission offers a concise overview of AI's role in cybersecurity, touching upon key applications like behavioral analytics and deep learning for threat detection.  While accurate, it would benefit from expanding on the potential risks associated with AI in this domain and providing more specific real-world examples.  The writing is clear and easy to understand.
#
#
# 2) Criteria Feedback:
#
#    - Criterion: Understanding of Topic
#    - Rating: good
#    - Evidence:
#      - Accurately identifies AI applications in cybersecurity (behavioral analytics, intrusion detection, deep learning).
#      - Mentions the benefit of faster threat detection.
#      - Demonstrates a basic understanding of AI's impact on cybersecurity.
#    - Improvement Tip:  Expand on the types of AI techniques used (e.g., explain how deep learning works in this context).
#
#
#    - Criterion: Application to Real-World Context
#    - Rating: average
#    - Evidence:
#      - Mentions "organizations" and "evolving cyber threats," but lacks specific examples.
#      - The examples are somewhat generic.
#    - Improvement Tip: Provide concrete examples of organizations using these AI-based solutions (e.g., a specific company or industry).
#
#
#    - Criterion: Critical Thinking and Insight
#    - Rating: needs_improvement
#    - Evidence:
#      - The submission primarily focuses on the benefits of AI in cybersecurity.
#      - Little discussion of potential drawbacks or challenges.
#    - Improvement Tip: Discuss potential risks, such as AI's vulnerability to adversarial attacks or the ethical implications of automated decision-making in cybersecurity.
#
#
#    - Criterion: Originality and Perspective
#    - Rating: average
#    - Evidence:
#      - The information presented is largely factual and commonly known.
#      - Lacks a unique perspective or original insight.
#    - Improvement Tip: Offer a personal reflection on the future implications of AI in cybersecurity or explore a less commonly discussed aspect of the topic.
#
#
#    - Criterion: Clarity and Communication
#    - Rating: good
#    - Evidence:
#      - The writing is concise and easy to understand.
#      - Uses appropriate technical terminology.
#      - The ideas are presented in a logical order.
#    - Improvement Tip:  Consider adding a brief concluding sentence to summarize the main points.
#
#
# 3) Suggested Grade (optional):  B-
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Majority Label: Ai
# Mean Confidence: 0.95
# - Vote: AI (conf=0.95)
# - Vote: AI (conf=0.95)
# - Vote: AI (conf=0.95)
#
# --- SUBMISSION 3 (True Label: Human) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# 1) Overall Summary:
# This submission offers a concise and relevant reflection on the role of AI in cybersecurity, drawing on a personal experience to illustrate its practical applications. While the response is brief, it effectively highlights both the benefits and the limitations of AI in this context.  The example provided is engaging and relatable.
#
#
# 2) Criteria Feedback:
#    - Criterion: Understanding of Topic
#    - Rating: good
#    - Evidence:
#      - *Accurately describes AI's role in enhancing, not replacing, human analysts.*
#      - *Correctly identifies AI's ability to detect subtle anomalies (phrasing, sender behavior).*
#      - *Demonstrates understanding of AI's application in email filtering.*
#    - Improvement Tip: Briefly mention other AI applications in cybersecurity (e.g., threat detection, vulnerability analysis).
#
#    - Criterion: Application to Real-World Context
#    - Rating: excellent
#    - Evidence:
#      - *Provides a specific, detailed, and personally relevant example of an AI-based email filter successfully identifying phishing attempts.*
#      - *The example clearly shows the practical application of AI in a real-world cybersecurity scenario.*
#      - *The narrative effectively conveys the impact of the AI system.*
#    - Improvement Tip:  Consider adding a contrasting example where AI might have limitations.
#
#    - Criterion: Critical Thinking and Insight
#    - Rating: good
#    - Evidence:
#      - *The submission moves beyond a simple description by reflecting on the implications of the AI system's performance.*
#      - *The author articulates a nuanced understanding of AI's role as a tool to augment human capabilities.*
#      - *The personal anecdote reveals a shift in perspective regarding AI's value.*
#    - Improvement Tip: Explore potential ethical considerations or challenges associated with using AI in cybersecurity.
#
#    - Criterion: Originality and Perspective
#    - Rating: good
#    - Evidence:
#      - *The personal anecdote provides a unique perspective grounded in direct experience.*
#      - *The reflection on the limitations of AI (not replacing humans) is insightful.*
#      - *The shift in the author's viewpoint adds a personal touch.*
#    - Improvement Tip:  Consider exploring a less commonly discussed aspect of AI in cybersecurity.
#
#    - Criterion: Clarity and Communication
#    - Rating: excellent
#    - Evidence:
#      - *The response is concise, clear, and easy to understand.*
#      - *The narrative is well-structured and logically presented.*
#      - *The language is appropriate for an IT audience.*
#    - Improvement Tip: None needed.
#
#
# 3) Suggested Grade (optional):  A-
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Majority Label: Human
# Mean Confidence: 0.95
# - Vote: Human (conf=0.95)
# - Vote: Human (conf=0.95)
# - Vote: Human (conf=0.95)
#
# --- SUBMISSION 4 (True Label: Human) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# 1) Overall Summary:
# This submission offers a concise and relevant example of AI in cybersecurity, showcasing practical application and positive impact.  While the response is brief, it effectively communicates a key benefit of AI in threat detection and response.  The personal anecdote adds engagement but could benefit from broader context and discussion of potential risks.
#
#
# 2) Criteria Feedback:
#    - Criterion: Understanding of Topic
#    - Rating: good
#    - Evidence:
#      - *Clearly understands the application of AI in threat detection.*
#      - *Accurately describes the time-saving benefit of AI-powered tools.*
#      - *Recognizes the importance of AI's adaptive learning capabilities.*
#    - Improvement Tip: Briefly define AI in cybersecurity to establish a foundational understanding for the reader.
#
#    - Criterion: Application to Real-World Context
#    - Rating: good
#    - Evidence:
#      - *Provides a specific, relatable example from the author's experience.*
#      - *Illustrates a practical application of AI in a Security Operations Center (SOC).*
#      - *Quantifies the positive impact (more than half reduction in triage time).*
#    - Improvement Tip: Include an example of a different AI application in cybersecurity (e.g., threat prediction, vulnerability analysis).
#
#    - Criterion: Critical Thinking and Insight
#    - Rating: average
#    - Evidence:
#      - *Highlights the importance of AI's adaptive learning.*
#      - *Implicitly acknowledges the challenge of distinguishing real threats from noise.*
#    - Improvement Tip: Analyze the potential downsides or limitations of AI in cybersecurity; for example, discuss the possibility of AI-driven attacks or biases in algorithms.
#
#    - Criterion: Originality and Perspective
#    - Rating: good
#    - Evidence:
#      - *Offers a personal anecdote, providing a unique perspective.*
#    - Improvement Tip:  Expand on the unique challenges or opportunities presented by the specific AI tool used.
#
#    - Criterion: Clarity and Communication
#    - Rating: good
#    - Evidence:
#      - *Concise and easy to understand.*
#      - *Uses clear and appropriate language for an IT audience.*
#    - Improvement Tip:  Slightly expand the explanation to provide more context and detail about the AI tool and its features.
#
#
# 3) Suggested Grade (optional):
# B
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Majority Label: Hybrid
# Mean Confidence: 0.883
# - Vote: Hybrid (conf=0.95)
# - Vote: Hybrid (conf=0.85)
# - Vote: Hybrid (conf=0.85)
#
# --- SUBMISSION 5 (True Label: Hybrid) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# 1) Overall Summary:
# This submission offers a concise and relevant example of AI in cybersecurity, highlighting both its benefits and limitations.  The student effectively demonstrates the importance of human oversight in AI-driven security systems. The response is clear and easy to understand, though it could benefit from broader exploration of AI's role in cybersecurity.
#
#
# 2) Criteria Feedback:
#    - Criterion: Understanding of Topic
#    - Rating: good
#    - Evidence:
#      - Accurately describes the use of AI for monitoring user activity.
#      - Recognizes the potential for false positives in AI-driven systems.
#      - Understands the need for human oversight and feedback loops.
#    - Improvement Tip:  Expand on different types of AI applications in cybersecurity beyond anomaly detection.
#
#    - Criterion: Application to Real-World Context
#    - Rating: good
#    - Evidence:
#      - Provides a specific, relatable example from a cloud environment.
#      - Describes a realistic challenge (false alarms) and its resolution.
#      - Illustrates the practical application of AI in a cybersecurity context.
#    - Improvement Tip: Include a diverse range of real-world examples, showcasing AI's use in different security domains (e.g., threat detection, incident response).
#
#    - Criterion: Critical Thinking and Insight
#    - Rating: good
#    - Evidence:
#      - Identifies a key limitation of AI in cybersecurity (false alarms).
#      - Highlights the crucial role of human expertise in mitigating AI's limitations.
#      - Shows understanding of the need for continuous improvement and feedback loops.
#    - Improvement Tip: Analyze the ethical implications of using AI in cybersecurity or discuss potential future challenges.
#
#    - Criterion: Originality and Perspective
#    - Rating: average
#    - Evidence:
#      - The example is relevant but not unique.
#      - The perspective is practical and valuable, but not groundbreaking.
#      - The insights are based on a specific experience, but lack broader reflection.
#    - Improvement Tip: Explore a less commonly discussed aspect of AI in cybersecurity, offering a novel perspective.
#
#    - Criterion: Clarity and Communication
#    - Rating: excellent
#    - Evidence:
#      - The response is concise, clear, and well-structured.
#      - The language is appropriate for an IT audience.
#      - The ideas are presented logically and easily understood.
#    - Improvement Tip:  Maintain the high level of clarity and conciseness.
#
#
# 3) Suggested Grade (optional): B
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Majority Label: Hybrid
# Mean Confidence: 0.95
# - Vote: Hybrid (conf=0.95)
# - Vote: Hybrid (conf=0.95)
# - Vote: Hybrid (conf=0.95)
#
# --- SUBMISSION 6 (True Label: Hybrid) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# 1) Overall Summary:
# This submission offers a concise and relevant examination of AI in cybersecurity.  The student effectively uses a real-world example to illustrate the capabilities and limitations of AI in this domain. The response is well-written and easy to understand. However, expanding on the potential risks and exploring future directions would strengthen the analysis.
#
#
# 2) Criteria Feedback:
#    - Criterion: Understanding of Topic
#    - Rating: good
#    - Evidence:
#      - Accurately describes AI's role in identifying command-and-control traffic.
#      - Recognizes the limitations of AI in detecting subtle threats.
#      - Understands the concept of AI as a "force multiplier."
#    - Improvement Tip: Briefly define AI in the context of cybersecurity to establish a foundational understanding for the reader.
#
#    - Criterion: Application to Real-World Context
#    - Rating: excellent
#    - Evidence:
#      - Uses a specific, relatable example of a red team-blue team exercise.
#      - The example directly illustrates the practical application of AI in cybersecurity.
#      - The scenario highlights both the strengths and weaknesses of AI tools.
#    - Improvement Tip:  Consider adding another real-world example to showcase a different aspect of AI in cybersecurity.
#
#    - Criterion: Critical Thinking and Insight
#    - Rating: good
#    - Evidence:
#      - Recognizes the limitations of AI and the continued importance of human expertise.
#      - The "force multiplier" analogy demonstrates thoughtful consideration of AI's role.
#      - Implicitly acknowledges the need for a balanced approach combining AI and human skills.
#    - Improvement Tip:  Explore the ethical implications or potential biases associated with AI-driven cybersecurity tools.
#
#    - Criterion: Originality and Perspective
#    - Rating: average
#    - Evidence:
#      - The red team-blue team example is a common scenario, but the analysis is insightful.
#      - The student's perspective is valuable but not wholly unique.
#    - Improvement Tip:  Consider exploring a less commonly discussed aspect of AI in cybersecurity, such as explainable AI or AI-driven threat hunting.
#
#    - Criterion: Clarity and Communication
#    - Rating: excellent
#    - Evidence:
#      - The response is concise, well-structured, and easy to understand.
#      - Uses clear and precise language appropriate for an IT audience.
#      - Effectively conveys the main points in a few sentences.
#    - Improvement Tip: No specific improvement needed.
#
#
# 3) Suggested Grade (optional):  B+
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Majority Label: Hybrid
# Mean Confidence: 0.95
# - Vote: Hybrid (conf=0.95)
# - Vote: Hybrid (conf=0.95)
# - Vote: Hybrid (conf=0.95)
#
# ================= Processing psychology.json =================
#
# --- SUBMISSION 1 (True Label: AI) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# 1) Overall Summary:
# This submission provides a good overview of cognitive biases and their real-world implications.  The student effectively explains confirmation bias, anchoring bias, and the availability heuristic, illustrating their impact on healthcare, consumer behavior, and legal settings. However, the discussion of mitigation strategies could be more detailed and the analysis of real-world examples could be deepened.
#
#
# 2) Criteria Feedback:
#    - Criterion: Conceptual Understanding of Biases
#    - Rating: good
#    - Evidence:
#      - Clearly defines and explains confirmation bias, anchoring bias, and the availability heuristic.
#      - Accurately links these biases to relevant psychological theories.
#      - Shows a good grasp of the core concepts.
#    - Improvement Tip:  Expand on the theoretical underpinnings of each bias, perhaps by including a brief discussion of the relevant cognitive processes involved.
#
#    - Criterion: Application to Real-World Scenarios
#    - Rating: good
#    - Evidence:
#      - Provides relevant examples in healthcare, consumer behavior, and the legal system.
#      - Attempts to link the biases to these scenarios.
#      - Examples are appropriate but could be more detailed and nuanced.
#    - Improvement Tip: Develop the real-world examples by providing more specific details and exploring the causal links between the biases and the outcomes more thoroughly.
#
#    - Criterion: Critical Evaluation and Mitigation Strategies
#    - Rating: average
#    - Evidence:
# ...
#      - Describes typical developmental progression for ages 3-6.
#      - Uses relevant examples to illustrate developmental milestones.
#    - Improvement Tip:  Expand on the developmental trajectory, perhaps incorporating a table or chart to visually represent the progression of skills.
#
#
#    - Criterion: Evaluation of Evidence-Based Approaches
#    - Rating: good
#    - Evidence:
#      - Mentions and explains effective strategies (dialogic reading, phonemic awareness games).
#      - Provides research support (Justice & Ezell, 2002; Lonigan et al., 2008).
#      - Connects strategies to improved outcomes (vocabulary, narrative skills).
#    - Improvement Tip:  Critically analyze the strengths and limitations of each approach, comparing their effectiveness across different contexts.
#
#
#    - Criterion: Consideration of Diversity and Inclusion
#    - Rating: good
#    - Evidence:
#      - Addresses the need for adaptation for diverse learners (multilingual, developmental delays).
#      - Suggests specific inclusive practices (integrating home languages, visual supports).
#      - Connects inclusive practices to equitable access.
#    - Improvement Tip: Provide more detailed examples of how these adaptations are implemented in practice, drawing on further research.
#
#
#    - Criterion: Research Integration and Referencing
#    - Rating: good
#    - Evidence:
#      - Uses several relevant sources (Justice & Ezell, 2002; Lonigan et al., 2008; Neuman & Wright, 2014; Snow, 2006).
#      - Correctly cites sources within the text.
#    - Improvement Tip: Expand the range of sources to provide a more comprehensive overview of the field.
#
#
#    - Criterion: Structure and Academic Writing
#    - Rating: good
#    - Evidence:
#      - Presents information in a logical and coherent manner.
#      - Maintains a formal and academic tone.
#      - Demonstrates clear and concise writing.
#    - Improvement Tip: Consider structuring the response into distinct paragraphs to improve the flow and readability.
#
#
# 3) Suggested Grade (optional):  B+
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Majority Label: Ai
# Mean Confidence: 0.95
# - Vote: AI (conf=0.95)
# - Vote: AI (conf=0.95)
# - Vote: AI (conf=0.95)
#
# --- SUBMISSION 2 (True Label: AI) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# 1) Overall Summary:
#
# This submission demonstrates a good understanding of early literacy development and incorporates some evidence-based approaches.  The student adequately addresses diversity and inclusion, although more detailed examples would strengthen this section. The research integration and academic writing are satisfactory.
#
#
# 2) Criteria Feedback:
#
#    - Criterion: Understanding of Early Literacy Development
#    - Rating: good
#    - Evidence:
#      - Clearly identifies key early literacy skills (phonological awareness, vocabulary, print knowledge).
#      - Explains the developmental progression from letter recognition to phoneme blending.
#      - Uses an example of typical development.
#    - Improvement Tip:  Expand on the developmental milestones within the 3-6 age range, providing specific examples for each skill.
#
#    - Criterion: Evaluation of Evidence-Based Approaches
#    - Rating: good
#    - Evidence:
#      - Mentions shared book reading and phonemic games as evidence-based approaches.
#      - Cites Whitehurst et al. (1994) to support the effectiveness of repeated reading.
#    - Improvement Tip: Critically analyze the strengths and limitations of the mentioned approaches, drawing on further research to support your claims.
#
#    - Criterion: Consideration of Diversity and Inclusion
#    - Rating: good
#    - Evidence:
#      - Suggests adapting strategies for diverse learners (bilingual books, culturally familiar content).
#    - Improvement Tip: Provide more specific examples of inclusive practices and discuss how these address the unique needs of diverse learners (e.g., learners with disabilities, from different socioeconomic backgrounds).
#
#    - Criterion: Research Integration and Referencing
#    - Rating: good
#    - Evidence:
#      - Uses at least one relevant academic source (Whitehurst et al., 1994).
#      -  The reference appears to be correctly formatted.
#    - Improvement Tip: Increase the number of academic sources to support your claims and ensure consistent referencing throughout.
#
#    - Criterion: Structure and Academic Writing
#    - Rating: good
#    - Evidence:
#      - Essay follows a logical structure with an introduction and conclusion.
#      - Mostly maintains a formal tone.
#      - Minimal grammatical errors.
#    - Improvement Tip:  Refine the introduction to more clearly state the essay's purpose and argument.
#
#
# 3) Suggested Grade (optional):  B
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Majority Label: Hybrid
# Mean Confidence: 0.817
# - Vote: Hybrid (conf=0.85)
# - Vote: Hybrid (conf=0.75)
# - Vote: Hybrid (conf=0.85)
#
# --- SUBMISSION 3 (True Label: Human) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# 1) Overall Summary:
#
# This submission demonstrates a good foundational understanding of early literacy development, particularly phonological awareness.  The student effectively integrates research to support their points, showing a good grasp of relevant concepts within the 3-6 age range. However, the submission is limited in scope, lacking a critical evaluation of evidence-based approaches and a discussion of diversity and inclusion.
#
#
# 2) Criteria Feedback:
#
# - Criterion: Understanding of Early Literacy Development
#    - Rating: good
#    - Evidence:
#      - Clearly explains phonological awareness and its importance.
#      - Accurately describes the developmental progression of phonological awareness, citing Lonigan et al. (2000).
#      - Mentions vocabulary and print knowledge as key components.
#    - Improvement Tip: Expand the explanation to include a broader range of early literacy skills and milestones, such as narrative skills and letter knowledge.
#
# - Criterion: Evaluation of Evidence-Based Approaches
#    - Rating: needs_improvement
#    - Evidence:
#      - No specific evidence-based approaches are evaluated.
#      - The text focuses on describing early literacy skills rather than evaluating interventions.
#    - Improvement Tip: Discuss and critically analyze at least one or two evidence-based approaches (e.g., shared reading, phonological awareness training) supported by research.
#
# - Criterion: Consideration of Diversity and Inclusion
#    - Rating: needs_improvement
#    - Evidence:
#      - The submission does not address the diverse needs of learners.
#    - Improvement Tip:  Discuss how early literacy development and instruction might vary for children from diverse linguistic and cultural backgrounds or with different developmental needs.
#
# - Criterion: Research Integration and Referencing
#    - Rating: good
#    - Evidence:
#      - Relevant research (Lonigan et al., 2000) is cited to support claims.
#      - The citation appears to be correctly formatted.
#    - Improvement Tip: Increase the number of research sources to broaden the scope and depth of the analysis.
#
# - Criterion: Structure and Academic Writing
#    - Rating: good
#    - Evidence:
#      - The writing is clear and well-organized for the limited scope.
#      - The language is mostly formal and academic.
#    - Improvement Tip:  Expand the submission to include a clear introduction and conclusion, further enhancing the overall structure and flow.
#
#
# 3) Suggested Grade (optional):  B-
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Majority Label: Human
# Mean Confidence: 0.95
# - Vote: Human (conf=0.95)
# - Vote: Human (conf=0.95)
# - Vote: Human (conf=0.95)
#
# --- SUBMISSION 4 (True Label: Human) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# 1) Overall Summary:
# This submission demonstrates a basic understanding of early literacy development in children aged 3-6 years.  The student correctly identifies key pre-reading skills but lacks depth in explaining developmental progression and the evaluation of evidence-based approaches.  Further development is needed to incorporate diverse learners' needs and strengthen research integration.
#
#
# 2) Criteria Feedback:
#    - Criterion: Understanding of Early Literacy Development
#    - Rating: good
#    - Evidence:
#      - Identifies key pre-reading skills (phonological awareness, vocabulary, print knowledge).
#      - Provides examples of developmental milestones (rhyming, letter recognition).
#      - Mentions typical developmental patterns.
#    - Improvement Tip: Expand on the developmental progression of these skills, including the range of typical development and variations.
#
#    - Criterion: Evaluation of Evidence-Based Approaches
#    - Rating: needs_improvement
#    - Evidence:
#      - No specific evidence-based approaches are mentioned or evaluated.
#      - The text lacks references to support claims.
#    - Improvement Tip: Research and discuss at least two evidence-based approaches (e.g., shared reading, phonics instruction) and evaluate their effectiveness with research support.
#
#    - Criterion: Consideration of Diversity and Inclusion
#    - Rating: needs_improvement
#    - Evidence:
#      - The submission does not address the needs of diverse learners.
#    - Improvement Tip: Discuss how early literacy development and instruction can be adapted for children from diverse linguistic and cultural backgrounds, and those with different learning needs.
#
#    - Criterion: Research Integration and Referencing
#    - Rating: needs_improvement
#    - Evidence:
#      - The submission lacks academic sources and citations.
#    - Improvement Tip: Integrate relevant research from peer-reviewed journals and books, using a consistent citation style.
#
#    - Criterion: Structure and Academic Writing
#    - Rating: good
#    - Evidence:
#      - The submission has a clear introduction and a logical flow of ideas.
#      - The writing style is relatively formal and easy to understand.
#    - Improvement Tip:  While the structure is good, enhance the conclusion by summarizing key findings and highlighting the importance of early literacy development.
#
#
# 3) Suggested Grade (optional):
# B-
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Majority Label: Human
# Mean Confidence: 0.85
# - Vote: Human (conf=0.85)
# - Vote: Human (conf=0.85)
# - Vote: Human (conf=0.85)
#
# --- SUBMISSION 5 (True Label: Hybrid) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# 1) Overall Summary:
#
# This submission demonstrates a good foundational understanding of early literacy development, particularly phonological awareness.  The student accurately identifies key pre-reading skills and their developmental progression. However, the submission lacks depth in evaluating evidence-based approaches and addressing diversity and inclusion.  Further development is needed in these areas to meet the assignment's requirements.
#
#
# 2) Criteria Feedback:
#
#    - Criterion: Understanding of Early Literacy Development
#    - Rating: good
#    - Evidence:
#      - Accurately identifies key pre-reading skills (phonological awareness, vocabulary, print knowledge).
#      - Explains the developmental progression of phonological awareness, citing Lonigan et al. (2000).
#      - Clearly describes the importance of these skills for later reading success.
#    - Improvement Tip: Expand on the explanation of developmental milestones, providing more specific examples for each skill across the 3-6 age range.
#
#
#    - Criterion: Evaluation of Evidence-Based Approaches
#    - Rating: needs_improvement
#    - Evidence:
#      - No specific evidence-based approaches are evaluated.
#      - The text focuses on describing the skills, not on evaluating methods for teaching them.
#    - Improvement Tip:  Discuss and critically evaluate at least two evidence-based approaches (e.g., shared reading, phonics instruction) for fostering pre-reading skills, supporting your analysis with research.
#
#
#    - Criterion: Consideration of Diversity and Inclusion
#    - Rating: needs_improvement
#    - Evidence:
#      - The submission does not address the diverse needs of learners.
#    - Improvement Tip: Discuss how cultural and linguistic backgrounds, as well as developmental variations, impact early literacy acquisition and how instructional approaches can be adapted inclusively.
#
#
#    - Criterion: Research Integration and Referencing
#    - Rating: good
#    - Evidence:
#      - Uses one relevant academic source (Lonigan et al., 2000).
#      - The citation appears to be correctly formatted.
#    - Improvement Tip: Incorporate additional peer-reviewed research to support claims and broaden the scope of the discussion.
#
#
#    - Criterion: Structure and Academic Writing
#    - Rating: good
#    - Evidence:
#      - The writing is clear and coherent.
#      - The introduction clearly sets the context.
#    - Improvement Tip:  Consider adding a concluding paragraph to summarise key points and reiterate the importance of early literacy development.
#
#
# 3) Suggested Grade (optional):  B-
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Majority Label: Hybrid
# Mean Confidence: 0.85
# - Vote: Hybrid (conf=0.85)
# - Vote: Hybrid (conf=0.85)
# - Vote: Hybrid (conf=0.85)
#
# --- SUBMISSION 6 (True Label: Hybrid) ---
#
# --- RUBRIC-ALIGNED FEEDBACK ---
#
# 1) Overall Summary:
#
# This submission demonstrates a basic understanding of early literacy development in the 3-6 age range, mentioning key skills like phonological awareness and print knowledge. However, it lacks depth in explaining developmental progression and fails to evaluate evidence-based approaches or consider diverse learners' needs.  The submission would benefit from expanding on the described skills and incorporating relevant research and examples.
#
#
# 2) Criteria Feedback:
#
#    - Criterion: Understanding of Early Literacy Development
#    - Rating: average
#    - Evidence:
#      - Mentions key skills like phonological awareness, vocabulary, and print knowledge.
#      - Provides a general overview of developmental milestones around ages 4-5.
#      - Lacks depth in explaining the developmental progression of these skills.
#    - Improvement Tip: Expand on the description of each skill, detailing the developmental stages within the 3-6 year range and providing concrete examples of each.
#
#    - Criterion: Evaluation of Evidence-Based Approaches
#    - Rating: needs_improvement
#    - Evidence:
#      - No evidence-based approaches or interventions are mentioned or evaluated.
#      - The submission does not refer to any research or studies.
#    - Improvement Tip: Research and incorporate at least two evidence-based approaches (e.g., shared reading, dialogic reading) to support pre-reading skills, critically evaluating their effectiveness with supporting research.
#
#    - Criterion: Consideration of Diversity and Inclusion
#    - Rating: needs_improvement
#    - Evidence:
#      - The submission does not address the diverse needs of learners.
#      - There is no discussion of how approaches can be adapted for children from different linguistic or cultural backgrounds.
#    - Improvement Tip: Discuss how the identified evidence-based approaches can be adapted to meet the needs of diverse learners, considering factors such as language background, cultural experiences, and developmental differences.
#
#    - Criterion: Research Integration and Referencing
#    - Rating: poor
#    - Evidence:
#      - The submission lacks any academic sources or references.
#      - No research is cited to support the claims made.
#    - Improvement Tip: Conduct thorough research using peer-reviewed academic sources and integrate these findings into your writing, using appropriate in-text citations and a reference list.
#
#    - Criterion: Structure and Academic Writing
#    - Rating: average
#    - Evidence:
#      - The submission presents information in a somewhat structured manner.
#      - The writing style is descriptive but lacks the depth of an academic essay.
#    - Improvement Tip: Develop a clear introduction and conclusion, and use more formal academic language and sentence structures.
#
#
# 3) Suggested Grade (optional):  D
#
# --- ACADEMIC INTEGRITY DETECTION ---
#
# Majority Label: Human
# Mean Confidence: 0.85
# - Vote: Human (conf=0.85)
# - Vote: Human (conf=0.85)
# - Vote: Human (conf=0.85)
