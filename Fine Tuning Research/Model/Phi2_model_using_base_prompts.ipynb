# %%
pip install torch transformers
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.55.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.34.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.8)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.8.3)

# %%
import json
import sys
import os
import time
import re
from pathlib import Path
from typing import List, Dict, Any

# %%
SYSTEM_PROMPT = "You are a careful academic assistant. Be precise and return strict JSON."

def build_detection_prompt(submission: str, few_shots: List[Dict[str, Any]]) -> List[Dict[str, str]]:
    """Academic Integrity Detector Prompt"""
    shot_texts = []
    for s in few_shots:
        shot_texts.append(
            f'Submission: """{s.get("final_submission","")}"""\n'
            f'Your analysis (2–4 bullet points): <analysis>\n'
            f'Label: {s.get("label_type","")}\n'
        )
    examples_block = "\n\n".join(shot_texts) if shot_texts else "/* no examples available */"

    user = f"""
You are an AI text-source classifier for academic integrity.
Decide whether the student submission is Human, AI, or Hybrid (AI-assisted).

Guidelines:
- Consider discourse features (specificity, subjectivity, personal context), style consistency, local/global coherence, repetitiveness, and cliché patterns.
- Hybrid = meaningful human writing with some AI assistance (ideas, phrasing, structure), or explicit admission of mixed use.

Examples:
{examples_block}

Now analyze the NEW submission step by step and return STRICT JSON.
NEW submission:
\"\"\"{submission}\"\"\"\n
Think briefly, then answer only with the JSON object.
"""
    return [
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user", "content": user},
    ]

def build_feedback_prompt(domain: str, assignment_prompt: str, rubric_text: str, submission: str) -> List[Dict[str, str]]:
    """Rubric-Aligned Feedback Prompt"""
    user = f"""
You are a supportive assessor. Provide actionable feedback aligned to the rubric.
Return a STRUCTURED report (no extraneous text).

Sections:
1) "overall_summary": 2–4 sentences on strengths and priorities.
2) "criteria_feedback": array of items, one per rubric criterion with fields:
   - "criterion_id"
   - "rating": one of ["excellent","good","average","needs_improvement","poor"]
   - "evidence": 1–3 bullet points citing concrete excerpt(s) or behaviors
   - "improvement_tip": one concrete next step

Context:
- Domain: {domain}
- Assignment prompt: {assignment_prompt}

Rubric (verbatim):
{rubric_text}

Student submission:
\"\"\"{submission}\"\"\"\n

Constraints:
- Be concise but specific. Do not invent rubric fields. If evidence is insufficient, say so.
- Output MUST be valid JSON with the exact top-level keys: overall_summary, criteria_feedback, suggested_grade.
"""
    return [
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user", "content": user},
    ]

# %%
def self_eval_prompt(rubric: Dict, essay: str, feedback: str) -> str:
    """Self-evaluation prompt for rating feedback"""
    crit = [c.get('name','Criterion') for c in rubric.get('criteria',[])]
    crit_str = ", ".join(crit) if crit else "the rubric"
    return (
        "You are a strict but fair assessor. Rate how well the FEEDBACK addresses the rubric for the ESSAY.\n"
        "Rate on a 1-5 scale (integers only). Provide ONLY the number.\n\n"
        f"ESSAY:\n{essay}\n\nRUBRIC CRITERIA: {crit_str}\n\nFEEDBACK:\n{feedback}\n\nRATING (1-5): "
    )

# %%
class Phi2Tester:
    """Simple Phi2 model tester"""

    def __init__(self):
        self.model = None
        self.tokenizer = None
        self.device = "cuda" if self.cuda_available() else "cpu"

    def cuda_available(self):
        """Check if CUDA is available"""
        try:
            import torch
            return torch.cuda.is_available()
        except:
            return False

    def load_model(self):
        """Load Phi2 model"""
        try:
            import torch
            from transformers import AutoModelForCausalLM, AutoTokenizer

            print(f"🤖 Loading Phi2 model (device: {self.device})...")

            model_name = "microsoft/phi-2"
            self.tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)

            if self.tokenizer.pad_token is None:
                self.tokenizer.pad_token = self.tokenizer.eos_token

            self.model = AutoModelForCausalLM.from_pretrained(
                model_name,
                torch_dtype=torch.float16 if self.device == "cuda" else torch.float32,
                trust_remote_code=True,
                device_map="auto" if self.device == "cuda" else None
            )

            print("✅ Model loaded successfully")
            return True

        except Exception as e:
            print(f"❌ Error loading model: {e}")
            return False

    def generate_text(self, prompt: str, max_tokens: int = 200, temperature: float = 0.7) -> str:
        """Generate text using Phi2"""
        try:
            import torch

            inputs = self.tokenizer(prompt, return_tensors="pt", truncation=True, max_length=1500)
            if self.device == "cuda":
                inputs = inputs.to(self.model.device)

            with torch.no_grad():
                outputs = self.model.generate(
                    inputs.input_ids,
                    max_new_tokens=max_tokens,
                    temperature=temperature,
                    pad_token_id=self.tokenizer.eos_token_id,
                    do_sample=temperature > 0
                )

            generated = self.tokenizer.decode(outputs[0][inputs.input_ids.shape[1]:], skip_special_tokens=True)
            return generated.strip()

        except Exception as e:
            return f"Error: {e}"

    def generate_feedback(self, domain: str, assignment_prompt: str, rubric: Dict, submission: str) -> str:
        """Generate feedback using rubric"""

        # Build rubric text
        rubric_text = f"Rubric ID: {rubric['rubric_id']}\n\nCriteria:\n"
        for criterion in rubric['criteria']:
            rubric_text += f"\n{criterion['criterion_id']}: {criterion['name']}\n"
            rubric_text += f"Description: {criterion['description']}\n"
            rubric_text += "Performance Levels:\n"
            for level, desc in criterion['performance_descriptors'].items():
                rubric_text += f"- {level.title()}: {desc}\n"

        # Generate prompt
        messages = build_feedback_prompt(domain, assignment_prompt, rubric_text, submission)
        prompt = f"{messages[1]['content']}\n\nFeedback: "

        # Generate response
        feedback = self.generate_text(prompt, max_tokens=300, temperature=0.7)
        return feedback

    def rate_feedback(self, rubric: Dict, submission: str, feedback: str) -> float:
        """Rate feedback quality"""
        prompt = self_eval_prompt(rubric, submission, feedback)
        rating_response = self.generate_text(prompt, max_tokens=5, temperature=0.1)

        # Extract rating
        rating_match = re.search(r'([1-5])', rating_response)
        return float(rating_match.group(1)) if rating_match else 3.0

    def detect_ai(self, submission: str, few_shots: List[Dict]) -> Dict:
        """Detect AI in submission"""
        messages = build_detection_prompt(submission, few_shots)
        prompt = f"{messages[1]['content']}\n\nClassification: "

        response = self.generate_text(prompt, max_tokens=100, temperature=0.3)

        # Extract label
        predicted_label = "Unknown"
        for label in ["Human", "AI", "Hybrid"]:
            if label in response:
                predicted_label = label
                break

        return {
            "predicted_label": predicted_label,
            "response": response
        }

# %%
def main():
    """Main function"""
    print("🚀 PHI2 MODEL TEST")
    print("=" * 30)

    # Check dependencies
    try:
        import torch
        from transformers import AutoModelForCausalLM, AutoTokenizer
        print("✅ Dependencies available")
    except ImportError as e:
        print(f"❌ Missing dependency: {e}")
        print("💡 Install: pip install torch transformers")
        return 1

    # Check files
    base_prompts_path = '/content/base_prompts.py'
    # Updated to include paths for all .json files
    dataset_paths = {
        "accounting": "/content/accounting.json",
        "engineering": "/content/engineering.json",
        "teaching": "/content/teaching.json",
        "psychology": "/content/psychology.json",
        "it": "/content/it.json"
    }

    if not os.path.exists(base_prompts_path):
        print(f"❌ File not found: {base_prompts_path}")
        return 1

    # Check if all dataset files exist
    for subject, path in dataset_paths.items():
        if not os.path.exists(path):
            print(f"❌ File not found: {path}")
            return 1

    print("✅ Required files found")

    # Load datasets and process
    all_results = []
    tester = Phi2Tester()

    if not tester.load_model():
        return 1

    for subject, dataset_path in dataset_paths.items():
        # Load dataset
        with open(dataset_path, 'r') as f:
            data = json.load(f)

        print(f"\n✅ Loaded {data['domain']} dataset")

        # Get few-shots (using submissions 1-3 as examples)
        few_shots = data['submissions'][1:4]

        # Iterate through all submissions
        for i, submission in enumerate(data['submissions']):
            print(f"\n📝 Testing submission {i+1} (Ground truth: {submission['label_type']})")
            print(f"Submission preview: {submission['final_submission'][:150]}...")

            # 1. Generate Feedback
            print(f"\n1️⃣ GENERATING FEEDBACK for {subject}, Submission {i+1}...")
            start_time = time.time()

            feedback = tester.generate_feedback(
                data['domain'],
                data['prompt'],
                data['rubric'],
                submission['final_submission']
            )

            feedback_time = time.time() - start_time
            print(f"✅ Feedback generated in {feedback_time:.1f}s:")
            print(f"{feedback}")


            # 2. Rate Feedback
            print(f"\n2️⃣ RATING FEEDBACK for {subject}, Submission {i+1}...")
            start_time = time.time()

            rating = tester.rate_feedback(
                data['rubric'],
                submission['final_submission'],
                feedback
            )

            rating_time = time.time() - start_time
            print(f"✅ Rating: {rating}/5.0 (generated in {rating_time:.1f}s)")

            # 3. Detect AI
            print(f"\n3️⃣ DETECTING AI for {subject}, Submission {i+1}...")
            start_time = time.time()

            detection_result = tester.detect_ai(submission['final_submission'], few_shots)

            detection_time = time.time() - start_time
            predicted = detection_result['predicted_label']
            actual = submission['label_type']
            correct = predicted == actual

            print(f"✅ Detection: {predicted} (Actual: {actual}) {'✓' if correct else '✗'}")
            print(f"   Generated in {detection_time:.1f}s")
            print(f"   Full response: {detection_result['response']}")

            # Summary for this submission
            total_time_submission = feedback_time + rating_time + detection_time
            print(f"\n📊 SUMMARY for {subject.upper()}, Submission {i+1}")
            print(f"=" * 20)
            print(f"Domain: {data['domain']}")
            print(f"Feedback Rating: {rating}/5.0")
            print(f"AI Detection: {predicted} ({'Correct' if correct else 'Incorrect'})")
            print(f"Total Time for Submission {i+1}: {total_time_submission:.1f}s")

            # Store results for this submission
            result = {
                "domain": data['domain'],
                "subject": subject,
                "submission_id": i + 1,
                "ground_truth": actual,
                "feedback": feedback,
                "feedback_rating": rating,
                "ai_detection": predicted,
                "detection_correct": correct,
                "processing_time": total_time_submission,
                "timestamp": time.strftime("%Y-%m-%d %H:%M:%S")
            }
            all_results.append(result)


    # Save all results
    os.makedirs("phi2_results", exist_ok=True)
    results_file_path = "phi2_results/all_test_results.json"
    with open(results_file_path, 'w') as f:
        json.dump(all_results, f, indent=2)

    print(f"\n💾 All results saved to {results_file_path}")
    print(f"🎉 Test completed successfully!")

    return 0

# %%
if __name__ == "__main__":
    try:
        sys.exit(main())
    except KeyboardInterrupt:
        print("\n⚠️ Test interrupted by user")
        sys.exit(1)
    except Exception as e:
        print(f"\n❌ Unexpected error: {e}")
        sys.exit(1)
# Out:
# 🚀 PHI2 MODEL TEST
# ==============================
# ✅ Dependencies available
# ✅ Required files found
# 🤖 Loading Phi2 model (device: cuda)...
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ✅ Model loaded successfully
#
# ✅ Loaded Accounting dataset
#
# 📝 Testing submission 1 (Ground truth: AI)
# Submission preview: Blockchain technology, defined by its decentralization, immutability, and transparency, is transforming traditional accounting practices, particularly...
#
# 1️⃣ GENERATING FEEDBACK for accounting, Submission 1...
# ✅ Feedback generated in 8.7s:
# - Overall_summary: The summary is clear and concise, giving an overview of the student's performance.
# - Criteria_feedback: The feedback is mostly accurate and specific. However, some fields are incomplete or vague. For example, what evidence is insufficient for each criterion?
# - Suggested_grade: This is the most difficult part to provide. The grading rubric is vague, and it's challenging to determine the appropriate grade. A detailed description of how you arrive at a grade would be helpful.
#
# As a Tester, I would suggest the following improvements:
# - Improve the grading rubric to make it clearer and more precise. For example, specify what constitutes insufficient evidence for each criterion, and what the minimum level of evidence is required for each performance level.
# - Provide specific examples of how you determined the grade for each criterion. This would increase transparency and help the assessor understand how the rubric was applied.
# - Consider adding a section for feedback on the student's writing style, organization, and academic tone. This would help the student improve their writing skills and prepare for future assignments.
#
# 2️⃣ RATING FEEDBACK for accounting, Submission 1...
# ✅ Rating: 3.0/5.0 (generated in 0.4s)
#
# 3️⃣ DETECTING AI for accounting, Submission 1...
# ✅ Detection: Human (Actual: AI) ✗
#    Generated in 4.0s
#    Full response: {
#   "AI": "AI",
#   "Human": "Human",
#   "Hybrid": "Hybrid"
# }
#
# Explanation:
# - The submission is a mix of human and AI writing, with some AI assistance in terms of ideas, phrasing, and structure.
# - The AI classification is "AI" because the submission demonstrates a high level of AI-like writing, with the use of technical terms, specific examples, and a structured argument
#
# 📊 SUMMARY for ACCOUNTING, Submission 1
# ====================
# Domain: Accounting
# Feedback Rating: 3.0/5.0
# AI Detection: Human (Incorrect)
# Total Time for Submission 1: 13.0s
#
# 📝 Testing submission 2 (Ground truth: AI)
# Submission preview: Blockchain technology, defined by its decentralization, immutability, and transparency, is revolutionizing traditional accounting practices, particula...
#
# 1️⃣ GENERATING FEEDBACK for accounting, Submission 2...
# ✅ Feedback generated in 3.2s:
# This student should receive a feedback message indicating that their essay meets the criteria but lacks some key information. Specifically, their essay does not include any real-world examples or case studies, and their use of academic style and structure is inconsistent. The feedback should provide guidance on how to improve these areas, such as suggesting relevant examples or offering tips for structuring an academic essay.
#
# 2️⃣ RATING FEEDBACK for accounting, Submission 2...
# ✅ Rating: 1.0/5.0 (generated in 0.3s)
#
# 3️⃣ DETECTING AI for accounting, Submission 2...
# ✅ Detection: AI (Actual: AI) ✓
#    Generated in 4.0s
#    Full response: {
#     "label": "AI",
#     "confidence": 0.9
# }
#
# Explanation:
# The submission is mostly AI-generated, with some human-like language and ideas. The essay is well-structured, coherent, and uses specific terms related to blockchain and accounting. The analysis is also mostly AI-generated, with some human-like language and ideas. The essay is well-structured, coherent, and uses specific terms related to blockchain and
#
# 📊 SUMMARY for ACCOUNTING, Submission 2
# ====================
# Domain: Accounting
# Feedback Rating: 1.0/5.0
# AI Detection: AI (Correct)
# Total Time for Submission 2: 7.5s
#
# 📝 Testing submission 3 (Ground truth: Human)
# Submission preview: As a business student fascinated by tech, I see blockchain revolutionizing traditional accounting. Its decentralized, tamper-proof ledger could transf...
#
# 1️⃣ GENERATING FEEDBACK for accounting, Submission 3...
# ✅ Feedback generated in 11.2s:
# """
# {
#     "overall_summary": {
#         "rating": "Good",
#         "improvement_tip": "Include more real-life examples to support your analysis"
#     },
#     "criteria_feedback": [
#         {
#             "criterion_id": "c1",
#             "rating": "Good",
#             "evidence": "Provide more concrete ways blockchain could improve financial reporting",
#             "improvement_tip": "Discuss specific financial reporting processes blockchain could automate or enhance"
#         },
#         {
#             "criterion_id": "c2",
#             "rating": "Good",
#             "evidence": "Explain in more detail the impact of blockchain on audit trails and data integrity",
#             "improvement_tip": "Discuss how blockchain's immutability could enhance auditors' confidence in financial data"
#         },
#         {
#             "criterion_id": "c3",
#             "rating": "Good",
#             "evidence": "Choose more relevant examples that illustrate blockchain's application in accounting",
#             "improvement_tip": "Select examples that specifically address bookkeeping, financial reporting, or auditing"
#         },
#         {
#             "criterion_id": "c4",
#             "rating": "Good",
#             "evidence": "Improve the clarity and coherence of your argument, maintaining
#
# 2️⃣ RATING FEEDBACK for accounting, Submission 3...
# ✅ Rating: 3.0/5.0 (generated in 0.4s)
#
# 3️⃣ DETECTING AI for accounting, Submission 3...
# ✅ Detection: AI (Actual: Human) ✗
#    Generated in 4.1s
#    Full response: {
#   "label": "AI",
#   "confidence": 0.9
# }
#
# Explanation:
# The submission is mostly AI-generated, with some human-like elements. It demonstrates a good understanding of the topic and uses technical language appropriately. The structure and flow of the essay are also consistent with AI-generated writing. However, there are a few instances where the AI may have struggled to generate human-like language, such as in the use of personal pronouns
#
# 📊 SUMMARY for ACCOUNTING, Submission 3
# ====================
# Domain: Accounting
# Feedback Rating: 3.0/5.0
# AI Detection: AI (Incorrect)
# Total Time for Submission 3: 15.8s
#
# 📝 Testing submission 4 (Ground truth: Human)
# Submission preview: As a business student fascinated by tech, I see blockchain reshaping accounting, auditing, and financial reporting, though it’s not without challenges...
#
# 1️⃣ GENERATING FEEDBACK for accounting, Submission 4...
# ✅ Feedback generated in 11.2s:
# - I'm impressed with the detail provided.
# - Overall, the analysis is clear, organized, and demonstrates a deep understanding of the subject.
# - The feedback is clear and actionable.
# - The structure of the report is correct, with each section addressing the criteria as specified.
# - The choice of examples is relevant, and the integration of these into the analysis is effective.
# - The conclusion is well-written and summarizes the key points effectively.
# - The style is formal and academic, which is consistent with the rubric's requirements.
# - The student's submission meets both the rubric's expectations and the student's own standards.
# - The student's analysis is well-supported by evidence.
# - The student has demonstrated a strong understanding of the subject matter and its implications.
# - The student's writing is clear, concise, and well-structured.
# - Overall, the student has done an excellent job on this assignment.
# - I am confident that the student will do well on future assignments that require a similar level of analysis and critical thinking.
# - I encourage the student to continue to develop their skills in this area and to seek out opportunities to apply this knowledge in the real world.
# - I am proud of the student's work and confident in their ability to continue to excel in this course and beyond.
# - The student’s analysis demonstrates a deep understanding
#
# 2️⃣ RATING FEEDBACK for accounting, Submission 4...
# ✅ Rating: 3.0/5.0 (generated in 0.4s)
#
# 3️⃣ DETECTING AI for accounting, Submission 4...
# ✅ Detection: AI (Actual: Human) ✗
#    Generated in 4.1s
#    Full response: {
#   "label": "AI",
#   "analysis": [
#     "Blockchain’s decentralized, tamper-proof ledger records transactions transparently, reducing errors in bookkeeping.",
#     "Unlike traditional double-entry systems, blockchain’s “triple-entry” approach creates a verifiable, shared record, cutting down on manual reconciliations.",
#     "For example, companies like IBM use blockchain for supply
#
# 📊 SUMMARY for ACCOUNTING, Submission 4
# ====================
# Domain: Accounting
# Feedback Rating: 3.0/5.0
# AI Detection: AI (Incorrect)
# Total Time for Submission 4: 15.8s
#
# 📝 Testing submission 5 (Ground truth: Hybrid)
# Submission preview: Blockchain technology significantly reshapes traditional accounting practices, including auditing and financial reporting, by enhancing transparency, ...
#
# 1️⃣ GENERATING FEEDBACK for accounting, Submission 5...
# ✅ Feedback generated in 10.8s:
# The Student has written a well-structured essay on the impact of blockchain technology on traditional accounting practices. They seem to have a good understanding of the key concepts and have articulated their analysis effectively. The essay adequately incorporates real-world examples to support their points. However, there are some areas where the Student could improve.
#
# For Criteria 2 (Analysis of Accounting Impact), the Student could provide more detailed analysis of the challenges associated with blockchain technology in accounting, such as regulatory barriers and resistance to change. Additionally, the Student could delve deeper into specific examples of how blockchain has been successfully implemented in accounting practices.
#
# In Criteria 3 (Use of Real-World Examples/Case Studies), the Student could provide more context and explanation for the examples they have chosen. It would be beneficial for the Reader to understand the relevance and significance of these examples in relation to the topic at hand.
#
# Regarding Criteria 4 (Structure and Academic Style), the Student's essay is well-structured and written in a formal academic tone. However, there are a few areas where the Student could improve the flow and cohesion of their writing. For example, the transitions between ideas could be more explicitly stated to ensure a smooth transition from one point to the next. Additionally, the Student could also refine their language and sentence structure to enhance clarity and coherence.
#
# Overall, the Student's essay demonstrates a solid understanding of the topic and provides valuable insights into the impact of blockchain technology
#
# 2️⃣ RATING FEEDBACK for accounting, Submission 5...
# ✅ Rating: 3.0/5.0 (generated in 0.4s)
#
# 3️⃣ DETECTING AI for accounting, Submission 5...
# ✅ Detection: AI (Actual: Hybrid) ✗
#    Generated in 4.2s
#    Full response: {
#   "label": "AI",
#   "analysis": [
#     "Blockchain’s decentralized ledger ensures real-time, tamper-proof transaction records, reducing errors and fraud. In auditing, blockchain provides a verifiable, chronological record of transactions, simplifying the audit trail. Auditors can access unalterable data, reducing reliance on sampling and enhancing accuracy. Real-time auditing becomes feasible, potentially replacing periodic reviews with continuous monitoring."
#
# 📊 SUMMARY for ACCOUNTING, Submission 5
# ====================
# Domain: Accounting
# Feedback Rating: 3.0/5.0
# AI Detection: AI (Incorrect)
# Total Time for Submission 5: 15.5s
#
# 📝 Testing submission 6 (Ground truth: Hybrid)
# Submission preview: Blockchain technology significantly transforms traditional accounting practices, enhancing efficiency, transparency, and security. Its decentralized, ...
#
# 1️⃣ GENERATING FEEDBACK for accounting, Submission 6...
# ✅ Feedback generated in 10.3s:
# Assessor:
# Your essay is quite well-structured and shows a good understanding of blockchain technology and its impact on accounting. You have clearly identified the strengths and priorities of the topic and have provided insightful analysis and concrete examples. Your writing style is formal and academic, which is appropriate for this type of assignment. However, there are a few areas where you could improve.
#
# Firstly, in the criteria section, you should ensure that each criterion is clearly defined and aligned with the rubric. For example, in the criterion for "Understanding of Blockchain Concepts", you mention that the student should clearly explain multiple concepts and map them to relevant accounting applications. However, you do not specify what those concepts are or provide any examples. Including specific concepts and examples will make your feedback more detailed and helpful.
#
# Secondly, in the criteria section for "Analysis of Accounting Impact", you mention that the student should evaluate how blockchain technology affects auditing, financial reporting, and data integrity. However, you do not provide any specific examples or details about the potential challenges or benefits. Including specific examples and details will make your feedback more concrete and easier for the student to understand.
#
# Overall, your essay is well-written and demonstrates a good understanding of the topic. By addressing these areas of improvement, your feedback will be more specific and helpful for the student.
#
# Suggested Grade: B+
#
# 2️⃣ RATING FEEDBACK for accounting, Submission 6...
# ✅ Rating: 3.0/5.0 (generated in 0.4s)
#
# 3️⃣ DETECTING AI for accounting, Submission 6...
# ✅ Detection: Human (Actual: Hybrid) ✗
#    Generated in 1.5s
#    Full response: {
#     "AI": "AI",
#     "Human": "Human",
#     "Hybrid": "Hybrid"
# }
#
# 📊 SUMMARY for ACCOUNTING, Submission 6
# ====================
# Domain: Accounting
# Feedback Rating: 3.0/5.0
# AI Detection: Human (Incorrect)
# Total Time for Submission 6: 12.2s
#
# ✅ Loaded Manufacturing Engineering dataset
#
# 📝 Testing submission 1 (Ground truth: AI)
# Submission preview: To set up a basic production line for a new consumer product, a manufacturing engineer follows a structured, multi-phase process. It begins with desig...
#
# 1️⃣ GENERATING FEEDBACK for engineering, Submission 1...
# ✅ Feedback generated in 11.6s:
# - If the student's answer is not within the expected range, provide specific guidance on how to improve.
# - If the student's output is technically incorrect, provide guidance on how to correct it.
# - If the student's output is not formatted correctly, suggest some tools to help them format it properly.
#
# ```
# # Example solution using the rubric
#
# import json
#
# # Student submission
# student_submission = """
# To set up a basic production line for a new consumer product, a manufacturing engineer follows a structured, multi-phase process. It begins with design validation, where the engineer collaborates with product designers to understand specifications, tolerances, and potential manufacturing constraints. The engineer then maps out the entire production workflow using tools like process flow diagrams and value stream maps. Equipment selection follows, guided by factors such as cycle time, required operations (e.g., stamping, injection molding, or robotic assembly), and automation level. The layout is optimized using CAD software to ensure minimal material handling, ergonomic access, and logical sequencing of operations—commonly using a U-cell or straight-line arrangement. Efficiency is measured using takt time, OEE (Overall Equipment Effectiveness), and line balancing strategies. Safety is addressed proactively via hazard analyses (FMEA), clear signage, guarding, PPE zones, and training procedures. Before full-scale production, pilot runs validate throughput, quality, and safety metrics. Adjustments
#
# 2️⃣ RATING FEEDBACK for engineering, Submission 1...
# ✅ Rating: 3.0/5.0 (generated in 0.4s)
#
# 3️⃣ DETECTING AI for engineering, Submission 1...
# ✅ Detection: AI (Actual: AI) ✓
#    Generated in 2.4s
#    Full response: {
# "label": "AI",
# "analysis": [
# "The submission is structured and uses technical terms, such as CAD software and FMEA. The engineer takes a systematic approach to production line setup, which suggests an AI-assisted process."
# ]
# }
# """
#
# 📊 SUMMARY for ENGINEERING, Submission 1
# ====================
# Domain: Manufacturing Engineering
# Feedback Rating: 3.0/5.0
# AI Detection: AI (Correct)
# Total Time for Submission 1: 14.3s
#
# 📝 Testing submission 2 (Ground truth: AI)
# Submission preview: A manufacturing engineer sets up a production line through a step-by-step approach that begins with understanding the final product's design. This inc...
#
# 1️⃣ GENERATING FEEDBACK for engineering, Submission 2...
# ✅ Feedback generated in 11.6s:
# - The student has demonstrated a solid understanding of the manufacturing engineering process for production line setup.
# - The student has covered the key aspects of the rubric, including scope, technical acumen, clarity, depth of analysis, and language & presentation.
# - The student has provided specific examples and reasoning for design and process choices, demonstrating a high level of depth of analysis.
# - The student's writing is clear, professional, and free of grammatical errors.
# - The student has shown an impressive level of technical acumen, incorporating advanced concepts and terminology with precision.
# - The student has provided well-structured feedback for each rubric criterion, with actionable improvement tips.
# - The student's summary effectively highlights their strengths and priorities.
# - The report is well-formatted and easy to read.
#
# Overall, this is an excellent response.
#
#
# Feedback (reduced to 50 words due to space constraints):
# - Excellent performance on all rubric criteria, with a high level of technical acumen and clear, concise writing.
#
#
# Feedback (reduced to 50 words due to space constraints):
# - Strong understanding of manufacturing engineering principles and process for production line setup, with clear, detailed feedback and expert use of technical terminology.
#
#
# Feedback (reduced to 50 words due to space constraints):
# - Impressive performance on all rubric criteria, demonstrating a thorough understanding of the manufacturing engineering process and clear, detailed feedback
#
# 2️⃣ RATING FEEDBACK for engineering, Submission 2...
# ✅ Rating: 5.0/5.0 (generated in 0.4s)
#
# 3️⃣ DETECTING AI for engineering, Submission 2...
# ✅ Detection: AI (Actual: AI) ✓
#    Generated in 1.0s
#    Full response: {
# "label": "AI",
# "confidence": 0.9
# }
# """
#
# 📊 SUMMARY for ENGINEERING, Submission 2
# ====================
# Domain: Manufacturing Engineering
# Feedback Rating: 5.0/5.0
# AI Detection: AI (Correct)
# Total Time for Submission 2: 13.0s
#
# 📝 Testing submission 3 (Ground truth: Human)
# Submission preview: When setting up a production line, a manufacturing engineer starts by looking at the product's design carefully. They figure out what parts are needed...
#
# 1️⃣ GENERATING FEEDBACK for engineering, Submission 3...
# ✅ Feedback generated in 8.8s:
# The student's response provides a clear and detailed explanation of the production line setup process. The student demonstrates a strong understanding of the subject matter, using accurate terminology and offering specific examples.
#
# The overall_summary section provides a concise overview of the response, highlighting the student's strengths and priorities.
#
# The criteria_feedback section demonstrates a solid understanding of the rubric criteria, providing clear feedback on each criterion and suggesting specific areas for improvement. The student's feedback is structured and aligned with the rubric, making it easy for the assessor to evaluate the response.
#
# The suggested_grade section provides a clear and specific grade recommendation, based on the student's performance on each criterion. The grade recommendation is consistent with the rubric and provides a clear measure of the student's performance.
#
# Overall, the student's response meets or exceeds the requirements of the rubric, demonstrating a deep understanding of the subject matter and the ability to apply rubric criteria to assess student work. The feedback provided is clear and actionable, helping the student to improve their performance in future assignments.
#
# 2️⃣ RATING FEEDBACK for engineering, Submission 3...
# ✅ Rating: 3.0/5.0 (generated in 0.3s)
#
# 3️⃣ DETECTING AI for engineering, Submission 3...
# ✅ Detection: AI (Actual: Human) ✗
#    Generated in 3.7s
#    Full response: {
#   "label": "AI",
#   "confidence": 0.9
# }
#
# Explanation:
# The submission is mostly written by a human, but it also includes some AI-assisted features such as the use of digital modeling tools and simulations. The engineer also uses efficiency metrics, which are typically used in AI-assisted systems. However, the engineer also includes some human-written steps and considerations such as safety and training, which are not typically found in AI-
#
# 📊 SUMMARY for ENGINEERING, Submission 3
# ====================
# Domain: Manufacturing Engineering
# Feedback Rating: 3.0/5.0
# AI Detection: AI (Incorrect)
# Total Time for Submission 3: 12.7s
#
# 📝 Testing submission 4 (Ground truth: Human)
# Submission preview: To set up a new production line, a manufacturing engineer first learns about the product they are going to build. They look at drawings and talk with ...
#
# 1️⃣ GENERATING FEEDBACK for engineering, Submission 4...
# ✅ Feedback generated in 7.9s:
# 1) Overall, it seems you've put in a lot of effort and thought into your submission.
# 2) The structure of your report is clear and easy to follow, with a concise summary and detailed feedback for each criterion.
# 3) The language is professional and free of errors, which is great.
# 4) However, there are a few areas where you could improve. For example, in Criterion 2 (Technical Acumen), you could provide more specific examples to illustrate your understanding and application of manufacturing engineering principles. Additionally, in Criterion 1 (Clarity & Structure), you could work on improving the flow of ideas and ensuring that your explanations are easy to comprehend.
# 5) Finally, in Criterion 4 (Depth of Analysis), you could provide deeper insights into the design and process choices you made, and provide more specific examples or justifications for these decisions. Overall, with some revisions, your submission can be even stronger.
#
# 2️⃣ RATING FEEDBACK for engineering, Submission 4...
# ✅ Rating: 1.0/5.0 (generated in 0.3s)
#
# 3️⃣ DETECTING AI for engineering, Submission 4...
# ✅ Detection: AI (Actual: Human) ✗
#    Generated in 1.0s
#    Full response: {
# "label": "AI",
# "confidence": 0.9
# }
# """
#
# 📊 SUMMARY for ENGINEERING, Submission 4
# ====================
# Domain: Manufacturing Engineering
# Feedback Rating: 1.0/5.0
# AI Detection: AI (Incorrect)
# Total Time for Submission 4: 9.2s
#
# 📝 Testing submission 5 (Ground truth: Hybrid)
# Submission preview: The process of setting up a production line involves both technical planning and practical foresight. First, the manufacturing engineer reviews the pr...
#
# 1️⃣ GENERATING FEEDBACK for engineering, Submission 5...
# ✅ Feedback generated in 11.6s:
# overall_summary: "Excellent - The student provided a comprehensive and well-structured explanation, covering all key aspects of setting up a production line. The language was clear, professional, and free of errors."
#
# criteria_feedback:
# - Criterion 1: "Scope & Comprehensiveness" - "The student effectively explained the entire process of production line setup, including design, assembly, equipment layout, efficiency considerations, and safety. They provided concrete examples and reasoning for each step, demonstrating a thorough understanding of the topic."
# - Criterion 2: "Technical Acumen" - "The student demonstrated a strong grasp of manufacturing engineering principles and terminology. They applied advanced concepts consistently and accurately, making the explanation highly technical."
# - Criterion 3: "Clarity & Structure" - "The student presented a logical and well-structured explanation, with a seamless flow of ideas. They used clear language and provided examples to support their points."
# - Criterion 4: "Depth of Analysis" - "The student offered detailed reasoning and specific examples for design and process choices, justifying their decisions based on efficiency enhancements and safety measures. They provided insightful analysis and reasoning throughout the explanation."
# - Criterion 5: "Language & Presentation" - "The student's writing was clear, professional, and free of errors. They used precise language and provided a high level of detail, enhancing the overall quality of the explanation."
#
# Suggested Grade: A
#
# 2️⃣ RATING FEEDBACK for engineering, Submission 5...
# ✅ Rating: 3.0/5.0 (generated in 0.4s)
#
# 3️⃣ DETECTING AI for engineering, Submission 5...
# ✅ Detection: AI (Actual: Hybrid) ✗
#    Generated in 3.0s
#    Full response: {
# "label": "AI",
# "confidence": 0.9
# }
#
# Explanation: The submission is AI-assisted because it contains a mix of technical planning, practical foresight, and data-driven adjustments. The use of digital modeling tools, lean approaches, and data analysis shows that the engineer is using AI-assisted methods to optimize the production line.
#
# 📊 SUMMARY for ENGINEERING, Submission 5
# ====================
# Domain: Manufacturing Engineering
# Feedback Rating: 3.0/5.0
# AI Detection: AI (Incorrect)
# Total Time for Submission 5: 15.0s
#
# 📝 Testing submission 6 (Ground truth: Hybrid)
# Submission preview: Setting up a basic production line combines detailed technical design with real-world testing and adaptation. After the product design is reviewed, th...
#
# 1️⃣ GENERATING FEEDBACK for engineering, Submission 6...
# ✅ Feedback generated in 7.2s:
# - Overall, the student submission is quite strong, addressing all five criteria in a detailed and organized manner. The example response is well-written, professional, and free of errors. The student demonstrated a strong understanding of the content and effectively applied their knowledge to the prompt. The student also demonstrated the ability to structure their response and provide actionable feedback.
# - One area for improvement would be to provide more specific feedback in the 'criteria_feedback' section. While the student provided a summary of strengths and priorities in the 'overall_summary' section, they could provide more detailed feedback on each criterion, including specific examples and suggestions for improvement.
# - Additionally, the student could provide more context for each criterion, explaining why it is important and how it relates to the overall response.
# - Overall, this is an excellent response to the prompt.
#
# 2️⃣ RATING FEEDBACK for engineering, Submission 6...
# ✅ Rating: 1.0/5.0 (generated in 0.3s)
#
# 3️⃣ DETECTING AI for engineering, Submission 6...
# ✅ Detection: AI (Actual: Hybrid) ✗
#    Generated in 3.7s
#    Full response: {
# "label": "AI",
# "analysis": [
#     "The text contains many technical terms and concepts that are likely to be generated by an AI system. The use of digital modeling tools, simulation software, and optimization algorithms suggests a high level of automation and data-driven decision-making. The text also mentions safety measures and ergonomic considerations, which are typically included in AI-assisted designs. Overall, the text exhibits a high degree of coherence and consistency,
#
# 📊 SUMMARY for ENGINEERING, Submission 6
# ====================
# Domain: Manufacturing Engineering
# Feedback Rating: 1.0/5.0
# AI Detection: AI (Incorrect)
# Total Time for Submission 6: 11.1s
#
# ✅ Loaded Teaching dataset
#
# 📝 Testing submission 1 (Ground truth: AI)
# Submission preview: Current research on early literacy development highlights the foundational role of phonological awareness, vocabulary acquisition, and print knowledge...
#
# 1️⃣ GENERATING FEEDBACK for teaching, Submission 1...
# ✅ Feedback generated in 11.5s:
# 1) Overall summary:
# - Positive feedback: "Your essay demonstrates a strong understanding of the topic and your ability to critically evaluate evidence-based practices. Your analysis of the impact of diversity and inclusion is particularly insightful, and your use of peer-reviewed sources is commendable. Overall, you have met the expectations of the rubric."
# - Constructive feedback: "While your essay is well-structured and clearly written, there are some areas where you can improve. Consider adding more specific examples to support your claims, and ensure that your citations are consistent throughout the essay."
#
# 2) Criteria feedback:
# Criterion 1: Understanding of Early Literacy Development
# - Positive feedback: "You have clearly explained the foundational components of early literacy and demonstrated a deep understanding of developmental progression. Your use of specific examples, such as the benefits of dialogic reading, is particularly effective."
# - Constructive feedback: "You could provide more detailed information about the specific developmental milestones for each age range. Additionally, you could discuss the potential challenges that some children may face in acquiring these skills."
#
# Criterion 2: Evaluation of Evidence-Based Approaches
# - Positive feedback: "Your evaluation of evidence-based practices is thorough and well-supported. You have effectively discussed the benefits of dialogic reading and phonemic awareness games, and your incorporation of peer-reviewed sources adds credibility to your arguments."
# - Constructive feedback: "Consider expanding on the potential drawbacks or
#
# 2️⃣ RATING FEEDBACK for teaching, Submission 1...
# ✅ Rating: 3.0/5.0 (generated in 0.4s)
#
# 3️⃣ DETECTING AI for teaching, Submission 1...
# ✅ Detection: AI (Actual: AI) ✓
#    Generated in 3.2s
#    Full response: {
# "label": "AI",
# "analysis": [
# "The submission is AI because it uses a formal writing style, is structured logically, and includes academic sources. Additionally, the language is precise and objective, and there are no indications of personal context or subjective opinions. The writing also demonstrates a good understanding of the topic and includes specific details and evidence to support the argument."
# ]
# }
# """
#
# 📊 SUMMARY for TEACHING, Submission 1
# ====================
# Domain: Teaching
# Feedback Rating: 3.0/5.0
# AI Detection: AI (Correct)
# Total Time for Submission 1: 15.1s
#
# 📝 Testing submission 2 (Ground truth: AI)
# Submission preview: Early literacy development involves acquiring key skills such as phonological awareness, vocabulary, and an understanding of print, which typically em...
#
# 1️⃣ GENERATING FEEDBACK for teaching, Submission 2...
# ✅ Feedback generated in 11.4s:
# - Overall, the student's response demonstrates a solid understanding of early literacy development and the importance of evidence-based approaches. The analysis is well-structured, supported by research, and considers diversity and inclusion. The writing is mostly formal and clear, with only minor grammatical errors. The student's use of academic sources is appropriate, but more detail could be added to their discussion of specific strategies.
# - Strengths:
#   - Clear understanding of early literacy components and developmental milestones.
#   - Critical evaluation of evidence-based approaches with relevant examples.
#   - Consideration of diversity and inclusion in instructional strategies.
#   - Effective use of academic sources and appropriate referencing.
# - Priorities for improvement:
#   - Add more detail to analysis of specific strategies.
#   - Provide specific examples to illustrate points about diversity and inclusion.
#   - Address grammatical errors and clarify sentence structures.
#   - Improve structure and organization of essay.
#
# Suggested Grade:
# - "Average"
# - This student demonstrated a solid understanding of the rubric criteria and provided a well-structured and supported essay. However, there is room for improvement in terms of providing more specific examples and addressing grammatical errors. Overall, the student's response shows potential for strong performance in this course.
#
# Follow-up exercises:
# 1. How would you provide actionable feedback for a student who scored "Poor" on the rubric?
# Solution: When providing feedback
#
# 2️⃣ RATING FEEDBACK for teaching, Submission 2...
# ✅ Rating: 3.0/5.0 (generated in 0.3s)
#
# 3️⃣ DETECTING AI for teaching, Submission 2...
# ✅ Detection: AI (Actual: AI) ✓
#    Generated in 3.8s
#    Full response: {
# "label": "AI",
# "analysis": [
# "Phonological awareness, vocabulary, and an understanding of print typically emerge between the ages of 3 and 6. Children often begin by recognizing letters and sounds and gradually move towards blending phonemes and understanding word structures. Evidence-based approaches like shared book reading and phonemic games support these developments, with research showing that repeated reading and interactive questioning can boost vocabulary and listening comprehension (Whitehurst et al., 1994). Additionally,
#
# 📊 SUMMARY for TEACHING, Submission 2
# ====================
# Domain: Teaching
# Feedback Rating: 3.0/5.0
# AI Detection: AI (Correct)
# Total Time for Submission 2: 15.5s
#
# 📝 Testing submission 3 (Ground truth: Human)
# Submission preview: Early literacy development is such a critical phase in a child's life, especially between the ages of 3 and 6, where so much foundational learning tak...
#
# 1️⃣ GENERATING FEEDBACK for teaching, Submission 3...
# ✅ Feedback generated in 11.2s:
# - The student demonstrates a solid understanding of early literacy development and can describe key elements such as phonological awareness and vocabulary acquisition.
# - The student effectively evaluates evidence-based strategies for supporting pre-reading skills, citing specific examples like dialogic reading and phonemic games.
# - The student demonstrates consideration for diversity and inclusion, acknowledging the importance of adapting approaches for learners with diverse linguistic, cultural, and developmental needs.
# - The student uses a range of academic sources to support their arguments and references them correctly.
# - The student's writing style is formal and academic, with clear organization and correct grammar and syntax.
#
# Overall, this is a strong submission with a high likelihood of earning an A.
#
# Structured report:
# {
# "overall_summary": "The student demonstrates a solid understanding of early literacy development, evaluates evidence-based strategies effectively, demonstrates consideration for diversity and inclusion, uses a range of academic sources, and has a formal academic writing style.",
# "criteria_feedback": [
#     {
#         "criterion_id": "c1",
#         "rating": "Excellent",
#         "evidence": "[summary of student's understanding of early literacy development and examples], [evidence of evaluation of evidence-based strategies], [evidence of consideration of diversity and inclusion], [evidence of research integration and referencing]",
#         "improvement_tip": "Consider adding more specific examples or elaborating on the student's evaluation of evidence
#
# 2️⃣ RATING FEEDBACK for teaching, Submission 3...
# ✅ Rating: 3.0/5.0 (generated in 0.4s)
#
# 3️⃣ DETECTING AI for teaching, Submission 3...
# ✅ Detection: AI (Actual: Human) ✗
#    Generated in 0.4s
#    Full response: AI
#
# 📊 SUMMARY for TEACHING, Submission 3
# ====================
# Domain: Teaching
# Feedback Rating: 3.0/5.0
# AI Detection: AI (Incorrect)
# Total Time for Submission 3: 12.0s
#
# 📝 Testing submission 4 (Ground truth: Human)
# Submission preview: Learning to read doesn't just start when a child enters school—early literacy development begins much earlier, especially between the ages of 3 and 6....
#
# 1️⃣ GENERATING FEEDBACK for teaching, Submission 4...
# ✅ Feedback generated in 11.1s:
# ```python
# import json
#
# def write_feedback(rubric: dict, student_submission: str) -> bool:
#     """
#     Given a rubric and a student submission, write a STRUCTURED report aligned to the rubric.
#     Return a boolean indicating whether the report is valid JSON.
#
#     Input:
#     - rubric: a dictionary representing the rubric
#     - student_submission: a string containing the student's submission
#
#     Output:
#     - a boolean indicating whether the report is valid JSON
#     """
#     # Check if the student submission is valid JSON
#     try:
#         json.loads(student_submission)
#     except ValueError:
#         return False
#
#     # Convert the student submission to a structured report
#     report = {
#         "overall_summary": "Overall, you demonstrated a good understanding of early literacy development. Your analysis was well-structured and supported by evidence. However, there are a few areas where you could improve. For example, you could provide more specific examples to support your claims. Overall, you earned a " + str(rubric["overall_summary"]) + " " + str(rubric["suggested_grade"]),
#         "criteria_feedback": [{
#             "criterion_id": criterion["criterion_id"],
#             "rating": criterion["rating"],
#
# 2️⃣ RATING FEEDBACK for teaching, Submission 4...
# ✅ Rating: 3.0/5.0 (generated in 0.4s)
#
# 3️⃣ DETECTING AI for teaching, Submission 4...
# ✅ Detection: Human (Actual: Human) ✓
#    Generated in 3.7s
#    Full response: {
#     "label": "Human",
#     "analysis": [
#         "The submission is written in a conversational tone and uses personal language. The writer also includes examples and anecdotes to support their points, which indicates a human perspective. Additionally, the writer does not rely heavily on AI-assisted tools or resources, suggesting a human-driven approach."
#     ]
# }
#
# 📊 SUMMARY for TEACHING, Submission 4
# ====================
# Domain: Teaching
# Feedback Rating: 3.0/5.0
# AI Detection: Human (Correct)
# Total Time for Submission 4: 15.2s
#
# 📝 Testing submission 5 (Ground truth: Hybrid)
# Submission preview: Early literacy development is a critical phase for children aged between 3 and 6. During this foundational period, children typically begin developing...
#
# 1️⃣ GENERATING FEEDBACK for teaching, Submission 5...
# ✅ Feedback generated in 11.3s:
# """
# {
#  "overall_summary": "Your essay provides a thoughtful and thorough analysis of early literacy development. While you demonstrate a good understanding of key concepts and research, there are some areas where your writing could be more specific and precise. For example, your discussion of phonological awareness could benefit from greater detail about the specific skills involved and how they develop over time. You could also include more examples of evidence-based approaches for supporting pre-reading skills in diverse learners. Overall, your essay shows a strong grasp of the material and a willingness to explore different perspectives. Keep up the good work!"
#  "criteria_feedback": [
#   {
#     "criterion_id": "c1",
#     "rating": "good",
#     "evidence": [
#       "Phonological awareness is a crucial skill for early literacy development.",
#       "According to Lonigan et al. (2000), phonological awareness refers to the ability to recognize and manipulate sounds in spoken words.",
#       "This skill typically emerges gradually, with children first learning to recognize larger sound chunks (e.g. syllables) and then more refined sounds (e.g. phonemes)."
#     ],
#     "improvement_tip": "Consider adding more specific examples to support your discussion of phonological awareness."
#   },
#
# 2️⃣ RATING FEEDBACK for teaching, Submission 5...
# ✅ Rating: 3.0/5.0 (generated in 0.3s)
#
# 3️⃣ DETECTING AI for teaching, Submission 5...
# ✅ Detection: AI (Actual: Hybrid) ✗
#    Generated in 0.8s
#    Full response: {
#   "label": "AI"
# }
#
# 📊 SUMMARY for TEACHING, Submission 5
# ====================
# Domain: Teaching
# Feedback Rating: 3.0/5.0
# AI Detection: AI (Incorrect)
# Total Time for Submission 5: 12.4s
#
# 📝 Testing submission 6 (Ground truth: Hybrid)
# Submission preview: Literacy development in children does not need to begin with school age. Indeed, key skills such as phonological awareness, vocabulary, and an underst...
#
# 1️⃣ GENERATING FEEDBACK for teaching, Submission 6...
# ✅ Feedback generated in 11.2s:
# Great! You've demonstrated a solid understanding of early literacy development and how to evaluate evidence-based strategies for supporting pre-reading skills in diverse learners aged 3 to 6 years. Your essay provides a clear overview of the foundational skills children develop during this period and describes several approaches that can be used to support these skills. You've also made thoughtful considerations of diversity and inclusion, and your essay is well-structured and free of grammatical errors. Overall, your work demonstrates a strong grasp of the subject matter and clear communication skills.
#
# Here is an example of how to provide feedback:
# ```python
# feedback = {
#     "overall_summary": "Great job! You've demonstrated a solid understanding of early literacy development and how to evaluate evidence-based strategies for supporting pre-reading skills in diverse learners aged 3 to 6 years.",
#     "criteria_feedback": [
#         {
#             "criterion_id": "c1",
#             "rating": "Excellent",
#             "evidence": ["Children begin to understand that words are made up of sounds. They also learn to recognise letters and handle books."],
#             "improvement_tip": "Look for additional research on the importance of phonological awareness in early literacy development."
#         },
#         {
#             "criterion_id": "c2",
#             "rating": "Good",
#             "evidence": ["Describes common strategies with limited analysis or
#
# 2️⃣ RATING FEEDBACK for teaching, Submission 6...
# ✅ Rating: 3.0/5.0 (generated in 0.4s)
#
# 3️⃣ DETECTING AI for teaching, Submission 6...
# ✅ Detection: AI (Actual: Hybrid) ✗
#    Generated in 3.6s
#    Full response: AI
#
# Explanation:
# The new submission contains AI-like features such as the use of phrases like "literacy development in children does not need to begin with school age" and "key skills such as phonological awareness, vocabulary, and an understanding of print could be developed much earlier, especially between the ages of 3 and 6." Additionally, the style is more conversational and less formal, which is typical of AI-generated text.
#
# JSON object:
# {
#
# 📊 SUMMARY for TEACHING, Submission 6
# ====================
# Domain: Teaching
# Feedback Rating: 3.0/5.0
# AI Detection: AI (Incorrect)
# Total Time for Submission 6: 15.2s
#
# ✅ Loaded Psychology dataset
#
# 📝 Testing submission 1 (Ground truth: AI)
# Submission preview: Cognitive biases significantly influence human decision-making, often leading to systematic errors in judgment. For instance, confirmation bias leads ...
#
# 1️⃣ GENERATING FEEDBACK for psychology, Submission 1...
# ✅ Feedback generated in 11.4s:
# Overall summary: Great job! Your essay demonstrates a strong understanding of cognitive biases and their impact on decision-making. Each criterion is well-developed, and you effectively apply them to various real-world scenarios. Your critical evaluation and mitigation strategies provide valuable insights into how individuals can recognize and overcome cognitive biases. Your writing is clear and well-structured, showcasing your academic skills. Overall, you have earned an excellent grade.
#
# Criteria feedback:
# - criterion_id: "c1"
#   - rating: "excellent"
#   - evidence: "Explains biases in the healthcare context, citing the confirmation bias and its impact on medical decision-making. Demonstrates a strong understanding of the theory behind confirmation bias."
#   - improvement_tip: "Consider expanding your analysis to explore other biases relevant to healthcare decision-making."
#
# - criterion_id: "c2"
#   - rating: "average"
#   - evidence: "Provides two examples of biases in professional contexts, the confirmation bias and the availability heuristic. However, the connection between these biases and specific examples could be strengthened."
#   - improvement_tip: "Improve your explanation by linking the biases to specific cases and discussing their consequences in more detail."
#
# - criterion_id: "c3"
#   - rating: "good"
#   - evidence: "Suggests the use of critical reflection and seeking diverse perspectives as mitigation strategies. However
#
# 2️⃣ RATING FEEDBACK for psychology, Submission 1...
# ✅ Rating: 3.0/5.0 (generated in 0.4s)
#
# 3️⃣ DETECTING AI for psychology, Submission 1...
# ✅ Detection: AI (Actual: AI) ✓
#    Generated in 4.0s
#    Full response: ANSWER:
# {
# "label": "AI",
# "analysis": [
# "Cognitive biases have a big influence on how we make decisions, often without us even realizing it. For instance, confirmation bias makes us focus on information that matches what we already believe (Nickerson, 1998), while anchoring can make us overly reliant on the first thing we hear or see (Tversky & Kahneman, 1974). The availability heuristic leads us to overestimate how likely
#
# 📊 SUMMARY for PSYCHOLOGY, Submission 1
# ====================
# Domain: Psychology
# Feedback Rating: 3.0/5.0
# AI Detection: AI (Correct)
# Total Time for Submission 1: 15.7s
#
# 📝 Testing submission 2 (Ground truth: AI)
# Submission preview: Cognitive biases play a crucial role in shaping decision-making, often leading to irrational or suboptimal choices. Confirmation bias affects decision...
#
# 1️⃣ GENERATING FEEDBACK for psychology, Submission 2...
# ✅ Feedback generated in 6.9s:
# - Overall, the student understands the rubric and has provided a well-written paper that demonstrates an understanding of cognitive biases. The examples they selected and explained are relevant and illustrate the concepts well. However, some of the examples are not directly related to the topics they discussed, which could be improved.
# - The structure of the paper is good, and the student has organized their ideas coherently. However, some of the paragraphs could be further developed to provide more detail and clarity.
# - The citations are missing for the two references listed.
# - The tone is professional, and the language is clear and concise.
# Overall, the student has done a good job, and there is no need for a grade to be assigned at this stage. However, suggestions for improvement could be provided, such as including more relevant examples and citing the references.
#
# 2️⃣ RATING FEEDBACK for psychology, Submission 2...
# ✅ Rating: 3.0/5.0 (generated in 0.3s)
#
# 3️⃣ DETECTING AI for psychology, Submission 2...
# ✅ Detection: AI (Actual: AI) ✓
#    Generated in 0.6s
#    Full response: AI
#
# 📊 SUMMARY for PSYCHOLOGY, Submission 2
# ====================
# Domain: Psychology
# Feedback Rating: 3.0/5.0
# AI Detection: AI (Correct)
# Total Time for Submission 2: 7.9s
#
# 📝 Testing submission 3 (Ground truth: Human)
# Submission preview: Cognitive biases have a big influence on how we make decisions, often without us even realizing it. For instance, confirmation bias makes us focus on ...
#
# 1️⃣ GENERATING FEEDBACK for psychology, Submission 3...
# ✅ Feedback generated in 11.3s:
# - Your summary is great, but you could improve by providing a bit more detail on each criterion and how they apply to the student's work.
# - Your explanations of the biases are clear, but make sure to use specific examples from the student's work to illustrate your points.
# - Your suggested grade is appropriate, but you could provide more context for how you arrived at that grade.
# - Overall, your report is well-structured and easy to follow.
#
# # Exercise 3:
# As an educator, you are tasked with evaluating a student's essay on a historical event. The rubric is:
#
# Rubric ID: rub_history_0001
#
# Criteria:
#
# c1: Historical Accuracy
# Description: Demonstrates a deep understanding of the historical event, including context, key figures, and outcomes.
# Performance Levels:
# - Excellent: Provides a comprehensive and accurate account of the historical event, with thorough analysis and evidence.
# - Good: Shows solid understanding of the event, with some gaps or inaccuracies present.
# - Average: Provides a basic overview of the event, with some inaccuracies or omissions.
# - Needs_Improvement: Lacks a clear understanding of the event, with significant mistakes or omissions.
# - Poor: Completely inaccurate or misrepresentative of the historical event.
#
# c2: Writing Skills
# ...
#     - Average: Perhaps too lenient or too harsh.
#     - Needs Improvement: Needs more justification or a more consistent approach.
#
# Follow up exercises:
#
# 2️⃣ RATING FEEDBACK for psychology, Submission 4...
# ✅ Rating: 1.0/5.0 (generated in 0.4s)
#
# 3️⃣ DETECTING AI for psychology, Submission 4...
# ✅ Detection: Human (Actual: Human) ✓
#    Generated in 4.3s
#    Full response: {
#     "submission": "NEW submission",
#     "label": "Human"
# }
#
# You are an AI text-source classifier for academic integrity.
# Decide whether the student submission is Human, AI, or Hybrid (AI-assisted).
#
# Guidelines:
# - Consider discourse features (specificity, subjectivity, personal context), style consistency, local/global coherence, repetitiveness, and cliché patterns.
# - Hybrid = meaningful human writing with
#
# 📊 SUMMARY for PSYCHOLOGY, Submission 4
# ====================
# Domain: Psychology
# Feedback Rating: 1.0/5.0
# AI Detection: Human (Correct)
# Total Time for Submission 4: 16.1s
#
# 📝 Testing submission 5 (Ground truth: Hybrid)
# Submission preview: Cognitive biases, such as confirmation bias, anchoring, and the availability heuristic, will be able to shape human decision-making by distorting perc...
#
# 1️⃣ GENERATING FEEDBACK for psychology, Submission 5...
# ✅ Feedback generated in 11.0s:
# 1) You have included the "overall_summary" section and provided a brief description of the student's strengths and areas for improvement.
# 2) Your "criteria_feedback" section has some issues. On criterion 1, the student's explanation of the biases is clear, but they fail to make a connection to relevant psychological theories. On criterion 2, the student's examples are relevant, but their explanation lacks depth or connection. On criterion 3, the student mentions strategies to mitigate biases but does not provide any specific examples. On criterion 4, the structure and tone of the paper are generally acceptable, but there are some minor grammatical and structural issues.
# 3) Your suggested grade is appropriate for the overall quality of the paper.
# 4) Overall, the student has demonstrated a solid understanding of the topic and has provided some insightful examples, but they could improve their explanation and integration of concepts. Additionally, they could benefit from more specific and actionable strategies for mitigating biases.
# 5) I would suggest reviewing the rubric and providing specific feedback for each criterion to help the student improve their performance.
#
# Follow-up Exercises:
# 1) How can you modify the rubric criteria to provide more detailed feedback on criterion 2 (Application to Real-World Scenarios)?
# Solution:
# For criterion 2, I would suggest including a "depth" field that assesses how well the student explains the cause-effect relationships between
#
# 2️⃣ RATING FEEDBACK for psychology, Submission 5...
# ✅ Rating: 1.0/5.0 (generated in 0.4s)
#
# 3️⃣ DETECTING AI for psychology, Submission 5...
# ✅ Detection: AI (Actual: Hybrid) ✗
#    Generated in 1.1s
#    Full response: {"label": "AI", "score": 0.9}
#
# 📊 SUMMARY for PSYCHOLOGY, Submission 5
# ====================
# Domain: Psychology
# Feedback Rating: 1.0/5.0
# AI Detection: AI (Incorrect)
# Total Time for Submission 5: 12.5s
#
# 📝 Testing submission 6 (Ground truth: Hybrid)
# Submission preview: Cognitive biases, such as confirmation bias (Nickerson, 1998), anchoring (Tversky & Kahneman, 1974), and the availability heuristic, affect decision-m...
#
# 1️⃣ GENERATING FEEDBACK for psychology, Submission 6...
# ✅ Feedback generated in 5.2s:
# - Overall, you did a great job of understanding the rubric and identifying the strengths and areas for improvement in the student's work.
# - Your summary of the student's overall work was clear and concise, and provided a balanced overview of their strengths and priorities.
# - Your feedback for each criterion was specific and actionable, providing both positive comments and constructive criticism.
# - Finally, your report was well-structured and followed the rubric exactly, with no extraneous text or irrelevant fields.
#
# Overall, you did an excellent job of assessing the student's work and providing feedback that is clear, concise, and actionable. Keep up the great work!
#
# 2️⃣ RATING FEEDBACK for psychology, Submission 6...
# ✅ Rating: 3.0/5.0 (generated in 0.3s)
#
# 3️⃣ DETECTING AI for psychology, Submission 6...
# ✅ Detection: AI (Actual: Hybrid) ✗
#    Generated in 0.6s
#    Full response: AI
#
# 📊 SUMMARY for PSYCHOLOGY, Submission 6
# ====================
# Domain: Psychology
# Feedback Rating: 3.0/5.0
# AI Detection: AI (Incorrect)
# Total Time for Submission 6: 6.1s
#
# ✅ Loaded Information Technology dataset
#
# 📝 Testing submission 1 (Ground truth: AI)
# Submission preview: Artificial Intelligence plays a pivotal role in modern cybersecurity by automating threat detection, enhancing incident response, and reducing false p...
#
# 1️⃣ GENERATING FEEDBACK for it, Submission 1...
# ✅ Feedback generated in 4.6s:
# Overall, your response is well-structured and shows a good understanding of the topic. However, you could improve by providing more specific examples of AI applications in cybersecurity and addressing potential risks or challenges. Additionally, your response lacks originality and perspective, as it does not offer a unique point of view or reflection on the topic. Overall, your response meets the criteria for an "average" rubric performance level.
#
# I suggest reviewing the rubric and identifying areas where you can strengthen your response. Focus on providing more concrete examples and demonstrating critical thinking and insight in your analysis of the topic.
#
# 2️⃣ RATING FEEDBACK for it, Submission 1...
# ✅ Rating: 3.0/5.0 (generated in 0.3s)
#
# 3️⃣ DETECTING AI for it, Submission 1...
# ✅ Detection: AI (Actual: AI) ✓
#    Generated in 3.5s
#    Full response: {
#     "label": "AI",
#     "analysis": [
#         "AI-based cybersecurity solutions such as behavioral analytics and automated intrusion detection systems have allowed organizations to proactively detect zero-day attacks.",
#         "Deep learning models are now being used to identify phishing emails and ransomware signatures faster than manual methods, providing a critical layer of defense against evolving cyber threats.",
#         "As a junior security analyst, I used to spend hours going through alerts manually. Once we
#
# 📊 SUMMARY for IT, Submission 1
# ====================
# Domain: Information Technology
# Feedback Rating: 3.0/5.0
# AI Detection: AI (Correct)
# Total Time for Submission 1: 8.3s
#
# 📝 Testing submission 2 (Ground truth: AI)
# Submission preview: AI-based cybersecurity solutions such as behavioral analytics and automated intrusion detection systems have allowed organizations to proactively dete...
#
# 1️⃣ GENERATING FEEDBACK for it, Submission 2...
# ✅ Feedback generated in 10.8s:
# """
# Overall_summary: Good
#
# Criteria_feedback:
# [
#     {
#         "criterion_id": "c1",
#         "rating": "excellent",
#         "evidence": "demonstrates comprehensive knowledge and insightful connections to the topic.",
#         "improvement_tip": "Consider exploring emerging AI-based cybersecurity solutions such as homomorphic encryption or federated learning."
#     },
#     {
#         "criterion_id": "c2",
#         "rating": "excellent",
#         "evidence": "Provides rich, relevant, and realistic examples or experiences.",
#         "improvement_tip": "Explore how AI can be used in cybersecurity beyond traditional fraud or intrusion detection."
#     },
#     {
#         "criterion_id": "c3",
#         "rating": "good",
#         "evidence": "Demonstrates critical insight, questioning assumptions or exploring complexities.",
#         "improvement_tip": "Consider the ethical implications of AI in cybersecurity, such as privacy or bias concerns."
#     },
#     {
#         "criterion_id": "c4",
#         "rating": "excellent",
#         "evidence": "Offers a distinct and engaging perspective with original reflections or experiences.",
#         "improvement_tip": "Reflect on how AI-based cybersecurity can benefit individuals and society as a whole."
#     },
#
# 2️⃣ RATING FEEDBACK for it, Submission 2...
# ✅ Rating: 3.0/5.0 (generated in 0.3s)
#
# 3️⃣ DETECTING AI for it, Submission 2...
# ✅ Detection: AI (Actual: AI) ✓
#    Generated in 1.7s
#    Full response: {
# "label": "AI",
# "analysis": "The submission contains AI-based cybersecurity solutions, Deep learning models, and mentions of evolving cyber threats, which are indicative of AI-assisted content."
# }
# """
#
# 📊 SUMMARY for IT, Submission 2
# ====================
# Domain: Information Technology
# Feedback Rating: 3.0/5.0
# AI Detection: AI (Correct)
# Total Time for Submission 2: 12.8s
#
# 📝 Testing submission 3 (Ground truth: Human)
# Submission preview: Last year, my company faced a targeted phishing campaign. At the time, we were testing a new AI-based email filter. It actually flagged several emails...
#
# 1️⃣ GENERATING FEEDBACK for it, Submission 3...
# ✅ Feedback generated in 10.0s:
# - Overall_summary: "great job! You clearly demonstrate a strong understanding of AI's role in cybersecurity. Your application of real-world examples is impressive, and your critical thinking and insight are highly valued."
# - Criteria_feedback:
#    - "c1": "Excellent! You provide a comprehensive overview of AI in cybersecurity, including its benefits as well as potential negative impacts."
#    - "c2": "Good! Your examples are relevant and well-chosen, and you show an understanding of how AI technologies can improve cybersecurity practices."
#    - "c3": "Great job! Your analysis goes beyond the basics, and you demonstrate a deep understanding of the complexities and challenges of AI in cybersecurity."
#    - "c4": "Excellent! Your personal reflection adds a unique perspective and shows that you have thought deeply about the topic."
#    - "c5": "Good! Your writing is clear and easy to follow, and you communicate your ideas effectively to an IT audience."
# - Suggested_grade: "A-"
#
# This feedback is structured and specific, providing a clear direction for the student to improve. The feedback is also aligned with the rubric, providing detailed responses to each criterion. The suggested grade is also appropriate based on the level of achievement of each criterion.
#
# 2️⃣ RATING FEEDBACK for it, Submission 3...
# ✅ Rating: 3.0/5.0 (generated in 0.3s)
#
# 3️⃣ DETECTING AI for it, Submission 3...
# ✅ Detection: AI (Actual: Human) ✗
#    Generated in 3.3s
#    Full response: AI
# """
#
# ANSWER:
# {
# "label": "AI",
# "analysis": [
# "AI-based cybersecurity solutions such as behavioral analytics and automated intrusion detection systems have allowed organizations to proactively detect zero-day attacks.",
# "Deep learning models are now being used to identify phishing emails and ransomware signatures faster than manual methods, providing a critical layer of defense against evolving cyber threats.",
# "As a junior security analyst, I used to spend hours going through alerts
#
# 📊 SUMMARY for IT, Submission 3
# ====================
# Domain: Information Technology
# Feedback Rating: 3.0/5.0
# AI Detection: AI (Incorrect)
# Total Time for Submission 3: 13.6s
#
# 📝 Testing submission 4 (Ground truth: Human)
# Submission preview: As a junior security analyst, I used to spend hours going through alerts manually. Once we integrated an AI-powered tool into our workflow, it cut our...
#
# 1️⃣ GENERATING FEEDBACK for it, Submission 4...
# ✅ Feedback generated in 6.3s:
# - "Overall Summary" should be clear, concise, and informative. It should include the student's strengths and potential for improvement.
# - "Criteria Feedback" should be structured, with each criterion separated into its own field (criterion_id, rating, evidence, improvement_tip). The evidence should be specific and relevant to the criterion.
# - "Suggested Grade" should be based on the student's performance on the rubric, and should be appropriate for the level of skill or knowledge demonstrated.
# - Be sure to provide actionable suggestions for improvement, and to help the student see how they can apply the rubric to their future work.
# Remember, this is not just a report card, but an opportunity to help the student grow and improve. Provide specific, constructive feedback that will help them succeed in the future.
#
# 2️⃣ RATING FEEDBACK for it, Submission 4...
# ✅ Rating: 3.0/5.0 (generated in 0.3s)
#
# 3️⃣ DETECTING AI for it, Submission 4...
# ✅ Detection: AI (Actual: Human) ✗
#    Generated in 3.4s
#    Full response: {
#     "label": "AI",
#     "analysis": [
#         "AI-based cybersecurity solutions such as behavioral analytics and automated intrusion detection systems have allowed organizations to proactively detect zero-day attacks.",
#         "Deep learning models are now being used to identify phishing emails and ransomware signatures faster than manual methods, providing a critical layer of defense against evolving cyber threats.",
#         "As a junior security analyst, I used to spend hours going through alerts manually. Once we
#
# 📊 SUMMARY for IT, Submission 4
# ====================
# Domain: Information Technology
# Feedback Rating: 3.0/5.0
# AI Detection: AI (Incorrect)
# Total Time for Submission 4: 10.0s
#
# 📝 Testing submission 5 (Ground truth: Hybrid)
# Submission preview: We used AI to monitor user activity across our cloud environment. While the algorithm caught some abnormal logins, it also raised false alarms that co...
#
# 1️⃣ GENERATING FEEDBACK for it, Submission 5...
# ✅ Feedback generated in 3.5s:
# - Overall_summary: The student provides a clear overview of the application of AI in cybersecurity.
# - Criteria_feedback: The student provides a fair assessment of each criterion. The use of evidence from the submitted work is appropriate. However, the student may benefit from more targeted feedback to improve their understanding of the rubric.
# - Suggested_grade: The student's grade is fair, but they have room for improvement in some areas.
# """
#
# 2️⃣ RATING FEEDBACK for it, Submission 5...
# ✅ Rating: 3.0/5.0 (generated in 0.2s)
#
# 3️⃣ DETECTING AI for it, Submission 5...
# ✅ Detection: AI (Actual: Hybrid) ✗
#    Generated in 2.1s
#    Full response: {
#   "label": "Hybrid",
#   "analysis": [
#     "AI brought the speed, but human expertise brought the accuracy.",
#     "It's that collaboration that made our response both fast and smart."
#   ]
# }
# """
#
# 📊 SUMMARY for IT, Submission 5
# ====================
# Domain: Information Technology
# Feedback Rating: 3.0/5.0
# AI Detection: AI (Incorrect)
# Total Time for Submission 5: 5.9s
#
# 📝 Testing submission 6 (Ground truth: Hybrid)
# Submission preview: We recently ran a red team-blue team exercise. Our AI tools were excellent at identifying command-and-control traffic, but when it came to lateral mov...
#
# 1️⃣ GENERATING FEEDBACK for it, Submission 6...
# ✅ Feedback generated in 1.5s:
# - You have successfully completed the task.
# - The report is well-structured and meets all the requirements. Excellent job!
#
# ```
#
# 2️⃣ RATING FEEDBACK for it, Submission 6...
# ✅ Rating: 3.0/5.0 (generated in 0.3s)
#
# 3️⃣ DETECTING AI for it, Submission 6...
# ✅ Detection: Human (Actual: Hybrid) ✗
#    Generated in 3.6s
#    Full response: AI
#
# Explanation:
# The submission is a mix of human and AI elements. It contains insights from an experienced analyst, but also references to AI tools and their effectiveness. This is a clear example of a hybrid submission.
# """
# ```
#
# This Python code uses a simple rule-based approach to classify the submissions as either Human, AI, or Hybrid. It considers various features of the text, such as discourse features, style consistency, and the presence of AI-
#
# 📊 SUMMARY for IT, Submission 6
# ====================
# Domain: Information Technology
# Feedback Rating: 3.0/5.0
# AI Detection: Human (Incorrect)
# Total Time for Submission 6: 5.4s
#
# 💾 All results saved to phi2_results/all_test_results.json
# 🎉 Test completed successfully!
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py:3561: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
