# %% [markdown]
# NanoGPT

# %%
import requests
import json
from google.colab import userdata
from typing import List, Dict, Any

# %% [markdown]
# API Accessing

# %%
BASE_URL = "https://nano-gpt.com/api/v1"
API_KEY = "fe7dbca6-4709-4385-9698-acd163f901e6"

headers = {
    "Authorization": f"Bearer {API_KEY}",
    "Content-Type": "application/json",
    "Accept": "text/event-stream"
}

# %% [markdown]
# Function to communicate with the model

# %%
def stream_chat_completion(messages, model="chatgpt-4o-latest"):
    """
    Send a streaming chat completion request using the OpenAI-compatible endpoint.
    """
    data = {
        "model": model,
        "messages": messages,
        "stream": True  # Enable streaming
    }

    try:
        response = requests.post(
            f"{BASE_URL}/chat/completions",
            headers=headers,
            json=data,
            stream=True,
            timeout=180 # Add a timeout
        )
        response.raise_for_status() # Raises an HTTPError for bad responses (4xx or 5xx)
    except requests.exceptions.RequestException as e:
        print(f"An error occurred during the API request: {e}")
        return # Stop the generator if the request fails

    for line in response.iter_lines():
        if line:
            line = line.decode('utf-8')
            if line.startswith('data: '):
                line = line[6:]
            if line == '[DONE]':
                break
            try:
                chunk = json.loads(line)
                if chunk['choices'][0]['delta'].get('content'):
                    yield chunk['choices'][0]['delta']['content']
            except (json.JSONDecodeError, IndexError, KeyError):
                continue
# Out:
# Non-streaming API function defined.

# %% [markdown]
# Prompts

# %%
SYSTEM_PROMPT = "You are a careful academic assistant. Be precise and give clear structured output (not JSON, not CSV, no files)."


def build_detection_prompt(submission: str, few_shots: List[Dict[str, Any]]) -> List[Dict[str, str]]:
    """
    Academic Integrity Detector Prompt
    ----------------------------------
    Purpose:
        Classifies student submissions as Human, AI, or Hybrid (AI-assisted).

    Technique:
        - Role-based prompting
        - Few-shot support
        - CoT (reasoning encouraged but hidden from output)
        - Output in plain text

    Expected Output (example format in plain text):
        Label: Human | AI | Hybrid
        Rationale:
        - short bullet point 1
        - short bullet point 2
        Flags: style_inconsistency / high_verbatim / generic_phrasing / none
    """
    # Build few-shot block
    shot_texts = []
    for s in few_shots:
        shot_texts.append(
            f'Submission: """{s.get("final_submission","")}"""\n'
            f'Your analysis (2–4 bullet points): <analysis>\n'
            f'Label: {s.get("label_type","")}\n'
        )
    examples_block = "\n\n".join(shot_texts) if shot_texts else "/* no examples available */"

    user = f"""
You are an AI text-source classifier for academic integrity.
Decide whether the student submission is Human, AI, or Hybrid (AI-assisted).

Guidelines:
- Consider discourse features (specificity, subjectivity, personal context), style consistency, local/global coherence, repetitiveness, and cliché patterns.
- Hybrid = meaningful human writing with some AI assistance, or explicit admission of mixed use.

Examples:
{examples_block}

Now analyze the NEW submission and respond in plain text with the following structure:
Label: ...
Rationale:
- point 1
- point 2
Flags: ...
NEW submission:
\"\"\"{submission}\"\"\"\n
"""
    return [
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user", "content": user},
    ]


def build_feedback_prompt(domain: str, assignment_prompt: str, rubric_text: str, submission: str) -> List[Dict[str, str]]:
    """
    Rubric-Aligned Feedback Prompt
    ------------------------------
    Purpose:
        Generates structured, supportive feedback for a student submission.

    Technique:
        - Role-based prompting
        - Rubric-grounded evaluation
        - Output in plain text

    Expected Output (example format in plain text):
        Overall Summary:
        <2–4 sentence overview>

        Criteria Feedback:
        Criterion: <criterion_id>
        Rating: Excellent | Good | Average | Needs Improvement | Poor
        Reason:
        - point 1
        - point 2
        Improvement Tip: one concrete suggestion

        Overall Rating: Excellent | Good | Average | Needs Improvement | Poor
    """
    user = f"""
You are a supportive assessor. Provide actionable feedback aligned to the rubric.
Return plain structured text only (no JSON, no files).

Sections to include:
1) Overall Summary: 2–4 sentences on strengths and priorities.
2) Criteria Feedback: for each rubric criterion include:
   - Criterion
   - Rating (excellent, good, average, needs_improvement, poor)
   - Evidence (1–3 bullet points citing excerpts or behaviors)
   - Improvement Tip (one concrete step)
3) Overall Rating: Excellent | Good | Average | Needs Improvement | Poor

Context:
- Domain: {domain}
- Assignment prompt: {assignment_prompt}

Rubric (verbatim):
{rubric_text}

Student submission:
\"\"\"{submission}\"\"\"\n
"""
    return [
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user", "content": user},
    ]

# %% [markdown]
# Loading the dataset

# %%
import json
import os

def load_multiple_json_files(file_paths: list) -> list:
    """
    Loads multiple JSON files and returns a list of loaded data dictionaries.

    Args:
        file_paths (list): List of full file paths to JSON files.

    Returns:
        List of dictionaries, each representing the data from one JSON file.
    """
    loaded_data = []
    for file_name in file_paths:
        try:
            with open(file_name, 'r') as f:
                data = json.load(f)
                if 'domain' in data and 'submissions' in data:
                    print(f"Loaded domain '{data['domain']}' with {len(data['submissions'])} submissions from '{file_name}'.")
                    loaded_data.append(data)
                else:
                    print(f"WARNING: File '{file_name}' missing 'domain' or 'submissions' keys. Skipping.")
        except FileNotFoundError:
            print(f"ERROR: The file '{file_name}' was not found. Skipping.")
        except json.JSONDecodeError:
            print(f"ERROR: The file '{file_name}' is not a valid JSON. Skipping.")
    return loaded_data

# --- Example usage ---
file_list = [
    'accounting.json',
    'teaching.json',
    'psychology.json',
    'it.json',
    'engineering.json'
]

all_domains_data = load_multiple_json_files(file_list)
print(f"\nTotal domains loaded: {len(all_domains_data)}")
# Out:
# Loaded domain 'Accounting' with 6 submissions from 'accounting.json'.
# Loaded domain 'Teaching' with 6 submissions from 'teaching.json'.
# Loaded domain 'Psychology' with 6 submissions from 'psychology.json'.
# Loaded domain 'Information Technology' with 6 submissions from 'it.json'.
# Loaded domain 'Manufacturing Engineering' with 6 submissions from 'engineering.json'.
#
# Total domains loaded: 5

# %% [markdown]
# Evaluation Function

# %%
# Function to generate self-evaluation rating
def build_self_eval_prompt(rubric: Dict, essay: str, feedback: str) -> str:
    crit = [c.get('name','Criterion') for c in rubric.get('criteria',[])]
    crit_str = ", ".join(crit) if crit else "the rubric"
    return (
        "You are a strict but fair assessor. Rate how well the FEEDBACK addresses the rubric for the ESSAY.\n"
        "Rate on a 1-5 scale (integers only). Provide ONLY the number.\n\n"
        f"ESSAY:\n{essay}\n\n"
        f"RUBRIC CRITERIA: {crit_str}\n\n"
        f"FEEDBACK:\n{feedback}\n\n"
        "RATING (1-5): "
    )

# %% [markdown]
# Function to detect and generate feedback based on training data and prompt and also evaulate the model performance.

# %%
# Define allowed standard labels globally
ALLOWED_LABELS = ["AI", "Human", "Hybrid"]

from collections import defaultdict
import pandas as pd

# Initialize overall counters
overall_true = []
overall_pred = []

for domain_data in all_domains_data:
    domain = domain_data['domain']
    assignment_prompt = domain_data['prompt']
    rubric_text = json.dumps(domain_data['rubric'], indent=2)
    submissions = domain_data['submissions']

    # Domain-level counters
    domain_true = []
    domain_pred = []

    print(f"\n{'='*80}")
    print(f"=== STARTING EVALUATION FOR '{domain}' DOMAIN ===")
    print(f"{'='*80}\n")

    for i, submission_data in enumerate(submissions):
        submission_text = submission_data['final_submission']
        ground_truth_label = submission_data['label_type'].strip()

        # Normalize ground truth
        if ground_truth_label not in ALLOWED_LABELS:
            for label in ALLOWED_LABELS:
                if label.lower() in ground_truth_label.lower():
                    ground_truth_label = label
                    break
            else:
                ground_truth_label = "Unknown"

        print(f"{'-'*80}")
        print(f"Submission {i+1} (Ground Truth: {ground_truth_label})")
        print(f"{'-'*80}\n")

        # --- TASK 1: Detection ---
        few_shots = [s for j, s in enumerate(submissions) if i != j][:2]
        detection_messages = build_detection_prompt(submission_text, few_shots)
        full_detection = ""
        predicted_label = "Unknown"

        try:
            for chunk in stream_chat_completion(detection_messages):
                print(chunk, end='', flush=True)
                full_detection += chunk

            # --- Normalize predicted label ---
            for line in full_detection.splitlines():
                if "Label" in line:
                    predicted_label = line.split(":")[1].strip()
                    break

            # Standardize predicted label
            if predicted_label not in ALLOWED_LABELS:
                for label in ALLOWED_LABELS:
                    if label.lower() in predicted_label.lower():
                        predicted_label = label
                        break
                else:
                    predicted_label = "Unknown"

        except Exception as e:
            print(f"Error generating detection: {str(e)}")
            full_detection = "Error generating detection."

        # Add to domain and overall lists
        domain_true.append(ground_truth_label)
        domain_pred.append(predicted_label)
        overall_true.append(ground_truth_label)
        overall_pred.append(predicted_label)

        print("\n")

        # --- TASK 2: Feedback ---
        feedback_messages = build_feedback_prompt(
            domain=domain,
            assignment_prompt=assignment_prompt,
            rubric_text=rubric_text,
            submission=submission_text
        )
        full_feedback = ""
        try:
            for chunk in stream_chat_completion(feedback_messages):
                print(chunk, end='', flush=True)
                full_feedback += chunk
        except Exception as e:
            print(f"Error generating feedback: {str(e)}")
            full_feedback = "Error generating feedback."
        print("\n")

        # --- TASK 3: Self-Evaluation Rating ---
        print(">>> 3. Self-Evaluation Rating (1-5):")
        rating_prompt_text = build_self_eval_prompt(domain_data['rubric'], submission_text, full_feedback)
        rating_messages = [
            {"role": "system", "content": SYSTEM_PROMPT},
            {"role": "user", "content": rating_prompt_text},
        ]
        try:
            rating_response = get_chat_completion(rating_messages)
            print(rating_response)
        except Exception as e:
            print(f"Error generating rating: {str(e)}")

    # --- Domain-Level Confusion Matrix ---
    domain_cm = pd.crosstab(
        pd.Series(domain_true, name='Ground Truth'),
        pd.Series(domain_pred, name='Predicted'),
        rownames=['Ground Truth'],
        colnames=['Predicted'],
        dropna=False
    )
    print(f"\nConfusion Matrix for Domain '{domain}':")
    print(domain_cm)
    print(f"\n{'='*80}\n")

# --- Overall Confusion Matrix ---
overall_cm = pd.crosstab(
    pd.Series(overall_true, name='Ground Truth'),
    pd.Series(overall_pred, name='Predicted'),
    rownames=['Ground Truth'],
    colnames=['Predicted'],
    dropna=False
)
print("\nOverall Confusion Matrix Across All Domains:")
print(overall_cm)
# Out:
# ================================================================================
# === STARTING EVALUATION FOR 'Accounting' DOMAIN ===
# ================================================================================
#
# --------------------------------------------------------------------------------
# Submission 1 (Ground Truth: AI)
# --------------------------------------------------------------------------------
#
# Label: AI
#
# Rationale:
# - **Point 1**: The submission demonstrates polished, formal discourse with concise, technical explanation, a hallmark of machine-written content. It includes standard phrases often found in AI-generated text, such as "transformative shift," "significant improvements," and "tamper-proof audit trails."
# - **Point 2**: Style consistency and global coherence dominate without notable personal context or subjective framing; the language remains purely informational, dispensing dense facts without variability. Additionally, examples like "Ernst & Young uses its Blockchain Analyzer" and "PwC exploring blockchain-based auditing tools" are typical in AI-rendered writing that relies heavily on known institutional references.
# - **Point 3**: The submission lacks personal engagement or narrative-driven expressions, which are often human elements. Moreover, the segmentation of paragraphs uniformly reflects AI's structural precision, avoiding redundancy or stylistic deviations.
#
# Flags:
# - Presence of generic, well-rehearsed explanatory patterns.
# - No evidence of human-specific subjectivity or contextualized insights.
#
# **1) Overall Summary:**
# The submission demonstrates a solid understanding of blockchain technology and its implications for accounting, particularly in auditing and financial reporting. Strengths include clear explanations of key blockchain concepts and the effective use of real-world examples. To improve, the analysis of regulatory challenges could be more detailed, and the structure could benefit from more distinct organization of points.
#
# **2) Criteria Feedback:**
#
# **Criterion: Understanding of Blockchain Concepts**
# - **Rating:** Excellent
# - **Evidence:**
#   - Clearly defines blockchain principles like decentralization, immutability, and smart contracts.
#   - Maps these principles to accounting applications such as fraud detection, error reduction, and process automation.
#   - Provides comprehensive explanations of concepts like decentralized ledgers and smart contracts.
# - **Improvement Tip:** Consider briefly discussing additional blockchain elements, such as cryptographic security, to further enrich the explanation.
#
# **Criterion: Analysis of Accounting Impact**
# - **Rating:** Good
# - **Evidence:**
#   - Discusses benefits such as tamper-proof audit trails and real-time reporting.
#   - Mentions regulatory uncertainty and scalability issues as challenges.
#   - Highlights the role of enhanced transparency in decision-making.
# - **Improvement Tip:** Deepen the analysis by elaborating on how specific challenges (e.g., lack of blockchain-specific standards) affect smaller firms or particular auditing processes.
#
# **Criterion: Use of Real-World Examples/Case Studies**
# - **Rating:** Excellent
# - **Evidence:**
#   - References Ernst & Young’s Blockchain Analyzer for auditing cryptocurrency transactions.
#   - Mentions JPMorgan’s Quorum platform for interbank reconciliations.
#   - Includes PwC's exploration into blockchain-based auditing tools.
# - **Improvement Tip:** Enhance the integration of examples by comparing their effectiveness or approaches in addressing accounting challenges.
#
# **Criterion: Structure and Academic Style**
# - **Rating:** Good
# - **Evidence:**
#   - Demonstrates a formal academic tone and logical flow.
#   - Organizes key concepts and analysis within a cohesive essay.
#   - Some opportunities exist to better segment discussions on benefits versus challenges.
# - **Improvement Tip:** Use headings or clearer transitions to distinctly separate points on blockchain benefits, applications, and challenges for better readability.
#
# **3) Overall Rating:** Good
#
# >>> 3. Self-Evaluation Rating (1-5):
# 4
# --------------------------------------------------------------------------------
# Submission 2 (Ground Truth: AI)
# --------------------------------------------------------------------------------
#
# Label: AI
#
# Rationale:
# - The submission exhibits AI-like traits, including highly structured and formulaic phrasing with seamless integration of technical terms (e.g., "decentralized ledgers," "immutable records," "smart contracts"). There is no evident subjectivity or personal context that would signal human-authored input.
# - Discourse features like global coherence are strong, but the writing feels overly polished, featuring consistent use of clichés ("reliable audit trails," "reducing manual errors and intermediaries"), which are common signs of AI language models. Conciseness, lack of variability in sentence structure, and absence of experiential narratives indicate machine-generated text.
# - Specificity in examples (e.g., "Ernst & Young employs its Blockchain Analyzer") is presented without deeper elaboration, a feature often found in AI-written content when aiming for technical authority without human-derived insights.
#
# Flags:
# - No overt indicators of hybrid effort or personal/contextual input.
# - Submission uses real-world examples, but their superficial discussion leans toward an AI sourcing pattern.
#
# **Overall Summary:**
# This submission demonstrates a solid understanding of blockchain principles and their application to accounting, especially in areas such as auditing and financial reporting. Strengths include clear articulation of foundational blockchain concepts and the inclusion of relevant real-world examples. To enhance the analysis further, more depth could be added to the exploration of blockchain’s challenges and potential limitations in accounting.
#
# ---
#
# **Criteria Feedback:**
#
# 1. **Criterion:** Understanding of Blockchain Concepts
#    **Rating:** Excellent
#    **Evidence:**
#    - Clearly defines and discusses blockchain fundamentals like decentralization, immutability, and smart contracts.
#    - Maps these principles to accounting impacts such as improved efficiency, trust, and accuracy.
#    - Articulates how these attributes solve specific accounting issues, e.g., tamper-proof record keeping.
#    **Improvement Tip:** Delve deeper into technical nuances (e.g., scalability or consensus mechanisms) to show a more advanced understanding of blockchain's workings.
#
# 2. **Criterion:** Analysis of Accounting Impact
#    **Rating:** Good
#    **Evidence:**
#    - Discusses how blockchain simplifies audit trails for fraud detection and verification.
#    - Explains the automation benefits (e.g., real-time financial reporting and error reduction) through smart contracts.
#    - Notes specific mechanisms (e.g., transparency) that support financial reporting.
#    **Improvement Tip:** Expand on challenges or risks associated with blockchain adoption (e.g., cost of implementation, regulatory limitations) to provide a more balanced evaluation.
#
# 3. **Criterion:** Use of Real-World Examples/Case Studies
#    **Rating:** Excellent
#    **Evidence:**
#    - References Ernst & Young’s Blockchain Analyzer and its utility in cryptocurrency audits.
#    - Cites IBM’s blockchain application for supply chain financing to showcase real-time financial reporting.
#    - Examples are directly tied to accounting outcomes, demonstrating relevance.
#    **Improvement Tip:** Introduce additional industry-specific examples (e.g., insurance, taxation) to further reinforce the breadth of blockchain applications.
#
# 4. **Criterion:** Structure and Academic Style
#    **Rating:** Good
#    **Evidence:**
#    - Presenting arguments in a structured, clear, and formal manner.
#    - Logical flow of ideas, starting with an introduction and continuing into specific examples and analysis.
#    - Strong use of terminology appropriate for academic and professional accounting discussions.
#    **Improvement Tip:** Add subheadings to categorize key discussion points and ensure smoother transitions between sections for enhanced coherence.
#
# ---
#
# **Overall Rating:** Good
#
# >>> 3. Self-Evaluation Rating (1-5):
# 4
# --------------------------------------------------------------------------------
# Submission 3 (Ground Truth: Human)
# --------------------------------------------------------------------------------
#
# Label: Hybrid
#
# Rationale:
# - The submission reflects personal engagement with the topic ("As a business student fascinated by tech"), adding subjective and contextual elements indicative of human authorship.
# - The discourse includes specific examples and insights (e.g., IBM in supply chain finance, Deloitte testing blockchain auditing) that align with academic rigor. However, the consistent technical structure and polished phrasing throughout suggest potential AI assistance in refining the arguments.
# - While global coherence is maintained, some phrasing ("garbage in, garbage out") introduces a casual tone inconsistent with the more formal style elsewhere. This fluctuation hints at human intervention in modifying or mixing contributions.
#
# Flags:
# - Possible minor AI assistance in enhancing style consistency and technical clarity.
# - Mixed discourse mode combining personal input with refined, professional commentary (e.g., blending subjective observations with systematic technical descriptions).
#
# ### Overall Summary:
# The submission demonstrates enthusiasm for the topic of blockchain technology and its implications for accounting practices. The content highlights strengths in identifying use cases, linking blockchain concepts to accounting applications, and addressing both benefits and challenges. However, there is room for more detailed analysis and structure to enhance depth and academic rigor.
#
# ### Criteria Feedback:
#
# #### Criterion: Understanding of Blockchain Concepts
# - **Rating:** Good
# - **Evidence:**
#   - Mentions key blockchain principles like decentralization ("decentralized, tamper-proof ledger") and immutability ("cryptographically secure transaction recording").
#   - Connects these concepts to accounting applications such as reducing errors, fraud prevention, and automated reconciliations.
#   - Touches on the “triple-entry” system but doesn’t fully explain its mechanics or significance.
# - **Improvement Tip:** Expand the explanation of blockchain principles, such as smart contracts, and provide greater clarity on how these mechanisms work in accounting contexts to elevate understanding.
#
# ---
#
# #### Criterion: Analysis of Accounting Impact
# - **Rating:** Good
# - **Evidence:**
#   - Identifies key impacts like improved transparency ("real-time updates"), efficiency ("slashing audit times"), and fraud prevention ("tamper-proof ledger").
#   - Acknowledges challenges like "garbage in, garbage out" and high setup costs.
#   - Addresses complex implications like resistance to transparency and potential privacy concerns.
# - **Improvement Tip:** Broaden the analysis by discussing secondary effects, such as implications for regulatory compliance or how blockchain influences global accounting standards, with stronger evidence to support claims.
#
# ---
#
# #### Criterion: Use of Real-World Examples/Case Studies
# - **Rating:** Good
# - **Evidence:**
#   - References IBM’s blockchain use in supply chain finance and Deloitte’s testing of blockchain for audits.
#   - Provides relevant context for examples, demonstrating practical blockchain applications.
#   - Mentions a 2023 study but doesn’t elaborate on its details or methodology.
# - **Improvement Tip:** Include more specific details or additional case studies with quantitative evidence (e.g., outcomes or performance metrics) to reinforce the application of blockchain in accounting practices.
#
# ---
#
# #### Criterion: Structure and Academic Style
# - **Rating:** Average
# - **Evidence:**
#   - The submission has a conversational tone ("as a business student fascinated by tech") rather than formal academic language.
#   - Ideas are presented in a loosely organized structure without clear sections or transitions.
#   - The conclusion is brief and lacks synthesis of the key arguments.
# - **Improvement Tip:** Revise the essay with clearer headings, structured arguments, and formal academic style. Ensure smooth transitions between sections, and deepen the conclusion by summarizing insights and offering a future outlook.
#
# ---
#
# ### Overall Rating: Good
# The essay demonstrates a solid grasp of blockchain technology concepts and their relevance to accounting but would benefit from deeper analysis, clearer structure, and a more formal academic tone to reach excellence.
#
# >>> 3. Self-Evaluation Rating (1-5):
# 4
# --------------------------------------------------------------------------------
# Submission 4 (Ground Truth: Human)
# --------------------------------------------------------------------------------
#
# Label: Hybrid
#
# Rationale:
# - **Personal context and subjective tone**: The submission opens with a personal statement (“As a business student fascinated by tech”), which reflects a subjective perspective indicative of human writing. Throughout, the writer situates themselves and their observations, suggesting human involvement in crafting the narrative.
# - **Creative phrasing and balanced argumentation**: The response balances optimism about blockchain’s potential with a nuanced acknowledgment of its limitations (e.g., “blockchain’s only as good as the data entered” and “more of a complementary tool, best for specific cases”), which demonstrates original thought. This level of critical thinking and contextual balance is less typical of purely AI-generated text.
# - **Structured and specific examples**: Familiarity with real-world examples, such as “Deloitte testing blockchain” and “IBM using blockchain for supply chain finance,” is presented in a structured yet conversational style, suggesting an AI tool may have supplied some data or examples, but a human integrated and personalized the discussion.
# - **AI-assisted coherence and formulation of ideas**: The polished sentences, efficient organization, and broad coverage of blockchain’s potential applications (e.g., “triple-entry” bookkeeping, real-time financial reporting) suggest that the student likely relied on AI assistance to refine or supplement their content.
#
# Flags:
# - The polished nature of the language and specifically pre-organized ideas suggest potential AI assistance in generating certain sections or enhancing phrasing.
# - Use of clear technical examples like IBM, Deloitte, and GAAP compatibility aligns with AI patterns often seen in academic AI-generated content. However, the human perspective and personalization indicate meaningful human effort in shaping the text.
#
# **1) Overall Summary:**
# The submission provides an engaging and well-explained perspective on blockchain’s potential impact on accounting. Strengths include a clear understanding of concepts like decentralization and triple-entry, as well as relevant, real-world examples. However, the analysis could benefit from deeper exploration of challenges and clearer organization to enhance its academic rigor.
#
# **2) Criteria Feedback:**
#
# **Criterion: Understanding of Blockchain Concepts**
# - **Rating:** Excellent
# - **Evidence:**
#    - Clearly explains core blockchain principles like decentralization, immutability, and triple-entry systems.
#    - Demonstrates relevance to accounting, such as reducing errors and automation in bookkeeping.
#    - Connects blockchain’s properties to broader impacts like trust enhancement.
# - **Improvement Tip:** Expand slightly on advanced concepts like smart contracts and their tailored implications for accounting.
#
# **Criterion: Analysis of Accounting Impact**
# - **Rating:** Good
# - **Evidence:**
#    - Highlights benefits like reduced reconciliation, real-time auditing, and transparency in financial reporting.
#    - Mentions challenges, including data input reliability, high implementation costs, and regulatory readiness.
#    - Notes blockchain’s complementary rather than disruptive role in traditional accounting.
# - **Improvement Tip:** Deepen the analysis of specific challenges (e.g., privacy issues with transparent ledgers) and provide concrete suggestions for mitigating them.
#
# **Criterion: Use of Real-World Examples/Case Studies**
# - **Rating:** Good
# - **Evidence:**
#    - References IBM’s application of blockchain in supply chain finance.
#    - Discusses Deloitte’s use of blockchain in auditing experiments, showing industry relevance.
#    - Mentions blockchain’s transformative potential for stakeholders, like increased market transparency.
# - **Improvement Tip:** Add another example or expand on how current firms are overcoming blockchain-related hurdles (e.g., small businesses or standard-setting bodies).
#
# **Criterion: Structure and Academic Style**
# - **Rating:** Average
# - **Evidence:**
#    - Conversational introduction ("As a business student fascinated by tech") reduces academic tone.
#    - Lacks strong transitions between sections, leading to some disjointed points.
#    - Presentation of counterarguments (e.g., "blockchain’s only as good as the data entered") is valid but needs clearer development within an academic format.
# - **Improvement Tip:** Revise the structure for better flow, starting with a concise introduction, followed by well-organized evaluation points, and a more formal writing style.
#
# **3) Overall Rating:** Good
#
# >>> 3. Self-Evaluation Rating (1-5):
# 4
# --------------------------------------------------------------------------------
# Submission 5 (Ground Truth: Hybrid)
# --------------------------------------------------------------------------------
#
# Label: AI
#
# Rationale:
# - The submission demonstrates a highly structured and coherent exposition with uniform language and a formal tone, which is characteristic of AI-generated content. There is a lack of personal context, creativity, or subjective interpretation typical of human-authored work.
# - The writing relies on generalizations, technical explanations, and real-world examples (e.g., blockchain’s impact on auditing and financial reporting) presented in a formulaic manner. These features align with common AI-generated outputs that synthesize information from various sources in an impartial style.
# - There is no evidence of stylistic variability or human-specific discourse features, such as anecdotal reasoning, emotional expressions, or personalized framing.
#
# Flags: None
#
# **Overall Summary**
# The submission demonstrates a good understanding of blockchain technology's foundational concepts and discusses its relevance to accounting comprehensively. Key strengths include the clear explanation of how blockchain impacts auditing and financial reporting, supported by specific examples. To improve, more depth and real-world case studies could be used to solidify the discussion and enhance the analysis further.
#
# **Criteria Feedback**
#
# **Criterion**: *Understanding of Blockchain Concepts*
# **Rating**: Good
# **Evidence**:
# - Clearly describes blockchain features: decentralized, immutable ledger and smart contracts.
# - Maps these concepts to accounting applications like automated bookkeeping and instant reconciliation.
# **Improvement Tip**: Expand on technical details (e.g., smart contract functionality or consensus mechanisms) to demonstrate deeper knowledge.
#
# **Criterion**: *Analysis of Accounting Impact*
# **Rating**: Excellent
# **Evidence**:
# - Discusses specific impacts on auditing (simplified audit trail, real-time auditing).
# - Identifies challenges like auditor expertise and privacy concerns.
# - Relates blockchain to faster reporting cycles and reduced discrepancies.
# **Improvement Tip**: Provide further analysis of blockchain’s long-term potential evolution in accounting, such as regulatory changes or global adoption trends.
#
# **Criterion**: *Use of Real-World Examples/Case Studies*
# **Rating**: Average
# **Evidence**:
# - Mentions general examples (automated bookkeeping, reducing reconciliation time).
# - Includes plausible scenarios like real-time auditing.
# **Improvement Tip**: Incorporate specific, documented case studies or notable implementations of blockchain in accounting (e.g., companies like IBM or PwC using blockchain for financial processes).
#
# **Criterion**: *Structure and Academic Style*
# **Rating**: Good
# **Evidence**:
# - Well-structured arguments with logical flow from transparency to challenges and implications.
# - Formal academic tone maintained throughout.
# **Improvement Tip**: Improve transitions between sections to enhance cohesion further and ensure your arguments are connected seamlessly.
#
# **Overall Rating**: Good
#
# >>> 3. Self-Evaluation Rating (1-5):
# 4
# --------------------------------------------------------------------------------
# Submission 6 (Ground Truth: Hybrid)
# --------------------------------------------------------------------------------
#
# Label: Hybrid
#
# Rationale:
# - **Coherence and integration of human-specific contextual framing:** The submission reflects structured explanations and some depth of analysis in addressing blockchain's impact, challenges, and professional adaptation, demonstrating human-level critical thinking about practical implications and roles in accounting.
# - **AI-like syntactic patterns and efficiency-focused phrasing:** The text heavily incorporates polished transitions, descriptive overviews, and neatly categorized points (e.g., "enhancing trust and efficiency," "streamlining processes"), which are characteristic of AI-generated contributions.
#
# Flags:
# - **Stylistic uniformity and generalized phrasing suggest AI intervention:** The submission includes common patterns like over-clarified transitions ("such as invoice settlements, minimizing manual intervention and costs") and technical breadth spread evenly, which is indicative of AI assistance.
# - **Absence of direct personal insights or novel framing:** The essay lacks subjectivity or personal engagement, which may hint at reliance on external tools to streamline content.
#
# **Overall Summary:**
# The submission demonstrates a solid understanding of blockchain technology and its relevance to accounting, with thoughtful analysis of its potential advantages and challenges. Key strengths include the integration of specific blockchain features like smart contracts and transparency in auditing. To improve, the essay could incorporate real-world examples and further enhance structured argumentation.
#
# ---
#
# ### **Criteria Feedback**
#
# 1. **Criterion: Understanding of Blockchain Concepts**
#    - **Rating:** Excellent
#    - **Evidence:**
#      - Clearly explains core blockchain principles such as decentralization ("decentralized, immutable ledger ensures real-time, tamper-proof recording of transactions").
#      - Maps blockchain features (e.g., smart contracts) to accounting tasks ("automates routine tasks, such as invoice settlements, minimizing manual intervention and costs").
#      - Draws connections between blockchain’s immutability and fraud/error reduction.
#    - **Improvement Tip:** Provide brief elaborations for less-technical readers, especially for terms like "distributed ledger technology," to ensure full accessibility of concepts.
#
# 2. **Criterion: Analysis of Accounting Impact**
#    - **Rating:** Good
#    - **Evidence:**
#      - Discusses enhanced transparency and efficiency in financial reporting ("automated, accurate data aggregation, streamlining processes like reconciliation").
#      - Highlights blockchain’s transformative role in auditing through real-time data access and transparent audit trails.
#      - Mentions challenges such as regulatory uncertainty and the need for new auditing standards.
#    - **Improvement Tip:** Go deeper into how specific risks (e.g., "smart contract vulnerabilities") directly affect auditing and financial reporting, supported by examples or hypothetical scenarios.
#
# 3. **Criterion: Use of Real-World Examples/Case Studies**
#    - **Rating:** Needs Improvement
#    - **Evidence:**
#      - The essay provides no real-world examples or specific case studies, which limits the application of theoretical insights.
#      - The analysis focuses on conceptual and potential impacts without grounding in practical implementations.
#    - **Improvement Tip:** Include at least one real-world example, such as a firm using blockchain for auditing (e.g., "PwC's use of blockchain audit tools") or financial reporting, to enhance the practical relevance of arguments.
#
# 4. **Criterion: Structure and Academic Style**
#    - **Rating:** Good
#    - **Evidence:**
#      - The essay has a coherent flow, starting with a broad overview, followed by discussions on specific impacts.
#      - Maintains a formal tone throughout.
#      - Some sections lack transitions (e.g., the shift from financial reporting to auditing feels abrupt).
#    - **Improvement Tip:** Use explicit linking phrases to enhance narrative transitions (e.g., “Building on this” or “In addition to financial reporting impacts…”). This will improve the logical flow between points.
#
# ---
#
# **Overall Rating:** Good
#
# >>> 3. Self-Evaluation Rating (1-5):
# 4
#
# Confusion Matrix for Domain 'Accounting':
# Predicted     AI  Hybrid
# Ground Truth
# AI             2       0
# Human          0       2
# Hybrid         1       1
#
# ================================================================================
#
#
# ================================================================================
# === STARTING EVALUATION FOR 'Teaching' DOMAIN ===
# ================================================================================
#
# --------------------------------------------------------------------------------
# Submission 1 (Ground Truth: AI)
# --------------------------------------------------------------------------------
#
# Label: Hybrid
#
# Rationale:
# - The submission demonstrates high academic rigor, structured coherence, and extensive use of peer-reviewed sources, resembling AI-generated writing patterns that focus on informational density and polished formal tone.
# - However, there is evidence of nuanced perspectives and contextual adaptation for diverse learners (e.g., multilingual and special needs examples), which suggests human intervention or personal subjectivity not typically inherent to AI-generated text alone.
# - The balanced use of citations and the seamless, coherent integration of highly specific examples indicate potential AI support for generating or refining content, coupled with meaningful human input for customizing details.
#
# Flags:
# - Possible over-reliance on AI for initial drafting or expanding areas of technical detail.
# - Monitor for continued human engagement to ensure originality and academic integrity.
#
# **1) Overall Summary:**
# The submission demonstrates a solid understanding of key early literacy concepts, developmental milestones, and evidence-based strategies for pre-reading skills. The essay is structured well and references credible research effectively. The primary area for improvement lies in providing deeper critical analysis of the strategies and expanding the practical examples of diversity considerations.
#
# **2) Criteria Feedback:**
#
# **Criterion:** Understanding of Early Literacy Development
# **Rating:** Excellent
# **Evidence:**
# - Clearly discusses foundational components such as phonological awareness, print knowledge, and vocabulary acquisition.
# - Explains developmental progression from ages 3 to 6, citing specific milestones (e.g., environmental print recognition, letter-sound associations, phonemic segmentation).
# - Properly integrates research examples such as Justice & Ezell (2002) and Lonigan et al. (2008).
# **Improvement Tip:** Incorporate specific examples that illustrate how milestones are observed or assessed in classroom practice to strengthen application.
#
# **Criterion:** Evaluation of Evidence-Based Approaches
# **Rating:** Good
# **Evidence:**
# - Highlights strategies like dialogic reading and phonemic awareness games, with clear explanation of their benefits for literacy (e.g., fostering vocabulary, inferencing, and decoding).
# - Supports strategies with credible research citations (e.g., Justice & Ezell, Lonigan et al.).
# **Improvement Tip:** Expand critical evaluation by comparing strengths and limitations of different approaches (e.g., dialogic reading versus shared book reading in specific contexts).
#
# **Criterion:** Consideration of Diversity and Inclusion
# **Rating:** Good
# **Evidence:**
# - Mentions adaptations for multilingual learners, such as integrating home languages and culturally relevant stories.
# - Discusses supports for children with developmental delays, including visual aids and multisensory activities.
# **Improvement Tip:** Provide more concrete examples of how these adaptations are implemented in practice, such as specific activities or materials tailored to diverse needs.
#
# **Criterion:** Research Integration and Referencing
# **Rating:** Excellent
# **Evidence:**
# - References multiple peer-reviewed sources (e.g., Neuman and Wright; Snow) to substantiate claims.
# - Citations are accurate and sources are directly relevant to the topic.
# **Improvement Tip:** Ensure the integration of sources also includes nuanced analysis rather than primarily supporting general claims.
#
# **Criterion:** Structure and Academic Writing
# **Rating:** Excellent
# **Evidence:**
# - Paragraph is logically structured and flows coherently with clarity in presenting ideas.
# - Maintains formal academic tone, precise language, and correct grammar.
# **Improvement Tip:** Consider segmenting extended paragraphs into shorter sections for readability and focus on distinct ideas.
#
# **3) Overall Rating:** Good
#
# While the submission is well-informed and academically rigorous, further critical analysis of evidence-based strategies and broader examples of diversity considerations would lift the work to an excellent standard.
#
# >>> 3. Self-Evaluation Rating (1-5):
# 4
# --------------------------------------------------------------------------------
# Submission 2 (Ground Truth: AI)
# --------------------------------------------------------------------------------
#
# Label: Hybrid
#
# Rationale:
# - The submission demonstrates a formal tone and structured academic style consistent with AI-generated text, especially in its concise summaries, reliance on evidence-based practices, and inclusion of citations (e.g., "Whitehurst et al., 1994").
# - However, the final sentence introduces subjective critique ("more detail on implementation could strengthen the analysis"), which aligns more with human input or reflective adjustments. This blend of rigor and personal commentary suggests human involvement in editing or augmenting AI-produced output.
# - The writing lacks significant repetition, clichés, or abrupt shifts in style, adding to the likelihood of a human revision layer on a foundation that may involve AI.
#
# Flags: Minor likelihood of AI base text with human modifications; the subjective critique is a key marker.
#
# 1) **Overall Summary**
# The submission demonstrates a solid understanding of early literacy concepts and some evidence-based approaches, particularly shared book reading. Strengths include the integration of credible research and attention to how strategies can be adapted for diverse learners. Priorities for improvement include providing more specific analysis of strategy implementation and exploring diverse learners' needs in greater detail.
#
# 2) **Criteria Feedback**
#
#    - **Criterion:** Understanding of Early Literacy Development
#      - **Rating:** Good
#      - **Evidence:**
#        - Describes early literacy components like phonological awareness, vocabulary, and print knowledge.
#        - Includes developmental progression from letter recognition to blending sounds.
#      - **Improvement Tip:** Expand on specific developmental milestones, such as examples of key skills expected at different ages within the 3–6 range.
#
#    - **Criterion:** Evaluation of Evidence-Based Approaches
#      - **Rating:** Average
#      - **Evidence:**
#        - Identifies shared book reading and phonemic games as evidence-based strategies.
#        - References research on the positive effects of repeated reading and interactive questioning (Whitehurst et al., 1994).
#      - **Improvement Tip:** Provide a deeper analysis of how these approaches work in practice (e.g., specific steps, challenges, or adaptations for diverse settings). Include additional strategies for a comprehensive evaluation.
#
#    - **Criterion:** Consideration of Diversity and Inclusion
#      - **Rating:** Average
#      - **Evidence:**
#        - Mentions the role of bilingual books and culturally familiar content.
#        - Recognizes the need to adapt strategies for learners from diverse backgrounds.
#      - **Improvement Tip:** Offer concrete examples of inclusive practices tailored to specific learner needs, such as linguistic support for English language learners or strategies for children with developmental delays.
#
#    - **Criterion:** Research Integration and Referencing
#      - **Rating:** Good
#      - **Evidence:**
#        - Cites an academic source (Whitehurst et al., 1994) to support claims.
#        - Research aligns with the discussion of evidence-based approaches.
#      - **Improvement Tip:** Include a broader range of peer-reviewed studies to reinforce claims and demonstrate extensive research integration.
#
#    - **Criterion:** Structure and Academic Writing
#      - **Rating:** Good
#      - **Evidence:**
#        - Writing is logically structured with a clear introduction, body, and conclusion.
#        - Maintains a mostly formal academic tone with minimal grammatical issues.
#      - **Improvement Tip:** Refine sentence structures to enhance clarity and flow. Ensure all expressions are concise and aligned with academic conventions.
#
# 3) **Overall Rating:** Good
#
# >>> 3. Self-Evaluation Rating (1-5):
# 4
# --------------------------------------------------------------------------------
# Submission 3 (Ground Truth: Human)
# --------------------------------------------------------------------------------
#
# Label: Hybrid
#
# Rationale:
# - **Point 1:** The submission blends formal academic discourse with a slightly subjective tone, evidenced by phrases such as "critical phase in a child's life," which suggest some level of personal engagement or emphasis typical of human-written text. The writing also exhibits human-like specificity, referencing developmental progression in phonological awareness and vocabulary acquisition, but lacks the dense academic structuring of purely AI-generated text.
# - **Point 2:** Integration of sources like Lonigan et al. (2000) and precise descriptions of literacy milestones reflect a structured, probably AI-assisted approach in academic style and coherence. However, subjectivity and engagement point to human input, particularly in passages that go beyond purely formal analysis (e.g., "especially between the ages of 3 and 6, where so much foundational learning takes place").
#
# Flags:
# - Possible AI assistance in maintaining formal tone, coherence, and technical accuracy in citations and phrasing.
#
# **Overall Summary**
# The submission covers foundational aspects of early literacy development effectively, emphasizing phonological awareness, vocabulary, and print knowledge. Strengths include a clear understanding of developmental milestones informed by research, though priorities should include evaluation of instructional approaches, diversity considerations, and integration of additional sources for a comprehensive analysis.
#
# ---
#
# **Criteria Feedback**
#
# 1. **Criterion: Understanding of Early Literacy Development**
#    - **Rating:** Good
#    - **Evidence:**
#      - Clearly outlines foundational skills such as phonological awareness, vocabulary acquisition, and print knowledge.
#      - Includes developmental progression insights, citing Lonigan et al. (2000) regarding phonological awareness stages.
#    - **Improvement Tip:** Expand discussion to cover additional developmental milestones (e.g., narrative skills and alphabet knowledge) to demonstrate deeper understanding.
#
# 2. **Criterion: Evaluation of Evidence-Based Approaches**
#    - **Rating:** Needs Improvement
#    - **Evidence:**
#      - No instructional methods or interventions are identified (e.g., dialogic reading, shared book reading).
#      - No evaluation or evidence-based analysis is provided.
#    - **Improvement Tip:** Introduce and critique specific evidence-based strategies that support pre-reading skills, such as phonemic games or interactive reading activities, supported by relevant studies.
#
# 3. **Criterion: Consideration of Diversity and Inclusion**
#    - **Rating:** Needs Improvement
#    - **Evidence:**
#      - Does not address how literacy approaches might be adapted for diverse learners (e.g., ESL children or those with disabilities).
#      - No mention of linguistic or cultural considerations.
#    - **Improvement Tip:** Incorporate discussion on inclusive strategies, such as using multilingual resources or individualized support plans for developmental delays.
#
# 4. **Criterion: Research Integration and Referencing**
#    - **Rating:** Average
#    - **Evidence:**
#      - Cites Lonigan et al. (2000), a credible academic source, but minimal integration of additional research.
#      - Missing references for vocabulary and print development claims.
#    - **Improvement Tip:** Use and cite multiple peer-reviewed studies to strengthen arguments, ensuring correct and consistent referencing.
#
# 5. **Criterion: Structure and Academic Writing**
#    - **Rating:** Good
#    - **Evidence:**
#      - Essay is cohesive and flows logically, with appropriate academic tone.
#      - Language is clear and grammatically correct; minor improvements needed for transitions between concepts.
#    - **Improvement Tip:** Develop a stronger introduction and conclusion to frame the discussion and connect key ideas comprehensively.
#
# ---
#
# **Overall Rating:** Needs Improvement
#
# >>> 3. Self-Evaluation Rating (1-5):
# 4
# --------------------------------------------------------------------------------
# Submission 4 (Ground Truth: Human)
# --------------------------------------------------------------------------------
#
# Label: **Human**
#
# Rationale:
# - The submission exhibits subjectivity and a conversational tone, reflecting a personal and intuitive human writing style rather than rigid academic formalism or algorithmic structuring. Local coherence is maintained, but the text lacks the global coherence and deep rigor typical of AI-generated submissions or AI-assisted work.
# - There is little evidence of cliché patterns or excessive repetitiveness, and the level of detail provided is more general than typical AI drafting output, which often includes precise citations, exhaustive examples, or dense informational content. The lack of citations and specific theoretical anchoring further highlights the human origin.
#
# Flags:
# - The response is low on academic depth and formal style, with room for further elaboration or inclusion of evidence-based approaches. It reflects an informal understanding rather than a highly structured scholarly output.
#
# **Overall Summary**:
# The submission demonstrates a foundational understanding of early literacy development, highlighting key pre-reading skills and developmental milestones. While the writing effectively explains some aspects of early literacy, deeper analysis, evidence-based evaluation, and consideration of diverse learners are areas needing further development to meet the assignment’s comprehensive goals.
#
# ---
#
# **Criteria Feedback**:
#
# **Criterion**: *Understanding of Early Literacy Development*
# - **Rating**: Good
# - **Evidence**:
#   - The submission identifies foundational skills (e.g., phonological awareness, vocabulary, print knowledge).
#   - It explains developmental milestones like rhyming words around age 4 and recognizing letters before school.
#   - It acknowledges that early literacy development happens pre-school.
# - **Improvement Tip**: Expand on how these skills interact and develop over time, using specific examples or sequences backed by research (e.g., stages of phonological awareness).
#
# ---
#
# **Criterion**: *Evaluation of Evidence-Based Approaches*
# - **Rating**: Poor
# - **Evidence**:
#   - No mention of instructional strategies or evidence-based approaches supporting early literacy (e.g., dialogic reading).
# - **Improvement Tip**: Introduce and evaluate at least one evidence-based strategy (e.g., shared book reading), linking it to supporting research and detailing how it promotes key pre-reading skills.
#
# ---
#
# **Criterion**: *Consideration of Diversity and Inclusion*
# - **Rating**: Poor
# - **Evidence**:
#   - No discussion of how early literacy approaches can be adapted for diverse learners.
# - **Improvement Tip**: Incorporate examples showing how strategies might be made inclusive for children from different linguistic or cultural backgrounds or with developmental delays.
#
# ---
#
# **Criterion**: *Research Integration and Referencing*
# - **Rating**: Needs Improvement
# - **Evidence**:
#   - The submission lacks integration of academic sources or referencing.
# - **Improvement Tip**: Integrate research-based studies or data (e.g., citing developmental literacy studies) to substantiate claims, using a formal referencing style.
#
# ---
#
# **Criterion**: *Structure and Academic Writing*
# - **Rating**: Good
# - **Evidence**:
#   - The writing is clear, logical, and free of grammatical errors.
#   - The structure introduces the topic effectively and maintains focus.
# - **Improvement Tip**: Add a formal conclusion summarizing key points and formally transitioning to recommendations or further implications.
#
# ---
#
# **Overall Rating**: Needs Improvement
#
# >>> 3. Self-Evaluation Rating (1-5):
# 3
# --------------------------------------------------------------------------------
# Submission 5 (Ground Truth: Hybrid)
# --------------------------------------------------------------------------------
#
# **Label:** Hybrid (AI-assisted)
#
# **Rationale:**
# - The writing demonstrates clear organization, detailed explanation, and a formal tone that is characteristic of academic writing, which is consistent with AI-generated text. However, there are small elements of personal context or variability in phrasing (e.g., "The child rapidly acquires new vocabulary") that are slightly more human-like and suggest possible manual edits or additions.
# - Discourse features such as the combination of general developmental trends ("aged between 3 and 6") with subtle specificity ("starting with larger sound chunks") suggest a mixture of automated content structuring and human selected refinements. Nonetheless, there is no explicit admission of mixed input.
#
# **Flags:**
# - None evident in terms of explicit misuse, but stylistic shifts and high academic polish signal potential AI contribution.
#
# **Overall Summary:**
# The submission demonstrates a foundational understanding of early literacy development and includes relevant concepts such as phonological awareness, vocabulary acquisition, and print knowledge. However, critical analysis of evidence-based approaches and considerations for diversity are missing, which limits scope and depth of assessment.
#
# ---
#
# ### **Criteria Feedback**
#
# #### **1. Understanding of Early Literacy Development**
# - **Rating:** Good
# - **Evidence:**
#   - Explains foundational concepts such as phonological awareness, vocabulary acquisition, and print knowledge with accurate definitions and developmental progression.
#   - Mentions research from Lonigan et al. (2000) to describe the gradual development of phonological awareness.
#
# - **Improvement Tip:** Add additional examples or discuss other components, such as emergent writing or narrative skills, to further enrich the discussion of early literacy milestones.
#
# ---
#
# #### **2. Evaluation of Evidence-Based Approaches**
# - **Rating:** Needs Improvement
# - **Evidence:**
#   - Does not evaluate instructional methods or interventions like dialogic reading, phonemic games, or shared book reading.
#   - Fails to critique or provide evidence for how these strategies support pre-reading skills in young learners.
#
# - **Improvement Tip:** Incorporate at least one or two evidence-based strategies with supporting research (e.g., dialogue-based reading improves vocabulary or phonemic games enhance sound manipulation) to strengthen evaluation.
#
# ---
#
# #### **3. Consideration of Diversity and Inclusion**
# - **Rating:** Poor
# - **Evidence:**
#   - No mention of how approaches can be adapted for diverse learners, such as those from different linguistic backgrounds or children with developmental delays.
#   - Submission lacks references to inclusive practices or customization of methods.
#
# - **Improvement Tip:** Include considerations on adapting literacy strategies for learners with diverse linguistic, cultural, or developmental needs. For example, use bilingual picture books for multilingual learners or tactile resources for children with motor challenges.
#
# ---
#
# #### **4. Research Integration and Referencing**
# - **Rating:** Average
# - **Evidence:**
#   - References Lonigan et al. (2000), but integration is limited to one source without broader exploration of other relevant studies.
#   - Citation style is not clearly defined, suggesting minor gaps in academic referencing practices.
#
# - **Improvement Tip:** Integrate more peer-reviewed sources to provide a well-rounded analysis. Ensure proper referencing format and consistent citation practices throughout.
#
# ---
#
# #### **5. Structure and Academic Writing**
# - **Rating:** Good
# - **Evidence:**
#   - Well-structured with clear introduction and body; concepts flow logically and are expressed in an academic tone.
#   - Minor areas might benefit from richer transition phrases or deeper elaboration on ideas.
#
# - **Improvement Tip:** Add a conclusion summarizing implications of early literacy development. Consider refining sentence transitions for smoother reading.
#
# ---
#
# ### **Overall Rating:** Needs Improvement
# While the submission demonstrates some strengths, such as accurate descriptions of early literacy development and logical structure, it lacks critical evaluation of evidence-based approaches, diversity considerations, and integration of multiple research sources. Addressing these areas will significantly improve the submission's depth and alignment with the rubric criteria.
#
# >>> 3. Self-Evaluation Rating (1-5):
# 3
# --------------------------------------------------------------------------------
# Submission 6 (Ground Truth: Hybrid)
# --------------------------------------------------------------------------------
#
# Label: Hybrid (AI-assisted)
#
# Rationale:
# - The writing exhibits overall clear structure and focus on literacy milestones within the specified age range, but it lacks the depth, specificity, and range of academic citations present in advanced AI-only writing. The phrasing (e.g., "does not need to begin with school age" or "handle books") feels less formal and slightly more subjective than the typically polished writing of AI.
# - However, certain stylistic features such as the precision in summarizing developmental progression ("most children are able to rhyme simple words...") and the use of well-constructed sentences with smooth transitions suggest possible AI involvement in drafting or editing. The content also aligns with common AI outputs on literacy development, implying it may have been generated or supplemented with AI tools.
#
# Flags:
# ...
#
# 4. **Criterion**: Depth of Analysis
#    - **Rating**: Needs Improvement
#    - **Evidence**:
#      - Fails to justify why specific layout choices improve efficiency or reduce safety risks. For example, the benefit of placing machines a certain way is not explained in measurable terms.
#      - The safety measures, such as guard rails and signs, are mentioned without discussing how these align with regulatory standards (e.g., OSHA guidelines) or production-specific hazards.
#    - **Improvement Tip**: Provide detailed justifications and include specific examples, such as how a particular layout reduces cycle time or how safety protocols mitigate specific hazards.
#
# 5. **Criterion**: Language & Presentation
#    - **Rating**: Good
#    - **Evidence**:
#      - The submission is largely free of grammatical errors and written in a clear, concise tone.
#      - However, the language lacks professionalism at times (e.g., “moves around easily” could be replaced with “ensures efficient employee movement to minimize idle time”).
#    - **Improvement Tip**: Adopt more formal and precise phrasing to enhance the authority and technical professionalism of the writing.
#
# ### Overall Rating: Average
#
# ### Action Plan:
# 1. Expand the scope by addressing all the critical phases of production line setup, from supply chain considerations to end-product testing.
# 2. Use precise engineering terminology and demonstrate a stronger grasp of manufacturing principles such as lean practices or ergonomic design.
# 3. Provide specific examples and measurable outcomes to strengthen the depth of analysis (e.g., “A U-shaped layout minimized worker travel time by 15%”).
# 4. Utilize headings or bullet points to organize content and improve clarity.
# 5. Refine the professional tone of the language for greater technical credibility.
#
# >>> 3. Self-Evaluation Rating (1-5):
# 3
# --------------------------------------------------------------------------------
# Submission 4 (Ground Truth: Human)
# --------------------------------------------------------------------------------
#
# Label: Hybrid
#
# Rationale:
# - There are clear signs of human-authored writing, including subjective simplicity in explanation ("They look at drawings and talk with the designers"), use of accessible language, and personalization of context ("This helps save time and avoids confusion"). These traits suggest meaningful human effort and a conversational tone.
# - However, the structure and phrasing reflect distinctive AI characteristics, such as the repetitive description ("safety is also important, so they put in emergency stops, signs, and barriers..."), emphasis on straightforward list-like sequencing, and absence of nuanced discourse depth or elaboration on technical specificity typical of engineering expertise.
#
# Flags:
# - Potential oversimplification likely influenced by AI assistance.
# - Lack of technical terminology and formal coherence often expected in specialized academic writing.
#
# **Overall Summary**
# The submission effectively conveys a basic overview of how a manufacturing engineer sets up a production line, including considerations for tools, machine placement, efficiency, and safety. Strengths include addressing key phases logically and emphasizing practical safety measures. However, the explanation lacks depth, technical terminology, and detailed reasoning that align with advanced manufacturing engineering principles.
#
# ---
#
# **Criteria Feedback**
#
# **Criterion 1: Scope & Comprehensiveness**
# - **Rating**: Average
# - **Evidence**:
#   - Mentions initial design steps such as reviewing drawings and breaking work into steps.
#   - Covers equipment layout and efficiency considerations, e.g., placing machines in order to save time and avoid confusion.
#   - Includes basic safety measures like emergency stops and barriers.
# - **Improvement Tip**: Expand on the phases by incorporating specific sub-processes (e.g., equipment calibration or assembly validation) or advanced safety protocols beyond physical barriers and emergency stops.
#
# **Criterion 2: Technical Acumen**
# - **Rating**: Average
# - **Evidence**:
#   - Demonstrates an elementary understanding of production line setup but uses generalized terms such as "machines" without specifying types of equipment or technical aspects like automation or lean practices.
#   - Lacks precise engineering terminology such as "ergonomics" (instead, referred to as "avoids heavy lifting").
# - **Improvement Tip**: Use more precise language and include advanced technical concepts like takt time, line balancing, or machinery-specific details to demonstrate deeper knowledge of manufacturing workflows.
#
# **Criterion 3: Clarity & Structure**
# - **Rating**: Good
# - **Evidence**:
#   - Organizes the explanation into logical steps: understand the product, match tools to tasks, optimize machine layout, and perform safety checks.
#   - The flow is easy to follow, with transitions between points, e.g., moving from efficiency concerns to safety protocols.
# - **Improvement Tip**: Enhance clarity further by structuring sections explicitly (e.g., Introduction, Equipment Layout, Efficiency, and Safety) and transitioning more smoothly between phases for a polished response.
#
# **Criterion 4: Depth of Analysis**
# - **Rating**: Average
# - **Evidence**:
#   - Basic justifications are given for decisions, e.g., machine placement "to save time and avoid confusion," and safety measures "to keep people safe."
#   - Lacks illustrative examples or specific reasoning, such as diagrams, efficiency calculations, or ergonomic considerations.
# - **Improvement Tip**: Incorporate specific examples (e.g., "placing an XYZ conveyor by the assembly line to improve flow") and detailed reasons for each choice, linking them to measurable efficiency or safety outcomes.
#
# **Criterion 5: Language & Presentation**
# - **Rating**: Good
# - **Evidence**:
#   - Writing is clear and free of grammatical errors. Ideas are presented in a professional tone.
#   - Lacks advanced technical language but maintains readability throughout.
# - **Improvement Tip**: Use more sophisticated phrasing to reflect professional engineering standards. Integrate technical vocabulary to align with industry best practices.
#
# ---
#
# **Overall Rating**: Average
#
# While the response shows foundational knowledge of production line setup, it needs greater technical depth, comprehensive analysis, and advanced terminology to meet higher rubric standards. Focus on adding specific examples, detailed reasoning, and precise engineering language for improvement.
#
# >>> 3. Self-Evaluation Rating (1-5):
# 3
# --------------------------------------------------------------------------------
# Submission 5 (Ground Truth: Hybrid)
# --------------------------------------------------------------------------------
#
# Label: Hybrid
#
# Rationale:
# - **Discourse features**: While the submission contains technical accuracy and specificity consistent with AI-generated content, it also demonstrates examples and contextual commentary (e.g., "For example, a compact U-shaped layout can reduce motion waste and improve team communication") that suggest the presence of human reasoning or anecdotal incorporation.
# - **Style consistency**: The writing generally retains a formal technical tone but includes elements of human subjectivity or prioritization (such as emphasizing safety as integral "from the beginning"), which aligns with a hybrid composition.
# - **Local/global coherence**: The submission flows logically but includes slightly more personalized phrasing compared to uniform AI outputs.
# - **Cliché patterns**: While professional phrasing is present, such as "data-driven adjustments" or "lean approaches," the mixture of structured technical descriptions with contextual examples hints at human intervention.
#
# Flags:
# - The balanced blend of specific technical language and practical examples suggests AI-assisted editing or augmentation.
# - No explicit admission of AI use, but certain stylistic decisions and incorporation of human-like commentary point to hybridization.
#
# **Overall Summary**:
# This submission demonstrates a solid understanding of the production line setup process, including key considerations like efficiency and safety. The response shows strengths in recognizing and applying essential manufacturing engineering principles, though there is room for additional depth and specificity in some areas.
#
# ---
#
# **Criteria Feedback**:
#
# 1. **Criterion**: Scope & Comprehensiveness
#    **Rating**: Good
#    **Evidence**:
#    - Covers phases including design review, material requirements, equipment selection, layout design, efficiency analysis, safety integration, and trial adjustments.
#    - Acknowledges tools like Gantt charts, process maps, cellular manufacturing layouts, and takt time analysis.
#    - Lacks detailed exploration of specific assembly steps and integration of equipment into production.
#    **Improvement Tip**: Expand on specific actions taken during assembly and provide concrete examples of how equipment interacts in the production line.
#
# 2. **Criterion**: Technical Acumen
#    **Rating**: Excellent
#    **Evidence**:
#    - Terminology like "takt time," "cellular manufacturing," "line balancing tools," and "motion waste" is used accurately.
#    - Demonstrates an understanding of lean principles and safety integration during setup.
#    **Improvement Tip**: No major improvement needed; continue to include precise engineering terminology to strengthen technical communication further.
#
# 3. **Criterion**: Clarity & Structure
#    **Rating**: Good
#    **Evidence**:
#    - Response is logically sequenced, moving from design review to layout design, efficiency analysis, safety, and adjustments.
#    - Use of concise explanations ensures readability, but transitions between phases (e.g., from layout to efficiency) could be more fluid.
#    **Improvement Tip**: Incorporate smoother transitions between sections to enhance readability further and ensure the explanation flows seamlessly.
#
# 4. **Criterion**: Depth of Analysis
#    **Rating**: Average
#    **Evidence**:
#    - Provides general reasoning for layout decisions (e.g., U-shaped layout reduces motion waste) and efficiency considerations (e.g., buffer zones).
#    - Lacks detailed, illustrative examples of specific equipment or processes used during production.
#    **Improvement Tip**: Include specific examples of equipment and clearly justify each decision with detailed reasoning (e.g., choosing a conveyor for high-speed operations or specific automation tools for precision assembly).
#
# 5. **Criterion**: Language & Presentation
#    **Rating**: Excellent
#    **Evidence**:
#    - Writing is clear, professional, and free of grammatical or spelling errors.
#    - Uses articulate language with precise word choices, enhancing communication.
#    **Improvement Tip**: No major improvement needed; maintain consistent attention to language quality.
#
# ---
#
# **Overall Rating**: Good
#
# >>> 3. Self-Evaluation Rating (1-5):
# 4
# --------------------------------------------------------------------------------
# Submission 6 (Ground Truth: Hybrid)
# --------------------------------------------------------------------------------
#
# Label: Hybrid
#
# Rationale:
# - The submission exhibits a structured approach and technical terminology consistent with manufacturing engineering (e.g., "takt time," "feedback loops"), which are common features of AI-generated content. However, the inclusion of human-like subjectivity and consideration for worker intuition (e.g., "how intuitive the setup is for workers") suggests personal contextualization likely contributed by a human writer.
# - Stylistically, the piece avoids excessive verbosity or purely formulaic explanations, showing signs of manual editing or human refinement overlaying an AI-generated draft. The prose includes nuanced phrasing (e.g., "real-world testing and adaptation," "key operations") that evidence human input.
#
# Flags:
# - Slight stylistic detachment around technical terms (e.g., "simulation software to predict performance under various conditions") suggests partial AI assistance to bolster coherence and detail.
# - Increased alignment between structure and phrasing from earlier examples implies familiarity with AI writing models.
#
# ### Overall Summary:
# The submission demonstrates a solid understanding of the production line setup process, including several key steps such as equipment selection, layout design, and safety considerations. While the explanation generally covers the core elements effectively, there are opportunities to deepen the level of detail and integrate specific examples to strengthen the analysis and technical clarity. Overall organization and language use are strong.
#
# ---
#
# ### Criteria Feedback:
#
# #### Criterion: **Scope & Comprehensiveness**
# - **Rating:** Good
# - **Evidence:**
#   - The submission outlines significant phases, including reviewing product design, drafting layouts, equipment selection, and conducting test runs.
#   - Safety measures are incorporated, such as emergency stops, clear operator paths, and signage.
#   - Efficiency is addressed with concepts like takt time and bottleneck identification.
# - **Improvement Tip:** Expand on specific phases like initial design review or final assembly, providing examples (e.g., specific materials or processes) to ensure the process is fully covered end-to-end.
#
# ---
#
# #### Criterion: **Technical Acumen**
# - **Rating:** Good
# - **Evidence:**
#   - Correct terminology such as "takt time," "simulation software," and "ergonomic checks" is employed.
#   - The explanation reflects a solid understanding of principles like efficiency optimization and logical process grouping.
# - **Improvement Tip:** Introduce more advanced manufacturing concepts or metrics, such as Overall Equipment Effectiveness (OEE), to showcase a deeper grasp of technical principles.
#
# ---
#
# #### Criterion: **Clarity & Structure**
# - **Rating:** Excellent
# - **Evidence:**
#   - The explanation follows a logical sequence from product review to iterative refinement, making it easy to follow.
#   - Transitions between phases are smooth, and the purpose of each step is clearly articulated.
# - **Improvement Tip:** Maintain this strong level of organization while potentially using brief subheaders or bullet points in future submissions to further enhance clarity.
#
# ---
#
# #### Criterion: **Depth of Analysis**
# - **Rating:** Average
# - **Evidence:**
#   - Basic reasoning is provided, such as grouping processes to minimize material handling and embedding safety into layouts.
#   - No specific examples (e.g., what machines, product materials, or test results) are provided to substantiate the decisions or highlight trade-offs.
# - **Improvement Tip:** Include detailed examples or data, such as specific machine types, layouts, or a description of an observed bottleneck in the test run, to enhance analytical depth.
#
# ---
#
# #### Criterion: **Language & Presentation**
# - **Rating:** Excellent
# - **Evidence:**
#   - Writing is clear, professional, and free of grammatical errors.
#   - Complex ideas are communicated with concise and precise language.
# - **Improvement Tip:** Continue using professional language while occasionally varying sentence structure for added interest.
#
# ---
#
# ### Overall Rating:
# **Good**
#
# >>> 3. Self-Evaluation Rating (1-5):
# 4
#
# Confusion Matrix for Domain 'Manufacturing Engineering':
# Predicted     AI  Hybrid
# Ground Truth
# AI             2       0
# Human          0       2
# Hybrid         0       2
#
# ================================================================================
#
#
# Overall Confusion Matrix Across All Domains:
# Predicted     AI  Human  Hybrid
# Ground Truth
# AI             7      0       3
# Human          1      1       8
# Hybrid         5      0       5
