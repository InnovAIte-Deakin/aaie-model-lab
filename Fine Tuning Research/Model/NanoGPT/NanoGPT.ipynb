# %% [markdown]
# # NanoGPT

# %%
import requests
import json
# from google.colab import userdata
from typing import List, Dict, Any
import os
import random
import time

# %% [markdown]
# ### API Accessing

# %%
BASE_URL = "https://nano-gpt.com/api/v1"

os.environ["NANO_GPT_API_KEY"] = "NanoGPT-Key"
API_KEY = os.getenv("NANO_GPT_API_KEY")
if not API_KEY:
    raise ValueError("Missing API key! Please set it with os.environ['NANO_GPT_API_KEY']='your-key-here'")

headers = {
    "Authorization": f"Bearer {API_KEY}",
    "Content-Type": "application/json",
    "Accept": "text/event-stream"
}

# %% [markdown]
# ### Function to communicate with the model

# %%
def stream_chat_completion(messages, model="chatgpt-4o-latest", max_retries=5):
    data = {"model": model, "messages": messages, "stream": True}

    for attempt in range(max_retries):
        try:
            response = requests.post(
                f"{BASE_URL}/chat/completions",
                headers=headers,
                json=data,
                stream=True,
                timeout=180
            )
            if response.status_code == 429:
                wait = 2 ** attempt
                print(f"Rate limit hit. Retrying in {wait}s...")
                time.sleep(wait)
                continue
            response.raise_for_status()
            for line in response.iter_lines():
                if line:
                    line = line.decode("utf-8")
                    if line.startswith("data: "):
                        line = line[6:]
                    if line == "[DONE]":
                        break
                    try:
                        chunk = json.loads(line)
                        if chunk['choices'][0]['delta'].get('content'):
                            yield chunk['choices'][0]['delta']['content']
                    except (json.JSONDecodeError, IndexError, KeyError):
                        continue
            return
        except requests.exceptions.RequestException as e:
            if attempt < max_retries - 1:
                wait = 2 ** attempt
                print(f"Request failed ({e}). Retrying in {wait}s...")
                time.sleep(wait)
            else:
                print(f"Failed after {max_retries} attempts: {e}")
                return

# %%
def get_chat_completion(messages, model="chatgpt-4o-latest"):
    """
    Non-streaming chat completion request that returns the full response text.
    """
    data = {
        "model": model,
        "messages": messages,
        "stream": False
    }

    try:
        response = requests.post(
            f"{BASE_URL}/chat/completions",
            headers=headers,
            json=data,
            timeout=180
        )
        response.raise_for_status()
        result = response.json()
        return result['choices'][0]['message']['content'].strip()
    except requests.exceptions.RequestException as e:
        print(f"Error during API request: {e}")
        return "Error generating response."
    except (KeyError, IndexError):
        return "Error parsing model response."

# %% [markdown]
# ### Prompts

# %%
SYSTEM_PROMPT = "You are a careful academic assistant. Be precise and give clear structured output (not JSON, not CSV, no files)."


def build_detection_prompt(submission: str, few_shots: List[Dict[str, Any]]) -> List[Dict[str, str]]:
    """
    Academic Integrity Detector Prompt
    ----------------------------------
    Purpose:
        Classifies student submissions as Human, AI, or Hybrid (AI-assisted).

    Technique:
        - Role-based prompting
        - Few-shot support
        - CoT (reasoning encouraged but hidden from output)
        - Output in plain text

    Expected Output (example format in plain text):
        Label: Human | AI | Hybrid
        Rationale:
        - short bullet point 1
        - short bullet point 2
        Flags: style_inconsistency / high_verbatim / generic_phrasing / none
    """
    # Build few-shot block
    shot_texts = []
    for s in few_shots:
        shot_texts.append(
            f'Submission: """{s.get("final_submission","")}"""\n'
            f'Your analysis (2–4 bullet points): <analysis>\n'
            f'Label: {s.get("label_type","")}\n'
        )
    examples_block = "\n\n".join(shot_texts) if shot_texts else "/* no examples available */"

    user = f"""
You are an AI text-source classifier for academic integrity.
Decide whether the student submission is Human, AI, or Hybrid (AI-assisted).

Guidelines:
- Consider discourse features (specificity, subjectivity, personal context), style consistency, local/global coherence, repetitiveness, and cliché patterns.
- Hybrid = meaningful human writing with some AI assistance, or explicit admission of mixed use.

Examples:
{examples_block}

Now analyze the NEW submission and respond in plain text with the following structure:
Label: ...
Rationale:
- point 1
- point 2
Flags: ...
NEW submission:
\"\"\"{submission}\"\"\"\n
"""
    return [
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user", "content": user},
    ]


def build_feedback_prompt(domain: str, assignment_prompt: str, rubric_text: str, submission: str) -> List[Dict[str, str]]:
    """
    Rubric-Aligned Feedback Prompt
    ------------------------------
    Purpose:
        Generates structured, supportive feedback for a student submission.

    Technique:
        - Role-based prompting
        - Rubric-grounded evaluation
        - Output in plain text

    Expected Output (example format in plain text):
        Overall Summary:
        <2–4 sentence overview>

        Criteria Feedback:
        Criterion: <criterion_id>
        Rating: Excellent | Good | Average | Needs Improvement | Poor
        Reason:
        - point 1
        - point 2
        Improvement Tip: one concrete suggestion

        Overall Rating: Excellent | Good | Average | Needs Improvement | Poor
    """
    user = f"""
You are a supportive assessor. Provide actionable feedback aligned to the rubric.
Return plain structured text only (no JSON, no files).

Sections to include:
1) Overall Summary: 2–4 sentences on strengths and priorities.
2) Criteria Feedback: for each rubric criterion include:
   - Criterion
   - Rating (excellent, good, average, needs_improvement, poor)
   - Evidence (1–3 bullet points citing excerpts or behaviors)
   - Improvement Tip (one concrete step)
3) Overall Rating: Excellent | Good | Average | Needs Improvement | Poor

Context:
- Domain: {domain}
- Assignment prompt: {assignment_prompt}

Rubric (verbatim):
{rubric_text}

Student submission:
\"\"\"{submission}\"\"\"\n
"""
    return [
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user", "content": user},
    ]

# %% [markdown]
# ### Loading the dataset

# %%
import json
import os

def load_multiple_json_files(file_paths: list) -> list:
    """
    Loads multiple JSON files and returns a list of loaded data dictionaries.

    Args:
        file_paths (list): List of full file paths to JSON files.

    Returns:
        List of dictionaries, each representing the data from one JSON file.
    """
    loaded_data = []
    for file_name in file_paths:
        try:
            with open(file_name, 'r') as f:
                data = json.load(f)
                if 'domain' in data and 'submissions' in data:
                    print(f"Loaded domain '{data['domain']}' with {len(data['submissions'])} submissions from '{file_name}'.")
                    loaded_data.append(data)
                else:
                    print(f"WARNING: File '{file_name}' missing 'domain' or 'submissions' keys. Skipping.")
        except FileNotFoundError:
            print(f"ERROR: The file '{file_name}' was not found. Skipping.")
        except json.JSONDecodeError:
            print(f"ERROR: The file '{file_name}' is not a valid JSON. Skipping.")
    return loaded_data

# example usage
file_list = [
    'Training_Data/accounting.json',
    'Training_Data/teaching.json',
    'Training_Data/psychology.json',
    'Training_Data/it.json',
    'Training_Data/engineering.json'
]

all_domains_data = load_multiple_json_files(file_list)
print(f"\nTotal domains loaded: {len(all_domains_data)}")
# Out:
# Loaded domain 'Accounting' with 6 submissions from 'Training_Data/accounting.json'.
# Loaded domain 'Teaching' with 6 submissions from 'Training_Data/teaching.json'.
# Loaded domain 'Psychology' with 6 submissions from 'Training_Data/psychology.json'.
# Loaded domain 'Information Technology' with 6 submissions from 'Training_Data/it.json'.
# Loaded domain 'Manufacturing Engineering' with 6 submissions from 'Training_Data/engineering.json'.
#
# Total domains loaded: 5

# %% [markdown]
# ### Evaluation Function

# %%
# function to generate self-evaluation rating
def build_self_eval_prompt(rubric: Dict, essay: str, feedback: str) -> str:
    crit = [c.get('name','Criterion') for c in rubric.get('criteria',[])]
    crit_str = ", ".join(crit) if crit else "the rubric"
    return (
        "You are a strict but fair assessor. Rate how well the FEEDBACK addresses the rubric for the ESSAY.\n"
        "Rate on a 1-5 scale (integers only). Provide ONLY the number.\n\n"
        f"ESSAY:\n{essay}\n\n"
        f"RUBRIC CRITERIA: {crit_str}\n\n"
        f"FEEDBACK:\n{feedback}\n\n"
        "RATING (1-5): "
    )

# %% [markdown]
# ### Function to detect and generate feedback based on training data and prompt and also evaulate the model performance.

# %%
# define allowed standard labels globally
ALLOWED_LABELS = ["AI", "Human", "Hybrid"]

# %%
def normalize_label(label: str, allowed=ALLOWED_LABELS) -> str:
    """
    Normalize a label to one of the allowed values (AI, Human, Hybrid).
    Returns "Unknown" if no match is found.
    """
    for a in allowed:
        if a.lower() in label.lower():
            return a
    return "Unknown"

# %%
results = []

from collections import defaultdict
import pandas as pd

# initialize overall counters
overall_true = []
overall_pred = []

for domain_data in all_domains_data:
    domain = domain_data['domain']
    assignment_prompt = domain_data['prompt']
    rubric_text = json.dumps(domain_data['rubric'], indent=2)
    submissions = domain_data['submissions']

    # domain-level counters
    domain_true = []
    domain_pred = []

    print(f"\n{'='*80}")
    print(f"=== STARTING EVALUATION FOR '{domain}' DOMAIN ===")
    print(f"{'='*80}\n")

    for i, submission_data in enumerate(submissions):
        submission_text = submission_data['final_submission']
        ground_truth_label = submission_data['label_type'].strip()
        
        # normalize
        ground_truth_label = normalize_label(ground_truth_label)

        print(f"{'-'*80}")
        print(f"Submission {i+1} (Ground Truth: {ground_truth_label})")
        print(f"{'-'*80}\n")

        # detection
        available_shots = [s for j, s in enumerate(submissions) if i != j]
        
        few_shots = random.sample(
            available_shots,
            k=min(2, len(available_shots)))
        
        detection_messages = build_detection_prompt(submission_text, few_shots)
        full_detection = ""
        predicted_label = "Unknown"

        try:
            for chunk in stream_chat_completion(detection_messages):
                print(chunk, end='', flush=True)
                full_detection += chunk

            # normalize predicted label
            for line in full_detection.splitlines():
                if "Label" in line:
                    predicted_label = line.split(":")[1].strip()
                    break

            predicted_label = normalize_label(predicted_label)

        except Exception as e:
            print(f"Error generating detection: {str(e)}")
            full_detection = "Error generating detection."

        # Add to domain and overall lists
        domain_true.append(ground_truth_label)
        domain_pred.append(predicted_label)
        overall_true.append(ground_truth_label)
        overall_pred.append(predicted_label)

        print("\n")

        time.sleep(0.5)
        
        # feedback
        feedback_messages = build_feedback_prompt(
            domain=domain,
            assignment_prompt=assignment_prompt,
            rubric_text=rubric_text,
            submission=submission_text
        )
        full_feedback = ""
        try:
            for chunk in stream_chat_completion(feedback_messages):
                print(chunk, end='', flush=True)
                full_feedback += chunk
        except Exception as e:
            print(f"Error generating feedback: {str(e)}")
            full_feedback = "Error generating feedback."
        print("\n")

        # Self-Evaluation Rating
        print(">>> 3. Self-Evaluation Rating (1-5):")
        rating_prompt_text = build_self_eval_prompt(domain_data['rubric'], submission_text, full_feedback)
        rating_messages = [
            {"role": "system", "content": SYSTEM_PROMPT},
            {"role": "user", "content": rating_prompt_text},
        ]
        try:
            rating_response = get_chat_completion(rating_messages)
            print(rating_response)
        except Exception as e:
            print(f"Error generating rating: {str(e)}")
        
        results.append({
        "Domain": domain,
        "Submission Index": i + 1,
        "Ground Truth": ground_truth_label,
        "Predicted": predicted_label,
        "Detection Output": full_detection,
        "Feedback": full_feedback,
        "Self-Eval Rating": rating_response
        })

    # domain-Level confusion matrix
    domain_cm = pd.crosstab(
        pd.Series(domain_true, name='Ground Truth'),
        pd.Series(domain_pred, name='Predicted'),
        rownames=['Ground Truth'],
        colnames=['Predicted'],
        dropna=False
    )
    print(f"\nConfusion Matrix for Domain '{domain}':")
    print(domain_cm)
    print(f"\n{'='*80}\n")

# overall confusion matrix
overall_cm = pd.crosstab(
    pd.Series(overall_true, name='Ground Truth'),
    pd.Series(overall_pred, name='Predicted'),
    rownames=['Ground Truth'],
    colnames=['Predicted'],
    dropna=False
)
print("\nOverall Confusion Matrix Across All Domains:")
print(overall_cm)
# Out:
# ================================================================================
# === STARTING EVALUATION FOR 'Accounting' DOMAIN ===
# ================================================================================
#
# --------------------------------------------------------------------------------
# Submission 1 (Ground Truth: AI)
# --------------------------------------------------------------------------------
#
# Label: AI
#
# Rationale:
# - The submission demonstrates highly polished and formalized writing with consistently neutral tone, advanced vocabulary, and concise phrasing, characteristics commonly seen in AI-generated outputs.
# - The structure is globally coherent, with a logical flow and well-segmented paragraphs, but lacks subjective depth, personal context, or evaluative nuance that would indicate a human writer reflecting on the topic.
# - The discourse includes repetitive patterns and clichés associated with general AI output, such as "transformative shift," "enhance data integrity and automation," and reiterative phrasing about "efficiency" and "trust."
# - Local coherence is precise, but appears over-optimized, with few transitions that indicate human-like critical thinking or the processing of ideas through a personal lens.
#
# Flags: High likelihood of AI assistance due to the lack of personal tone, over-reliance on generic elaborations, and uncharacteristically uniform style.
#
# ### 1) Overall Summary:
# The submission demonstrates strong understanding of blockchain principles and their application to accounting, particularly highlighting concepts like decentralization, immutability, and smart contracts. Real-world examples such as Ernst & Young and JPMorgan are effectively integrated, offering clarity and relevance. While the analysis is insightful, further exploration of challenges and critical evaluation of blockchain’s limitations could strengthen the argument.
#
# ---
#
# ### 2) Criteria Feedback:
#
# #### **Criterion: Understanding of Blockchain Concepts**
# - **Rating**: Excellent
# - **Evidence**:
#   - Clearly identifies and explains blockchain principles such as decentralization, immutability, and smart contracts.
#   - Maps these principles to accounting functions, like automation and fraud detection, with precise detail.
#   - Recognizes blockchain’s ability to create tamper-proof audit trails and enable real-time financial reporting.
# - **Improvement Tip**: Consider extending the discussion to additional blockchain features (e.g., tokenization or interoperability) to showcase the breadth of understanding.
#
# ---
#
# #### **Criterion: Analysis of Accounting Impact**
# - **Rating**: Good
# - **Evidence**:
#   - Evaluates enhanced efficiency, trust, and transparency in auditing and financial reporting through blockchain.
#   - Identifies challenges such as regulatory uncertainty, scalability issues, and technical expertise required for adoption.
#   - Mentions blockchain’s ability to enhance fraud detection and streamline assurance processes.
# - **Improvement Tip**: Develop a more critical analysis by exploring broader implications (e.g., how blockchain might disrupt auditing standards or reshape professional roles).
#
# ---
#
# #### **Criterion: Use of Real-World Examples/Case Studies**
# - **Rating**: Excellent
# - **Evidence**:
#   - Incorporates highly relevant examples like Ernst & Young’s Blockchain Analyzer for cryptocurrency audits.
#   - Highlights JPMorgan’s Quorum platform for interbank reconciliations—a strong connection between theory and practice.
#   - Mentions PwC’s exploratory blockchain auditing tools, showcasing industry relevance.
# - **Improvement Tip**: Expand examples to include smaller firms or those in diverse global regions to provide a balanced perspective.
#
# ---
#
# #### **Criterion: Structure and Academic Style**
# - **Rating**: Good
# - **Evidence**:
#   - Arguments follow logical progression with clear transitions between concepts.
#   - Maintains formal academic tone and avoids casual language.
#   - Could improve coherence by separating paragraphs more distinctly for challenges versus benefits.
# - **Improvement Tip**: Revise paragraph structure to explicitly juxtapose benefits and challenges, enhancing clarity and flow.
#
# ---
#
# ### 3) Overall Rating:
# **Good**
#
# The submission demonstrates a solid grasp of blockchain technology and its application within accounting, reinforced by relevant examples. To elevate the work further, the student should include a deeper critical evaluation of blockchain's challenges and implications while refining structural organization for greater clarity.
#
# >>> 3. Self-Evaluation Rating (1-5):
# 4
# --------------------------------------------------------------------------------
# Submission 2 (Ground Truth: AI)
# --------------------------------------------------------------------------------
#
# Label: Hybrid
#
# Rationale:
# - The submission demonstrates high specificity and technical accuracy, indicative of potential AI-generated content, particularly in the structured presentation of key features and detailed applications (e.g., EY Blockchain Analyzer and IBM case).
# - The tone and coherence are consistent, but the integration of real-world examples suggests human input or revision for added credibility and contextual relevance that AI tools often lack.
# - The essay mentions its exploration purpose, implying a structured argumentative approach. This narrative device could reflect meaningful human intervention rather than purely AI-driven output.
#
# Flags:
# - Limited subjectivity or personal context, which aligns with AI-produced content.
# - Potential hybridization, as the real-world references (e.g., EY and IBM) require manual research or human validation alongside AI’s general pattern-based text generation.
#
# ### Overall Summary:
# The submission demonstrates a solid understanding of blockchain concepts and effectively links them to key impacts on auditing and financial reporting. The inclusion of real-world examples enhances the application of theoretical knowledge. Priorities for improvement include expanding the analysis to address challenges and refining the document’s structure for greater coherence.
#
# ---
#
# ### Criteria Feedback:
#
# **Criterion:** Understanding of Blockchain Concepts
# **Rating:** Excellent
# **Evidence:**
# - Clearly explains decentralization, immutability, and smart contracts, connecting each to accounting applications (e.g., tamper-proof audit trails).
# - Defines blockchain principles such as decentralized ledgers and immutable records with strong relevance to accounting.
# - Strong emphasis on blockchain's efficiency and trust-enhancing capabilities.
# **Improvement Tip:** Ensure definitions are complemented by deeper exploration of any potential limitations or risks associated with these principles.
#
# ---
#
# **Criterion:** Analysis of Accounting Impact
# **Rating:** Good
# **Evidence:**
# - Identifies blockchain’s ability to streamline auditing through tamper-proof records and enhanced fraud detection.
# - Discusses the automation of tasks like invoicing for improved accuracy and reduced intermediaries.
# - Mentions real-time financial reporting benefits.
# **Improvement Tip:** Provide a more balanced analysis by addressing challenges, such as regulatory hurdles or the risks of implementing blockchain systems in traditional accounting environments.
#
# ---
#
# **Criterion:** Use of Real-World Examples/Case Studies
# **Rating:** Good
# **Evidence:**
# - References Ernst & Young’s Blockchain Analyzer as an example of auditing enhancement.
# - Highlights IBM’s blockchain application in supply chain financing to improve reporting efficiency.
# **Improvement Tip:** Expand the scope of examples by discussing additional real-world applications (e.g., blockchain adoption by specific companies or industries beyond cryptocurrency). Include more details about how these examples demonstrate blockchain’s transformative effects.
#
# ---
#
# **Criterion:** Structure and Academic Style
# **Rating:** Good
# **Evidence:**
# - The essay is structured logically with clear segments discussing concepts, impacts, and examples.
# - Maintains a formal academic tone throughout.
# **Improvement Tip:** Strengthen transitions between ideas to improve coherence and flow, particularly when shifting from theoretical concepts to practical examples.
#
# ---
#
# ### Overall Rating: Good
#
# >>> 3. Self-Evaluation Rating (1-5):
# 4
# --------------------------------------------------------------------------------
# Submission 3 (Ground Truth: Human)
# --------------------------------------------------------------------------------
#
# Label: Hybrid
#
# Rationale:
# - **Presence of Personal Context**: The submission begins with a personal perspective from the student ("As a business student fascinated by tech"), a hallmark of human authorship that demonstrates subjectivity and individual context, rather than the objective, detached tone typical of purely AI-generated content.
# - **Structured Analysis and Varied Tone**: The essay alternates between technical explanations (e.g., blockchain’s cryptographic security) and subjective, evaluative reflections (e.g., “garbage in, garbage out,” “Accountants must adapt gradually”), suggesting human engagement and nuanced understanding, with possible assistance from AI-generated phrasing for some technical details.
# - **AI-Like Features**: While generally coherent, parts of the submission display traits common in AI-generated writing, such as slightly polished and formal phrasing (e.g., "boost market efficiency," "verifiable transaction record") and generalized descriptions that align closely with typical AI outputs. The language appears a bit "polished," which might point to AI-assisted refinement.
#
# Flags:
# - Some sections might be AI-assisted for technical terminology or structured phrasing. However, meaningful personal input and subjective reflections strongly indicate human involvement.
#
# ### Overall Summary
# The submission demonstrates a solid understanding of blockchain's potential impact on accounting, supported by relevant applications in auditing and financial reporting. The informal tone detracts from the academic rigor, and while examples are included, they could benefit from more in-depth explanations. Strengthening the analysis and refining structure will elevate the overall quality.
#
# ---
#
# ### Criteria Feedback
#
# #### Criterion: Understanding of Blockchain Concepts
# - **Rating**: Good
# - **Evidence**:
#   - Accurately explains blockchain principles such as decentralization and immutability ("decentralized, tamper-proof ledger could transform bookkeeping, auditing, and financial reporting").
#   - Connects concepts to practical accounting applications (e.g., "real-time, cryptographically secure transaction recording reduces errors and fraud").
# - **Improvement Tip**: Expand on smart contracts and their specific applications in accounting to provide a more nuanced understanding of blockchain principles.
#
# ---
#
# #### Criterion: Analysis of Accounting Impact
# - **Rating**: Good
# - **Evidence**:
#   - Highlights clear benefits such as reducing reconciliation efforts and automating tasks ("blockchain’s distributed ledger ensures accuracy, automating tasks like reconciliations").
#   - Discusses auditing improvements enabled by blockchain’s “triple-entry” system and associated challenges ("garbage in, garbage out").
# - **Improvement Tip**: Deepen the explanation of challenges such as the lack of accounting standards or privacy issues, evaluating their long-term implications on adoption.
#
# ---
#
# #### Criterion: Use of Real-World Examples/Case Studies
# - **Rating**: Good
# - **Evidence**:
#   - Includes relevant examples, such as IBM’s use of blockchain in supply chain finance and Deloitte’s testing of blockchain in auditing.
#   - References a 2023 study on financial reporting improvements.
# - **Improvement Tip**: Provide more detail on the IBM and Deloitte examples—for instance, explain the specific results achieved or the scalability of these applications.
#
# ---
#
# #### Criterion: Structure and Academic Style
# - **Rating**: Average
# - **Evidence**:
#   - Demonstrates general organization with clear topic progression (e.g., moving from bookkeeping to auditing and financial reporting).
#   - Uses informal language ("I see blockchain revolutionizing…") and conversational phrasing, which detracts from the academic tone.
# - **Improvement Tip**: Reframe the essay in an academic tone, avoiding first-person narration and ensuring transitions are formal and cohesive.
#
# ---
#
# ### Overall Rating: Good
#
# >>> 3. Self-Evaluation Rating (1-5):
# 4
# --------------------------------------------------------------------------------
# Submission 4 (Ground Truth: Human)
# --------------------------------------------------------------------------------
#
# Label: Hybrid
#
# Rationale:
# - **Personal Context and Subjectivity**: The submission includes personal context ("As a business student fascinated by tech"), which is a feature of human writing. This suggests some level of engagement and personal reflection not typically generated by AI.
# - **Style Consistency**: While the overall structure and content are coherent and meaningful, parts of the text exhibit precise, formulaic phrasing and structured examples (e.g., "Blockchain’s decentralized, tamper-proof ledger records transactions transparently, reducing errors in bookkeeping"), characteristic of AI-generated text.
# - **Use of Examples and Specificity**: The submission integrates real-world examples (e.g., IBM, Deloitte) and explanations that are highly specific, blending detailed, AI-like output with a human tone of analysis and reflection.
# - **Critical Analysis and Nuance**: The mention of both benefits and drawbacks (e.g., privacy concerns, cost issues, limitations of traditional standards) suggests a balanced perspective, but the language occasionally lapses into polished AI-style phrasing.
#
# Flags:
# - Possible moderate AI assistance in phrasing and structure of technical descriptions.
# - Human input is evident in personal reflections, nuanced insights, and context-specific commentary.
#
#
# 1) **Overall Summary**:
# The submission demonstrates a strong interest in the interplay between blockchain technology and accounting. The student effectively highlights key concepts such as decentralization and immutability, along with their links to auditing and reporting. However, the analysis could benefit from deeper exploration of core accounting impacts and a more structured presentation to improve academic clarity.
#
# ---
#
# 2) **Criteria Feedback**:
#
# - **Criterion: Understanding of Blockchain Concepts**
#   - **Rating**: Excellent
#   - **Evidence**:
#     - Clearly explains decentralization with references to shared, tamper-proof ledgers.
#     - Introduces the "triple-entry" system and contrasts it with traditional double-entry.
#     - Demonstrates understanding of blockchain's transparency and its implications for error reduction in bookkeeping.
#   - **Improvement Tip**: Deepen discussion of more advanced blockchain principles like smart contracts and how these can automate specific accounting functionalities.
#
# - **Criterion: Analysis of Accounting Impact**
#   - **Rating**: Good
#   - **Evidence**:
#     - Discusses real-time audits enabled by immutable records, reducing costs and boosting efficiency.
#     - Addresses financial reporting innovations like real-time insights for stakeholders, enhancing market transparency.
#     - Notes challenges, including input fraud, high implementation costs, and the lack of GAAP-readiness.
#   - **Improvement Tip**: Provide a more detailed breakdown of blockchain's potential impacts (e.g., how automation specifically transforms reconciliation processes) and evaluate challenges more critically.
#
# - **Criterion: Use of Real-World Examples/Case Studies**
#   - **Rating**: Good
#   - **Evidence**:
#     - Refers to IBM’s use of blockchain for supply chain finance to illustrate automation benefits.
#     - Mentions Deloitte’s experiments with blockchain in auditing to show real-world applicability.
#   - **Improvement Tip**: Expand the use of examples by referencing additional industries or case studies to strengthen the argument (e.g., non-financial use cases that could inspire accounting practices).
# - **Criterion: Structure and Academic Style**
#   - **Rating**: Average
#   - **Evidence**:
#     - The essay opens conversationally (“As a business student fascinated by tech”), which is inconsistent with formal academic tone.
#     - Ideas are clear, but transitions between topics (e.g., from auditing benefits to challenges) are abrupt, reducing the cohesion of the argument.
#     - Some points combine multiple issues (e.g., GAAP-readiness and privacy) without clear separation.
#   - **Improvement Tip**: Adopt a more formal and objective tone throughout. Structure the essay with clear sections (e.g., introduction, blockchain's principles, impacts on auditing, impacts on reporting, challenges, conclusion). Use transition phrases to maintain logical flow.
#
# ---
#
# 3) **Overall Rating**: Good
#
# >>> 3. Self-Evaluation Rating (1-5):
# 4
# --------------------------------------------------------------------------------
# Submission 5 (Ground Truth: Hybrid)
# --------------------------------------------------------------------------------
#
# Label: AI
#
# Rationale:
# - The submission shows hallmarks of AI-generated text, including a formal and consistently impersonal tone, minimal subjectivity, and no inclusion of personal or contextual specificity (e.g., no unique perspective, experiences, or real-world commentary beyond general trends). This is consistent with content typical of well-trained language models.
# - The writing demonstrates high global coherence and a logical, structured flow, including clear segmentation by topic (e.g., description of blockchain's applications in bookkeeping, auditing, and financial reporting) without meaningful variation in style or voice. This "clean and perfect" structure often signals AI involvement.
# - There is some repetitiveness in the phrasing of features or functions of blockchain technology, albeit with paraphrasing. The orderly, polished redundancy mirrors patterns found in AI-produced essays, designed to emphasize key points.
# - No discourse markers or stylistic "fingerprints" characteristic of human contribution—such as subjective interpretations, creative expressions, or specific situational examples—are evident in the text.
#
# Flags:
# - High likelihood of AI assistance rather than Hybrid, as the submission lacks any distinctly "human" writing features or identifiable personal input.
# - Suitable for further verification in academic integrity reviews, given its likely "machine-perfect" generation.
#
# ### Overall Summary
# The submission demonstrates a solid understanding of blockchain technology and its potential impacts on accounting practices, with clear explanations of concepts like decentralization, immutability, smart contracts, and their applications in auditing and financial reporting. The analysis is insightful and identifies challenges alongside benefits, though the essay could be enhanced through the inclusion of specific real-world examples and a more structured format.
#
# ### Criteria Feedback
#
# #### Criterion: Understanding of Blockchain Concepts
# - **Rating**: Excellent
# - **Evidence**:
#   - Clearly explains blockchain principles, such as "decentralized, immutable ledger" and "smart contracts," and connects them to accounting processes like automating bookkeeping and reconciliation.
#   - Provides thorough elaboration on the concepts of tamper-proof transaction records and their impacts on fraud reduction.
#   - Maps blockchain features directly to accounting applications, including real-time transaction recording and enhanced accuracy.
# - **Improvement Tip**: Include academic citations or definitions from technical sources to strengthen explanations further.
#
# #### Criterion: Analysis of Accounting Impact
# - **Rating**: Good
# - **Evidence**:
#   - Discusses impacts such as "verifiable, chronological record of transactions" for auditing and "faster reporting cycles" to improve financial reporting.
#   - Highlights challenges areas, such as the "need for auditors to develop blockchain expertise" and "investment in infrastructure and regulatory alignment."
#   - Evaluates auditing benefits, such as reduced reliance on sampling, with plausible reasoning.
# - **Improvement Tip**: Add deeper analysis, such as specific regulatory implications or how blockchain mitigates auditing risks, to elevate the discussion.
#
# #### Criterion: Use of Real-World Examples/Case Studies
# - **Rating**: Average
# - **Evidence**:
#   - While the submission is rich in theoretical applications, it does not reference actual case studies or real-world examples.
#   - Mentions general applications like accounts payable but lacks specific organizations, industry samples, or blockchain platforms (e.g., SAP Blockchain, Ethereum-based systems).
# - **Improvement Tip**: Incorporate real-world examples or reference case studies, such as how a specific company has integrated blockchain into financial reporting or audits.
#
# #### Criterion: Structure and Academic Style
# - **Rating**: Good
# - **Evidence**:
#   - The essay maintains a formal tone and uses clear, precise language suitable for academic writing.
#   - Displays logical flow by presenting blockchain concepts followed by their application impacts on auditing and financial reporting.
#   - Transitions between sections are present but could be further refined for better coherence.
# - **Improvement Tip**: Introduce subheadings or organize the content into distinct sections (e.g., Blockchain Basics, Auditing Impact, Financial Reporting) for enhanced readability.
#
# ### Overall Rating
# **Good**
#
# >>> 3. Self-Evaluation Rating (1-5):
# 4
# --------------------------------------------------------------------------------
# Submission 6 (Ground Truth: Hybrid)
# --------------------------------------------------------------------------------
#
# Label: AI
#
# Rationale:
# - High stylistic consistency with polished phrasing and concise exposition suggests algorithmic generation. The writing demonstrates advanced coherence and formal neutrality typical of AI-generated content.
# - There is frequent use of generalized statements and technical jargon without subjective or personal engagement, echoing patterns consistent with AI-generated text (e.g., "Blockchain fosters a more reliable, automated accounting ecosystem").
# - The submission lacks human-like discourse features such as personal context, anecdotal examples, or nuanced debate. It follows a rigid structure emphasizing factual presentation.
#
# Flags:
# - Absence of personal voice or contextual specificity.
# - Overuse of non-conversational phrasing and technical detail typical of AI-text outputs.
#
# ### Overall Summary:
# The submission demonstrates a strong grasp of blockchain concepts and their implications for accounting, particularly in auditing and financial reporting. Strengths include detailed explanations of benefits and challenges, with clear connections to accounting practices. Priority areas for improvement involve the use of real-world examples and refining the structure for better coherence.
#
# ---
#
# ### Criteria Feedback:
#
# #### Criterion: Understanding of Blockchain Concepts
# **Rating:** Excellent
# **Evidence:**
# - Clearly explains blockchain principles, including decentralization, immutability, and smart contracts.
# - Maps blockchain features, such as tamper-proof ledgers and automation, to their relevance in fraud prevention and cost reduction.
# - Discusses technical aspects such as distributed ledger technology.
#
# **Improvement Tip:**
# Explore additional blockchain features (e.g., scalability solutions or private vs. public blockchains) to enrich the discussion further.
#
# ---
#
# #### Criterion: Analysis of Accounting Impact
# **Rating:** Good
# **Evidence:**
# - Discusses auditing transformations, including real-time, comprehensive data analysis enabled by transparent audit trails.
# - Explores how blockchain streamlines financial reporting with automated reconciliation and data aggregation.
# - Identifies challenges like smart contract vulnerabilities and regulatory uncertainty.
#
# **Improvement Tip:**
# Provide a more detailed analysis of the challenges, supported by explanations of specific risks and the evolving standards required to mitigate them.
#
# ---
#
# #### Criterion: Use of Real-World Examples/Case Studies
# **Rating:** Average
# **Evidence:**
# - General references to blockchain applications (e.g., invoice settlement, audit transparency) without citing actual companies or scenarios.
# - Lacks case studies from firms or industries currently utilizing blockchain in auditing or financial reporting.
#
# **Improvement Tip:**
# Include at least one concrete example of a company or industry using blockchain (e.g., IBM’s blockchain solutions in supply chain finance) to strengthen your argument.
#
# ---
#
# #### Criterion: Structure and Academic Style
# **Rating:** Good
# **Evidence:**
# - Arguments are presented in a clear sequence with proper paragraphs.
# - Formal academic tone is consistent, though transitions between ideas could be smoother.
# - Concludes with a thoughtful summary of blockchain’s overall impact on accounting.
#
# **Improvement Tip:**
# Use more topic sentences and transitional phrases to improve the logical flow and connect different sections cohesively.
#
# ---
#
# ### Overall Rating: Good
#
# >>> 3. Self-Evaluation Rating (1-5):
# 4
#
# Confusion Matrix for Domain 'Accounting':
# Predicted     AI  Hybrid
# Ground Truth
# AI             1       1
# Human          0       2
# Hybrid         2       0
#
# ================================================================================
#
#
# ================================================================================
# === STARTING EVALUATION FOR 'Teaching' DOMAIN ===
# ================================================================================
#
# --------------------------------------------------------------------------------
# Submission 1 (Ground Truth: AI)
# --------------------------------------------------------------------------------
#
# Label: Hybrid
#
# Rationale:
# - The submission exhibits advanced formal academic writing with structured argumentation, integration of peer-reviewed references, and a high level of coherence. This depth and polish, combined with specific citations, suggest possible AI assistance in refining or generating text.
# - The breadth of academic sources (e.g., multiple citations) and the language precision (e.g., "instructional responsiveness," "developmentally appropriate ways") reflect a level of detail and sophistication that may not be consistently characteristic of human student writing, potentially indicating AI input.
# - Some sections, like "inclusive lens ensures equitable access to literacy development," echo polished AI-typical phrasing and generalities around inclusivity, raising suspicion about automated phrase generation. However, the consideration of diverse learners and integration of specific examples suggest some meaningful human contribution.
#
# Flags:
# - Potential AI-generated synthesis of academic sources.
# - Evaluation required to confirm the authenticity of cited materials and assess the balance between AI assistance and human input.
#
# ### Overall Summary:
# The submission demonstrates a solid understanding of early literacy development and incorporates evidence-based strategies effectively. Strengths include addressing diverse learner needs and integrating relevant research sources. Priority areas for improvement involve expanding analysis of strategies and further refining academic writing conventions.
#
# ### Criteria Feedback:
#
# #### Criterion: Understanding of Early Literacy Development
# - **Rating**: Good
# - **Evidence**:
#   - Provides clear details on foundational skills such as phonological awareness, vocabulary acquisition, and print knowledge.
#   - Correctly identifies developmental milestones, such as letter-sound associations by age 3 and decoding by age 6.
# - **Improvement Tip**: Expand explanations with concrete examples or case applications to deepen the demonstration of developmental progression.
#
# #### Criterion: Evaluation of Evidence-Based Approaches
# - **Rating**: Good
# - **Evidence**:
#   - Evaluates dialogic reading and phonological awareness games effectively, referencing their developmental appropriateness.
#   - Includes evidence from credible sources to support claims (e.g., Justice & Ezell; Lonigan et al.).
# - **Improvement Tip**: Provide critical commentary on limitations or contextual factors affecting the effectiveness of these strategies.
#
# #### Criterion: Consideration of Diversity and Inclusion
# - **Rating**: Excellent
# - **Evidence**:
#   - Thoughtfully discusses adaptations for multilingual learners and children with developmental delays.
#   - Suggests specific methods such as integrating home languages and using visual supports.
#   - References inclusive practices from credible research (e.g., Neuman & Wright).
# - **Improvement Tip**: Continue highlighting specific examples and expand discussion to include more diverse learner profiles or additional inclusive strategies.
#
# #### Criterion: Research Integration and Referencing
# - **Rating**: Good
# - **Evidence**:
#   - Incorporates several peer-reviewed sources aligned with the argument (e.g., Snow, Justice & Ezell).
#   - References are accurate and align with academic standards.
# - **Improvement Tip**: Broaden the scope of integrated research by incorporating studies beyond those cited to strengthen evidence depth and variety.
#
# #### Criterion: Structure and Academic Writing
# - **Rating**: Good
# - **Evidence**:
#   - Writing is formal and coherent, maintaining a clear flow from introduction to conclusion.
#   - Minor grammatical inconsistencies or expression issues (e.g., greater emphasis on transitions could improve cohesion).
# - **Improvement Tip**: Review for language precision and enhance transitions between ideas for a more polished academic tone.
#
# ### Overall Rating: Good
#
# >>> 3. Self-Evaluation Rating (1-5):
# 4
# --------------------------------------------------------------------------------
# Submission 2 (Ground Truth: AI)
# --------------------------------------------------------------------------------
#
# Label: Hybrid
#
# Rationale:
# - The submission demonstrates a formal academic tone and includes references to research (e.g., "Whitehurst et al., 1994"), which suggests external inputs typical of AI assistance. References are not individualized and align with patterns seen in AI-generated content.
# - The writing is highly structured, coherent, and free of grammatical issues, but the specificity in strategies (e.g., "bilingual books" and "shared book reading") and critical insight regarding inclusion suggest a level of human interpretation and emphasis on academic discussions.
# - The final critique about "more detail on implementation" introduces subjective reasoning, indicating potential human engagement in highlighting gaps.
#
# Flags:
# - Potential reliance on AI for coherent academic phrasing and incorporation of polished references.
# - Human contribution appears in subjective critiques and nuanced awareness of diversity/inclusion considerations.
#
# **Overall Summary**
# This submission demonstrates a foundational understanding of early literacy development and incorporates relevant evidence-based approaches with appropriate academic references. There is thoughtful attention to diversity, although more specific implementation details and deeper critical analysis are areas for improvement. The essay is well-structured and written in a clear academic style with minimal errors.
#
# ---
#
# **Criteria Feedback**
#
# **Criterion: Understanding of Early Literacy Development**
# - **Rating:** Good
# - **Evidence:**
#   - Mentions key components such as "phonological awareness, vocabulary, and print knowledge."
#   - Addresses developmental progression, e.g., "Children often begin by recognizing letters and sounds and gradually move towards blending phonemes and understanding word structures."
# - **Improvement Tip:** Expand on the specific milestones for ages 3 to 6, providing more detailed examples of how these skills typically develop at different stages.
#
# **Criterion: Evaluation of Evidence-Based Approaches**
# - **Rating:** Average
# - **Evidence:**
#   - Identifies shared book reading and phonemic games as evidence-based approaches.
#   - Cites relevant research (e.g., "Whitehurst et al., 1994") to support claims about the benefits of interactive questioning and repeated reading.
# - **Improvement Tip:** Critically evaluate each strategy by discussing its limitations or effectiveness in specific contexts, supported by additional research evidence.
#
# **Criterion: Consideration of Diversity and Inclusion**
# - **Rating:** Good
# - **Evidence:**
#   - Acknowledges the importance of using "bilingual books" and "culturally familiar content" to enhance inclusivity.
#   - Notes that these strategies can "enhance relevance and motivation," indicating an understanding of diverse learners’ needs.
# - **Improvement Tip:** Provide more specific examples of how these strategies can be adapted for learners with varied developmental needs, such as children with disabilities or those in multilingual contexts.
#
# **Criterion: Research Integration and Referencing**
# - **Rating:** Good
# - **Evidence:**
#   - Incorporates an academic source (e.g., "Whitehurst et al., 1994") with appropriate referencing.
#   - Aligns evidence with the discussion of strategies and outcomes.
# - **Improvement Tip:** Broaden the range of peer-reviewed sources to include more recent studies, ensuring comprehensive support for all claims.
#
# **Criterion: Structure and Academic Writing**
# - **Rating:** Good
# - **Evidence:**
#   - Clear structure with introduction, body, and conclusion.
#   - Formal tone maintained throughout and "minimal grammatical issues" noted.
# - **Improvement Tip:** Strive for greater precision in language when analyzing strategies or discussing diversity to ensure ideas are articulated as critically and clearly as possible.
#
# ---
#
# **Overall Rating:** Good
#
# >>> 3. Self-Evaluation Rating (1-5):
# 4
# --------------------------------------------------------------------------------
# Submission 3 (Ground Truth: Human)
# --------------------------------------------------------------------------------
#
# Label: Hybrid
# Rationale:
# - The submission demonstrates traits of stylistic hybridity. While the essay exhibits a conversational and subjective tone in places (e.g., "such a critical phase in a child's life"), it also incorporates structured, formal academic writing typical of AI-generated texts (e.g., "Phonological awareness, in particular, is a strong predictor of later reading success"). This mix is suggestive of AI assistance in refining or expanding human writing.
# - There is some repetition in phrasing (e.g., "foundational learning," "sets the stage for decoding and comprehension") that suggests iterative drafting, likely by a human with AI support to polish. The references (e.g., "Lonigan et al. (2000)") are aligned with academic norms, but the submission doesn't exhibit overly polished coherence or depth typical of pure AI output.
#
# Flags:
# - The submission uses closely paraphrased references without including deeper analytical commentary, a common feature of AI assistance.
#
# ### Overall Summary:
# The submission demonstrates a clear foundational understanding of early literacy development, with effective integration of key concepts such as phonological awareness, vocabulary, and print knowledge. However, it lacks evaluation of evidence-based approaches and consideration of diversity and inclusion, both of which are essential to the assignment prompt prioritizing research-informed instructional methods tailored to diverse learners.
#
# ### Criteria Feedback:
#
# #### Criterion: Understanding of Early Literacy Development
# - **Rating:** Good
# - **Evidence:**
#   - The submission effectively identifies core skills (phonological awareness, vocabulary, print concepts) and relates them to developmental milestones.
#   - Specific mention of phonological awareness progression (syllable to phoneme level) demonstrates solid understanding.
#   - Integration of research (Lonigan et al., 2000) supports an informed discussion.
# - **Improvement Tip:** Extend the explanation to include more detailed examples and nuances of developmental milestones for ages 3 to 6, such as how environmental factors influence vocabulary acquisition or print knowledge.
#
# ---
#
# #### Criterion: Evaluation of Evidence-Based Approaches
# - **Rating:** Needs Improvement
# - **Evidence:**
#   - No specific instructional strategies (e.g., dialogic reading, phonemic games) are evaluated.
#   - The submission focuses solely on core skill development without assessing methods or interventions to support these skills.
# - **Improvement Tip:** Include evaluation of at least one or two evidence-based approaches, such as dialogic reading or shared book reading, with reference to research supporting their effectiveness.
#
# ---
#
# #### Criterion: Consideration of Diversity and Inclusion
# - **Rating:** Poor
# - **Evidence:**
#   - No mention of adapting literacy strategies to account for diverse linguistic, cultural, or developmental needs.
#   - Submission overlooks the significance of tailoring approaches to meet the needs of multilingual learners or children with developmental delays.
# - **Improvement Tip:** Address diversity by discussing how strategies (e.g., vocabulary enrichment) can be adapted for children from varied backgrounds and include examples from research.
#
# ---
#
# #### Criterion: Research Integration and Referencing
# - **Rating:** Average
# - **Evidence:**
#   - One peer-reviewed source (Lonigan et al., 2000) is correctly cited.
#   - Limited integration of additional academic literature weakens the depth of analysis.
# - **Improvement Tip:** Incorporate more varied academic sources (e.g., on evidence-based strategies, effects of diversity) and integrate them into the discussion with accurate referencing.
#
# ---
#
# #### Criterion: Structure and Academic Writing
# - **Rating:** Good
# - **Evidence:**
#   - Clear and logical paragraph structure with appropriate academic tone.
#   - Language is concise and free from grammatical errors.
# - **Improvement Tip:** Use subheadings or transitions to better organize the essay around prompt components (e.g., early literacy development, evidence-based strategies, diversity considerations).
#
# ### Overall Rating: **Needs Improvement**
# While the submission demonstrates good foundational knowledge of early literacy development, it lacks critical evaluation of instructional methods and fails to consider diversity and inclusion, falling short of meeting the prompt requirements comprehensively. Focus is needed on integrating evidence and addressing diverse learner needs to align more closely with the rubric criteria.
#
# >>> 3. Self-Evaluation Rating (1-5):
# 3
# --------------------------------------------------------------------------------
# Submission 4 (Ground Truth: Human)
# --------------------------------------------------------------------------------
#
# Label: Hybrid
# Rationale:
# - The submission features specific information on early literacy development and uses terminology like "phonological awareness," "vocabulary," and "knowledge about print," which suggests informed writing. However, the phrasing and structure bear similarities to overly polished AI-generated text and clichés often found in AI-assisted writing.
# - There is evidence of meaningful human input, such as sentence variation and non-mechanical transitions, but stylistically, the consistency and fluency point to the possibility of AI assistance in refining or structuring the content.
# Flags:
# - High overlap in ideas and wording compared to generic academic discussions on this topic.
# - The absence of personal subjectivity or nuanced examples suggests AI might have contributed significantly to the coherence.
#
# ### Overall Summary
# The submission demonstrates a foundational understanding of early literacy development, with clear references to key skills such as phonological awareness, vocabulary, and print knowledge. However, it does not provide in-depth coverage of developmental milestones, nor does it address the full scope of the assignment, particularly regarding evidence-based approaches, diversity considerations, and research integration. Strengthening these areas would enhance the overall rigor and alignment with the rubric.
#
# ### Criteria Feedback
#
# #### Criterion: Understanding of Early Literacy Development
# - **Rating:** Average
# - **Evidence:**
#   - Mentions foundational skills like phonological awareness, vocabulary, and print knowledge.
#   - Provides developmental examples, such as understanding rhymes around age 4 and recognizing letters before school.
#   - General descriptions lack deeper analysis of developmental progression or variability in milestones.
# - **Improvement Tip:** Expand the discussion by detailing how each pre-reading skill develops over time and include examples of how variations may occur in children due to individual differences.
#
# #### Criterion: Evaluation of Evidence-Based Approaches
# - **Rating:** Poor
# - **Evidence:**
#   - No evidence-based instructional strategies or methods (e.g., dialogic reading, phonemic games) are discussed.
#   - The submission does not evaluate or support pre-reading skill development using research or specific interventions.
# - **Improvement Tip:** Research and discuss at least two evidence-based approaches, such as shared book reading or explicit phonics instruction, and evaluate their effectiveness using supporting evidence.
#
# #### Criterion: Consideration of Diversity and Inclusion
# - **Rating:** Poor
# - **Evidence:**
#   - There is no mention of how the approaches can account for diverse learners or considerations for cultural, linguistic, or developmental differences.
# - **Improvement Tip:** Highlight how early literacy strategies can be adapted to meet the needs of diverse learners (e.g., bilingual children, children with developmental delays) and reference inclusive practices from research.
#
# #### Criterion: Research Integration and Referencing
# - **Rating:** Needs Improvement
# - **Evidence:**
#   - There are no citations of academic sources or integration of research to substantiate claims.
#   - Key points lack evidence drawn from credible studies or peer-reviewed literature.
# - **Improvement Tip:** Use several academic sources to support claims and integrate these into your analysis. Ensure accurate citations using an appropriate citation style.
#
# #### Criterion: Structure and Academic Writing
# - **Rating:** Good
# - **Evidence:**
#   - The submission is logically structured with an introduction, some organization of ideas, and generally clear writing.
#   - There are no significant grammatical errors or awkward phrasing.
# - **Improvement Tip:** Ensure the introduction, body, and conclusion are explicitly defined, and further refine writing by transitioning smoothly between points to improve flow and coherence.
#
# ### Overall Rating
# **Needs Improvement**
#
# ### Suggested Focus Areas
# - Incorporate evidence-based approaches with critical evaluation.
# - Address diversity and inclusion comprehensively.
# - Integrate credible research with correct referencing.
# - Expand on developmental milestones to demonstrate deeper knowledge of early literacy.
#
# >>> 3. Self-Evaluation Rating (1-5):
# 2
# --------------------------------------------------------------------------------
# Submission 5 (Ground Truth: Hybrid)
# --------------------------------------------------------------------------------
#
# Label: Hybrid
# Rationale:
# - The submission includes specific academic references ("Lonigan et al. (2000)"), precise terminology, and structured explanations typical of formal, evidence-based academic writing, which are stylistic hallmarks of AI-generated text.
# - However, the occasional use of slightly conversational phrasing ("The child rapidly acquires new vocabulary through exposure to rich language environments") and consistent focus on a human voice ("this sets the stage for decoding and comprehension later on") suggests that meaningful human editing or context shaping occurred.
#
# Flags:
# - The possibility of AI-assisted phrasing and structure is high due to the formal tone and integration of academic references.
# - No explicit personal experience or subjective context is included, strengthening inference of AI involvement alongside human editing.
#
# 1) **Overall Summary**:
# The submission demonstrates a strong grasp of foundational concepts in early literacy development, particularly phonological awareness, vocabulary, and print knowledge. However, the scope is limited to general descriptions of these skills, and there is insufficient analysis of evidence-based approaches or adaptation for diverse learners—a key aspect of the assignment prompt. Clear writing and use of a scholarly source are notable strengths.
#
# 2) **Criteria Feedback**:
# - **Criterion**: Understanding of Early Literacy Development
#   - **Rating**: Good
#   - **Evidence**:
#     - Clearly describes core literacy components such as phonological awareness, vocabulary acquisition, and print conventions.
#     - References developmental progressions (e.g., from syllables to phonemes).
#     - Cites Lonigan et al. (2000) to support phonological awareness development.
#   - **Improvement Tip**: Incorporate discussion of developmental differences among learners aged 3 to 6, with examples to better illustrate literacy milestones.
#
# - **Criterion**: Evaluation of Evidence-Based Approaches
#   - **Rating**: Needs Improvement
#   - **Evidence**:
#     - The submission does not examine specific instructional methods (e.g., dialogic reading, phonemic games).
#     - No critical evaluation of evidence-based strategies is present.
#   - **Improvement Tip**: Research and include at least two evidence-based approaches (e.g., shared book reading or phonemic awareness games), evaluating their effectiveness and citing supporting studies.
#
# - **Criterion**: Consideration of Diversity and Inclusion
#   - **Rating**: Needs Improvement
#   - **Evidence**:
#     - No explicit mention of adaptation to diverse linguistic, cultural, or developmental needs.
#   - **Improvement Tip**: Address how each literacy strategy can be tailored for learners with varying abilities and cultural backgrounds, providing at least one specific example.
#
# - **Criterion**: Research Integration and Referencing
#   - **Rating**: Average
#   - **Evidence**:
#     - Includes one peer-reviewed reference (Lonigan et al., 2000), correctly cited.
#     - Limited integration of additional academic sources to support claims.
#   - **Improvement Tip**: Expand use of credible academic references to strengthen points and demonstrate deeper engagement with current research.
#
# - **Criterion**: Structure and Academic Writing
#   - **Rating**: Good
#   - **Evidence**:
#     - Writing is clear, formal, and free of grammatical errors.
#     - Logical structure is evident, starting with an introduction and followed by core literacy components.
#   - **Improvement Tip**: Enhance the essay’s coherence by connecting each section directly to the assignment prompt and including a conclusion reinforcing key insights.
#
# 3) **Overall Rating**: Average
# ...
#
# **Improvement Tip:** Refine transitions by emphasizing how decisions in one phase (e.g., layout planning) drive outcomes in subsequent phases (e.g., safety and efficiency during assembly).
#
# ---
#
# #### **Criterion: Depth of Analysis**
# **Rating:** Average
# **Evidence:**
# - Provides basic reasoning for decisions (e.g., placing machines to minimize movement or using guard rails for safety), but lacks detailed justifications or illustrative examples.
# - Does not analyze trade-offs (e.g., balancing speed vs. cost or ensuring safety without reducing efficiency).
#
# **Improvement Tip:** Include specific examples (e.g., "placing assembly tables in a U-shaped layout to minimize worker movement") and analyze the rationale behind each choice.
#
# ---
#
# #### **Criterion: Language & Presentation**
# **Rating:** Good
# **Evidence:**
# - The writing is clear and free of major grammatical errors, maintaining professional tone and readability.
# - Minor improvements could enhance precision (e.g., replacing "makes changes" with "implements design adjustments").
#
# **Improvement Tip:** Use more precise language and industry-specific terms to enhance professionalism (e.g., "ergonomic design adjustments" instead of "changes to fix it").
#
# ---
#
# ### 3) **Overall Rating**
# **Average**
#
# ---
#
# **Action Plan for Improvement:**
# - Deepen technical detail by integrating manufacturing engineering principles, specific terminologies, and illustrative examples.
# - Expand comprehensiveness, particularly in intermediate phases (e.g., workflow optimization).
# - Strengthen reasoning and analysis, discussing trade-offs and providing clear justifications for decisions.
#
# >>> 3. Self-Evaluation Rating (1-5):
# 3
# --------------------------------------------------------------------------------
# Submission 4 (Ground Truth: Human)
# --------------------------------------------------------------------------------
#
# Label: Human
# Rationale:
# - The submission displays features of personal, anecdotal tone, with simple sentence structures and limited technical terminology, typical of human-authored writing. It lacks extensive subject-specific jargon or stylistic markers of AI-generated text.
# - The narrative includes practical, subjective touches like “talk with the designers” and “helps save time,” rather than adhering to highly formalized or algorithmic explanations. Coherence is local (step-by-step recounting), but lacks the advanced structure often seen in AI outputs. This simplicity and specificity indicate likely human authorship.
#
# Flags:
# - Not highly technical, potentially indicating lower academic depth than expected for the subject level. May need review for detail and rigor.
#
# **Overall Summary:**
# The submission demonstrates an understanding of basic production line setup for a new consumer product, touching on important elements of design communication, equipment layout, efficiency, and safety. While the overview is functional, it lacks depth and detail in certain areas, particularly in technical reasoning and advanced insights into manufacturing processes. Greater clarity and specific examples would strengthen the response.
#
# ---
#
# **Criteria Feedback:**
#
# **Criterion:** Scope & Comprehensiveness
# **Rating:** Average
# **Evidence:**
# - Discusses breaking the process into steps and matching each step to tools or machines.
# - Mentions efficiency considerations (e.g., minimizing worker movement and heavy lifting) and safety measures (e.g., emergency stops, signs).
# - Does not explore the entire design-to-assembly flow, such as material handling, quality control, or integration of automated systems.
# **Improvement Tip:** Include a broader scope by detailing steps from initial prototyping phases to final quality and packaging processes, considering both manual and automated workflows.
#
# **Criterion:** Technical Acumen
# **Rating:** Average
# **Evidence:**
# - The explanation uses simple terminology (e.g., "machines are placed in a row that follows the right order") rather than precise technical language like "workflow optimization" or "ergonomic design principles."
# - Insufficient discussion of advanced manufacturing principles like lean manufacturing or safety-related compliance (e.g., OSHA standards).
# **Improvement Tip:** Incorporate technical terminology and concepts, such as process optimization methods, safety regulations, and specifics of machine setup, to demonstrate deeper technical understanding.
#
# **Criterion:** Clarity & Structure
# **Rating:** Good
# **Evidence:**
# - Ideas follow a clear sequence from design to setup and testing stages.
# - The explanation is easy to follow but lacks refined transitions between phases.
# **Improvement Tip:** Add brief signposts or transitions between sections to guide the reader through the logical progression (e.g., "Once the layout is finalized, the focus shifts to...").
#
# **Criterion:** Depth of Analysis
# **Rating:** Average
# **Evidence:**
# - Provides a general explanation of steps but lacks specific examples of equipment, layout planning strategies, or safety protocols.
# - Mentions testing the setup but does not elaborate on criteria for evaluating or improving effectiveness.
# **Improvement Tip:** Offer specific examples of machinery placement strategies, such as conveyor systems for material flow or ergonomic measures like adjustable workstations. Include reasoning behind design decisions.
#
# **Criterion:** Language & Presentation
# **Rating:** Good
# **Evidence:**
# - Writing is generally clear and professional.
# - Minor improvements in formal phrasing (e.g., "talk with the designers" could be rephrased as "collaborates with design teams") would enhance readability and professionalism.
# **Improvement Tip:** Refine language to integrate professional tone and terminology, and review for occasional informal phrasing.
#
# ---
#
# **Overall Rating:** Average
#
# >>> 3. Self-Evaluation Rating (1-5):
# 3
# --------------------------------------------------------------------------------
# Submission 5 (Ground Truth: Hybrid)
# --------------------------------------------------------------------------------
#
# Label: AI
#
# Rationale:
# - **Discourse features**: The submission is highly formal, technical, and generalized with no personal context or subjective insights, which aligns strongly with AI-generated content. It reads as an optimized explanation without human idiosyncrasies or nuances.
# - **Style consistency**: The text is uniformly polished and detailed throughout. It uses advanced terminology such as "Gantt charts," "takt time," "cellular manufacturing," and "non-value-adding steps," suggesting algorithmic overgeneralization and lack of practical, narratively variable explanation.
# - **Global/local coherence**: While the content is logical and well-structured, the precision and conciseness are too optimized to reflect typical human cognitive processes, which often include elaboration or occasional digression.
# - **Cliché patterns**: The text frequently employs systematically structured phrases found in technical writing (e.g., "balancing cost with flexibility," "data-driven adjustments"), indicative of language model outputs.
#
# Flags: High likelihood of exclusively AI-generated content due to absence of personal experiential context and overly systematic style. No signs of meaningful human input are evident.
#
# ### Overall Summary
# The submission demonstrates a solid understanding of the production line setup process, with notable strengths in integrating efficiency and safety considerations. While the response provides a clear sequence of steps and incorporates relevant manufacturing terminology, opportunities remain to deepen the analysis with more specific examples and justifications for the decisions made.
#
# ---
#
# ### Criteria Feedback
#
# #### Criterion: Scope & Comprehensiveness
# **Rating:** Good
# **Evidence:**
# - The submission outlines key phases from product design to assembly, including material assessments, layout design, and efficiency enhancements.
# - Mentions lean principles like cellular manufacturing and highlights safety considerations such as equipment guards and PPE.
# - The trial run phase and continuous improvement activities (e.g., "data-driven adjustments") are briefly noted but lack detail.
#
# **Improvement Tip:** Expand on the trial and refinement stages, detailing specific examples of the types of issues typically encountered and how they are addressed.
#
# ---
#
# #### Criterion: Technical Acumen
# **Rating:** Excellent
# **Evidence:**
# - Correctly applies concepts such as lean manufacturing, takt time, and line balancing.
# - Accurately references tools like Gantt charts for planning and line balancing for efficiency evaluation.
# - Effectively integrates terminology (e.g., "non-value-adding steps," "cellular manufacturing") with appropriate context.
#
# **Improvement Tip:** Maintain the strong use of terminology while adding depth by incorporating advanced technical concepts such as downtime minimization metrics or automation integration strategies.
#
# ---
#
# #### Criterion: Clarity & Structure
# **Rating:** Excellent
# **Evidence:**
# - The explanation flows logically, with a clear progression from design review to trial runs.
# - Each step is concisely articulated, making the response easy to follow.
# - Transitions between planning (e.g., layout design) and operational stages are seamless.
#
# **Improvement Tip:** Consider brief introductory or concluding sentences to reinforce the flow and emphasize the interconnectedness of all phases.
#
# ---
#
# #### Criterion: Depth of Analysis
# **Rating:** Average
# **Evidence:**
# - Includes generalized reasoning (e.g., "U-shaped layout can reduce motion waste") but lacks specific, illustrative examples of how this applies in a real production context.
# - Identifies safety measures (e.g., "guards are installed") but does not provide rationale for why certain safety protocols are prioritized.
# - Mentions "data-driven adjustments" without elaboration on what metrics are analyzed or how decisions are informed.
#
# **Improvement Tip:** Strengthen the analytical depth by providing detailed examples such as a hypothetical production line scenario, specifying equipment choices, or justifying layout changes with quantitative metrics.
#
# ---
#
# #### Criterion: Language & Presentation
# **Rating:** Excellent
# **Evidence:**
# - Writing is clear, professional, and free of grammatical errors.
# - Sentences are concise and use precise language, enhancing readability.
# - The tone is appropriately formal, aligning with technical communication standards.
#
# **Improvement Tip:** Maintain attention to clarity and professionalism while ensuring technical details are emphasized in balance with the high-level overview.
#
# ---
#
# ### Overall Rating
# **Good**
#
# While the submission performs well in scope, structure, and technical understanding, further depth and specific examples are needed to elevate the overall analysis.
#
# >>> 3. Self-Evaluation Rating (1-5):
# 4
# --------------------------------------------------------------------------------
# Submission 6 (Ground Truth: Hybrid)
# --------------------------------------------------------------------------------
#
# Label: Hybrid
# Rationale:
# - The submission lacks personal or subjective elements, showing a technical, structured, and formal exposition, which is often associated with AI-written content. However, some practical design considerations (e.g., "intuitive setup for workers," "conducting ergonomic checks") suggest some real-world insight that goes beyond typical AI-generated generalizations.
# - The style and terminology indicate domain-specific competence, yet the structure and phrasing (e.g., sequential, predominantly textbook-like with technical terms succinctly packed) exhibit a coherence and repetitiveness typical of AI assistance.
# - The inclusion of non-standard considerations like "intuitive setup" and "feedback loops" hints at integration of original human experience or elaboration, suggesting a blend of human-initiated thought with refined input from an AI tool.
#
# Flags:
# - Possible AI-assisted technical knowledge.
# - Absence of subjective narrative or personal experience that would confirm fully human writing.
#
#
# **Overall Summary:**
# The submission demonstrates a solid understanding of the production line setup process, including important technical aspects like takt time, bottleneck analysis, and safety measures. Strengths include its structured explanation of logical layout creation and emphasis on iterative refinement through testing. However, the response could provide more detailed reasoning for specific decisions and incorporate additional illustrative examples for a deeper analysis.
#
# ---
#
# **Criteria Feedback:**
#
# **Criterion: Scope & Comprehensiveness**
# **Rating:** Good
# **Evidence:**
# - Covers the process from product design review to final refinement through a test run, touching on key phases such as production sequencing, ergonomics, and troubleshooting.
# - Mentions efficiency (takt time, bottlenecks) and safety measures (emergency stops, signage).
# - Does not include a deeper discussion of procurement/logistics steps or team collaboration during the process.
# **Improvement Tip:** Expand on the design-to-assembly flow by discussing preliminary supplier/equipment selections, as well as team decision-making within phases like layout planning or safety review.
#
# ---
#
# **Criterion: Technical Acumen**
# **Rating:** Excellent
# **Evidence:**
# - Applies precise manufacturing engineering terminology, including “takt time,” “simulation software,” “ergonomic checks,” and “minimal material handling.”
# - Effectively uses foundational engineering principles to describe logical layout grouping and performance evaluation (e.g., testing for bottlenecks).
# **Improvement Tip:** Consider briefly touching on advanced tools (e.g., CNC programming optimization or Lean Six Sigma integration) to demonstrate even deeper technical breadth.
#
# ---
#
# **Criterion: Clarity & Structure**
# **Rating:** Excellent
# **Evidence:**
# - The explanation is logically sequenced, moving fluidly from design to testing phases.
# - Ideas are cohesively linked, with each phase of the production setup building on the previous one.
# **Improvement Tip:** No major issues; maintain this level of clear organization in future work.
#
# ---
#
# **Criterion: Depth of Analysis**
# **Rating:** Good
# **Evidence:**
# - Provides considerations such as selecting machines based on “precision, capacity, and compatibility” and embedding safety measures into layouts.
# - Lacks specific examples or deeper analysis of key design choices, such as selecting equipment or interpreting test-run results.
# **Improvement Tip:** Add specific examples (e.g., how a bottleneck was identified and addressed) and elaborate on alternative choices to enhance the justification of design or layout decisions.
#
# ---
#
# **Criterion: Language & Presentation**
# **Rating:** Excellent
# **Evidence:**
# - Writing is articulate and professional, effectively using terminology and formal language.
# - No noticeable grammatical or typographical errors.
# **Improvement Tip:** Maintain this high standard; no additional improvement needed.
#
# ---
#
# **Overall Rating:** Good
#
# >>> 3. Self-Evaluation Rating (1-5):
# 4
#
# Confusion Matrix for Domain 'Manufacturing Engineering':
# Predicted     AI  Human  Hybrid
# Ground Truth
# AI             1      0       1
# Human          0      1       1
# Hybrid         1      0       1
#
# ================================================================================
#
#
# Overall Confusion Matrix Across All Domains:
# Predicted     AI  Human  Hybrid  Unknown
# Ground Truth
# AI             5      0       5        0
# Human          1      1       7        1
# Hybrid         5      0       5        0

# %%
# all submission confusion matrix
print(overall_cm)
# Out:
# Predicted     AI  Human  Hybrid  Unknown
# Ground Truth
# AI             5      0       5        0
# Human          1      1       7        1
# Hybrid         5      0       5        0
